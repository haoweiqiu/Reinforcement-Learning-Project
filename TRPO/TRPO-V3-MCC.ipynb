# %%
import torch
import gym
from numpy.random import choice
from copy import deepcopy
from torch.nn.utils.convert_parameters import parameters_to_vector
from torch.nn.utils.convert_parameters import vector_to_parameters


class TRPOAgent:
    """Continuous TRPO agent."""

    def __init__(self, policy, discount=0.98, kl_delta=0.01, cg_iteration=10,
                 cg_dampening=0.001, cg_tolerance=1e-10, cg_state_percent=0.1):
        self.policy = policy
        self.discount = discount
        self.kl_delta = kl_delta
        self.cg_iteration = cg_iteration
        self.cg_dampening = cg_dampening
        self.cg_tolerance = cg_tolerance
        self.cg_state_percent = cg_state_percent
        self.distribution = torch.distributions.normal.Normal

        # Cuda check
        self.device = (torch.device('cuda') if torch.cuda.is_available()
                       else torch.device('cpu'))
        policy.to(self.device)

        # Infer action dimensions from policy
        policy_modules = [module for module in policy.modules() if not
                          isinstance(module, torch.nn.Sequential)]
        action_dims = policy_modules[-1].out_features

        # Set logstd
        self.logstd = torch.ones(action_dims, requires_grad=True,
                                 device=self.device)
        with torch.no_grad():
            self.logstd /= self.logstd.exp()

        self.buffers = {'log_probs': [], 'actions': [],
                        'completed_rewards': [], 'states': []}

    def __call__(self, state):
        """
        Peforms forward pass on the NN and parameterized distribution.

        Parameters
        ----------
        state : torch.Tensor
            Tensor passed into NN and distribution.

        Returns
        -------
            Action choice for each action dimension.
        """
        state = torch.as_tensor(state, dtype=torch.float32, device=self.device)

        # Parameterize distribution with policy, sample action
        normal_dist = self.distribution(self.policy(state), self.logstd.exp())
        action = normal_dist.sample()
        # Save information
        self.buffers['actions'].append(action)
        self.buffers['log_probs'].append(normal_dist.log_prob(action))
        self.buffers['states'].append(state)
        return action.cpu().numpy()

    def kl(self, new_policy, new_std, states, grad_new=True):
        """Compute KL divergence between current policy and new one.

        Parameters
        ----------
        new_policy : TRPOAgent
        new_std : torch.Tensor
        states : torch.Tensor
            States to compute KL divergence over.
        grad_new : bool, optional
            Enable gradient of new policy.
        """
        mu1 = self.policy(states)
        log_sigma1 = self.logstd
        mu2 = new_policy(states)
        log_sigma2 = new_std

        # Detach other as gradient should only be w.r.t. to one
        if grad_new:
            mu1, log_sigma1 = mu1.detach(), log_sigma1.detach()
        else:
            mu2, log_sigma2 = mu2.detach(), log_sigma2.detach()

        # Compute KL over all states
        kl_matrix = ((log_sigma2 - log_sigma1) + 0.5 * (log_sigma1.exp().pow(2)
                     + (mu1 - mu2).pow(2)) / log_sigma2.exp().pow(2) - 0.5)

        # Sum over action dim, average over all states
        return kl_matrix.sum(1).mean()

    def surrogate_objective(self, new_policy, new_std, states, actions,
                            log_probs, advantages):
        new_dist = self.distribution(new_policy(states), new_std.exp())
        new_prob = new_dist.log_prob(actions)

        entropy_bonus = new_dist.entropy().mean()

        # Detach old log_probs, only compute grad w.r.t. new policy
        ratio = new_prob.exp() / log_probs.detach().exp()

        return (ratio * advantages.view(-1, 1)).mean() + 0.01 * entropy_bonus

    def line_search(self, gradients, states, actions, log_probs, rewards):
        step_size = (2 * self.kl_delta / gradients.dot(
            self.fisher_vector_direct(gradients, states))).sqrt()
        step_size_decay = 1.5
        line_search_attempts = 10

        # New policy
        current_parameters = parameters_to_vector(self.policy.parameters())
        new_policy = deepcopy(self.policy)
        vector_to_parameters(current_parameters + step_size * gradients,
                             new_policy.parameters())
        new_std = self.logstd.detach() + step_size * self.logstd.grad

        #  Shrink gradient until KL constraint met and improvement
        for attempt in range(line_search_attempts):
            # Obtain kl divergence and objective
            with torch.no_grad():
                kl_value = self.kl(new_policy, new_std, states)
                objective = self.surrogate_objective(new_policy, new_std,
                                                     states, actions, log_probs,
                                                     rewards)

            # Shrink gradient if KL constraint not met or reward lower
            if kl_value > self.kl_delta or objective < 0:
                step_size /= step_size_decay
                vector_to_parameters(current_parameters + step_size *
                                     gradients, new_policy.parameters())
                new_std = self.logstd.detach() + step_size * self.logstd.grad
            #  Return new policy and std if KL and reward met
            else:
                return new_policy, new_std.requires_grad_()

        # Return old policy and std if constraints never met
        return self.policy, self.logstd

    def fisher_vector_direct(self, vector, states):
        """Computes the fisher vector product through direct method.

        The FVP can be determined by first taking the gradient of KL
        divergence w.r.t. the parameters and the dot product of this
        with the input vector, then a gradient over this again w.r.t.
        the parameters.
        """
        vector = vector.clone().requires_grad_()
        # Gradient of KL w.r.t. network param
        self.policy.zero_grad()
        kl_divergence = self.kl(self.policy, self.logstd, states)
        grad_kl = torch.autograd.grad(kl_divergence, self.policy.parameters(),
                                      create_graph=True)
        grad_kl = torch.cat([grad.view(-1) for grad in grad_kl])

        # Gradient of the gradient vector dot product w.r.t. param
        grad_vector_dot = grad_kl.dot(vector)
        fisher_vector_product = torch.autograd.grad(grad_vector_dot,
                                                    self.policy.parameters())
        fisher_vector_product = torch.cat([out.view(-1) for out in
                                           fisher_vector_product]).detach()

        # Apply CG dampening and return fisher vector product
        return fisher_vector_product + self.cg_dampening * vector.detach()

    def conjugate_gradient(self, b, states):
        """
        Solve Ax = b for A as FIM and b as initial gradient.

        Source:
        https://github.com/ikostrikov/pytorch-trpo/blob/master/trpo.py

        Slight modifications to original, all credit to original.
        """
        p = b.clone()
        r = b.clone().double()
        x = torch.zeros(*p.shape, device=self.device).double()
        rdotr = r.dot(r)
        for _ in range(self.cg_iteration):
            fvp = self.fisher_vector_direct(p, states).double()
            v = rdotr / p.double().dot(fvp)
            x += v * p.double()
            r -= v * fvp
            new_rdotr = r.dot(r)
            mu = new_rdotr / rdotr
            p = (r + mu * p.double()).float()
            rdotr = new_rdotr
            if rdotr < self.cg_tolerance:
                break
        return x.float()

    def optimize(self):
        # Return if no completed episodes
        if len(self.buffers['completed_rewards']) == 0:
            return
 
        # Convert all buffers to tensors
        num_batch_steps = len(self.buffers['completed_rewards'])
        rewards = torch.tensor(self.buffers['completed_rewards'])
        actions = torch.stack(self.buffers['actions'][:num_batch_steps])
        states = torch.stack(self.buffers['states'][:num_batch_steps])
        log_probs = torch.stack(self.buffers['log_probs'][:num_batch_steps])
        rewards, actions, states, log_probs = (rewards.to(self.device),
                                               actions.to(self.device), 
                                               states.to(self.device),
                                               log_probs.to(self.device))

        # Normalize rewards over episodes
        rewards = (rewards - rewards.mean()) / rewards.std()

        # Compute regular gradient
        self.surrogate_objective(self.policy, self.logstd, states, actions,
                                 log_probs, rewards).backward()
        gradients = parameters_to_vector(
            [param.grad for param in self.policy.parameters()])

        # Choose states for conjugate gradient with np.random.choice
        number_of_states = int(self.cg_state_percent * num_batch_steps)
        cg_states = states[choice(len(states), number_of_states, replace=False)]

        # Compute search direction as A^(-1)g, A is FIM
        gradients = self.conjugate_gradient(gradients, cg_states)
        # Find new policy and std with line search
        self.policy, self.logstd = self.line_search(gradients, states, actions,
                                                    log_probs, rewards)

        # Update buffers removing processed steps
        for key, storage in self.buffers.items():
            del storage[:num_batch_steps]

    def train(self, env_name, seed=None, batch_size=12000, iterations=100,
              max_episode_length=None, verbose=False):

        # Initialize env
        env = gym.make(env_name)
        if seed is not None:
            torch.manual_seed(seed)
            env.seed(seed)
        if max_episode_length is None:
            max_episode_length = 999
        # Recording
        recording = {'episode_reward': [[]],
                     'episode_length': [0],
                     'num_episodes_in_iteration': []}

        # Begin training
        observation = env.reset()
        if type(observation) == tuple:
            observation = observation[0]
        for iteration in range(iterations):
            # Set initial value to 0
            recording['num_episodes_in_iteration'].append(0)

            for step in range(batch_size):
                # Take step with agent
                #print()
                observation, reward, done, info,  _ = env.step(self(observation))

                # Recording, increment episode values
                recording['episode_length'][-1] += 1
                recording['episode_reward'][-1].append(reward)

                # End of episode
                if (done or
                        recording['episode_length'][-1] >= max_episode_length):
                    # Calculate discounted reward
                    discounted_reward = recording['episode_reward'][-1].copy()
                    for index in range(len(discounted_reward) - 2, -1, -1):
                        discounted_reward[index] += self.discount * \
                            discounted_reward[index + 1]
                    self.buffers['completed_rewards'].extend(discounted_reward)

                    # Set final recording of episode reward to total
                    recording['episode_reward'][-1] = \
                        sum(recording['episode_reward'][-1])
                    # Recording
                    recording['episode_length'].append(0)
                    recording['episode_reward'].append([])
                    recording['num_episodes_in_iteration'][-1] += 1

                    # Reset environment
                    observation = env.reset()
                    if type(observation) == tuple:
                        observation = observation[0]

            # Print information if verbose
            if verbose:
                num_episode = recording['num_episodes_in_iteration'][-1]
                avg = (round(sum(recording['episode_reward'][-num_episode:-1])
                             / (num_episode - 1), 3))
                print(f'Average Reward over Iteration {iteration}: {avg}')
            # Optimize after batch
            self.optimize()

        # Return recording information
        return recording

    def save_model(self, path):
        torch.save({
            'policy': self.policy.state_dict(),
            'logstd': self.logstd
        }, path)

    def load_model(self, path):
        checkpoint = torch.load(path)
        self.policy.load_state_dict(checkpoint['policy'])
        self.logstd = checkpoint['logstd'].to(self.device)

# %%
import gym
import torch
import os
import pickle
import matplotlib.pyplot as plt



reward_list = []

# %%
for i in range(2):
    nn = torch.nn.Sequential(torch.nn.Linear(2, 32), torch.nn.Tanh(),
                            torch.nn.Linear(32, 1))
    init_weights = (lambda param: torch.nn.init.xavier_normal_(param.weight) if
                    isinstance(param, torch.nn.Linear) else None)
    nn.apply(init_weights)

    # Initialize the agent
    agent = TRPOAgent(policy=nn)

    policy_name = type(agent).__name__

    # Train
    records = agent.train('MountainCarContinuous-v0', batch_size=10000,
                        iterations=500, max_episode_length=999, verbose=True)

    rewards_per_iter = []
    s = e = 0
    for i in range(len(records['num_episodes_in_iteration'])):
        num = records['num_episodes_in_iteration'][i]
        e += records['num_episodes_in_iteration'][i]
        avg = sum(records['episode_reward'][s:e]) / num
        rewards_per_iter.append(avg)
        s = e
    reward_list.append(rewards_per_iter)
    
agent.save_model(f'{policy_name}.pth')
pickle.dump(records, open(f'{policy_name}_records.pickle', 'wb'))
#plot_info(records, policy_name)

# Display
'''
env = gym.make('MountainCarContinuous-v0', render_mode = "human")
ob = env.reset()
if type(ob) == tuple:
    ob = ob[0]
for i in range(2):
    action = agent(ob)
    ob, _, done, info, _ = env.step(action)
    #env.render()
    if done:
        ob = env.reset()
        if type(ob) == tuple:
            ob = ob[0]
'''

def plot_info(records, policy_name):
    rewards_per_iter = []
    s = e = 0
    for i in range(5, len(records['num_episodes_in_iteration'])):
        num = records['num_episodes_in_iteration'][i]
        e += records['num_episodes_in_iteration'][i]
        avg = sum(records['episode_reward'][s:e]) / num
        rewards_per_iter.append(avg)
        s = e
    print(max(rewards_per_iter))
    max_iter = max(enumerate(rewards_per_iter), key=lambda t: t[1])[0]
    plt.plot(list(range(5, len(rewards_per_iter) + 5)), rewards_per_iter)
    plt.text(min(max_iter, len(rewards_per_iter) - 10),
             rewards_per_iter[max_iter],
             "Max Reward: " + str(round(rewards_per_iter[max_iter], 2)))

    plt.title(f"{policy_name} reward per iter on MountainCarContinuous-v0")
    plt.ylabel("Reward")
    plt.xlabel("Iteration")
    plt.show()
# Out:
# C:\Users\chery\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# Average Reward over Iteration 0: -211.607
# Average Reward over Iteration 1: -138.351
# Average Reward over Iteration 2: -90.512
# Average Reward over Iteration 3: -37.997
# Average Reward over Iteration 4: 24.652
# Average Reward over Iteration 5: 21.491
# Average Reward over Iteration 6: 43.402
# Average Reward over Iteration 7: 46.721
# Average Reward over Iteration 8: 56.995
# Average Reward over Iteration 9: 63.732
# Average Reward over Iteration 10: 58.069
# Average Reward over Iteration 11: 65.492
# Average Reward over Iteration 12: 66.827
# Average Reward over Iteration 13: 68.865
# Average Reward over Iteration 14: 68.262
# Average Reward over Iteration 15: 70.678
# Average Reward over Iteration 16: 72.439
# Average Reward over Iteration 17: 75.755
# Average Reward over Iteration 18: 74.612
# Average Reward over Iteration 19: 71.883
# Average Reward over Iteration 20: 68.791
# Average Reward over Iteration 21: 70.823
# Average Reward over Iteration 22: 68.407
# Average Reward over Iteration 23: 67.417
# Average Reward over Iteration 24: 68.951
# Average Reward over Iteration 25: 66.331
# Average Reward over Iteration 26: 66.003
# Average Reward over Iteration 27: 64.5
# Average Reward over Iteration 28: 59.665
# Average Reward over Iteration 29: 63.2
# Average Reward over Iteration 30: 63.218
# Average Reward over Iteration 31: 60.697
# Average Reward over Iteration 32: 60.784
# Average Reward over Iteration 33: 63.377
# Average Reward over Iteration 34: 61.034
# Average Reward over Iteration 35: 59.827
# Average Reward over Iteration 36: 59.707
# Average Reward over Iteration 37: 61.797
# Average Reward over Iteration 38: 57.469
# Average Reward over Iteration 39: 60.416
# Average Reward over Iteration 40: 57.544
# Average Reward over Iteration 41: 58.461
# Average Reward over Iteration 42: 60.619
# Average Reward over Iteration 43: 60.896
# Average Reward over Iteration 44: 62.484
# Average Reward over Iteration 45: 61.097
# Average Reward over Iteration 46: 65.013
# Average Reward over Iteration 47: 64.328
# Average Reward over Iteration 48: 64.771
# Average Reward over Iteration 49: 60.144
# Average Reward over Iteration 50: 62.39
# Average Reward over Iteration 51: 61.453
# Average Reward over Iteration 52: 61.747
# Average Reward over Iteration 53: 58.574
# Average Reward over Iteration 54: 55.183
# Average Reward over Iteration 55: 59.4
# Average Reward over Iteration 56: 58.417
# Average Reward over Iteration 57: 57.3
# Average Reward over Iteration 58: 59.396
# Average Reward over Iteration 59: 59.574
# Average Reward over Iteration 60: 61.984
# Average Reward over Iteration 61: 59.057
# Average Reward over Iteration 62: 64.881
# Average Reward over Iteration 63: 65.188
# Average Reward over Iteration 64: 62.983
# Average Reward over Iteration 65: 61.923
# Average Reward over Iteration 66: 67.081
# Average Reward over Iteration 67: 65.653
# Average Reward over Iteration 68: 62.91
# Average Reward over Iteration 69: 59.998
# Average Reward over Iteration 70: 59.911
# Average Reward over Iteration 71: 57.748
# Average Reward over Iteration 72: 59.567
# Average Reward over Iteration 73: 60.277
# Average Reward over Iteration 74: 60.808
# Average Reward over Iteration 75: 62.761
# Average Reward over Iteration 76: 62.809
# Average Reward over Iteration 77: 64.061
# Average Reward over Iteration 78: 61.396
# Average Reward over Iteration 79: 60.856
# Average Reward over Iteration 80: 65.468
# Average Reward over Iteration 81: 56.379
# Average Reward over Iteration 82: 60.375
# Average Reward over Iteration 83: 59.897
# Average Reward over Iteration 84: 61.069
# Average Reward over Iteration 85: 60.0
# Average Reward over Iteration 86: 59.527
# Average Reward over Iteration 87: 59.786
# Average Reward over Iteration 88: 57.2
# Average Reward over Iteration 89: 54.267
# Average Reward over Iteration 90: 52.889
# Average Reward over Iteration 91: 54.779
# Average Reward over Iteration 92: 50.613
# Average Reward over Iteration 93: 54.484
# Average Reward over Iteration 94: 51.898
# Average Reward over Iteration 95: 52.253
# Average Reward over Iteration 96: 50.596
# Average Reward over Iteration 97: 47.002
# Average Reward over Iteration 98: 47.316
# Average Reward over Iteration 99: 44.465
# Average Reward over Iteration 100: 40.614
# Average Reward over Iteration 101: 46.164
# Average Reward over Iteration 102: 49.769
# Average Reward over Iteration 103: 47.146
# Average Reward over Iteration 104: 49.46
# Average Reward over Iteration 105: 54.256
# Average Reward over Iteration 106: 50.879
# Average Reward over Iteration 107: 49.494
# Average Reward over Iteration 108: 44.373
# Average Reward over Iteration 109: 44.419
# Average Reward over Iteration 110: 47.654
# Average Reward over Iteration 111: 42.15
# Average Reward over Iteration 112: 46.179
# Average Reward over Iteration 113: 41.952
# Average Reward over Iteration 114: 43.39
# Average Reward over Iteration 115: 45.293
# Average Reward over Iteration 116: 42.654
# Average Reward over Iteration 117: 40.833
# Average Reward over Iteration 118: 33.865
# Average Reward over Iteration 119: 32.289
# Average Reward over Iteration 120: 33.022
# Average Reward over Iteration 121: 32.052
# Average Reward over Iteration 122: 32.905
# Average Reward over Iteration 123: 32.026
# Average Reward over Iteration 124: 37.845
# Average Reward over Iteration 125: 33.164
# Average Reward over Iteration 126: 36.614
# Average Reward over Iteration 127: 37.489
# Average Reward over Iteration 128: 43.418
# Average Reward over Iteration 129: 46.346
# Average Reward over Iteration 130: 42.202
# Average Reward over Iteration 131: 45.994
# Average Reward over Iteration 132: 45.433
# Average Reward over Iteration 133: 44.96
# Average Reward over Iteration 134: 43.177
# Average Reward over Iteration 135: 39.933
# Average Reward over Iteration 136: 42.095
# Average Reward over Iteration 137: 35.766
# Average Reward over Iteration 138: 30.877
# Average Reward over Iteration 139: 27.973
# Average Reward over Iteration 140: 24.715
# Average Reward over Iteration 141: 33.788
# Average Reward over Iteration 142: 30.166
# Average Reward over Iteration 143: 20.153
# Average Reward over Iteration 144: 29.358
# Average Reward over Iteration 145: 35.157
# Average Reward over Iteration 146: 33.32
# Average Reward over Iteration 147: 34.65
# Average Reward over Iteration 148: 39.7
# Average Reward over Iteration 149: 40.37
# Average Reward over Iteration 150: 34.766
# Average Reward over Iteration 151: 34.31
# Average Reward over Iteration 152: 36.192
# Average Reward over Iteration 153: 35.945
# Average Reward over Iteration 154: 34.761
# Average Reward over Iteration 155: 39.87
# Average Reward over Iteration 156: 41.287
# Average Reward over Iteration 157: 39.139
# Average Reward over Iteration 158: 36.85
# Average Reward over Iteration 159: 32.523
# Average Reward over Iteration 160: 42.681
# Average Reward over Iteration 161: 40.536
# Average Reward over Iteration 162: 42.454
# Average Reward over Iteration 163: 41.512
# Average Reward over Iteration 164: 30.518
# Average Reward over Iteration 165: 42.739
# Average Reward over Iteration 166: 40.957
# Average Reward over Iteration 167: 35.659
# Average Reward over Iteration 168: 37.394
# Average Reward over Iteration 169: 38.137
# Average Reward over Iteration 170: 41.779
# Average Reward over Iteration 171: 30.088
# Average Reward over Iteration 172: 27.574
# Average Reward over Iteration 173: 36.928
# Average Reward over Iteration 174: 41.549
# Average Reward over Iteration 175: 40.142
# Average Reward over Iteration 176: 49.499
# Average Reward over Iteration 177: 52.472
# Average Reward over Iteration 178: 48.566
# Average Reward over Iteration 179: 50.42
# Average Reward over Iteration 180: 43.248
# Average Reward over Iteration 181: 45.444
# Average Reward over Iteration 182: 47.226
# Average Reward over Iteration 183: 48.47
# Average Reward over Iteration 184: 41.894
# Average Reward over Iteration 185: 46.485
# Average Reward over Iteration 186: 47.326
# Average Reward over Iteration 187: 47.527
# Average Reward over Iteration 188: 47.972
# Average Reward over Iteration 189: 51.644
# Average Reward over Iteration 190: 48.44
# Average Reward over Iteration 191: 44.771
# Average Reward over Iteration 192: 51.248
# Average Reward over Iteration 193: 46.468
# Average Reward over Iteration 194: 51.088
# Average Reward over Iteration 195: 48.689
# Average Reward over Iteration 196: 43.612
# Average Reward over Iteration 197: 47.051
# Average Reward over Iteration 198: 49.433
# Average Reward over Iteration 199: 52.161
# Average Reward over Iteration 200: 50.859
# Average Reward over Iteration 201: 53.434
# Average Reward over Iteration 202: 56.109
# Average Reward over Iteration 203: 61.365
# Average Reward over Iteration 204: 64.209
# Average Reward over Iteration 205: 60.818
# Average Reward over Iteration 206: 62.069
# Average Reward over Iteration 207: 65.758
# Average Reward over Iteration 208: 64.474
# Average Reward over Iteration 209: 66.313
# Average Reward over Iteration 210: 66.044
# Average Reward over Iteration 211: 65.948
# Average Reward over Iteration 212: 66.693
# Average Reward over Iteration 213: 64.808
# Average Reward over Iteration 214: 67.542
# Average Reward over Iteration 215: 67.912
# Average Reward over Iteration 216: 69.75
# Average Reward over Iteration 217: 68.165
# Average Reward over Iteration 218: 72.11
# Average Reward over Iteration 219: 70.916
# Average Reward over Iteration 220: 72.471
# Average Reward over Iteration 221: 70.662
# Average Reward over Iteration 222: 71.089
# Average Reward over Iteration 223: 74.197
# Average Reward over Iteration 224: 73.164
# Average Reward over Iteration 225: 73.095
# Average Reward over Iteration 226: 75.15
# Average Reward over Iteration 227: 75.768
# Average Reward over Iteration 228: 73.669
# Average Reward over Iteration 229: 77.304
# Average Reward over Iteration 230: 76.537
# Average Reward over Iteration 231: 77.04
# Average Reward over Iteration 232: 75.522
# Average Reward over Iteration 233: 77.938
# Average Reward over Iteration 234: 76.109
# Average Reward over Iteration 235: 73.571
# Average Reward over Iteration 236: 72.803
# Average Reward over Iteration 237: 73.947
# Average Reward over Iteration 238: 73.259
# Average Reward over Iteration 239: 77.981
# Average Reward over Iteration 240: 77.801
# Average Reward over Iteration 241: 75.539
# Average Reward over Iteration 242: 75.02
# Average Reward over Iteration 243: 76.685
# Average Reward over Iteration 244: 76.395
# Average Reward over Iteration 245: 75.357
# Average Reward over Iteration 246: 74.904
# Average Reward over Iteration 247: 79.177
# Average Reward over Iteration 248: 79.563
# Average Reward over Iteration 249: 80.919
# Average Reward over Iteration 250: 79.5
# Average Reward over Iteration 251: 80.23
# Average Reward over Iteration 252: 79.739
# Average Reward over Iteration 253: 80.204
# Average Reward over Iteration 254: 80.821
# Average Reward over Iteration 255: 80.795
# Average Reward over Iteration 256: 81.378
# Average Reward over Iteration 257: 80.743
# Average Reward over Iteration 258: 82.656
# Average Reward over Iteration 259: 80.844
# Average Reward over Iteration 260: 82.233
# Average Reward over Iteration 261: 83.141
# Average Reward over Iteration 262: 83.323
# Average Reward over Iteration 263: 81.773
# Average Reward over Iteration 264: 83.112
# Average Reward over Iteration 265: 82.791
# Average Reward over Iteration 266: 82.585
# Average Reward over Iteration 267: 81.057
# Average Reward over Iteration 268: 82.482
# Average Reward over Iteration 269: 83.063
# Average Reward over Iteration 270: 83.765
# Average Reward over Iteration 271: 82.034
# Average Reward over Iteration 272: 83.239
# Average Reward over Iteration 273: 82.28
# Average Reward over Iteration 274: 81.823
# Average Reward over Iteration 275: 80.351
# Average Reward over Iteration 276: 81.203
# Average Reward over Iteration 277: 79.303
# Average Reward over Iteration 278: 82.742
# Average Reward over Iteration 279: 79.63
# Average Reward over Iteration 280: 80.579
# Average Reward over Iteration 281: 79.536
# Average Reward over Iteration 282: 80.986
# Average Reward over Iteration 283: 80.258
# Average Reward over Iteration 284: 78.305
# Average Reward over Iteration 285: 76.787
# Average Reward over Iteration 286: 77.562
# Average Reward over Iteration 287: 77.029
# Average Reward over Iteration 288: 75.169
# Average Reward over Iteration 289: 76.758
# Average Reward over Iteration 290: 78.638
# Average Reward over Iteration 291: 76.631
# Average Reward over Iteration 292: 77.491
# Average Reward over Iteration 293: 77.511
# Average Reward over Iteration 294: 74.28
# Average Reward over Iteration 295: 76.099
# Average Reward over Iteration 296: 72.969
# Average Reward over Iteration 297: 75.63
# Average Reward over Iteration 298: 73.971
# Average Reward over Iteration 299: 72.903
# Average Reward over Iteration 300: 73.552
# Average Reward over Iteration 301: 72.199
# Average Reward over Iteration 302: 74.685
# Average Reward over Iteration 303: 69.91
# Average Reward over Iteration 304: 72.331
# Average Reward over Iteration 305: 74.677
# Average Reward over Iteration 306: 73.99
# Average Reward over Iteration 307: 73.648
# Average Reward over Iteration 308: 69.646
# Average Reward over Iteration 309: 69.084
# Average Reward over Iteration 310: 73.404
# Average Reward over Iteration 311: 75.24
# Average Reward over Iteration 312: 71.937
# Average Reward over Iteration 313: 68.202
# Average Reward over Iteration 314: 71.802
# Average Reward over Iteration 315: 71.85
# Average Reward over Iteration 316: 70.692
# Average Reward over Iteration 317: 66.38
# Average Reward over Iteration 318: 64.145
# Average Reward over Iteration 319: 69.025
# Average Reward over Iteration 320: 67.664
# Average Reward over Iteration 321: 67.915
# Average Reward over Iteration 322: 69.903
# Average Reward over Iteration 323: 69.448
# Average Reward over Iteration 324: 68.732
# Average Reward over Iteration 325: 68.505
# Average Reward over Iteration 326: 62.832
# Average Reward over Iteration 327: 65.778
# Average Reward over Iteration 328: 64.61
# Average Reward over Iteration 329: 66.86
# Average Reward over Iteration 330: 70.428
# Average Reward over Iteration 331: 68.335
# Average Reward over Iteration 332: 65.926
# Average Reward over Iteration 333: 67.742
# Average Reward over Iteration 334: 66.821
# Average Reward over Iteration 335: 62.245
# Average Reward over Iteration 336: 65.306
# Average Reward over Iteration 337: 65.689
# Average Reward over Iteration 338: 69.728
# Average Reward over Iteration 339: 72.286
# Average Reward over Iteration 340: 72.54
# Average Reward over Iteration 341: 73.19
# Average Reward over Iteration 342: 68.701
# Average Reward over Iteration 343: 73.405
# Average Reward over Iteration 344: 73.861
# Average Reward over Iteration 345: 72.978
# Average Reward over Iteration 346: 73.796
# Average Reward over Iteration 347: 75.001
# Average Reward over Iteration 348: 70.852
# Average Reward over Iteration 349: 75.439
# Average Reward over Iteration 350: 76.481
# Average Reward over Iteration 351: 75.305
# Average Reward over Iteration 352: 77.022
# Average Reward over Iteration 353: 75.534
# Average Reward over Iteration 354: 76.302
# Average Reward over Iteration 355: 75.979
# Average Reward over Iteration 356: 73.207
# Average Reward over Iteration 357: 73.373
# Average Reward over Iteration 358: 77.132
# Average Reward over Iteration 359: 76.699
# Average Reward over Iteration 360: 75.033
# Average Reward over Iteration 361: 75.837
# Average Reward over Iteration 362: 76.373
# Average Reward over Iteration 363: 75.924
# Average Reward over Iteration 364: 75.571
# Average Reward over Iteration 365: 76.622
# Average Reward over Iteration 366: 76.502
# Average Reward over Iteration 367: 77.57
# Average Reward over Iteration 368: 78.71
# Average Reward over Iteration 369: 78.889
# Average Reward over Iteration 370: 76.917
# Average Reward over Iteration 371: 76.676
# Average Reward over Iteration 372: 76.257
# Average Reward over Iteration 373: 75.307
# Average Reward over Iteration 374: 75.506
# Average Reward over Iteration 375: 77.508
# Average Reward over Iteration 376: 78.514
# Average Reward over Iteration 377: 77.29
# Average Reward over Iteration 378: 77.983
# Average Reward over Iteration 379: 76.018
# Average Reward over Iteration 380: 76.795
# Average Reward over Iteration 381: 78.138
# Average Reward over Iteration 382: 77.363
# Average Reward over Iteration 383: 77.145
# Average Reward over Iteration 384: 77.795
# Average Reward over Iteration 385: 77.91
# Average Reward over Iteration 386: 78.954
# Average Reward over Iteration 387: 78.235
# Average Reward over Iteration 388: 79.476
# Average Reward over Iteration 389: 79.93
# Average Reward over Iteration 390: 80.52
# Average Reward over Iteration 391: 80.284
# Average Reward over Iteration 392: 79.123
# Average Reward over Iteration 393: 78.786
# Average Reward over Iteration 394: 78.639
# Average Reward over Iteration 395: 78.738
# Average Reward over Iteration 396: 77.745
# Average Reward over Iteration 397: 77.523
# Average Reward over Iteration 398: 78.379
# Average Reward over Iteration 399: 78.18
# Average Reward over Iteration 400: 78.77
# Average Reward over Iteration 401: 78.588
# Average Reward over Iteration 402: 79.554
# Average Reward over Iteration 403: 79.034
# Average Reward over Iteration 404: 79.566
# Average Reward over Iteration 405: 78.976
# Average Reward over Iteration 406: 79.347
# Average Reward over Iteration 407: 79.628
# Average Reward over Iteration 408: 78.706
# Average Reward over Iteration 409: 79.535
# Average Reward over Iteration 410: 78.04
# Average Reward over Iteration 411: 79.423
# Average Reward over Iteration 412: 78.202
# Average Reward over Iteration 413: 77.748
# Average Reward over Iteration 414: 77.117
# Average Reward over Iteration 415: 78.341
# Average Reward over Iteration 416: 77.439
# Average Reward over Iteration 417: 78.935
# Average Reward over Iteration 418: 78.109
# Average Reward over Iteration 419: 78.722
# Average Reward over Iteration 420: 77.279
# Average Reward over Iteration 421: 79.46
# Average Reward over Iteration 422: 80.505
# Average Reward over Iteration 423: 78.536
# Average Reward over Iteration 424: 79.614
# Average Reward over Iteration 425: 79.301
# Average Reward over Iteration 426: 77.939
# Average Reward over Iteration 427: 77.429
# Average Reward over Iteration 428: 78.396
# Average Reward over Iteration 429: 76.886
# Average Reward over Iteration 430: 76.746
# Average Reward over Iteration 431: 75.565
# Average Reward over Iteration 432: 76.786
# Average Reward over Iteration 433: 78.384
# Average Reward over Iteration 434: 78.314
# Average Reward over Iteration 435: 78.001
# Average Reward over Iteration 436: 77.538
# Average Reward over Iteration 437: 76.158
# Average Reward over Iteration 438: 76.943
# Average Reward over Iteration 439: 77.183
# Average Reward over Iteration 440: 77.668
# Average Reward over Iteration 441: 77.75
# Average Reward over Iteration 442: 75.461
# Average Reward over Iteration 443: 78.065
# Average Reward over Iteration 444: 77.089
# Average Reward over Iteration 445: 77.847
# Average Reward over Iteration 446: 75.806
# Average Reward over Iteration 447: 77.57
# Average Reward over Iteration 448: 78.931
# Average Reward over Iteration 449: 78.305
# Average Reward over Iteration 450: 76.944
# Average Reward over Iteration 451: 76.533
# Average Reward over Iteration 452: 78.0
# Average Reward over Iteration 453: 78.735
# Average Reward over Iteration 454: 75.28
# Average Reward over Iteration 455: 77.623
# Average Reward over Iteration 456: 78.094
# Average Reward over Iteration 457: 79.236
# Average Reward over Iteration 458: 77.33
# Average Reward over Iteration 459: 78.246
# Average Reward over Iteration 460: 78.853
# Average Reward over Iteration 461: 77.611
# Average Reward over Iteration 462: 76.372
# Average Reward over Iteration 463: 78.687
# Average Reward over Iteration 464: 79.608
# Average Reward over Iteration 465: 78.014
# Average Reward over Iteration 466: 79.688
# Average Reward over Iteration 467: 79.087
# Average Reward over Iteration 468: 79.521
# Average Reward over Iteration 469: 76.676
# Average Reward over Iteration 470: 78.891
# Average Reward over Iteration 471: 76.115
# Average Reward over Iteration 472: 76.326
# Average Reward over Iteration 473: 75.986
# Average Reward over Iteration 474: 70.922
# Average Reward over Iteration 475: 72.921
# Average Reward over Iteration 476: 70.074
# Average Reward over Iteration 477: 70.505
# Average Reward over Iteration 478: 73.745
# Average Reward over Iteration 479: 73.441
# Average Reward over Iteration 480: 69.247
# Average Reward over Iteration 481: 68.658
# Average Reward over Iteration 482: 66.07
# Average Reward over Iteration 483: 65.767
# Average Reward over Iteration 484: 67.1
# Average Reward over Iteration 485: 65.894
# Average Reward over Iteration 486: 68.463
# Average Reward over Iteration 487: 70.626
# Average Reward over Iteration 488: 73.614
# Average Reward over Iteration 489: 71.708
# Average Reward over Iteration 490: 72.282
# Average Reward over Iteration 491: 75.394
# Average Reward over Iteration 492: 75.381
# Average Reward over Iteration 493: 74.511
# Average Reward over Iteration 494: 74.032
# Average Reward over Iteration 495: 75.541
# Average Reward over Iteration 496: 76.022
# Average Reward over Iteration 497: 75.9
# Average Reward over Iteration 498: 75.569
# Average Reward over Iteration 499: 76.492
# Average Reward over Iteration 0: -246.534
# Average Reward over Iteration 1: -192.247
# Average Reward over Iteration 2: -165.395
# Average Reward over Iteration 3: -139.194
# Average Reward over Iteration 4: -61.122
# Average Reward over Iteration 5: -12.169
# Average Reward over Iteration 6: 17.291
# Average Reward over Iteration 7: 31.039
# Average Reward over Iteration 8: 37.343
# Average Reward over Iteration 9: 42.948
# Average Reward over Iteration 10: 38.87
# Average Reward over Iteration 11: 40.171
# Average Reward over Iteration 12: 41.517
# Average Reward over Iteration 13: 41.942
# Average Reward over Iteration 14: 46.896
# Average Reward over Iteration 15: 51.551
# Average Reward over Iteration 16: 50.336
# Average Reward over Iteration 17: 53.988
# Average Reward over Iteration 18: 55.419
# Average Reward over Iteration 19: 60.991
# Average Reward over Iteration 20: 58.647
# Average Reward over Iteration 21: 59.529
# Average Reward over Iteration 22: 58.191
# Average Reward over Iteration 23: 65.981
# Average Reward over Iteration 24: 63.702
# Average Reward over Iteration 25: 64.306
# Average Reward over Iteration 26: 61.598
# Average Reward over Iteration 27: 65.148
# Average Reward over Iteration 28: 70.035
# Average Reward over Iteration 29: 66.444
# Average Reward over Iteration 30: 65.297
# Average Reward over Iteration 31: 66.931
# Average Reward over Iteration 32: 68.689
# Average Reward over Iteration 33: 65.39
# Average Reward over Iteration 34: 70.05
# Average Reward over Iteration 35: 69.992
# Average Reward over Iteration 36: 69.068
# Average Reward over Iteration 37: 71.836
# Average Reward over Iteration 38: 69.674
# Average Reward over Iteration 39: 72.572
# Average Reward over Iteration 40: 70.113
# Average Reward over Iteration 41: 69.958
# Average Reward over Iteration 42: 70.01
# Average Reward over Iteration 43: 70.792
# Average Reward over Iteration 44: 69.88
# Average Reward over Iteration 45: 71.86
# Average Reward over Iteration 46: 73.534
# Average Reward over Iteration 47: 72.997
# Average Reward over Iteration 48: 75.511
# Average Reward over Iteration 49: 75.42
# Average Reward over Iteration 50: 75.072
# Average Reward over Iteration 51: 77.297
# Average Reward over Iteration 52: 77.295
# Average Reward over Iteration 53: 76.282
# Average Reward over Iteration 54: 74.112
# Average Reward over Iteration 55: 74.065
# Average Reward over Iteration 56: 70.806
# Average Reward over Iteration 57: 70.545
# Average Reward over Iteration 58: 71.92
# Average Reward over Iteration 59: 71.44
# Average Reward over Iteration 60: 66.261
# Average Reward over Iteration 61: 66.082
# Average Reward over Iteration 62: 67.987
# Average Reward over Iteration 63: 69.008
# Average Reward over Iteration 64: 68.461
# Average Reward over Iteration 65: 65.048
# Average Reward over Iteration 66: 68.805
# Average Reward over Iteration 67: 64.387
# Average Reward over Iteration 68: 62.519
# Average Reward over Iteration 69: 64.69
# Average Reward over Iteration 70: 62.515
# Average Reward over Iteration 71: 60.066
# Average Reward over Iteration 72: 59.722
# Average Reward over Iteration 73: 59.909
# Average Reward over Iteration 74: 63.869
# Average Reward over Iteration 75: 60.722
# Average Reward over Iteration 76: 61.199
# Average Reward over Iteration 77: 64.36
# Average Reward over Iteration 78: 59.294
# Average Reward over Iteration 79: 61.726
# Average Reward over Iteration 80: 62.806
# Average Reward over Iteration 81: 59.242
# Average Reward over Iteration 82: 58.787
# Average Reward over Iteration 83: 63.077
# Average Reward over Iteration 84: 64.148
# Average Reward over Iteration 85: 61.632
# Average Reward over Iteration 86: 61.431
# Average Reward over Iteration 87: 63.157
# Average Reward over Iteration 88: 58.617
# Average Reward over Iteration 89: 62.712
# Average Reward over Iteration 90: 61.217
# Average Reward over Iteration 91: 62.232
# Average Reward over Iteration 92: 63.463
# Average Reward over Iteration 93: 61.464
# Average Reward over Iteration 94: 64.508
# Average Reward over Iteration 95: 67.452
# Average Reward over Iteration 96: 66.772
# Average Reward over Iteration 97: 69.479
# Average Reward over Iteration 98: 70.957
# Average Reward over Iteration 99: 71.631
# Average Reward over Iteration 100: 70.896
# Average Reward over Iteration 101: 74.29
# Average Reward over Iteration 102: 73.53
# Average Reward over Iteration 103: 75.103
# Average Reward over Iteration 104: 76.004
# Average Reward over Iteration 105: 74.829
# Average Reward over Iteration 106: 74.394
# Average Reward over Iteration 107: 73.516
# Average Reward over Iteration 108: 73.904
# Average Reward over Iteration 109: 75.557
# Average Reward over Iteration 110: 75.734
# Average Reward over Iteration 111: 71.999
# Average Reward over Iteration 112: 73.563
# Average Reward over Iteration 113: 71.72
# Average Reward over Iteration 114: 71.358
# Average Reward over Iteration 115: 70.775
# Average Reward over Iteration 116: 70.464
# Average Reward over Iteration 117: 72.006
# Average Reward over Iteration 118: 71.465
# Average Reward over Iteration 119: 70.84
# Average Reward over Iteration 120: 75.075
# Average Reward over Iteration 121: 72.356
# Average Reward over Iteration 122: 72.457
# Average Reward over Iteration 123: 71.21
# Average Reward over Iteration 124: 69.239
# Average Reward over Iteration 125: 66.907
# Average Reward over Iteration 126: 66.152
# Average Reward over Iteration 127: 66.904
# Average Reward over Iteration 128: 66.131
# Average Reward over Iteration 129: 65.378
# Average Reward over Iteration 130: 64.894
# Average Reward over Iteration 131: 68.86
# Average Reward over Iteration 132: 66.732
# Average Reward over Iteration 133: 69.375
# Average Reward over Iteration 134: 69.349
# Average Reward over Iteration 135: 68.364
# Average Reward over Iteration 136: 67.076
# Average Reward over Iteration 137: 65.054
# Average Reward over Iteration 138: 65.098
# Average Reward over Iteration 139: 66.875
# Average Reward over Iteration 140: 64.69
# Average Reward over Iteration 141: 65.185
# Average Reward over Iteration 142: 66.99
# Average Reward over Iteration 143: 63.597
# Average Reward over Iteration 144: 63.47
# Average Reward over Iteration 145: 64.266
# Average Reward over Iteration 146: 63.361
# Average Reward over Iteration 147: 61.139
# Average Reward over Iteration 148: 58.475
# Average Reward over Iteration 149: 62.839
# Average Reward over Iteration 150: 62.461
# Average Reward over Iteration 151: 60.865
# Average Reward over Iteration 152: 54.198
# Average Reward over Iteration 153: 59.598
# Average Reward over Iteration 154: 59.601
# Average Reward over Iteration 155: 59.393
# Average Reward over Iteration 156: 61.747
# Average Reward over Iteration 157: 59.183
# Average Reward over Iteration 158: 63.991
# Average Reward over Iteration 159: 64.325
# Average Reward over Iteration 160: 62.643
# Average Reward over Iteration 161: 60.59
# Average Reward over Iteration 162: 62.31
# Average Reward over Iteration 163: 61.682
# Average Reward over Iteration 164: 62.618
# Average Reward over Iteration 165: 59.829
# Average Reward over Iteration 166: 64.875
# Average Reward over Iteration 167: 64.316
# Average Reward over Iteration 168: 63.472
# Average Reward over Iteration 169: 60.773
# Average Reward over Iteration 170: 64.077
# Average Reward over Iteration 171: 62.128
# Average Reward over Iteration 172: 64.861
# Average Reward over Iteration 173: 65.667
# Average Reward over Iteration 174: 67.062
# Average Reward over Iteration 175: 68.907
# Average Reward over Iteration 176: 68.993
# Average Reward over Iteration 177: 70.296
# Average Reward over Iteration 178: 70.385
# Average Reward over Iteration 179: 73.379
# Average Reward over Iteration 180: 72.809
# Average Reward over Iteration 181: 73.804
# Average Reward over Iteration 182: 72.659
# Average Reward over Iteration 183: 69.801
# Average Reward over Iteration 184: 69.198
# Average Reward over Iteration 185: 72.67
# Average Reward over Iteration 186: 68.558
# Average Reward over Iteration 187: 67.394
# Average Reward over Iteration 188: 70.216
# Average Reward over Iteration 189: 73.072
# Average Reward over Iteration 190: 73.758
# Average Reward over Iteration 191: 72.048
# Average Reward over Iteration 192: 69.772
# Average Reward over Iteration 193: 72.065
# Average Reward over Iteration 194: 73.263
# Average Reward over Iteration 195: 77.253
# Average Reward over Iteration 196: 74.284
# Average Reward over Iteration 197: 74.454
# Average Reward over Iteration 198: 72.333
# Average Reward over Iteration 199: 72.739
# Average Reward over Iteration 200: 75.015
# Average Reward over Iteration 201: 73.719
# Average Reward over Iteration 202: 72.512
# Average Reward over Iteration 203: 72.028
# Average Reward over Iteration 204: 71.226
# Average Reward over Iteration 205: 71.196
# Average Reward over Iteration 206: 71.568
# Average Reward over Iteration 207: 70.951
# Average Reward over Iteration 208: 67.696
# Average Reward over Iteration 209: 66.85
# Average Reward over Iteration 210: 69.118
# Average Reward over Iteration 211: 70.32
# Average Reward over Iteration 212: 71.879
# Average Reward over Iteration 213: 74.562
# Average Reward over Iteration 214: 75.784
# Average Reward over Iteration 215: 74.445
# Average Reward over Iteration 216: 74.038
# Average Reward over Iteration 217: 73.999
# Average Reward over Iteration 218: 73.808
# Average Reward over Iteration 219: 72.741
# Average Reward over Iteration 220: 68.802
# Average Reward over Iteration 221: 69.704
# Average Reward over Iteration 222: 66.903
# Average Reward over Iteration 223: 68.745
# Average Reward over Iteration 224: 70.69
# Average Reward over Iteration 225: 67.964
# Average Reward over Iteration 226: 67.564
# Average Reward over Iteration 227: 68.716
# Average Reward over Iteration 228: 69.092
# Average Reward over Iteration 229: 69.903
# Average Reward over Iteration 230: 69.845
# Average Reward over Iteration 231: 71.481
# Average Reward over Iteration 232: 71.847
# Average Reward over Iteration 233: 72.608
# Average Reward over Iteration 234: 72.33
# Average Reward over Iteration 235: 71.789
# Average Reward over Iteration 236: 73.732
# Average Reward over Iteration 237: 74.851
# Average Reward over Iteration 238: 72.367
# Average Reward over Iteration 239: 71.94
# Average Reward over Iteration 240: 72.137
# Average Reward over Iteration 241: 72.425
# Average Reward over Iteration 242: 68.983
# Average Reward over Iteration 243: 68.547
# Average Reward over Iteration 244: 67.426
# Average Reward over Iteration 245: 68.805
# Average Reward over Iteration 246: 67.776
# Average Reward over Iteration 247: 71.152
# Average Reward over Iteration 248: 69.185
# Average Reward over Iteration 249: 66.85
# Average Reward over Iteration 250: 69.4
# Average Reward over Iteration 251: 71.263
# Average Reward over Iteration 252: 69.914
# Average Reward over Iteration 253: 71.854
# Average Reward over Iteration 254: 74.224
# Average Reward over Iteration 255: 75.399
# Average Reward over Iteration 256: 72.259
# Average Reward over Iteration 257: 71.315
# Average Reward over Iteration 258: 69.756
# Average Reward over Iteration 259: 71.363
# Average Reward over Iteration 260: 68.409
# Average Reward over Iteration 261: 69.654
# Average Reward over Iteration 262: 70.499
# Average Reward over Iteration 263: 67.333
# Average Reward over Iteration 264: 66.95
# Average Reward over Iteration 265: 65.325
# Average Reward over Iteration 266: 70.292
# Average Reward over Iteration 267: 66.759
# Average Reward over Iteration 268: 64.867
# Average Reward over Iteration 269: 68.266
# Average Reward over Iteration 270: 64.75
# Average Reward over Iteration 271: 67.922
# Average Reward over Iteration 272: 62.574
# Average Reward over Iteration 273: 65.445
# Average Reward over Iteration 274: 64.857
# Average Reward over Iteration 275: 69.593
# Average Reward over Iteration 276: 69.425
# Average Reward over Iteration 277: 68.841
# Average Reward over Iteration 278: 71.839
# Average Reward over Iteration 279: 68.569
# Average Reward over Iteration 280: 69.072
# Average Reward over Iteration 281: 72.157
# Average Reward over Iteration 282: 69.549
# Average Reward over Iteration 283: 67.39
# Average Reward over Iteration 284: 66.763
# Average Reward over Iteration 285: 68.414
# Average Reward over Iteration 286: 71.42
# Average Reward over Iteration 287: 71.482
# Average Reward over Iteration 288: 70.303
# Average Reward over Iteration 289: 69.84
# Average Reward over Iteration 290: 70.686
# Average Reward over Iteration 291: 68.648
# Average Reward over Iteration 292: 70.423
# Average Reward over Iteration 293: 71.608
# Average Reward over Iteration 294: 70.945
# Average Reward over Iteration 295: 70.671
# Average Reward over Iteration 296: 72.048
# Average Reward over Iteration 297: 69.131
# Average Reward over Iteration 298: 70.792
# Average Reward over Iteration 299: 69.892
# Average Reward over Iteration 300: 70.172
# Average Reward over Iteration 301: 71.028
# Average Reward over Iteration 302: 72.134
# Average Reward over Iteration 303: 73.415
# Average Reward over Iteration 304: 71.099
# Average Reward over Iteration 305: 71.152
# Average Reward over Iteration 306: 71.183
# Average Reward over Iteration 307: 70.041
# Average Reward over Iteration 308: 67.8
# Average Reward over Iteration 309: 68.232
# Average Reward over Iteration 310: 68.196
# Average Reward over Iteration 311: 67.853
# Average Reward over Iteration 312: 67.199
# Average Reward over Iteration 313: 66.366
# Average Reward over Iteration 314: 66.461
# Average Reward over Iteration 315: 65.746
# Average Reward over Iteration 316: 62.511
# Average Reward over Iteration 317: 59.78
# Average Reward over Iteration 318: 56.615
# Average Reward over Iteration 319: 58.78
# Average Reward over Iteration 320: 58.855
# Average Reward over Iteration 321: 61.209
# Average Reward over Iteration 322: 59.247
# Average Reward over Iteration 323: 64.338
# Average Reward over Iteration 324: 65.039
# Average Reward over Iteration 325: 62.781
# Average Reward over Iteration 326: 64.682
# Average Reward over Iteration 327: 68.956
# Average Reward over Iteration 328: 65.877
# Average Reward over Iteration 329: 65.086
# Average Reward over Iteration 330: 68.7
# Average Reward over Iteration 331: 68.506
# Average Reward over Iteration 332: 70.658
# Average Reward over Iteration 333: 71.358
# Average Reward over Iteration 334: 70.418
# Average Reward over Iteration 335: 72.527
# Average Reward over Iteration 336: 73.787
# Average Reward over Iteration 337: 71.927
# Average Reward over Iteration 338: 71.452
# Average Reward over Iteration 339: 72.027
# Average Reward over Iteration 340: 74.628
# Average Reward over Iteration 341: 74.028
# Average Reward over Iteration 342: 68.73
# Average Reward over Iteration 343: 72.467
# Average Reward over Iteration 344: 72.539
# Average Reward over Iteration 345: 70.517
# Average Reward over Iteration 346: 68.63
# Average Reward over Iteration 347: 67.146
# Average Reward over Iteration 348: 68.931
# Average Reward over Iteration 349: 67.185
# Average Reward over Iteration 350: 70.906
# Average Reward over Iteration 351: 69.155
# Average Reward over Iteration 352: 69.978
# Average Reward over Iteration 353: 68.245
# Average Reward over Iteration 354: 69.881
# Average Reward over Iteration 355: 67.361
# Average Reward over Iteration 356: 69.241
# Average Reward over Iteration 357: 68.856
# Average Reward over Iteration 358: 65.361
# Average Reward over Iteration 359: 67.383
# Average Reward over Iteration 360: 64.478
# Average Reward over Iteration 361: 64.515
# Average Reward over Iteration 362: 62.303
# Average Reward over Iteration 363: 60.152
# Average Reward over Iteration 364: 59.213
# Average Reward over Iteration 365: 58.817
# Average Reward over Iteration 366: 63.289
# Average Reward over Iteration 367: 58.804
# Average Reward over Iteration 368: 62.234
# Average Reward over Iteration 369: 59.394
# Average Reward over Iteration 370: 56.579
# Average Reward over Iteration 371: 56.706
# Average Reward over Iteration 372: 53.288
# Average Reward over Iteration 373: 56.667
# Average Reward over Iteration 374: 56.957
# Average Reward over Iteration 375: 55.631
# Average Reward over Iteration 376: 58.468
# Average Reward over Iteration 377: 56.688
# Average Reward over Iteration 378: 59.471
# Average Reward over Iteration 379: 59.307
# Average Reward over Iteration 380: 59.541
# Average Reward over Iteration 381: 61.137
# Average Reward over Iteration 382: 55.122
# Average Reward over Iteration 383: 58.75
# Average Reward over Iteration 384: 54.823
# Average Reward over Iteration 385: 57.614
# Average Reward over Iteration 386: 59.533
# Average Reward over Iteration 387: 60.39
# Average Reward over Iteration 388: 57.055
# Average Reward over Iteration 389: 58.194
# Average Reward over Iteration 390: 55.437
# Average Reward over Iteration 391: 52.107
# Average Reward over Iteration 392: 53.281
# Average Reward over Iteration 393: 53.998
# Average Reward over Iteration 394: 52.356
# Average Reward over Iteration 395: 54.138
# Average Reward over Iteration 396: 50.367
# Average Reward over Iteration 397: 51.901
# Average Reward over Iteration 398: 53.989
# Average Reward over Iteration 399: 51.576
# Average Reward over Iteration 400: 53.583
# Average Reward over Iteration 401: 46.605
# Average Reward over Iteration 402: 42.736
# Average Reward over Iteration 403: 48.681
# Average Reward over Iteration 404: 45.891
# Average Reward over Iteration 405: 49.761
# Average Reward over Iteration 406: 54.658
# Average Reward over Iteration 407: 55.542
# Average Reward over Iteration 408: 57.603
# Average Reward over Iteration 409: 57.129
# Average Reward over Iteration 410: 55.816
# Average Reward over Iteration 411: 59.783
# Average Reward over Iteration 412: 59.231
# Average Reward over Iteration 413: 61.938
# Average Reward over Iteration 414: 61.223
# Average Reward over Iteration 415: 62.319
# Average Reward over Iteration 416: 62.365
# Average Reward over Iteration 417: 60.042
# Average Reward over Iteration 418: 58.721
# Average Reward over Iteration 419: 56.663
# Average Reward over Iteration 420: 54.509
# Average Reward over Iteration 421: 56.098
# Average Reward over Iteration 422: 56.153
# Average Reward over Iteration 423: 57.064
# Average Reward over Iteration 424: 55.646
# Average Reward over Iteration 425: 54.195
# Average Reward over Iteration 426: 55.394
# Average Reward over Iteration 427: 55.043
# Average Reward over Iteration 428: 52.057
# Average Reward over Iteration 429: 51.222
# Average Reward over Iteration 430: 48.606
# Average Reward over Iteration 431: 46.875
# Average Reward over Iteration 432: 50.775
# Average Reward over Iteration 433: 49.789
# Average Reward over Iteration 434: 45.84
# Average Reward over Iteration 435: 47.473
# Average Reward over Iteration 436: 51.063
# Average Reward over Iteration 437: 49.604
# Average Reward over Iteration 438: 48.522
# Average Reward over Iteration 439: 49.892
# Average Reward over Iteration 440: 50.773
# Average Reward over Iteration 441: 53.638
# Average Reward over Iteration 442: 57.441
# Average Reward over Iteration 443: 59.284
# Average Reward over Iteration 444: 56.388
# Average Reward over Iteration 445: 55.355
# Average Reward over Iteration 446: 52.495
# Average Reward over Iteration 447: 55.617
# Average Reward over Iteration 448: 57.41
# Average Reward over Iteration 449: 58.942
# Average Reward over Iteration 450: 59.728
# Average Reward over Iteration 451: 59.248
# Average Reward over Iteration 452: 59.612
# Average Reward over Iteration 453: 61.651
# Average Reward over Iteration 454: 62.487
# Average Reward over Iteration 455: 60.325
# Average Reward over Iteration 456: 61.245
# Average Reward over Iteration 457: 63.768
# Average Reward over Iteration 458: 62.469
# Average Reward over Iteration 459: 66.232
# Average Reward over Iteration 460: 62.818
# Average Reward over Iteration 461: 66.423
# Average Reward over Iteration 462: 66.378
# Average Reward over Iteration 463: 68.258
# Average Reward over Iteration 464: 69.16
# Average Reward over Iteration 465: 68.559
# Average Reward over Iteration 466: 70.367
# Average Reward over Iteration 467: 72.932
# Average Reward over Iteration 468: 69.906
# Average Reward over Iteration 469: 70.443
# Average Reward over Iteration 470: 74.646
# Average Reward over Iteration 471: 73.807
# Average Reward over Iteration 472: 75.517
# Average Reward over Iteration 473: 72.441
# Average Reward over Iteration 474: 74.233
# Average Reward over Iteration 475: 74.367
# Average Reward over Iteration 476: 74.588
# Average Reward over Iteration 477: 76.808
# Average Reward over Iteration 478: 77.346
# Average Reward over Iteration 479: 80.505
# Average Reward over Iteration 480: 79.35
# Average Reward over Iteration 481: 79.384
# Average Reward over Iteration 482: 78.198
# Average Reward over Iteration 483: 78.738
# Average Reward over Iteration 484: 77.127
# Average Reward over Iteration 485: 76.517
# Average Reward over Iteration 486: 75.131
# Average Reward over Iteration 487: 77.621
# Average Reward over Iteration 488: 74.443
# Average Reward over Iteration 489: 71.404
# Average Reward over Iteration 490: 71.685
# Average Reward over Iteration 491: 73.92
# Average Reward over Iteration 492: 73.4
# Average Reward over Iteration 493: 74.213
# Average Reward over Iteration 494: 71.872
# Average Reward over Iteration 495: 75.15
# Average Reward over Iteration 496: 71.705
# Average Reward over Iteration 497: 70.209
# Average Reward over Iteration 498: 74.096
# Average Reward over Iteration 499: 72.492

# %%
import numpy as np



par_1_75, par_1_25 = np.percentile(reward_list, [75, 25], axis = 0)
plt.plot(range(500), np.mean(reward_list , axis = 0))
plt.fill_between(range(500), par_1_25, par_1_75, alpha = 0.4)
plt.title(f"TRPO reward per iter on MountainCarContinuous-v0")
plt.ylabel("Reward")
plt.xlabel("Iteration")
plt.show()

# %%
import pickle
dataStore = {}

dataStore['TRPO'] = reward_list
    
with open('./' + 'Results_TRPO_MCC' + '.pkl', 'wb') as fp:
        pickle.dump(dataStore, fp)
        print('dictionary saved successfully to file')
# Out:
# dictionary saved successfully to file
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
