# %%
from torch import nn
from torch.nn import functional
import torch
from torch import nn
from torch.utils.data import TensorDataset, DataLoader
import gym
from collections import deque
import random
import numpy as np

# %%
class TileCoder_Carpole:
    def __init__(self, num_tiles_per_dim, num_tilings, state_limits, clip_limits=None):
        self.num_tiles_per_dim = num_tiles_per_dim
        self.num_tilings = num_tilings
        self.state_limits = np.array(state_limits)
        self.clip_limits = np.array(clip_limits) if clip_limits is not None else state_limits
        self.tile_widths = np.zeros(len(state_limits))
        self.offsets = np.zeros(len(state_limits))
        for i, (clip_limit, state_limit) in enumerate(zip(self.clip_limits, self.state_limits)):
            # Use the clipped limit for calculating tile width, but keep the original limit for clipping states
            self.tile_widths[i] = (clip_limit[1] - clip_limit[0]) / (num_tiles_per_dim - 2)
            self.offsets[i] = self.tile_widths[i] / (2 * num_tilings)
        self.total_tiles = num_tilings * num_tiles_per_dim * len(state_limits)

    def get_tile_indices(self, state):
        tile_indices = np.zeros(self.total_tiles)
        for tiling in range(self.num_tilings):
            for dim, (state_dim, limits, clip_limit, offset, tile_width) in enumerate(
                zip(state, self.state_limits, self.clip_limits, self.offsets, self.tile_widths)
            ):
                clipped_state_dim = np.clip(state_dim, clip_limit[0], clip_limit[1])
                norm_state_dim = ((clipped_state_dim - clip_limit[0]) + (tiling * offset)) / tile_width
                # Calculate tile index for the dimension, with special handling for outermost tiles
                tile = int(norm_state_dim) + 1
                tile = max(1, min(self.num_tiles_per_dim - 2, tile))
                index = (tiling * self.num_tiles_per_dim * len(self.state_limits)) + (dim * self.num_tiles_per_dim) + tile
                tile_indices[index] = 1
        return tile_indices

num_tiles_per_dim = 100
num_tilings = 5
state_limits = [[-2.4, 2.4], [-np.inf, np.inf], [-12 * 2 * np.pi / 360, 12 * 2 * np.pi / 360], [-np.inf, np.inf]]
clip_limits = [[-2.4, 2.4], [-10, 10], [-12 * 2 * np.pi / 360, 12 * 2 * np.pi / 360], [-10, 10]]

# Initialize your tile coder here

tile_coder = TileCoder_Carpole(num_tiles_per_dim=num_tiles_per_dim,
                              num_tilings=num_tilings,
                              state_limits=state_limits,
                              clip_limits=clip_limits
                              )
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import pickle

def save_rewards_data(rewards_data, filename='rewards_data.pkl'):
    """Save the rewards data to a pickle file."""
    with open(filename, 'wb') as file:
        pickle.dump(rewards_data, file)
    print(f'Rewards data saved to {filename}')


def load_rewards_data(filename='rewards_data.pkl'):
    """Load the rewards data from a pickle file."""
    try:
        with open(filename, 'rb') as file:
            rewards_data = pickle.load(file)
        print(f'Rewards data loaded from {filename}')
        return rewards_data
    except FileNotFoundError:
        print(f'Error: The file {filename} does not exist. Please check the file path and try again.')
        return None
    except Exception as e:
        print(f'An error occurred while loading the data: {e}')
        return None

# %%
import matplotlib.pyplot as plt

def plot_rewards(rewards_data, algorithm_name="Q learning"):
    """Plot the average performance and IQR of the policy."""
    plt.figure(figsize=(14, 7))

    for epsilon, alphas in rewards_data.items():
        for alpha, data in alphas.items():
            # Calculate average and IQR across runs for each episode
            data = np.array(data)  # Convert to numpy array for easier slicing
            avg_rewards = np.mean(data, axis=0)
            lower_quartile = np.percentile(data, 25, axis=0)
            upper_quartile = np.percentile(data, 75, axis=0)

            episodes = np.arange(len(avg_rewards)) + 1
            plt.plot(episodes, avg_rewards, label=f'ε={epsilon}, α={alpha}')
            plt.fill_between(episodes, lower_quartile, upper_quartile, alpha=0.25)

    plt.title(f'Average Performance and IQR by Epsilon and Alpha ({algorithm_name})')
    plt.xlabel('Episodes')
    plt.ylabel('Average Reward')
    plt.legend()
    plt.show()

# %%
# class RBFDiscritizer:
#     def __init__(self, num_rbf_per_state, state_bounds, num_states):
#         self.num_rbf_per_state = num_rbf_per_state
#         self.state_bounds = state_bounds
#         self.num_states = num_states
#         self.num_rbf = num_rbf_per_state * np.ones(self.num_states).astype(int)
#         self.num_ind = np.prod(self.num_rbf)
#         self.width = 1. / (self.num_rbf - 1.)
#         self.rbf_sigma = self.width[0] / 2.
#         self.rbf_den = 2 * self.rbf_sigma ** 2
#         self.centres = self.build_centers()

#     def build_centers(self):
#         # Generate a meshgrid for the centers based on the number of RBFs per dimension
#         ranges = [np.linspace(0, 1, num) for num in self.num_rbf]
#         mesh = np.meshgrid(*ranges, indexing='ij')
#         # Flatten the meshgrid and stack it to get the center coordinates
#         center_coords = np.stack([axis.flatten() for axis in mesh], axis=-1)
#         return center_coords

#     def normalize_state(self, state):
#         normalized = np.zeros(len(state))
#         for i, (lower, upper) in enumerate(self.state_bounds):
#             normalized[i] = (state[i] - lower) / (upper - lower)
#         return normalized

#     def encode(self, state):
#         normalized_state = self.normalize_state(state)
#         _phi = np.zeros(self.num_ind)
#         for _k in range(self.num_ind):
#             _phi[_k] = np.exp(-np.linalg.norm(normalized_state - self.centres[_k, :]) ** 2 / self.rbf_den)
#         return _phi

# %%
class Model(nn.Module):
    def __init__(self, input_features, output_values):
        super(Model, self).__init__()
        self.fc1 = nn.Linear(in_features=input_features, out_features=32)
        self.fc2 = nn.Linear(in_features=32, out_features=32)
        self.fc3 = nn.Linear(in_features=32, out_features=output_values)

    def forward(self, x):
        x = functional.selu(self.fc1(x))
        x = functional.selu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
# class DDQN:
#     def __init__(self, env, discretizer, use_cuda=True, learning_rate=1e-5, gamma=0.7, memory_len=10000, start_epsilon=1):
#         self.device = torch.device("cuda" if use_cuda and torch.cuda.is_available() else "cpu")
#         self.env = env
#         self.discretizer = discretizer
#         self.learning_rate = learning_rate
#         self.gamma = gamma

#         self.epsilon = start_epsilon
#         self.min_epsilon = 0.1
#         self.epsilon_decay = 0.9 / 2.5e3
#         self.memory_len = memory_len
#         self.memory = deque(maxlen=self.memory_len)
#         self.criterion = nn.MSELoss()

#         input_features = discretizer.num_ind
#         output_values = env.action_space.n
#         self.policy_net = Model(input_features, output_values).to(self.device)
#         self.target_net = Model(input_features, output_values).to(self.device)

#         self.target_net.load_state_dict(self.policy_net.state_dict())
#         self.target_net.eval()

#     def get_states_tensor(self, sample, states_idx):
#         sample_len = len(sample)
#         states_tensor = torch.empty((sample_len, self.discretizer.num_ind), dtype=torch.float32, requires_grad=False)

#         for i, state in enumerate(sample):
#             num_array = state[states_idx]
#             states_tensor[i, :] = torch.from_numpy(num_array)

#         return states_tensor

#     def normalize_state(self, state):
#         state[0] /= 2.5
#         state[1] /= 2.5
#         state[2] /= 0.3
#         state[3] /= 0.3

#     def state_reward(self, state, env_reward):
#         return env_reward - (abs(state[0]) + abs(state[2])) / 2.5

#     def get_action(self, state, e=None):
#         if e is None:
#             e = self.epsilon
#         if random.random() < e:
#             return random.randrange(0, self.env.action_space.n)
#         else:
#             encoded_state = self.discretizer.encode(state)
#             encoded_state = torch.tensor(encoded_state, dtype=torch.float32, device=self.device)
#             return self.policy_net(encoded_state).argmax().item()

#     def fit(self, model, inputs, labels):
#         inputs = inputs.to(self.device)
#         labels = labels.to(self.device)
#         train_ds = TensorDataset(inputs, labels)
#         train_dl = DataLoader(train_ds, batch_size=5)

#         optimizer = torch.optim.Adam(params=model.parameters(), lr=self.learning_rate)
#         model.train()
#         total_loss = 0.0

#         for x, y in train_dl:
#             out = model(x)
#             loss = self.criterion(out, y)
#             total_loss += loss.item()
#             optimizer.zero_grad()
#             loss.backward()
#             optimizer.step()

#         model.eval()
#         return total_loss / len(train_dl)

#     def optimize_model(self, train_batch_size=100):
#         if len(self.memory) < train_batch_size:
#             return
#         train_sample = random.sample(self.memory, train_batch_size)

#         state = self.get_states_tensor(train_sample, 0).to(self.device)
#         next_state = self.get_states_tensor(train_sample, 3).to(self.device)

#         q_estimates = self.policy_net(state).detach()
#         next_state_q_estimates = self.target_net(next_state).detach()
#         next_actions = self.policy_net(next_state).argmax(dim=1)

#         for i in range(len(train_sample)):
#             next_action = next_actions[i].item()
#             q_estimates[i][train_sample[i][1]] = (self.state_reward(next_state[i], train_sample[i][2]) +
#                                                   self.gamma * next_state_q_estimates[i][next_action].item())

#         self.fit(self.policy_net, state, q_estimates)

#     def train_one_episode(self):
#         current_state = self.env.reset()
#         self.normalize_state(current_state)
#         done = False
#         score = 0
#         reward = 0
#         while not done:
#             action = self.get_action(current_state, self.epsilon)
#             next_state, env_reward, done, _ = self.env.step(action)
#             self.normalize_state(next_state)
#             encoded_current_state = self.discretizer.encode(current_state)
#             encoded_next_state = self.discretizer.encode(next_state)
#             self.memory.append((encoded_current_state, action, env_reward, encoded_next_state))
#             current_state = next_state
#             score += env_reward
#             reward += self.state_reward(next_state, env_reward)

#             self.optimize_model(100)

#             self.epsilon = max(self.min_epsilon, self.epsilon - self.epsilon_decay)

#         return score, reward

#     def test(self):
#         state = self.env.reset()
#         self.normalize_state(state)
#         done = False
#         score = 0
#         reward = 0
#         while not done:
#             action = self.get_action(state, 0)  # Using 0 to bypass random action selection
#             state, env_reward, done, _ = self.env.step(action)
#             self.normalize_state(state)
#             score += env_reward
#             reward += self.state_reward(state, env_reward)

#         return score, reward

# %%
class DDQN:
    def __init__(self, env, tile_coder, use_cuda=True, learning_rate=1e-5, gamma=0.7, memory_len=10000, start_epsilon=1):
        self.device = torch.device("cuda" if use_cuda and torch.cuda.is_available() else "cpu")
        self.env = env
        self.tile_coder = tile_coder
        self.learning_rate = learning_rate
        self.gamma = gamma

        self.epsilon = start_epsilon
        self.min_epsilon = 0.1
        self.epsilon_decay = 0.9 / 2.5e3
        self.memory_len = memory_len
        self.memory = deque(maxlen=self.memory_len)
        self.criterion = nn.MSELoss()

        input_features = tile_coder.total_tiles
        output_values = env.action_space.n
        self.policy_net = Model(input_features, output_values).to(self.device)
        self.target_net = Model(input_features, output_values).to(self.device)

        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()

    def get_states_tensor(self, sample, states_idx):
        sample_len = len(sample)
        states_tensor = torch.empty((sample_len, self.tile_coder.total_tiles), dtype=torch.float32, requires_grad=False)

        for i, state in enumerate(sample):
            num_array = state[states_idx]
            states_tensor[i, :] = torch.from_numpy(num_array)

        return states_tensor

    def state_reward(self, state, env_reward):
        return env_reward - (abs(state[0]) + abs(state[2])) / 2.5

    def get_action(self, state, e=None):
        if e is None:
            e = self.epsilon
        if random.random() < e:
            return random.randrange(0, self.env.action_space.n)
        else:
            encoded_state = self.tile_coder.get_tile_indices(state)
            encoded_state = torch.tensor(encoded_state, dtype=torch.float32, device=self.device)
            return self.policy_net(encoded_state).argmax().item()

    def fit(self, model, inputs, labels):
        inputs = inputs.to(self.device)
        labels = labels.to(self.device)
        train_ds = TensorDataset(inputs, labels)
        train_dl = DataLoader(train_ds, batch_size=5)

        optimizer = torch.optim.Adam(params=model.parameters(), lr=self.learning_rate)
        model.train()
        total_loss = 0.0

        for x, y in train_dl:
            out = model(x)
            loss = self.criterion(out, y)
            total_loss += loss.item()
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        model.eval()
        return total_loss / len(train_dl)

    def optimize_model(self, train_batch_size=100):
        if len(self.memory) < train_batch_size:
            return
        train_sample = random.sample(self.memory, train_batch_size)

        state = self.get_states_tensor(train_sample, 0).to(self.device)
        next_state = self.get_states_tensor(train_sample, 3).to(self.device)

        q_estimates = self.policy_net(state).detach()
        next_state_q_estimates = self.target_net(next_state).detach()
        next_actions = self.policy_net(next_state).argmax(dim=1)

        for i in range(len(train_sample)):
            next_action = next_actions[i].item()
            q_estimates[i][train_sample[i][1]] = (self.state_reward(next_state[i], train_sample[i][2]) +
                                                  self.gamma * next_state_q_estimates[i][next_action].item())

        self.fit(self.policy_net, state, q_estimates)

    def train_one_episode(self):
        current_state = self.env.reset()
        done = False
        score = 0
        reward = 0
        while not done:
            action = self.get_action(current_state, self.epsilon)
            next_state, env_reward, done, _ = self.env.step(action)
            encoded_current_state = self.tile_coder.get_tile_indices(current_state)
            encoded_next_state = self.tile_coder.get_tile_indices(next_state)
            self.memory.append((encoded_current_state, action, env_reward, encoded_next_state))
            current_state = next_state
            score += env_reward
            reward += self.state_reward(next_state, env_reward)

            self.optimize_model(100)

            self.epsilon = max(self.min_epsilon, self.epsilon - self.epsilon_decay)

        return score, reward

    def test(self):
        state = self.env.reset()
        done = False
        score = 0
        reward = 0
        while not done:
            action = self.get_action(state, 0)  # Using 0 to bypass random action selection
            state, env_reward, done, _ = self.env.step(action)
            score += env_reward
            reward += self.state_reward(state, env_reward)

        return score, reward

# %%
num_states = 4
num_rbf_per_state=4
state_bounds = [(-2.4, 2.4), (-10.0, 10.0), (-0.42, 0.42), (-10.0, 10.0)]

# discretizer = RBFDiscritizer(num_rbf_per_state=num_rbf_per_state, state_bounds=state_bounds, num_states=num_states)

env = gym.make('CartPole-v1')
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(

# %%
def main(used_alpha, used_epsilon, env, tile_coder, target_update_delay, test_delay, memory_len=10000, num_runs=1, num_episode=1000, save_file=""):


    # Initialize storage for reward data
    rewards_data = {epsilon: {alpha: [] for alpha in used_alpha} for epsilon in used_epsilon}

    for epsilon in used_epsilon:
        for alpha in used_alpha:
            print(f"Training with epsilon: {epsilon}, alpha: {alpha}")
            run_rewards = []  # Collect rewards for each run for the current config

            for run in range(num_runs):

                # avoid decay
                current_epsilon = epsilon

                print(f"Run {run + 1}/{num_runs}")

                # renew the wrapper class
                ddqn = DDQN(
                    env=env,
                    tile_coder=tile_coder,
                    use_cuda=True,
                    learning_rate=alpha,
                    gamma=0.99,
                    memory_len=memory_len,
                    start_epsilon=current_epsilon
                )

                best_test_reward = 0

                episode_rewards = []  # Collect rewards for each episode in the current run
                for i in range(num_episode):
                    score, reward = ddqn.train_one_episode()

                    print(f'Episode {i + 1}: score: {score} - reward: {reward}')

                    if i % target_update_delay == 0:
                        ddqn.target_net.load_state_dict(ddqn.policy_net.state_dict())
                        ddqn.target_net.eval()

                    if (i + 1) % test_delay == 0:
                        test_score, test_reward = ddqn.test()
                        print(f'Test Episode {i + 1}: test score: {test_score} - test reward: {test_reward}')
                        if test_reward > best_test_reward:
                            print('New best test reward. Saving model')
                            best_test_reward = test_reward
                            # torch.save(ddqn.policy_net.state_dict(), f'policy_net_{run}.pth')

                    # Add the rewards
                    episode_rewards.append(score)

                if num_episode % test_delay != 0:
                    test_score, test_reward = ddqn.test()
                    print(f'Test Episode {num_episode}: test score: {test_score} - test reward: {test_reward}')
                    if test_reward > best_test_reward:
                        print('New best test reward. Saving model')
                        best_test_reward = test_reward
                        # torch.save(ddqn.policy_net.state_dict(), f'policy_net_{run}.pth')

                # save the run rewards
                run_rewards.append(episode_rewards)

                print(f'best test reward: {best_test_reward}')

            # Store the rewards for the current epsilon and alpha configuration
            rewards_data[epsilon][alpha] = run_rewards

    if not(save_file == ""):
        save_rewards_data(rewards_data, save_file)

    return rewards_data

# %%
rewards_data = main(
    used_alpha=[1e-2,1e-3,1e-4],
    used_epsilon=[0.1,0.5,0.9],  # start epsilon
    env=env,
    tile_coder=tile_coder,
    target_update_delay=5,
    test_delay=10,
    memory_len=10000,
    num_runs=1,
    num_episode=500,
    save_file="example_data.pkl"
)
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/utils/passive_env_checker.py:241: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# Streaming output truncated to the last 5000 lines.
# Episode 28: score: 15.0 - reward: 14.259069566428662
# Episode 29: score: 12.0 - reward: 11.153722281754018
# Episode 30: score: 16.0 - reward: 14.93898080214858
# Test Episode 30: test score: 9.0 - test reward: 8.511109679937363
# New best test reward. Saving model
# Episode 31: score: 16.0 - reward: 15.301351578533648
# Episode 32: score: 14.0 - reward: 13.093800161778926
# Episode 33: score: 25.0 - reward: 24.112349433451893
# Episode 34: score: 65.0 - reward: 61.181111380830416
# Episode 35: score: 16.0 - reward: 15.184111493825913
# Episode 36: score: 30.0 - reward: 28.35100298225879
# Episode 37: score: 14.0 - reward: 12.90907339155674
# Episode 38: score: 18.0 - reward: 17.27260641157627
# Episode 39: score: 27.0 - reward: 26.03779813349247
# Episode 40: score: 16.0 - reward: 15.442859359085562
# Test Episode 40: test score: 14.0 - test reward: 12.894118724763393
# New best test reward. Saving model
# Episode 41: score: 13.0 - reward: 12.429531809687616
# Episode 42: score: 11.0 - reward: 10.207534733414649
# Episode 43: score: 20.0 - reward: 19.28506731688976
# Episode 44: score: 15.0 - reward: 14.04696066081524
# Episode 45: score: 12.0 - reward: 11.121917909383773
# Episode 46: score: 16.0 - reward: 14.672601629793643
# Episode 47: score: 55.0 - reward: 48.339331337064486
# Episode 48: score: 26.0 - reward: 24.188363487273453
# Episode 49: score: 9.0 - reward: 8.302065387368202
# Episode 50: score: 18.0 - reward: 17.269669987261295
# Test Episode 50: test score: 10.0 - test reward: 9.441238873824478
# Episode 51: score: 23.0 - reward: 21.995755260810256
# Episode 52: score: 14.0 - reward: 13.106137081980705
# Episode 53: score: 37.0 - reward: 35.38306440934538
# Episode 54: score: 14.0 - reward: 13.375013813748955
# Episode 55: score: 9.0 - reward: 8.389412174373865
# Episode 56: score: 14.0 - reward: 13.105665056407451
# Episode 57: score: 25.0 - reward: 23.534080217033623
# Episode 58: score: 34.0 - reward: 32.63184778615833
# Episode 59: score: 11.0 - reward: 10.130919900536538
# Episode 60: score: 16.0 - reward: 15.351381035149098
# Test Episode 60: test score: 12.0 - test reward: 11.243465301394462
# Episode 61: score: 27.0 - reward: 25.4865759536624
# Episode 62: score: 48.0 - reward: 43.03202892839909
# Episode 63: score: 19.0 - reward: 18.122627620398998
# Episode 64: score: 27.0 - reward: 25.40449259728193
# Episode 65: score: 13.0 - reward: 12.248266738653182
# Episode 66: score: 12.0 - reward: 11.321181350946425
# Episode 67: score: 23.0 - reward: 21.127537227422003
# Episode 68: score: 22.0 - reward: 21.017738901823755
# Episode 69: score: 23.0 - reward: 20.614151237905027
# Episode 70: score: 13.0 - reward: 12.42836645245552
# Test Episode 70: test score: 11.0 - test reward: 10.243854996562005
# Episode 71: score: 12.0 - reward: 11.304298957437275
# Episode 72: score: 23.0 - reward: 22.11943556377664
# Episode 73: score: 18.0 - reward: 17.22980274260044
# Episode 74: score: 11.0 - reward: 10.102845793962478
# Episode 75: score: 9.0 - reward: 8.223556646704674
# Episode 76: score: 19.0 - reward: 18.064005365967752
# Episode 77: score: 36.0 - reward: 33.19636391848326
# Episode 78: score: 23.0 - reward: 22.10249947533011
# Episode 79: score: 16.0 - reward: 15.340835247933864
# Episode 80: score: 11.0 - reward: 10.394360448606312
# Test Episode 80: test score: 11.0 - test reward: 10.11052918434143
# Episode 81: score: 16.0 - reward: 15.249012143164872
# Episode 82: score: 10.0 - reward: 9.367746819555759
# Episode 83: score: 12.0 - reward: 11.365463456511495
# Episode 84: score: 14.0 - reward: 13.264707417786122
# Episode 85: score: 31.0 - reward: 30.072265153378243
# Episode 86: score: 19.0 - reward: 18.061621250212195
# Episode 87: score: 8.0 - reward: 7.399876520037652
# Episode 88: score: 21.0 - reward: 19.786065395176415
# Episode 89: score: 11.0 - reward: 10.41166000366211
# Episode 90: score: 9.0 - reward: 8.497235754132271
# Test Episode 90: test score: 8.0 - test reward: 7.584668666124345
# Episode 91: score: 15.0 - reward: 13.978923101723193
# Episode 92: score: 12.0 - reward: 11.280707612633707
# Episode 93: score: 16.0 - reward: 14.988364298269152
# Episode 94: score: 13.0 - reward: 11.955085477232931
# Episode 95: score: 50.0 - reward: 45.74406069293619
# Episode 96: score: 13.0 - reward: 12.027778244018553
# Episode 97: score: 10.0 - reward: 9.47144093811512
# Episode 98: score: 59.0 - reward: 56.36630907878279
# Episode 99: score: 11.0 - reward: 10.41868044734001
# Episode 100: score: 9.0 - reward: 8.492716436088084
# Test Episode 100: test score: 12.0 - test reward: 11.404719688370825
# Episode 101: score: 29.0 - reward: 27.564188031107197
# Episode 102: score: 26.0 - reward: 24.118677842617036
# Episode 103: score: 27.0 - reward: 25.010012821853163
# Episode 104: score: 20.0 - reward: 18.39403638392687
# Episode 105: score: 24.0 - reward: 23.02029305398465
# Episode 106: score: 16.0 - reward: 14.900156424939633
# Episode 107: score: 17.0 - reward: 16.11310877557844
# Episode 108: score: 14.0 - reward: 13.292505197972059
# Episode 109: score: 21.0 - reward: 19.602728590369225
# Episode 110: score: 12.0 - reward: 11.247791239619255
# Test Episode 110: test score: 12.0 - test reward: 11.378985992819072
# Episode 111: score: 22.0 - reward: 20.977277558296922
# Episode 112: score: 17.0 - reward: 16.394676947593688
# Episode 113: score: 9.0 - reward: 8.331333255767822
# Episode 114: score: 9.0 - reward: 8.35383668988943
# Episode 115: score: 11.0 - reward: 10.219505989551543
# Episode 116: score: 23.0 - reward: 21.025540374219414
# Episode 117: score: 12.0 - reward: 11.237375186011196
# Episode 118: score: 11.0 - reward: 10.32824776917696
# Episode 119: score: 10.0 - reward: 9.427120220661163
# Episode 120: score: 12.0 - reward: 11.356238037347794
# Test Episode 120: test score: 8.0 - test reward: 7.520831495523454
# Episode 121: score: 25.0 - reward: 23.812789134681225
# Episode 122: score: 26.0 - reward: 25.089063880220053
# Episode 123: score: 16.0 - reward: 15.126957032084464
# Episode 124: score: 10.0 - reward: 9.240534414350988
# Episode 125: score: 14.0 - reward: 13.229191201180218
# Episode 126: score: 11.0 - reward: 10.085969339311124
# Episode 127: score: 13.0 - reward: 12.140968731045723
# Episode 128: score: 12.0 - reward: 11.355354784429071
# Episode 129: score: 22.0 - reward: 20.82630109079182
# Episode 130: score: 15.0 - reward: 14.286387528479098
# Test Episode 130: test score: 13.0 - test reward: 12.171176292747258
# Episode 131: score: 12.0 - reward: 11.082851192355154
# Episode 132: score: 21.0 - reward: 19.88084200061858
# Episode 133: score: 24.0 - reward: 22.833779825456443
# Episode 134: score: 10.0 - reward: 9.221005034446716
# Episode 135: score: 18.0 - reward: 16.74826520085335
# Episode 136: score: 18.0 - reward: 17.118596771359446
# Episode 137: score: 13.0 - reward: 12.124991160631183
# Episode 138: score: 18.0 - reward: 17.331478832662107
# Episode 139: score: 22.0 - reward: 20.983182028494777
# Episode 140: score: 19.0 - reward: 17.47764337658882
# Test Episode 140: test score: 12.0 - test reward: 11.432293821871282
# Episode 141: score: 13.0 - reward: 12.187804593145847
# Episode 142: score: 10.0 - reward: 9.262828220427036
# Episode 143: score: 14.0 - reward: 13.275848978012801
# Episode 144: score: 29.0 - reward: 27.3592054605484
# Episode 145: score: 35.0 - reward: 33.61057549268007
# Episode 146: score: 13.0 - reward: 12.380715526640413
# Episode 147: score: 12.0 - reward: 11.016947472095488
# Episode 148: score: 18.0 - reward: 16.621633008122448
# Episode 149: score: 15.0 - reward: 14.247655893862248
# Episode 150: score: 14.0 - reward: 13.41487123221159
# Test Episode 150: test score: 15.0 - test reward: 13.968546146154402
# New best test reward. Saving model
# Episode 151: score: 16.0 - reward: 15.162436669319867
# Episode 152: score: 14.0 - reward: 12.946719397604465
# Episode 153: score: 12.0 - reward: 11.32333816587925
# Episode 154: score: 14.0 - reward: 13.33455397747457
# Episode 155: score: 15.0 - reward: 14.320969436503946
# Episode 156: score: 27.0 - reward: 25.442461150884625
# Episode 157: score: 31.0 - reward: 29.320979334414005
# Episode 158: score: 54.0 - reward: 48.72958348095417
# Episode 159: score: 25.0 - reward: 23.96777149885893
# Episode 160: score: 17.0 - reward: 15.739772434532645
# Test Episode 160: test score: 13.0 - test reward: 12.313875797390937
# Episode 161: score: 25.0 - reward: 23.963589735329148
# Episode 162: score: 12.0 - reward: 11.249205873534084
# Episode 163: score: 17.0 - reward: 16.092674762010574
# Episode 164: score: 40.0 - reward: 38.44628415778278
# Episode 165: score: 17.0 - reward: 16.202381267771123
# Episode 166: score: 17.0 - reward: 16.06589817777276
# Episode 167: score: 25.0 - reward: 23.71444948464632
# Episode 168: score: 37.0 - reward: 35.541832959651956
# Episode 169: score: 54.0 - reward: 51.45604327991607
# Episode 170: score: 37.0 - reward: 35.87779926070943
# Test Episode 170: test score: 11.0 - test reward: 10.391634259372948
# Episode 171: score: 10.0 - reward: 9.506857252120973
# Episode 172: score: 19.0 - reward: 18.30644797384739
# Episode 173: score: 24.0 - reward: 22.20692246854305
# Episode 174: score: 26.0 - reward: 24.914795531332494
# Episode 175: score: 19.0 - reward: 18.00369452238083
# Episode 176: score: 17.0 - reward: 16.106821040809155
# Episode 177: score: 25.0 - reward: 23.81453357189894
# Episode 178: score: 16.0 - reward: 15.103663551807404
# Episode 179: score: 31.0 - reward: 29.468314433097838
# Episode 180: score: 19.0 - reward: 17.99322967901826
# Test Episode 180: test score: 9.0 - test reward: 8.493586668372155
# Episode 181: score: 17.0 - reward: 16.404116269946098
# Episode 182: score: 17.0 - reward: 16.195451103150845
# Episode 183: score: 11.0 - reward: 10.4092931188643
# Episode 184: score: 23.0 - reward: 21.21304459571838
# Episode 185: score: 85.0 - reward: 76.14458459764718
# Episode 186: score: 23.0 - reward: 22.079094692319632
# Episode 187: score: 36.0 - reward: 34.5895784549415
# Episode 188: score: 34.0 - reward: 32.48407924026251
# Episode 189: score: 10.0 - reward: 9.23941013813019
# Episode 190: score: 40.0 - reward: 37.40975702404977
# Test Episode 190: test score: 10.0 - test reward: 9.28637220710516
# Episode 191: score: 16.0 - reward: 15.312306419014933
# Episode 192: score: 13.0 - reward: 12.066784970462322
# Episode 193: score: 21.0 - reward: 19.705768418312072
# Episode 194: score: 39.0 - reward: 36.99752823114396
# Episode 195: score: 12.0 - reward: 11.245845378935337
# Episode 196: score: 12.0 - reward: 11.37024767547846
# Episode 197: score: 16.0 - reward: 15.452526282612235
# Episode 198: score: 13.0 - reward: 12.118728085234762
# Episode 199: score: 18.0 - reward: 16.309130251407623
# Episode 200: score: 10.0 - reward: 9.496381911635398
# Test Episode 200: test score: 13.0 - test reward: 12.158463481068612
# Episode 201: score: 19.0 - reward: 17.597976464033128
# Episode 202: score: 18.0 - reward: 17.295823838561773
# Episode 203: score: 19.0 - reward: 17.458665409684183
# Episode 204: score: 16.0 - reward: 15.292061907052993
# Episode 205: score: 12.0 - reward: 11.501834504306316
# Episode 206: score: 8.0 - reward: 7.551078441739082
# Episode 207: score: 12.0 - reward: 11.101712557673453
# Episode 208: score: 13.0 - reward: 12.136336444318292
# Episode 209: score: 27.0 - reward: 25.17921737581491
# Episode 210: score: 20.0 - reward: 19.29608764313161
# Test Episode 210: test score: 10.0 - test reward: 9.453568916767837
# Episode 211: score: 49.0 - reward: 45.9711651213467
# Episode 212: score: 40.0 - reward: 38.625418091565365
# Episode 213: score: 11.0 - reward: 10.39870046749711
# Episode 214: score: 17.0 - reward: 15.940116895735262
# Episode 215: score: 16.0 - reward: 15.245053483545778
# Episode 216: score: 19.0 - reward: 18.093227249383926
# Episode 217: score: 11.0 - reward: 10.051610875129699
# Episode 218: score: 9.0 - reward: 8.421546903252603
# Episode 219: score: 13.0 - reward: 12.225987092405557
# Episode 220: score: 19.0 - reward: 17.772669565677642
# Test Episode 220: test score: 11.0 - test reward: 10.304865917563438
# Episode 221: score: 11.0 - reward: 10.322922384738922
# Episode 222: score: 14.0 - reward: 13.039130568504335
# Episode 223: score: 37.0 - reward: 35.179577726125714
# Episode 224: score: 22.0 - reward: 21.104876250773668
# Episode 225: score: 25.0 - reward: 23.915687258541585
# Episode 226: score: 19.0 - reward: 18.00433311089873
# Episode 227: score: 19.0 - reward: 17.530897099524736
# Episode 228: score: 24.0 - reward: 22.88525979816914
# Episode 229: score: 13.0 - reward: 12.047940914332866
# Episode 230: score: 11.0 - reward: 10.329368719458579
# Test Episode 230: test score: 9.0 - test reward: 8.530645105242728
# Episode 231: score: 39.0 - reward: 37.25605402290821
# Episode 232: score: 26.0 - reward: 24.692766305059198
# Episode 233: score: 18.0 - reward: 17.086706879734994
# Episode 234: score: 23.0 - reward: 21.800512591749428
# Episode 235: score: 18.0 - reward: 17.156253051757815
# Episode 236: score: 18.0 - reward: 16.91372466534376
# Episode 237: score: 21.0 - reward: 20.16717000603676
# Episode 238: score: 23.0 - reward: 22.106257081031796
# Episode 239: score: 12.0 - reward: 11.166121476888655
# Episode 240: score: 20.0 - reward: 18.800658804178234
# Test Episode 240: test score: 14.0 - test reward: 12.91814308613539
# Episode 241: score: 23.0 - reward: 21.678942824900147
# Episode 242: score: 41.0 - reward: 38.1854770332575
# Episode 243: score: 12.0 - reward: 11.253094337880611
# Episode 244: score: 18.0 - reward: 16.731790283322333
# Episode 245: score: 32.0 - reward: 30.8439026132226
# Episode 246: score: 13.0 - reward: 12.410375548899175
# Episode 247: score: 10.0 - reward: 9.3158150061965
# Episode 248: score: 11.0 - reward: 10.348726147413256
# Episode 249: score: 19.0 - reward: 18.13339028656483
# Episode 250: score: 22.0 - reward: 20.476391386240717
# Test Episode 250: test score: 11.0 - test reward: 10.438775686174631
# Episode 251: score: 30.0 - reward: 28.839636750519272
# Episode 252: score: 16.0 - reward: 15.194370840117339
# Episode 253: score: 21.0 - reward: 20.04042287617922
# Episode 254: score: 31.0 - reward: 29.38893752843142
# Episode 255: score: 20.0 - reward: 18.983270744979382
# Episode 256: score: 25.0 - reward: 23.673412474989895
# Episode 257: score: 23.0 - reward: 22.11226436346769
# Episode 258: score: 15.0 - reward: 13.831417632102966
# Episode 259: score: 24.0 - reward: 23.13330354392528
# Episode 260: score: 35.0 - reward: 33.23613222464918
# Test Episode 260: test score: 13.0 - test reward: 12.447948114573954
# Episode 261: score: 15.0 - reward: 14.2863070294261
# Episode 262: score: 13.0 - reward: 11.93296657502651
# Episode 263: score: 12.0 - reward: 11.261074648797512
# Episode 264: score: 26.0 - reward: 25.078648039326072
# Episode 265: score: 12.0 - reward: 11.081351816654204
# Episode 266: score: 11.0 - reward: 10.334677819907665
# Episode 267: score: 26.0 - reward: 24.82008884251118
# Episode 268: score: 22.0 - reward: 21.089906153082843
# Episode 269: score: 12.0 - reward: 11.404378772526979
# Episode 270: score: 10.0 - reward: 9.332321835309267
# Test Episode 270: test score: 9.0 - test reward: 8.238830956816672
# Episode 271: score: 39.0 - reward: 36.65926460027695
# Episode 272: score: 14.0 - reward: 12.855970105528831
# Episode 273: score: 11.0 - reward: 10.425344894826411
# Episode 274: score: 20.0 - reward: 18.380703153461216
# Episode 275: score: 18.0 - reward: 17.332037257403137
# Episode 276: score: 13.0 - reward: 12.109700754284859
# Episode 277: score: 12.0 - reward: 11.31399355083704
# Episode 278: score: 26.0 - reward: 24.739538768678905
# Episode 279: score: 23.0 - reward: 21.9536534897983
# Episode 280: score: 28.0 - reward: 27.12465108605101
# Test Episode 280: test score: 10.0 - test reward: 9.271420732140541
# Episode 281: score: 22.0 - reward: 20.701868106424808
# Episode 282: score: 10.0 - reward: 9.387435895204545
# Episode 283: score: 22.0 - reward: 20.67773359119892
# Episode 284: score: 23.0 - reward: 22.00905695296824
# Episode 285: score: 11.0 - reward: 10.25518943667412
# Episode 286: score: 15.0 - reward: 14.271181827783586
# Episode 287: score: 18.0 - reward: 17.044284296035766
# Episode 288: score: 29.0 - reward: 27.676654161885377
# Episode 289: score: 18.0 - reward: 17.17836313843727
# Episode 290: score: 13.0 - reward: 12.084356939792633
# Test Episode 290: test score: 10.0 - test reward: 9.336444337666036
# Episode 291: score: 17.0 - reward: 16.019516628980632
# Episode 292: score: 15.0 - reward: 14.21946225166321
# Episode 293: score: 48.0 - reward: 46.05310074239969
# Episode 294: score: 15.0 - reward: 13.81246301010251
# Episode 295: score: 18.0 - reward: 17.057094918191435
# Episode 296: score: 20.0 - reward: 18.807797206938268
# Episode 297: score: 13.0 - reward: 12.235455559194088
# Episode 298: score: 11.0 - reward: 10.144484171271325
# Episode 299: score: 14.0 - reward: 13.200641137361526
# Episode 300: score: 28.0 - reward: 26.905842345207923
# Test Episode 300: test score: 10.0 - test reward: 9.444807311892509
# Episode 301: score: 13.0 - reward: 12.269153180718423
# Episode 302: score: 16.0 - reward: 14.875557467341423
# Episode 303: score: 13.0 - reward: 12.313058525323868
# Episode 304: score: 42.0 - reward: 39.402079755067824
# Episode 305: score: 23.0 - reward: 21.621547564864162
# Episode 306: score: 21.0 - reward: 19.997402557730673
# Episode 307: score: 13.0 - reward: 12.208659700676801
# Episode 308: score: 12.0 - reward: 11.277788810431957
# Episode 309: score: 36.0 - reward: 34.24531275182963
# Episode 310: score: 19.0 - reward: 17.879128594696528
# Test Episode 310: test score: 9.0 - test reward: 8.362715028226376
# Episode 311: score: 20.0 - reward: 18.998413857817653
# Episode 312: score: 36.0 - reward: 33.84726813994347
# Episode 313: score: 32.0 - reward: 31.028771957755087
# Episode 314: score: 18.0 - reward: 16.690384507179264
# Episode 315: score: 57.0 - reward: 53.45239638537169
# Episode 316: score: 18.0 - reward: 17.167250188440082
# Episode 317: score: 31.0 - reward: 29.360205188393582
# Episode 318: score: 20.0 - reward: 19.323379324749116
# Episode 319: score: 27.0 - reward: 24.94971437454224
# Episode 320: score: 20.0 - reward: 18.69638037383556
# Test Episode 320: test score: 9.0 - test reward: 8.47602891921997
# Episode 321: score: 35.0 - reward: 33.334543999284506
# Episode 322: score: 10.0 - reward: 9.351076070219278
# Episode 323: score: 22.0 - reward: 20.93297152966261
# Episode 324: score: 20.0 - reward: 19.340203768759967
# Episode 325: score: 43.0 - reward: 40.698603504896155
# Episode 326: score: 15.0 - reward: 14.266827452182769
# Episode 327: score: 24.0 - reward: 22.734359574317935
# Episode 328: score: 17.0 - reward: 15.816481561213731
# Episode 329: score: 17.0 - reward: 16.243213352560996
# Episode 330: score: 28.0 - reward: 25.819604434072968
# Test Episode 330: test score: 10.0 - test reward: 9.396420185267925
# Episode 331: score: 43.0 - reward: 39.97530120164155
# Episode 332: score: 21.0 - reward: 19.294390486925835
# Episode 333: score: 17.0 - reward: 15.920925343036648
# Episode 334: score: 17.0 - reward: 15.773658678680658
# Episode 335: score: 27.0 - reward: 24.834405407309525
# Episode 336: score: 43.0 - reward: 39.826107931882134
# Episode 337: score: 15.0 - reward: 14.063265316188334
# Episode 338: score: 24.0 - reward: 23.009117457270623
# Episode 339: score: 19.0 - reward: 17.943954980373384
# Episode 340: score: 15.0 - reward: 14.167198422551156
# Test Episode 340: test score: 9.0 - test reward: 8.36989236921072
# Episode 341: score: 33.0 - reward: 31.487405236065385
# Episode 342: score: 14.0 - reward: 12.914392256736756
# Episode 343: score: 19.0 - reward: 18.060834224522115
# Episode 344: score: 15.0 - reward: 14.26521638557315
# Episode 345: score: 36.0 - reward: 34.344354964792736
# Episode 346: score: 21.0 - reward: 20.14600807316601
# Episode 347: score: 64.0 - reward: 58.037514068186276
# Episode 348: score: 12.0 - reward: 11.266227310523389
# Episode 349: score: 10.0 - reward: 9.507771161198615
# Episode 350: score: 16.0 - reward: 14.991920001804829
# Test Episode 350: test score: 12.0 - test reward: 11.371478458493948
# Episode 351: score: 19.0 - reward: 18.067591574229297
# Episode 352: score: 12.0 - reward: 11.171727477759124
# Episode 353: score: 11.0 - reward: 10.396582680940629
# Episode 354: score: 19.0 - reward: 17.980793100595474
# Episode 355: score: 11.0 - reward: 10.273347361385822
# Episode 356: score: 41.0 - reward: 38.2728762542829
# Episode 357: score: 14.0 - reward: 12.928899790346621
# Episode 358: score: 16.0 - reward: 15.127160584181546
# Episode 359: score: 20.0 - reward: 18.657280282676222
# Episode 360: score: 20.0 - reward: 18.783035150170328
# Test Episode 360: test score: 9.0 - test reward: 8.48804697394371
# Episode 361: score: 11.0 - reward: 10.139196950197219
# Episode 362: score: 10.0 - reward: 9.310728996992113
# Episode 363: score: 32.0 - reward: 30.63206826969981
# Episode 364: score: 100.0 - reward: 86.37462447583678
# Episode 365: score: 24.0 - reward: 23.14959033504128
# Episode 366: score: 12.0 - reward: 11.324636393785477
# Episode 367: score: 20.0 - reward: 19.287865628302097
# Episode 368: score: 21.0 - reward: 20.2305861916393
# Episode 369: score: 19.0 - reward: 18.02290220409632
# Episode 370: score: 23.0 - reward: 21.75958077609539
# Test Episode 370: test score: 10.0 - test reward: 9.475239584594966
# Episode 371: score: 28.0 - reward: 26.90473051816225
# Episode 372: score: 16.0 - reward: 15.136781243234871
# Episode 373: score: 16.0 - reward: 14.795624401420353
# Episode 374: score: 78.0 - reward: 70.38948525413872
# Episode 375: score: 11.0 - reward: 10.381852129474282
# Episode 376: score: 54.0 - reward: 50.188548979163166
# Episode 377: score: 26.0 - reward: 24.32826390862464
# Episode 378: score: 14.0 - reward: 13.202873155474661
# Episode 379: score: 31.0 - reward: 29.866662110388283
# Episode 380: score: 29.0 - reward: 27.795820987224577
# Test Episode 380: test score: 9.0 - test reward: 8.443527422845364
# Episode 381: score: 21.0 - reward: 19.637010231614113
# Episode 382: score: 17.0 - reward: 16.34688379657455
# Episode 383: score: 17.0 - reward: 16.054034668207166
# Episode 384: score: 16.0 - reward: 15.054022557195276
# Episode 385: score: 9.0 - reward: 8.449678471684456
# Episode 386: score: 14.0 - reward: 13.09749431759119
# Episode 387: score: 30.0 - reward: 29.130752897262578
# Episode 388: score: 14.0 - reward: 13.130746331810952
# Episode 389: score: 19.0 - reward: 17.90856164246798
# Episode 390: score: 27.0 - reward: 25.271212323009966
# Test Episode 390: test score: 10.0 - test reward: 9.462126150727272
# Episode 391: score: 13.0 - reward: 12.349941348284482
# Episode 392: score: 34.0 - reward: 32.25058050230146
# Episode 393: score: 50.0 - reward: 48.35096629615874
# Episode 394: score: 19.0 - reward: 18.031218505650756
# Episode 395: score: 14.0 - reward: 13.329330530762673
# Episode 396: score: 12.0 - reward: 11.174887827783824
# Episode 397: score: 42.0 - reward: 39.25546794235708
# Episode 398: score: 15.0 - reward: 14.162489079870285
# Episode 399: score: 21.0 - reward: 19.96603616476059
# Episode 400: score: 29.0 - reward: 27.546603018045428
# Test Episode 400: test score: 9.0 - test reward: 8.403142538666724
# Episode 401: score: 28.0 - reward: 26.34924573227763
# Episode 402: score: 49.0 - reward: 46.78278542459011
# Episode 403: score: 17.0 - reward: 16.192763040959836
# Episode 404: score: 45.0 - reward: 42.56072981655598
# Episode 405: score: 14.0 - reward: 12.954648587107657
# Episode 406: score: 15.0 - reward: 14.248690498247745
# Episode 407: score: 15.0 - reward: 13.827086809277535
# Episode 408: score: 28.0 - reward: 25.91917995363474
# Episode 409: score: 32.0 - reward: 30.090431938320407
# Episode 410: score: 17.0 - reward: 16.05019273161888
# Test Episode 410: test score: 8.0 - test reward: 7.557472984492779
# Episode 411: score: 11.0 - reward: 10.255111175775527
# Episode 412: score: 15.0 - reward: 14.122302283346654
# Episode 413: score: 41.0 - reward: 37.61100630462169
# Episode 414: score: 29.0 - reward: 27.1642608448863
# Episode 415: score: 41.0 - reward: 38.91376389786601
# Episode 416: score: 26.0 - reward: 24.66885790377855
# Episode 417: score: 44.0 - reward: 41.11236118115483
# Episode 418: score: 14.0 - reward: 12.984908387064936
# Episode 419: score: 21.0 - reward: 19.664346939325334
# Episode 420: score: 19.0 - reward: 17.465278811752796
# Test Episode 420: test score: 8.0 - test reward: 7.429422453045846
# Episode 421: score: 21.0 - reward: 19.767845314741134
# Episode 422: score: 15.0 - reward: 14.150979681313038
# Episode 423: score: 20.0 - reward: 19.232256134971976
# Episode 424: score: 37.0 - reward: 35.18400334566832
# Episode 425: score: 24.0 - reward: 22.927729974687097
# Episode 426: score: 35.0 - reward: 33.52061667144298
# Episode 427: score: 33.0 - reward: 31.079826404154293
# Episode 428: score: 27.0 - reward: 25.762437786161897
# Episode 429: score: 13.0 - reward: 12.008220924437044
# Episode 430: score: 13.0 - reward: 12.237228153645994
# Test Episode 430: test score: 9.0 - test reward: 8.531896826624871
# Episode 431: score: 41.0 - reward: 39.57185894539579
# Episode 432: score: 13.0 - reward: 12.010925391316414
# Episode 433: score: 19.0 - reward: 17.99319075345993
# Episode 434: score: 9.0 - reward: 8.256475207209586
# Episode 435: score: 17.0 - reward: 15.940060152113434
# Episode 436: score: 36.0 - reward: 34.45934662148356
# Episode 437: score: 15.0 - reward: 14.3885710939765
# Episode 438: score: 27.0 - reward: 25.231890210509295
# Episode 439: score: 9.0 - reward: 8.40938031822443
# Episode 440: score: 23.0 - reward: 21.585608625411986
# Test Episode 440: test score: 9.0 - test reward: 8.527720859646799
# Episode 441: score: 35.0 - reward: 33.174310337007036
# Episode 442: score: 12.0 - reward: 11.167195092141627
# Episode 443: score: 11.0 - reward: 10.31255865395069
# Episode 444: score: 17.0 - reward: 16.369478937983512
# Episode 445: score: 14.0 - reward: 13.375371969491246
# Episode 446: score: 57.0 - reward: 51.22690806537867
# Episode 447: score: 11.0 - reward: 10.450146040320396
# Episode 448: score: 33.0 - reward: 30.949607475101942
# Episode 449: score: 24.0 - reward: 22.708211837708948
# Episode 450: score: 14.0 - reward: 13.119554645568131
# Test Episode 450: test score: 8.0 - test reward: 7.460303647816182
# Episode 451: score: 17.0 - reward: 15.687111236155035
# Episode 452: score: 9.0 - reward: 8.307939794659614
# Episode 453: score: 8.0 - reward: 7.548002696037292
# Episode 454: score: 8.0 - reward: 7.564684587717056
# Episode 455: score: 60.0 - reward: 52.89923616051673
# Episode 456: score: 10.0 - reward: 9.284075991809367
# Episode 457: score: 63.0 - reward: 60.416832259297365
# Episode 458: score: 23.0 - reward: 21.945313586294652
# Episode 459: score: 13.0 - reward: 12.188644517958165
# Episode 460: score: 27.0 - reward: 25.749531468749048
# Test Episode 460: test score: 9.0 - test reward: 8.555882619321345
# Episode 461: score: 28.0 - reward: 26.56554614342749
# Episode 462: score: 29.0 - reward: 27.331929526478056
# Episode 463: score: 12.0 - reward: 10.946459959447386
# Episode 464: score: 23.0 - reward: 21.393111273646355
# Episode 465: score: 12.0 - reward: 11.46250357106328
# Episode 466: score: 16.0 - reward: 15.109377045929433
# Episode 467: score: 16.0 - reward: 15.261909535527229
# Episode 468: score: 21.0 - reward: 19.64208950102329
# Episode 469: score: 13.0 - reward: 12.189176416397094
# Episode 470: score: 9.0 - reward: 8.439832130074501
# Test Episode 470: test score: 10.0 - test reward: 9.270100763440134
# Episode 471: score: 28.0 - reward: 26.241635622084143
# Episode 472: score: 26.0 - reward: 24.395140123367312
# Episode 473: score: 17.0 - reward: 15.860340557992457
# Episode 474: score: 27.0 - reward: 25.875408859550955
# Episode 475: score: 28.0 - reward: 26.756551763415334
# Episode 476: score: 10.0 - reward: 9.277108749747278
# Episode 477: score: 20.0 - reward: 19.152945328131313
# Episode 478: score: 25.0 - reward: 23.73509319722652
# Episode 479: score: 13.0 - reward: 12.536240897141395
# Episode 480: score: 27.0 - reward: 25.733585475012656
# Test Episode 480: test score: 11.0 - test reward: 10.339684022217988
# Episode 481: score: 15.0 - reward: 13.844851195812227
# Episode 482: score: 14.0 - reward: 13.206600320339202
# Episode 483: score: 35.0 - reward: 32.841851761937136
# Episode 484: score: 11.0 - reward: 10.044063967466355
# Episode 485: score: 23.0 - reward: 21.325815999507906
# Episode 486: score: 20.0 - reward: 18.901983448863028
# Episode 487: score: 16.0 - reward: 15.21466650366783
# Episode 488: score: 40.0 - reward: 38.19807940572501
# Episode 489: score: 20.0 - reward: 18.89431755542755
# Episode 490: score: 26.0 - reward: 24.916134838759902
# Test Episode 490: test score: 11.0 - test reward: 10.293957887589933
# Episode 491: score: 10.0 - reward: 9.41085102017969
# Episode 492: score: 9.0 - reward: 8.382000878453255
# Episode 493: score: 9.0 - reward: 8.511575435101985
# Episode 494: score: 9.0 - reward: 8.513011558353902
# Episode 495: score: 18.0 - reward: 17.236175421625372
# Episode 496: score: 17.0 - reward: 16.188930286467077
# Episode 497: score: 14.0 - reward: 13.370063908398153
# Episode 498: score: 24.0 - reward: 23.063256189227108
# Episode 499: score: 12.0 - reward: 11.24458705186844
# Episode 500: score: 26.0 - reward: 25.010790527611974
# Test Episode 500: test score: 9.0 - test reward: 8.502495679259301
# best test reward: 13.968546146154402
# Training with epsilon: 0.1, alpha: 0.001
# Run 1/1
# Episode 1: score: 11.0 - reward: 10.344011709094046
# Episode 2: score: 9.0 - reward: 8.367751559615135
# Episode 3: score: 11.0 - reward: 10.16655869334936
# Episode 4: score: 11.0 - reward: 10.343940916657447
# Episode 5: score: 10.0 - reward: 9.41221098601818
# Episode 6: score: 10.0 - reward: 9.429356655478477
# Episode 7: score: 9.0 - reward: 8.230997696518898
# Episode 8: score: 9.0 - reward: 8.513509736210109
# Episode 9: score: 11.0 - reward: 10.361714965105056
# Episode 10: score: 9.0 - reward: 8.407428803294897
# Test Episode 10: test score: 10.0 - test reward: 9.322417344152926
# New best test reward. Saving model
# Episode 11: score: 10.0 - reward: 9.33253826647997
# Episode 12: score: 9.0 - reward: 8.42867476940155
# Episode 13: score: 10.0 - reward: 9.498470766097308
# Episode 14: score: 13.0 - reward: 12.287687811255454
# Episode 15: score: 11.0 - reward: 10.504024629294873
# Episode 16: score: 12.0 - reward: 11.262710700929164
# Episode 17: score: 12.0 - reward: 11.32077894806862
# Episode 18: score: 10.0 - reward: 9.381799200177191
# Episode 19: score: 10.0 - reward: 9.422770312428474
# Episode 20: score: 10.0 - reward: 9.42950491011143
# Test Episode 20: test score: 9.0 - test reward: 8.473664819449185
# Episode 21: score: 9.0 - reward: 8.398048503696918
# Episode 22: score: 10.0 - reward: 9.213320264220238
# Episode 23: score: 12.0 - reward: 11.274624899029734
# Episode 24: score: 9.0 - reward: 8.45093397796154
# Episode 25: score: 14.0 - reward: 13.229064396023752
# Episode 26: score: 8.0 - reward: 7.387523359060287
# Episode 27: score: 10.0 - reward: 9.398783192038534
# Episode 28: score: 14.0 - reward: 12.947652614116668
# Episode 29: score: 11.0 - reward: 10.361996108293534
# Episode 30: score: 10.0 - reward: 9.4189128536731
# Test Episode 30: test score: 9.0 - test reward: 8.459950484335423
# Episode 31: score: 10.0 - reward: 9.461438561975957
# Episode 32: score: 15.0 - reward: 14.367800072208047
# Episode 33: score: 11.0 - reward: 10.352385239303112
# Episode 34: score: 11.0 - reward: 10.371851560473443
# Episode 35: score: 23.0 - reward: 22.00504932366312
# Episode 36: score: 9.0 - reward: 8.56424821317196
# Episode 37: score: 10.0 - reward: 9.404846490919589
# Episode 38: score: 9.0 - reward: 8.460128690302371
# Episode 39: score: 10.0 - reward: 9.459894818067552
# Episode 40: score: 10.0 - reward: 9.495380667597056
# Test Episode 40: test score: 11.0 - test reward: 10.41140502244234
# New best test reward. Saving model
# Episode 41: score: 10.0 - reward: 9.434656783193349
# Episode 42: score: 9.0 - reward: 8.495719915628433
# Episode 43: score: 10.0 - reward: 9.356337039172647
# Episode 44: score: 12.0 - reward: 11.071113477647303
# Episode 45: score: 9.0 - reward: 8.416698241233826
# Episode 46: score: 9.0 - reward: 8.495653913915156
# Episode 47: score: 9.0 - reward: 8.49743698835373
# Episode 48: score: 12.0 - reward: 11.325993705540894
# Episode 49: score: 13.0 - reward: 12.247756186872719
# Episode 50: score: 9.0 - reward: 8.449665486812593
# Test Episode 50: test score: 8.0 - test reward: 7.54522084891796
# Episode 51: score: 9.0 - reward: 8.219791400432587
# Episode 52: score: 10.0 - reward: 9.26637922525406
# Episode 53: score: 10.0 - reward: 9.442257779836655
# Episode 54: score: 13.0 - reward: 12.466553285159172
# Episode 55: score: 10.0 - reward: 9.450803233683109
# Episode 56: score: 11.0 - reward: 10.304655200615526
# Episode 57: score: 12.0 - reward: 11.197719579935075
# Episode 58: score: 11.0 - reward: 10.181580129265784
# Episode 59: score: 10.0 - reward: 9.48688845038414
# Episode 60: score: 10.0 - reward: 9.286099469661712
# Test Episode 60: test score: 11.0 - test reward: 10.314926871657372
# Episode 61: score: 10.0 - reward: 9.333036169409752
# Episode 62: score: 13.0 - reward: 12.297646463662385
# Episode 63: score: 9.0 - reward: 8.378136132657527
# Episode 64: score: 12.0 - reward: 11.155102363228798
# Episode 65: score: 16.0 - reward: 15.246668085455896
# Episode 66: score: 11.0 - reward: 10.427868565171957
# Episode 67: score: 9.0 - reward: 8.43582966774702
# Episode 68: score: 15.0 - reward: 14.280598488450051
# Episode 69: score: 9.0 - reward: 8.338334429264068
# Episode 70: score: 15.0 - reward: 14.31792986989021
# Test Episode 70: test score: 10.0 - test reward: 9.326801727712155
# Episode 71: score: 13.0 - reward: 12.380023552477361
# Episode 72: score: 15.0 - reward: 14.234489442408085
# Episode 73: score: 11.0 - reward: 10.170289623737334
# Episode 74: score: 11.0 - reward: 10.387932202219963
# Episode 75: score: 10.0 - reward: 9.297103197872637
# Episode 76: score: 12.0 - reward: 11.362053580582144
# Episode 77: score: 10.0 - reward: 9.412425638362764
# Episode 78: score: 12.0 - reward: 11.41188331320882
# Episode 79: score: 25.0 - reward: 23.2612675383687
# Episode 80: score: 10.0 - reward: 9.271252450346946
# Test Episode 80: test score: 14.0 - test reward: 13.22241472005844
# New best test reward. Saving model
# Episode 81: score: 17.0 - reward: 16.106745904684068
# Episode 82: score: 12.0 - reward: 11.32232200205326
# Episode 83: score: 15.0 - reward: 14.322474372386933
# Episode 84: score: 10.0 - reward: 9.394438604265451
# Episode 85: score: 20.0 - reward: 18.99542677178979
# Episode 86: score: 13.0 - reward: 12.29249511063099
# Episode 87: score: 17.0 - reward: 16.23159781396389
# Episode 88: score: 21.0 - reward: 20.282928670942784
# Episode 89: score: 14.0 - reward: 13.409083552658556
# Episode 90: score: 28.0 - reward: 25.923333718627692
# Test Episode 90: test score: 15.0 - test reward: 14.290975107997655
# New best test reward. Saving model
# Episode 91: score: 24.0 - reward: 22.313042436540126
# Episode 92: score: 29.0 - reward: 27.937753146886823
# Episode 93: score: 27.0 - reward: 26.07328995913267
# Episode 94: score: 21.0 - reward: 20.131116512417794
# Episode 95: score: 28.0 - reward: 26.489622769877318
# Episode 96: score: 12.0 - reward: 11.273708851635456
# Episode 97: score: 15.0 - reward: 14.16795173883438
# Episode 98: score: 21.0 - reward: 19.490676033496857
# Episode 99: score: 31.0 - reward: 29.200748310983183
# Episode 100: score: 17.0 - reward: 16.192362225055696
# Test Episode 100: test score: 14.0 - test reward: 13.27624040991068
# Episode 101: score: 21.0 - reward: 19.991502568125725
# Episode 102: score: 11.0 - reward: 10.258515724539755
# Episode 103: score: 20.0 - reward: 18.803733942657715
# Episode 104: score: 15.0 - reward: 13.724349570274354
# Episode 105: score: 29.0 - reward: 27.175826491415506
# Episode 106: score: 13.0 - reward: 12.089326407015326
# Episode 107: score: 17.0 - reward: 15.689146080613137
# Episode 108: score: 20.0 - reward: 18.500851106643676
# Episode 109: score: 17.0 - reward: 15.741624477505681
# Episode 110: score: 16.0 - reward: 14.64672757387161
# Test Episode 110: test score: 15.0 - test reward: 14.005410890281198
# Episode 111: score: 16.0 - reward: 15.034011927247047
# Episode 112: score: 24.0 - reward: 22.189913077652452
# Episode 113: score: 27.0 - reward: 24.778689262270927
# Episode 114: score: 10.0 - reward: 9.279678156971931
# Episode 115: score: 19.0 - reward: 17.953331050276756
# Episode 116: score: 18.0 - reward: 16.723806929588317
# Episode 117: score: 21.0 - reward: 19.68538475930691
# Episode 118: score: 18.0 - reward: 16.99829254001379
# Episode 119: score: 17.0 - reward: 15.918689964711666
# Episode 120: score: 29.0 - reward: 27.383586103469124
# Test Episode 120: test score: 22.0 - test reward: 20.596942151710387
# New best test reward. Saving model
# Episode 121: score: 24.0 - reward: 22.065100617706776
# Episode 122: score: 24.0 - reward: 22.44757817238569
# Episode 123: score: 25.0 - reward: 23.16908348947763
# Episode 124: score: 31.0 - reward: 29.540200325846673
# Episode 125: score: 20.0 - reward: 18.606353315711022
# Episode 126: score: 25.0 - reward: 23.23229619078338
# Episode 127: score: 30.0 - reward: 27.594643549621104
# Episode 128: score: 19.0 - reward: 17.505197264254093
# Episode 129: score: 15.0 - reward: 14.00905139669776
# Episode 130: score: 30.0 - reward: 28.307516859471797
# Test Episode 130: test score: 36.0 - test reward: 34.16675321459769
# New best test reward. Saving model
# Episode 131: score: 54.0 - reward: 49.519842794537546
# Episode 132: score: 42.0 - reward: 40.1572914486751
# Episode 133: score: 35.0 - reward: 32.683499838411805
# Episode 134: score: 19.0 - reward: 17.71255371365696
# Episode 135: score: 32.0 - reward: 30.46873266622424
# Episode 136: score: 17.0 - reward: 15.658612430095673
# Episode 137: score: 35.0 - reward: 33.17575140744447
# Episode 138: score: 164.0 - reward: 116.50563150197259
# Episode 139: score: 27.0 - reward: 25.67022721022367
# Episode 140: score: 104.0 - reward: 91.33110108077524
# Test Episode 140: test score: 17.0 - test reward: 16.036464005708694
# Episode 141: score: 27.0 - reward: 25.6083031821996
# Episode 142: score: 34.0 - reward: 32.43981421291828
# Episode 143: score: 78.0 - reward: 69.52609307765961
# Episode 144: score: 32.0 - reward: 30.02178043872118
# Episode 145: score: 20.0 - reward: 18.76848070807755
# Episode 146: score: 116.0 - reward: 82.70752954781055
# Episode 147: score: 33.0 - reward: 31.2114167522639
# Episode 148: score: 20.0 - reward: 18.605426079034807
# Episode 149: score: 51.0 - reward: 48.559678301215165
# Episode 150: score: 30.0 - reward: 27.614504934847353
# Test Episode 150: test score: 19.0 - test reward: 17.858829988539217
# Episode 151: score: 64.0 - reward: 59.05685141980647
# Episode 152: score: 15.0 - reward: 13.965760943293569
# Episode 153: score: 14.0 - reward: 13.218606004305183
# Episode 154: score: 28.0 - reward: 26.469280804693707
# Episode 155: score: 57.0 - reward: 54.36004892718048
# Episode 156: score: 32.0 - reward: 29.606077598035338
# Episode 157: score: 36.0 - reward: 34.338171592354776
# Episode 158: score: 128.0 - reward: 105.21290126740928
# Episode 159: score: 33.0 - reward: 31.51118067204952
# Episode 160: score: 22.0 - reward: 20.863530546426773
# Test Episode 160: test score: 26.0 - test reward: 24.593025881052018
# Episode 161: score: 33.0 - reward: 31.318851278722285
# Episode 162: score: 25.0 - reward: 23.66746651232243
# Episode 163: score: 105.0 - reward: 90.22618167400357
# Episode 164: score: 32.0 - reward: 29.87798671871424
# Episode 165: score: 27.0 - reward: 25.592354629933837
# Episode 166: score: 88.0 - reward: 82.01056061685087
# Episode 167: score: 23.0 - reward: 22.082982875406742
# Episode 168: score: 55.0 - reward: 50.15591596961023
# Episode 169: score: 36.0 - reward: 34.05162435714155
# Episode 170: score: 38.0 - reward: 35.43295305967331
# Test Episode 170: test score: 42.0 - test reward: 39.555014112591735
# New best test reward. Saving model
# Episode 171: score: 54.0 - reward: 50.63767050206663
# Episode 172: score: 60.0 - reward: 56.600362778827545
# Episode 173: score: 65.0 - reward: 57.809095516800866
# Episode 174: score: 91.0 - reward: 82.49446727782487
# Episode 175: score: 91.0 - reward: 84.15014590676877
# Episode 176: score: 22.0 - reward: 20.864215341210368
# Episode 177: score: 62.0 - reward: 58.043297898769374
# Episode 178: score: 113.0 - reward: 100.11795775517825
# Episode 179: score: 38.0 - reward: 36.43726346641779
# Episode 180: score: 42.0 - reward: 40.2661947801709
# Test Episode 180: test score: 50.0 - test reward: 47.95195833258331
# New best test reward. Saving model
# Episode 181: score: 38.0 - reward: 36.309246986359355
# Episode 182: score: 74.0 - reward: 70.90368290049956
# Episode 183: score: 32.0 - reward: 30.213540822267532
# Episode 184: score: 35.0 - reward: 33.70956149473786
# Episode 185: score: 41.0 - reward: 39.21463048756122
# Episode 186: score: 79.0 - reward: 74.0969617956318
# Episode 187: score: 35.0 - reward: 32.79791671931743
# Episode 188: score: 96.0 - reward: 85.28846243470909
# Episode 189: score: 35.0 - reward: 32.94261416494846
# Episode 190: score: 53.0 - reward: 51.04467510730027
# Test Episode 190: test score: 42.0 - test reward: 40.518391062319274
# Episode 191: score: 126.0 - reward: 99.45830014944075
# Episode 192: score: 151.0 - reward: 98.89027088880539
# Episode 193: score: 84.0 - reward: 77.08166850730777
# Episode 194: score: 70.0 - reward: 67.32477556057273
# Episode 195: score: 51.0 - reward: 49.437287365086384
# Episode 196: score: 57.0 - reward: 54.27110126912596
# Episode 197: score: 52.0 - reward: 49.352311719767755
# Episode 198: score: 40.0 - reward: 37.76773535460233
# Episode 199: score: 35.0 - reward: 33.73155034482479
# Episode 200: score: 54.0 - reward: 51.61916937604547
# Test Episode 200: test score: 74.0 - test reward: 71.48038650229573
# New best test reward. Saving model
# Episode 201: score: 39.0 - reward: 36.89576754420996
# Episode 202: score: 58.0 - reward: 55.15337276756763
# Episode 203: score: 89.0 - reward: 73.74238557964561
# Episode 204: score: 26.0 - reward: 24.190225502848627
# Episode 205: score: 57.0 - reward: 54.17768414169551
# Episode 206: score: 98.0 - reward: 83.69055538177493
# Episode 207: score: 135.0 - reward: 122.84570431457834
# Episode 208: score: 28.0 - reward: 26.86853891015053
# Episode 209: score: 125.0 - reward: 119.97443501651293
# Episode 210: score: 46.0 - reward: 43.57458650767802
# Test Episode 210: test score: 60.0 - test reward: 58.66732665225865
# Episode 211: score: 96.0 - reward: 85.39028925076127
# Episode 212: score: 16.0 - reward: 15.078886258602141
# Episode 213: score: 52.0 - reward: 47.62513619065285
# Episode 214: score: 52.0 - reward: 49.87291657589377
# Episode 215: score: 45.0 - reward: 43.22321272864937
# Episode 216: score: 76.0 - reward: 66.86573935002089
# Episode 217: score: 35.0 - reward: 33.01362438201904
# Episode 218: score: 51.0 - reward: 49.43710132986309
# Episode 219: score: 42.0 - reward: 40.03761552870273
# Episode 220: score: 85.0 - reward: 76.51515769846739
# Test Episode 220: test score: 41.0 - test reward: 39.16437620520591
# Episode 221: score: 34.0 - reward: 32.55130438953638
# Episode 222: score: 46.0 - reward: 44.65813276842237
# Episode 223: score: 49.0 - reward: 47.24293877780436
# Episode 224: score: 56.0 - reward: 50.93793895691635
# Episode 225: score: 48.0 - reward: 46.07666177600621
# Episode 226: score: 113.0 - reward: 104.76735034361486
# Episode 227: score: 36.0 - reward: 33.90561997815966
# Episode 228: score: 40.0 - reward: 38.36398492120207
# Episode 229: score: 36.0 - reward: 34.011425092816346
# Episode 230: score: 30.0 - reward: 28.678488241136076
# Test Episode 230: test score: 27.0 - test reward: 25.701568615436546
# Episode 231: score: 104.0 - reward: 74.69394902884957
# Episode 232: score: 49.0 - reward: 46.517929775267845
# Episode 233: score: 24.0 - reward: 22.589694896340372
# Episode 234: score: 103.0 - reward: 94.52108590044082
# Episode 235: score: 29.0 - reward: 27.521763221174474
# Episode 236: score: 34.0 - reward: 32.282082000002255
# Episode 237: score: 26.0 - reward: 24.36005708128214
# Episode 238: score: 39.0 - reward: 36.86644720435142
# Episode 239: score: 83.0 - reward: 78.72419107556343
# Episode 240: score: 90.0 - reward: 81.51000732630493
# Test Episode 240: test score: 70.0 - test reward: 67.09819432422518
# Episode 241: score: 214.0 - reward: 153.76329139173015
# Episode 242: score: 33.0 - reward: 31.18827697783709
# Episode 243: score: 18.0 - reward: 17.04525381028652
# Episode 244: score: 20.0 - reward: 19.1203781157732
# Episode 245: score: 22.0 - reward: 20.76126666814089
# Episode 246: score: 16.0 - reward: 15.121166718006135
# Episode 247: score: 45.0 - reward: 43.43121947534383
# Episode 248: score: 203.0 - reward: 159.00269852280613
# Episode 249: score: 41.0 - reward: 39.369703467935324
# Episode 250: score: 26.0 - reward: 24.656954175233842
# Test Episode 250: test score: 14.0 - test reward: 13.096013712137937
# Episode 251: score: 40.0 - reward: 38.01743273511529
# Episode 252: score: 28.0 - reward: 26.560116684436803
# Episode 253: score: 58.0 - reward: 52.99341061636806
# Episode 254: score: 89.0 - reward: 85.70671982830392
# Episode 255: score: 49.0 - reward: 45.422368717193606
# Episode 256: score: 131.0 - reward: 107.05609581470489
# Episode 257: score: 66.0 - reward: 62.52594608105716
# Episode 258: score: 36.0 - reward: 34.30578950047494
# Episode 259: score: 48.0 - reward: 45.7381324082613
# Episode 260: score: 36.0 - reward: 34.51349604949355
# Test Episode 260: test score: 47.0 - test reward: 45.13562183976175
# Episode 261: score: 105.0 - reward: 101.06006431877616
# Episode 262: score: 90.0 - reward: 77.79965343587101
# Episode 263: score: 63.0 - reward: 61.21162937022744
# Episode 264: score: 24.0 - reward: 22.91545220613479
# Episode 265: score: 22.0 - reward: 20.72286147773266
# Episode 266: score: 29.0 - reward: 27.756850887835025
# Episode 267: score: 25.0 - reward: 23.841803365945815
# Episode 268: score: 29.0 - reward: 27.272821503877644
# Episode 269: score: 98.0 - reward: 90.54273658283054
# Episode 270: score: 48.0 - reward: 42.95297417342663
# Test Episode 270: test score: 34.0 - test reward: 32.298282021284095
# Episode 271: score: 51.0 - reward: 48.976470267772676
# Episode 272: score: 31.0 - reward: 29.6711277462542
# Episode 273: score: 68.0 - reward: 64.78834063783289
# Episode 274: score: 22.0 - reward: 20.972713078558442
# Episode 275: score: 74.0 - reward: 68.6858663581312
# Episode 276: score: 51.0 - reward: 49.05479813665152
# Episode 277: score: 24.0 - reward: 22.590999855846164
# Episode 278: score: 29.0 - reward: 27.718555790185928
# Episode 279: score: 114.0 - reward: 92.57957584708927
# Episode 280: score: 62.0 - reward: 58.82611794769764
# Test Episode 280: test score: 15.0 - test reward: 13.785585746169092
# Episode 281: score: 32.0 - reward: 30.12496200799943
# Episode 282: score: 24.0 - reward: 22.452391478419308
# Episode 283: score: 41.0 - reward: 39.49709347374736
# Episode 284: score: 27.0 - reward: 25.937470780313017
# Episode 285: score: 94.0 - reward: 82.3350492864847
# Episode 286: score: 44.0 - reward: 41.951593135297294
# Episode 287: score: 18.0 - reward: 17.010586583614348
# Episode 288: score: 23.0 - reward: 21.952528087794782
# Episode 289: score: 43.0 - reward: 41.48133262395858
# Episode 290: score: 85.0 - reward: 80.5136291541159
# Test Episode 290: test score: 22.0 - test reward: 20.952680807560682
# Episode 291: score: 49.0 - reward: 46.496699894964706
# Episode 292: score: 27.0 - reward: 25.63383811414242
# Episode 293: score: 130.0 - reward: 99.53649392277003
# Episode 294: score: 61.0 - reward: 57.46375345811247
# Episode 295: score: 103.0 - reward: 68.24748380482198
# Episode 296: score: 35.0 - reward: 33.10669793784618
# Episode 297: score: 27.0 - reward: 25.51790092140436
# Episode 298: score: 47.0 - reward: 43.8612821727991
# Episode 299: score: 71.0 - reward: 62.3662664949894
# Episode 300: score: 103.0 - reward: 84.32357720322904
# Test Episode 300: test score: 61.0 - test reward: 57.39435653686526
# Episode 301: score: 85.0 - reward: 77.79842678084968
# Episode 302: score: 43.0 - reward: 40.51329731345176
# Episode 303: score: 161.0 - reward: 150.70068564899267
# Episode 304: score: 79.0 - reward: 76.60339066423475
# Episode 305: score: 103.0 - reward: 92.98519234508281
# Episode 306: score: 51.0 - reward: 49.138018236309286
# Episode 307: score: 101.0 - reward: 85.88529302328821
# Episode 308: score: 50.0 - reward: 48.59912131018937
# Episode 309: score: 66.0 - reward: 59.83928027153015
# Episode 310: score: 71.0 - reward: 69.10674957931042
# Test Episode 310: test score: 35.0 - test reward: 33.35512119233607
# Episode 311: score: 94.0 - reward: 83.58982209563254
# Episode 312: score: 40.0 - reward: 38.62973291426896
# Episode 313: score: 52.0 - reward: 49.87452849373221
# ...
# Episode 239: score: 18.0 - reward: 16.990954279899597
# Episode 240: score: 56.0 - reward: 52.93720719739794
# Test Episode 240: test score: 15.0 - test reward: 13.816151264309886
# Episode 241: score: 25.0 - reward: 23.607369926385577
# Episode 242: score: 62.0 - reward: 57.80168288797142
# Episode 243: score: 65.0 - reward: 62.366929032281014
# Episode 244: score: 28.0 - reward: 26.452991184592246
# Episode 245: score: 134.0 - reward: 123.12337630018587
# Episode 246: score: 16.0 - reward: 15.039919394254683
# Episode 247: score: 32.0 - reward: 30.066014008969074
# Episode 248: score: 31.0 - reward: 29.025452896952636
# Episode 249: score: 37.0 - reward: 34.56150555312634
# Episode 250: score: 37.0 - reward: 35.09065500497818
# Test Episode 250: test score: 46.0 - test reward: 43.832548724859954
# Episode 251: score: 66.0 - reward: 64.06295503433792
# Episode 252: score: 64.0 - reward: 60.58998048380019
# Episode 253: score: 30.0 - reward: 27.89152436852455
# Episode 254: score: 34.0 - reward: 31.44871617257595
# Episode 255: score: 46.0 - reward: 42.86460873484612
# Episode 256: score: 33.0 - reward: 30.708045202493658
# Episode 257: score: 27.0 - reward: 25.060662478208542
# Episode 258: score: 13.0 - reward: 12.244230973720551
# Episode 259: score: 31.0 - reward: 28.53733828514814
# Episode 260: score: 42.0 - reward: 39.68201435506344
# Test Episode 260: test score: 40.0 - test reward: 38.13121052235364
# Episode 261: score: 47.0 - reward: 43.834405706822864
# Episode 262: score: 36.0 - reward: 34.118918769061565
# Episode 263: score: 27.0 - reward: 25.236057692766195
# Episode 264: score: 17.0 - reward: 15.539114382863046
# Episode 265: score: 40.0 - reward: 36.86475323438644
# Episode 266: score: 42.0 - reward: 39.09728676378726
# Episode 267: score: 13.0 - reward: 12.095289787650106
# Episode 268: score: 24.0 - reward: 22.431754176318645
# Episode 269: score: 78.0 - reward: 72.49968332946301
# Episode 270: score: 31.0 - reward: 29.091422549262646
# Test Episode 270: test score: 18.0 - test reward: 16.560537678003314
# Episode 271: score: 33.0 - reward: 30.66466250419617
# Episode 272: score: 63.0 - reward: 59.787736245244744
# Episode 273: score: 40.0 - reward: 37.90586448237301
# Episode 274: score: 31.0 - reward: 29.298474432528025
# Episode 275: score: 48.0 - reward: 44.04672098159791
# Episode 276: score: 39.0 - reward: 36.4359823346138
# Episode 277: score: 50.0 - reward: 47.60727646797895
# Episode 278: score: 44.0 - reward: 41.25348939597606
# Episode 279: score: 37.0 - reward: 35.02953948453068
# Episode 280: score: 28.0 - reward: 26.80883693024516
# Test Episode 280: test score: 46.0 - test reward: 43.91922062337398
# Episode 281: score: 55.0 - reward: 51.565070746839055
# Episode 282: score: 43.0 - reward: 40.17853262796998
# Episode 283: score: 31.0 - reward: 28.724148342013358
# Episode 284: score: 21.0 - reward: 19.89865725636482
# Episode 285: score: 30.0 - reward: 28.184710059314966
# Episode 286: score: 44.0 - reward: 42.2722527205944
# Episode 287: score: 52.0 - reward: 49.8841286920011
# Episode 288: score: 43.0 - reward: 40.83042638897895
# Episode 289: score: 18.0 - reward: 16.917033308744433
# Episode 290: score: 33.0 - reward: 30.764890727400783
# Test Episode 290: test score: 34.0 - test reward: 31.792120170593268
# Episode 291: score: 32.0 - reward: 30.32561743557453
# Episode 292: score: 28.0 - reward: 26.730854135937985
# Episode 293: score: 45.0 - reward: 42.52114189565183
# Episode 294: score: 54.0 - reward: 51.55431831777095
# Episode 295: score: 25.0 - reward: 23.0712915122509
# Episode 296: score: 37.0 - reward: 35.283591750264165
# Episode 297: score: 57.0 - reward: 55.11394811719654
# Episode 298: score: 60.0 - reward: 58.23378241993487
# Episode 299: score: 47.0 - reward: 44.33824991807343
# Episode 300: score: 71.0 - reward: 66.45625968575477
# Test Episode 300: test score: 14.0 - test reward: 13.04700206592679
# Episode 301: score: 39.0 - reward: 36.88621013164521
# Episode 302: score: 65.0 - reward: 60.65761505961418
# Episode 303: score: 20.0 - reward: 18.775966140627858
# Episode 304: score: 75.0 - reward: 67.80202870443463
# Episode 305: score: 42.0 - reward: 39.30903071388602
# Episode 306: score: 27.0 - reward: 25.61886106729508
# Episode 307: score: 58.0 - reward: 55.55711609125136
# Episode 308: score: 42.0 - reward: 40.83970147632062
# Episode 309: score: 45.0 - reward: 42.69221150316297
# Episode 310: score: 100.0 - reward: 96.96435020714995
# Test Episode 310: test score: 72.0 - test reward: 69.92660217732191
# New best test reward. Saving model
# Episode 311: score: 70.0 - reward: 67.24891149103642
# Episode 312: score: 37.0 - reward: 34.65954001545906
# Episode 313: score: 61.0 - reward: 58.16366089964285
# Episode 314: score: 38.0 - reward: 35.70845999121666
# Episode 315: score: 44.0 - reward: 41.978986619412915
# Episode 316: score: 37.0 - reward: 35.43933047652244
# Episode 317: score: 62.0 - reward: 58.598645652830605
# Episode 318: score: 37.0 - reward: 34.99226906448604
# Episode 319: score: 61.0 - reward: 57.89347544340415
# Episode 320: score: 33.0 - reward: 30.162365606427194
# Test Episode 320: test score: 22.0 - test reward: 20.10579232722521
# Episode 321: score: 24.0 - reward: 22.731364853680134
# Episode 322: score: 33.0 - reward: 31.461062306165694
# Episode 323: score: 73.0 - reward: 70.40816290564834
# Episode 324: score: 33.0 - reward: 30.52525211721659
# Episode 325: score: 70.0 - reward: 67.25850140303372
# Episode 326: score: 36.0 - reward: 33.973104044795036
# Episode 327: score: 89.0 - reward: 83.14916431605816
# Episode 328: score: 36.0 - reward: 33.40496409386397
# Episode 329: score: 29.0 - reward: 27.685573500394813
# Episode 330: score: 46.0 - reward: 44.17596329115331
# Test Episode 330: test score: 51.0 - test reward: 48.768927834555505
# Episode 331: score: 23.0 - reward: 21.813843860104672
# Episode 332: score: 21.0 - reward: 20.049205082654954
# Episode 333: score: 41.0 - reward: 38.66037230938673
# Episode 334: score: 21.0 - reward: 19.812981684505942
# Episode 335: score: 27.0 - reward: 25.385747384279966
# Episode 336: score: 49.0 - reward: 46.246116743236776
# Episode 337: score: 31.0 - reward: 29.54219863712788
# Episode 338: score: 28.0 - reward: 26.568314921855926
# Episode 339: score: 13.0 - reward: 12.272648465633392
# Episode 340: score: 48.0 - reward: 44.690477790683516
# Test Episode 340: test score: 38.0 - test reward: 35.35496934577823
# Episode 341: score: 11.0 - reward: 10.275636269897223
# Episode 342: score: 34.0 - reward: 31.793117340654142
# Episode 343: score: 14.0 - reward: 13.062115067243576
# Episode 344: score: 90.0 - reward: 86.89481262639164
# Episode 345: score: 21.0 - reward: 20.02754498161375
# Episode 346: score: 45.0 - reward: 41.585848429799064
# Episode 347: score: 60.0 - reward: 57.58598908409477
# Episode 348: score: 44.0 - reward: 41.51646102219818
# Episode 349: score: 35.0 - reward: 33.49056764766574
# Episode 350: score: 25.0 - reward: 23.096542352437975
# Test Episode 350: test score: 13.0 - test reward: 12.27667405754328
# Episode 351: score: 39.0 - reward: 37.100465299189096
# Episode 352: score: 14.0 - reward: 12.715139496326444
# Episode 353: score: 53.0 - reward: 49.907245340943355
# Episode 354: score: 26.0 - reward: 24.94648537933826
# Episode 355: score: 43.0 - reward: 40.75325145311654
# Episode 356: score: 81.0 - reward: 72.12907901704311
# Episode 357: score: 26.0 - reward: 24.65143806040287
# Episode 358: score: 26.0 - reward: 24.331081666052334
# Episode 359: score: 38.0 - reward: 36.076118636876345
# Episode 360: score: 13.0 - reward: 11.941955387592314
# Test Episode 360: test score: 13.0 - test reward: 12.080473406612874
# Episode 361: score: 50.0 - reward: 46.80881597995758
# Episode 362: score: 41.0 - reward: 38.504935019463296
# Episode 363: score: 13.0 - reward: 12.179837769269943
# Episode 364: score: 19.0 - reward: 17.56621925383806
# Episode 365: score: 16.0 - reward: 15.109029179811479
# Episode 366: score: 28.0 - reward: 26.49906966648996
# Episode 367: score: 36.0 - reward: 34.59908780641854
# Episode 368: score: 26.0 - reward: 24.310351672768594
# Episode 369: score: 36.0 - reward: 33.431806621700524
# Episode 370: score: 37.0 - reward: 35.229727338254456
# Test Episode 370: test score: 36.0 - test reward: 34.25925216078758
# Episode 371: score: 30.0 - reward: 28.620655948668723
# Episode 372: score: 22.0 - reward: 20.81068643331528
# Episode 373: score: 14.0 - reward: 13.163601283729076
# Episode 374: score: 41.0 - reward: 38.60881110578776
# Episode 375: score: 34.0 - reward: 31.384558211266985
# Episode 376: score: 29.0 - reward: 27.05768177807331
# Episode 377: score: 66.0 - reward: 63.21348647624254
# Episode 378: score: 40.0 - reward: 37.617731991410245
# Episode 379: score: 55.0 - reward: 51.94413839429618
# Episode 380: score: 43.0 - reward: 40.575727996230135
# Test Episode 380: test score: 72.0 - test reward: 69.84761041663586
# Episode 381: score: 37.0 - reward: 34.902008107304574
# Episode 382: score: 20.0 - reward: 18.986533810198306
# Episode 383: score: 17.0 - reward: 16.18550516963005
# Episode 384: score: 12.0 - reward: 11.283835738897324
# Episode 385: score: 18.0 - reward: 17.177562428638335
# Episode 386: score: 27.0 - reward: 25.234556866995995
# Episode 387: score: 16.0 - reward: 14.970467704534533
# Episode 388: score: 34.0 - reward: 31.368221640586846
# Episode 389: score: 17.0 - reward: 15.834313639998435
# Episode 390: score: 16.0 - reward: 15.116087086498736
# Test Episode 390: test score: 34.0 - test reward: 31.113159063458436
# Episode 391: score: 18.0 - reward: 17.097339425981048
# Episode 392: score: 45.0 - reward: 42.77817941792309
# Episode 393: score: 46.0 - reward: 42.833491347730174
# Episode 394: score: 42.0 - reward: 39.63990475684405
# Episode 395: score: 36.0 - reward: 34.242567364871505
# Episode 396: score: 31.0 - reward: 29.437420960515738
# Episode 397: score: 39.0 - reward: 36.7371898420155
# Episode 398: score: 12.0 - reward: 11.177299307659267
# Episode 399: score: 12.0 - reward: 11.126256307959554
# Episode 400: score: 18.0 - reward: 16.943022365868092
# Test Episode 400: test score: 11.0 - test reward: 10.29397992193699
# Episode 401: score: 38.0 - reward: 34.875090458244095
# Episode 402: score: 33.0 - reward: 30.801255482435224
# Episode 403: score: 13.0 - reward: 12.215976130217312
# Episode 404: score: 10.0 - reward: 9.165847727656363
# Episode 405: score: 13.0 - reward: 11.937420988082886
# Episode 406: score: 16.0 - reward: 14.68962155729532
# Episode 407: score: 13.0 - reward: 12.196294752508402
# Episode 408: score: 13.0 - reward: 12.0413564234972
# Episode 409: score: 17.0 - reward: 15.658208896964789
# Episode 410: score: 18.0 - reward: 17.15632589161396
# Test Episode 410: test score: 14.0 - test reward: 12.882671925425528
# Episode 411: score: 28.0 - reward: 25.91986084282398
# Episode 412: score: 16.0 - reward: 14.696436047554016
# Episode 413: score: 13.0 - reward: 12.267055903375148
# Episode 414: score: 13.0 - reward: 12.120307835936547
# Episode 415: score: 33.0 - reward: 30.97840835154057
# Episode 416: score: 22.0 - reward: 20.522001688182357
# Episode 417: score: 9.0 - reward: 8.460536321997642
# Episode 418: score: 12.0 - reward: 11.250378071051092
# Episode 419: score: 13.0 - reward: 12.16920591890812
# Episode 420: score: 18.0 - reward: 16.776813126169145
# Test Episode 420: test score: 13.0 - test reward: 12.227485998347403
# Episode 421: score: 12.0 - reward: 11.23440013974905
# Episode 422: score: 20.0 - reward: 18.76738595068455
# Episode 423: score: 10.0 - reward: 9.143658757209778
# Episode 424: score: 13.0 - reward: 12.249715751409529
# Episode 425: score: 15.0 - reward: 13.779765895009042
# Episode 426: score: 11.0 - reward: 10.186391286551954
# Episode 427: score: 15.0 - reward: 14.154109856486322
# Episode 428: score: 34.0 - reward: 31.517242720723154
# Episode 429: score: 11.0 - reward: 10.309965057671072
# Episode 430: score: 13.0 - reward: 12.01587311476469
# Test Episode 430: test score: 16.0 - test reward: 14.987729954719544
# Episode 431: score: 13.0 - reward: 12.184988796710968
# Episode 432: score: 14.0 - reward: 13.32499036192894
# Episode 433: score: 11.0 - reward: 10.314520019292832
# Episode 434: score: 19.0 - reward: 17.643076033890242
# Episode 435: score: 39.0 - reward: 36.26723803281783
# Episode 436: score: 16.0 - reward: 15.064125230908392
# Episode 437: score: 44.0 - reward: 41.40906918346884
# Episode 438: score: 27.0 - reward: 25.328806516528132
# Episode 439: score: 21.0 - reward: 19.7647795855999
# Episode 440: score: 33.0 - reward: 30.547805452346797
# Test Episode 440: test score: 33.0 - test reward: 30.712965867668395
# Episode 441: score: 12.0 - reward: 11.270702983438968
# Episode 442: score: 31.0 - reward: 29.37703213393688
# Episode 443: score: 29.0 - reward: 26.717852461338047
# Episode 444: score: 41.0 - reward: 38.48370046317577
# Episode 445: score: 49.0 - reward: 46.370968601107606
# Episode 446: score: 32.0 - reward: 30.417137121409176
# Episode 447: score: 44.0 - reward: 40.745160138607034
# Episode 448: score: 33.0 - reward: 30.956851408258082
# Episode 449: score: 11.0 - reward: 10.37200665473938
# Episode 450: score: 28.0 - reward: 25.99668416678906
# Test Episode 450: test score: 13.0 - test reward: 12.297821456193924
# Episode 451: score: 28.0 - reward: 26.18565470576286
# Episode 452: score: 27.0 - reward: 25.323500517010682
# Episode 453: score: 11.0 - reward: 10.39356873780489
# Episode 454: score: 29.0 - reward: 27.027830324694516
# Episode 455: score: 34.0 - reward: 32.547848862409595
# Episode 456: score: 53.0 - reward: 50.171782910823815
# Episode 457: score: 12.0 - reward: 11.206106102466585
# Episode 458: score: 34.0 - reward: 31.5707609385252
# Episode 459: score: 22.0 - reward: 20.50860045216978
# Episode 460: score: 34.0 - reward: 32.08570123314857
# Test Episode 460: test score: 14.0 - test reward: 13.126112021505834
# Episode 461: score: 44.0 - reward: 42.418454718030986
# Episode 462: score: 36.0 - reward: 33.83270584791899
# Episode 463: score: 69.0 - reward: 65.06807991564271
# Episode 464: score: 18.0 - reward: 16.927644763886928
# Episode 465: score: 33.0 - reward: 30.793682667613034
# Episode 466: score: 31.0 - reward: 29.364850495755675
# Episode 467: score: 105.0 - reward: 100.95384169071913
# Episode 468: score: 43.0 - reward: 40.30263273119926
# Episode 469: score: 42.0 - reward: 39.20297609865665
# Episode 470: score: 26.0 - reward: 24.646953371167182
# Test Episode 470: test score: 50.0 - test reward: 47.70977481380106
# Episode 471: score: 50.0 - reward: 48.30557815991341
# Episode 472: score: 64.0 - reward: 62.050111732818195
# Episode 473: score: 38.0 - reward: 35.39082310199738
# Episode 474: score: 91.0 - reward: 87.0885562501848
# Episode 475: score: 45.0 - reward: 43.227748692035675
# Episode 476: score: 105.0 - reward: 92.7840130791068
# Episode 477: score: 68.0 - reward: 61.44320189356806
# Episode 478: score: 21.0 - reward: 20.065004013478756
# Episode 479: score: 29.0 - reward: 27.05794671922922
# Episode 480: score: 74.0 - reward: 65.77446760684252
# Test Episode 480: test score: 34.0 - test reward: 32.06692673824728
# Episode 481: score: 19.0 - reward: 17.696660541743036
# Episode 482: score: 47.0 - reward: 44.55970078296959
# Episode 483: score: 27.0 - reward: 25.753874248266225
# Episode 484: score: 52.0 - reward: 49.62801681607962
# Episode 485: score: 133.0 - reward: 112.72136688232422
# Episode 486: score: 16.0 - reward: 14.772133082151413
# Episode 487: score: 43.0 - reward: 40.85434158593416
# Episode 488: score: 26.0 - reward: 24.578750742226845
# Episode 489: score: 44.0 - reward: 41.82867664489895
# Episode 490: score: 32.0 - reward: 30.345796708762645
# Test Episode 490: test score: 45.0 - test reward: 43.017260369658466
# Episode 491: score: 32.0 - reward: 30.11784324347972
# Episode 492: score: 33.0 - reward: 31.05267958045006
# Episode 493: score: 42.0 - reward: 39.37149992818013
# Episode 494: score: 31.0 - reward: 29.818891489505766
# Episode 495: score: 43.0 - reward: 40.641682694479826
# Episode 496: score: 66.0 - reward: 62.890858922898765
# Episode 497: score: 26.0 - reward: 24.663822966814045
# Episode 498: score: 41.0 - reward: 39.154279532656076
# Episode 499: score: 39.0 - reward: 36.42438345775009
# Episode 500: score: 39.0 - reward: 36.688164916634555
# Test Episode 500: test score: 35.0 - test reward: 32.720412147045145
# best test reward: 69.92660217732191
# Rewards data saved to example_data.pkl

# %%
plot_rewards(rewards_data, algorithm_name="DDQN (TC CartPole)")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
