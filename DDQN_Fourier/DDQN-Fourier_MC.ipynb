# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import gym
from collections import deque
import random
import itertools
from torch import nn
from torch.nn import functional
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

import pickle

def save_rewards_data(rewards_data, filename='rewards_data.pkl'):
    """Save the rewards data to a pickle file."""
    with open(filename, 'wb') as file:
        pickle.dump(rewards_data, file)
    print(f'Rewards data saved to {filename}')


def load_rewards_data(filename='rewards_data.pkl'):
    """Load the rewards data from a pickle file."""
    try:
        with open(filename, 'rb') as file:
            rewards_data = pickle.load(file)
        print(f'Rewards data loaded from {filename}')
        return rewards_data
    except FileNotFoundError:
        print(f'Error: The file {filename} does not exist. Please check the file path and try again.')
        return None
    except Exception as e:
        print(f'An error occurred while loading the data: {e}')
        return None

class Fourier_Basis:
  def __init__(self, order, k):
    #self.env = env
    self.order = [order]*k
    self.coefficients = np.array([])

  def get_coefficients(self):
    prods = [range(0, i+1) for i in self.order]
    #print(prods)
    coeffs = [v for v in itertools.product(*prods)]
    self.coefficients = np.array(coeffs)
    return self.coefficients
  
  def value(self, state):
    self.get_coefficients()
    return np.cos(np.pi*np.dot(self.coefficients, state))
# Out:
# cpu

# %%
class Model(nn.Module):
    def __init__(self, input_features, output_values):
        super(Model, self).__init__()
        self.fc1 = nn.Linear(in_features=input_features, out_features=32)
        self.fc2 = nn.Linear(in_features=32, out_features=32)
        self.fc3 = nn.Linear(in_features=32, out_features=output_values)

    def forward(self, x):
        x = functional.selu(self.fc1(x))
        x = functional.selu(self.fc2(x))
        x = self.fc3(x)
        return x

class DDQN:
    def __init__(self, env, order, discretizer, use_cuda=True, learning_rate=1e-5, gamma=0.7, memory_len=10000, start_epsilon=1):
        self.device = torch.device("cuda" if use_cuda and torch.cuda.is_available() else "cpu")
        self.env = env
        self.discretizer = discretizer
        self.learning_rate = learning_rate
        self.gamma = gamma

        self.epsilon = start_epsilon
        self.min_epsilon = 0.0001
        self.epsilon_decay = 0.9 / 2.5e3
        self.memory_len = memory_len
        self.memory = deque(maxlen=self.memory_len)
        self.criterion = nn.MSELoss()

        input_features = (order + 1)**env.observation_space.shape[0]
        output_values = env.action_space.n
        self.policy_net = Model(input_features, output_values).to(self.device)
        self.target_net = Model(input_features, output_values).to(self.device)

        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()

    def get_states_tensor(self, sample, states_idx):
        sample_len = len(sample)
        states_tensor = torch.empty((sample_len, self.n_features), dtype=torch.float32, requires_grad=False)

        features_range = range(self.n_features)
        for i in range(sample_len):
            for j in features_range:
                states_tensor[i, j] = sample[i][states_idx][j].item()

        return states_tensor

    def normalize_state(self, state):
        if type(state) == tuple:
            state = state[0]
        state[0] /= 1.8
        state[1] /= 0.14
        

    def state_reward(self, state, env_reward):
        return env_reward - (abs(state[0]) + abs(state[1])) / 2.5

    def get_action(self, state, e=0.001):
        if random.random() < e:
            return random.randrange(0, self.env.action_space.n)
        else:
            encoded_state = (state - self.l_state) / self.d_state
            state_cos = self.discretizer.value(encoded_state)
            encoded_state = torch.tensor(state_cos, dtype=torch.float32, device=self.device)
            return self.policy_net(encoded_state).argmax().item()

    def fit(self, model, inputs, labels):
        inputs = inputs.to(self.device)
        labels = labels.to(self.device)
        train_ds = TensorDataset(inputs, labels)
        train_dl = DataLoader(train_ds, batch_size=5)

        optimizer = torch.optim.Adam(params=model.parameters(), lr=self.learning_rate)
        model.train()
        total_loss = 0.0

        for x, y in train_dl:
            out = model(x)
            loss = self.criterion(out, y)
            total_loss += loss.item()
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        model.eval()
        return total_loss / len(train_dl)

    def optimize_model(self, train_batch_size=100):
        if len(self.memory) < train_batch_size:
            return
        train_sample = random.sample(self.memory, train_batch_size)

        state = torch.tensor([s[0] for s in train_sample], dtype=torch.float32, device=device)
        next_state = torch.tensor([s[3] for s in train_sample], dtype=torch.float32, device=device)

        q_estimates = self.policy_net(state).detach()
        next_state_q_estimates = self.target_net(next_state).detach()
        next_actions = self.policy_net(next_state).argmax(dim=1)

        for i in range(len(train_sample)):
            next_action = next_actions[i].item()
            q_estimates[i][train_sample[i][1]] = (train_sample[i][2] +
                                                  self.gamma * next_state_q_estimates[i][next_action].item())

        self.fit(self.policy_net, state, q_estimates)

    def train_one_episode(self):
        current_state = self.env.reset()
        #self.normalize_state(current_state)
        done = False
        score = 0
        reward = 0
        step = 0
        while not done and step < 200:
            if type(current_state) == tuple:
                current_state = current_state[0]
            action = self.get_action(current_state, self.epsilon)
            next_state, env_reward, done,  _ = self.env.step(action)
            #self.normalize_state(next_state)
            encoded_current_state = self.discretizer.value((current_state - self.l_state) / self.d_state)
            encoded_next_state = self.discretizer.value((next_state - self.l_state) / self.d_state)
            self.memory.append((encoded_current_state, action, env_reward, encoded_next_state))
            current_state = next_state
            score += env_reward
            reward += self.state_reward(next_state, env_reward)

            self.optimize_model(100)
            step += 1

            self.epsilon = max(self.min_epsilon, self.epsilon - self.epsilon_decay)

        return score, reward

    def test(self):
        state = self.env.reset()
        #self.normalize_state(state)
        done = False
        score = 0
        reward = 0
        step = 0
        while not done and step < 200:
            if type(state) == tuple:
                state = state[0]
            action = self.get_action(state, 0)  # Using 0 to bypass random action selection
            state, env_reward, done,  _ = self.env.step(action)
            #self.normalize_state(state)
            score += env_reward
            reward += self.state_reward(state, env_reward)
            step += 1

        return score, reward

# %%
env = gym.make('MountainCar-v0')

order = 10
k = env.observation_space.shape[0]
FB = Fourier_Basis(order, k)

# %%
def main(used_alpha, used_epsilon, env, order, discretizer, target_update_delay, test_delay, memory_len=10000, num_runs=1, num_episode=1000, save_file=""):


    # Initialize storage for reward data
    rewards_data = {epsilon: {alpha: [] for alpha in used_alpha} for epsilon in used_epsilon}

    for epsilon in used_epsilon:
        for alpha in used_alpha:
            print(f"Training with epsilon: {epsilon}, alpha: {alpha}")
            run_rewards = []  # Collect rewards for each run for the current config

            for run in range(num_runs):
                
                # avoid decay
                current_epsilon = epsilon

                print(f"Run {run + 1}/{num_runs}")
                
                # renew the wrapper class
                ddqn = DDQN(
                    env=env, 
                    order = order,
                    discretizer=discretizer, 
                    use_cuda=True, 
                    learning_rate=alpha, 
                    gamma=0.99,
                    memory_len=memory_len, 
                    start_epsilon=current_epsilon
                )

                best_test_reward = 0

                episode_rewards = []  # Collect rewards for each episode in the current run
                for i in range(num_episode):
                    score, reward = ddqn.train_one_episode()

                    print(f'Episode {i + 1}: score: {score} - reward: {reward}')

                    if i % target_update_delay == 0:
                        ddqn.target_net.load_state_dict(ddqn.policy_net.state_dict())
                        ddqn.target_net.eval()

                    if (i + 1) % test_delay == 0:
                        test_score, test_reward = ddqn.test()
                        print(f'Test Episode {i + 1}: test score: {test_score} - test reward: {test_reward}')
                        if test_reward > best_test_reward:
                            print('New best test reward. Saving model')
                            best_test_reward = test_reward
                            # torch.save(ddqn.policy_net.state_dict(), f'policy_net_{run}.pth')

                    # Add the rewards
                    episode_rewards.append(score)

                if num_episode % test_delay != 0:
                    test_score, test_reward = ddqn.test()
                    print(f'Test Episode {num_episode}: test score: {test_score} - test reward: {test_reward}')
                    if test_reward > best_test_reward:
                        print('New best test reward. Saving model')
                        best_test_reward = test_reward
                        # torch.save(ddqn.policy_net.state_dict(), f'policy_net_{run}.pth')

                # save the run rewards
                run_rewards.append(episode_rewards)

                print(f'best test reward: {best_test_reward}')

            # Store the rewards for the current epsilon and alpha configuration
            rewards_data[epsilon][alpha] = run_rewards

    if not(save_file == ""):
        save_rewards_data(rewards_data, save_file)

    return rewards_data

# %%
rewards_data = main(
    used_alpha=[1e-4], 
    used_epsilon=[0.001],  # start epsilon
    env=env, 
    order = order,
    discretizer=FB,
    target_update_delay=2, 
    test_delay=10,
    memory_len=10000, 
    num_runs=3, 
    num_episode=500, 
    save_file="DDQN_Fourier_MC_2.pkl"
)
# Out:
# Training with epsilon: 0.001, alpha: 0.0001
# Run 1/3
# C:\Users\chery\AppData\Local\Temp\ipykernel_425364\195791383.py:97: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:264.)
#   state = torch.tensor([s[0] for s in train_sample], dtype=torch.float32, device=device)
# Episode 1: score: -200.0 - reward: -242.94758548735894
# Episode 2: score: -200.0 - reward: -242.4240356153339
# Episode 3: score: -200.0 - reward: -246.4966025148852
# Episode 4: score: -200.0 - reward: -249.90160663306736
# Episode 5: score: -200.0 - reward: -243.8327914895355
# Episode 6: score: -200.0 - reward: -245.95361198779412
# Episode 7: score: -200.0 - reward: -242.3276667761095
# Episode 8: score: -200.0 - reward: -230.8711484824083
# Episode 9: score: -200.0 - reward: -242.0963074214403
# Episode 10: score: -200.0 - reward: -242.21824417162068
# Test Episode 10: test score: -200.0 - test reward: -252.3090863906053
# Episode 11: score: -200.0 - reward: -242.67777636502322
# Episode 12: score: -200.0 - reward: -245.68326013830165
# Episode 13: score: -200.0 - reward: -240.47463750270174
# Episode 14: score: -200.0 - reward: -245.0042866837146
# Episode 15: score: -200.0 - reward: -244.80381369574764
# Episode 16: score: -200.0 - reward: -245.20381833039565
# Episode 17: score: -200.0 - reward: -244.47041349277148
# Episode 18: score: -200.0 - reward: -240.82417100916257
# Episode 19: score: -200.0 - reward: -241.46405364796317
# Episode 20: score: -200.0 - reward: -240.20356002744953
# Test Episode 20: test score: -200.0 - test reward: -243.47929209051938
# Episode 21: score: -151.0 - reward: -178.99205236660515
# Episode 22: score: -200.0 - reward: -242.38285960351806
# Episode 23: score: -139.0 - reward: -166.25766245149708
# Episode 24: score: -153.0 - reward: -183.71817500863506
# Episode 25: score: -183.0 - reward: -222.59233001222282
# Episode 26: score: -129.0 - reward: -154.45902647303396
# Episode 27: score: -137.0 - reward: -163.61467478428474
# Episode 28: score: -148.0 - reward: -177.31233839171247
# Episode 29: score: -135.0 - reward: -161.74290816621354
# Episode 30: score: -98.0 - reward: -119.20944181331022
# Test Episode 30: test score: -183.0 - test reward: -221.55801241823258
# Episode 31: score: -190.0 - reward: -230.8040744254727
# Episode 32: score: -198.0 - reward: -240.20405715273475
# Episode 33: score: -122.0 - reward: -147.88009287501055
# Episode 34: score: -185.0 - reward: -224.46717692555904
# Episode 35: score: -97.0 - reward: -118.29903187863158
# Episode 36: score: -200.0 - reward: -243.38239437319626
# Episode 37: score: -134.0 - reward: -160.51912334921656
# Episode 38: score: -200.0 - reward: -243.4276008916332
# Episode 39: score: -130.0 - reward: -159.06988526035667
# Episode 40: score: -200.0 - reward: -243.07468796211543
# Test Episode 40: test score: -196.0 - test reward: -237.7973803341991
# Episode 41: score: -161.0 - reward: -195.9071171512178
# Episode 42: score: -200.0 - reward: -240.12065804195643
# Episode 43: score: -141.0 - reward: -173.63531858820673
# Episode 44: score: -146.0 - reward: -178.18296824202992
# Episode 45: score: -155.0 - reward: -188.96412307572967
# Episode 46: score: -167.0 - reward: -203.79903998345372
# Episode 47: score: -141.0 - reward: -173.0893503328922
# Episode 48: score: -200.0 - reward: -239.54629074065997
# Episode 49: score: -170.0 - reward: -210.14906268366997
# Episode 50: score: -200.0 - reward: -241.73887699781218
# Test Episode 50: test score: -200.0 - test reward: -251.34718752327922
# Episode 51: score: -200.0 - reward: -245.1865538787143
# Episode 52: score: -200.0 - reward: -245.55465181425947
# Episode 53: score: -200.0 - reward: -243.09225335997152
# Episode 54: score: -200.0 - reward: -243.32784117819747
# Episode 55: score: -200.0 - reward: -244.09300433369708
# Episode 56: score: -200.0 - reward: -241.05415813831496
# Episode 57: score: -200.0 - reward: -243.55030763164606
# Episode 58: score: -200.0 - reward: -244.33549112023707
# Episode 59: score: -200.0 - reward: -243.5676946620222
# Episode 60: score: -200.0 - reward: -244.00137981592727
# Test Episode 60: test score: -200.0 - test reward: -253.4098759850272
# Episode 61: score: -200.0 - reward: -240.22384381284382
# Episode 62: score: -200.0 - reward: -240.03421589422055
# Episode 63: score: -200.0 - reward: -243.58891131744386
# Episode 64: score: -200.0 - reward: -237.56537475240214
# Episode 65: score: -200.0 - reward: -236.94907110038233
# Episode 66: score: -200.0 - reward: -237.12968814986803
# Episode 67: score: -200.0 - reward: -234.12973975949333
# Episode 68: score: -200.0 - reward: -233.68998175780288
# Episode 69: score: -200.0 - reward: -231.86708250000987
# Episode 70: score: -200.0 - reward: -237.80132124871812
# Test Episode 70: test score: -200.0 - test reward: -230.82943090795715
# Episode 71: score: -200.0 - reward: -237.39519067191188
# Episode 72: score: -200.0 - reward: -243.87276065402278
# Episode 73: score: -200.0 - reward: -231.4053571205084
# Episode 74: score: -200.0 - reward: -244.55058700189858
# Episode 75: score: -200.0 - reward: -238.29922083122443
# Episode 76: score: -200.0 - reward: -232.14638986590245
# Episode 77: score: -200.0 - reward: -241.52767739274717
# Episode 78: score: -200.0 - reward: -243.54994038966214
# Episode 79: score: -200.0 - reward: -244.85974015908428
# Episode 80: score: -200.0 - reward: -231.53465942113044
# Test Episode 80: test score: -200.0 - test reward: -237.55722106826187
# Episode 81: score: -200.0 - reward: -253.64670994903108
# Episode 82: score: -200.0 - reward: -237.07887142518786
# Episode 83: score: -200.0 - reward: -237.02774679876558
# Episode 84: score: -200.0 - reward: -241.18284177105713
# Episode 85: score: -200.0 - reward: -230.90096145423882
# Episode 86: score: -200.0 - reward: -236.62734078926226
# Episode 87: score: -189.0 - reward: -227.37444178839974
# Episode 88: score: -200.0 - reward: -253.49223722510814
# Episode 89: score: -200.0 - reward: -253.5931328296907
# Episode 90: score: -194.0 - reward: -234.4056263507984
# Test Episode 90: test score: -200.0 - test reward: -230.89283966061825
# Episode 91: score: -200.0 - reward: -238.89053309268033
# Episode 92: score: -190.0 - reward: -229.65623665328286
# Episode 93: score: -200.0 - reward: -243.45376954000005
# Episode 94: score: -195.0 - reward: -237.30123418225233
# Episode 95: score: -200.0 - reward: -242.6248911854961
# Episode 96: score: -200.0 - reward: -239.46981927811876
# Episode 97: score: -200.0 - reward: -241.4241099131905
# Episode 98: score: -175.0 - reward: -210.3130959788274
# Episode 99: score: -200.0 - reward: -242.5429514593588
# Episode 100: score: -187.0 - reward: -227.1185235588156
# Test Episode 100: test score: -192.0 - test reward: -232.43984190631505
# Episode 101: score: -176.0 - reward: -215.4884035060622
# Episode 102: score: -200.0 - reward: -249.7773965057297
# Episode 103: score: -200.0 - reward: -245.58542487265487
# Episode 104: score: -200.0 - reward: -251.34535735283185
# Episode 105: score: -200.0 - reward: -245.9883927312168
# Episode 106: score: -200.0 - reward: -250.4898498468756
# Episode 107: score: -178.0 - reward: -216.18204892570176
# Episode 108: score: -200.0 - reward: -242.88036050061237
# Episode 109: score: -179.0 - reward: -215.64883007450106
# Episode 110: score: -200.0 - reward: -246.96361284318226
# Test Episode 110: test score: -199.0 - test reward: -241.73296199856114
# Episode 111: score: -196.0 - reward: -238.44314973781843
# Episode 112: score: -200.0 - reward: -243.68448420373736
# Episode 113: score: -200.0 - reward: -240.38562309304515
# Episode 114: score: -200.0 - reward: -245.48251761008896
# Episode 115: score: -200.0 - reward: -244.85204141683667
# Episode 116: score: -200.0 - reward: -247.03405815661316
# Episode 117: score: -200.0 - reward: -246.12422389263764
# Episode 118: score: -200.0 - reward: -245.6823327878465
# Episode 119: score: -200.0 - reward: -244.204788835434
# Episode 120: score: -200.0 - reward: -247.15279639679918
# Test Episode 120: test score: -200.0 - test reward: -248.4160234092295
# Episode 121: score: -200.0 - reward: -244.14125690861667
# Episode 122: score: -200.0 - reward: -241.45753209731973
# Episode 123: score: -200.0 - reward: -244.9649571162823
# Episode 124: score: -200.0 - reward: -240.40441094458293
# Episode 125: score: -200.0 - reward: -247.31372894334802
# Episode 126: score: -200.0 - reward: -243.86943449784454
# Episode 127: score: -200.0 - reward: -244.3744175883267
# Episode 128: score: -200.0 - reward: -243.84451219960812
# Episode 129: score: -200.0 - reward: -244.32199667252968
# Episode 130: score: -200.0 - reward: -240.3451701468443
# Test Episode 130: test score: -200.0 - test reward: -241.88224190937447
# Episode 131: score: -200.0 - reward: -245.73851668070367
# Episode 132: score: -200.0 - reward: -240.977736911254
# Episode 133: score: -200.0 - reward: -246.0632952666163
# Episode 134: score: -200.0 - reward: -234.94581205461637
# Episode 135: score: -200.0 - reward: -238.03983044669116
# Episode 136: score: -111.0 - reward: -134.1760245111017
# Episode 137: score: -110.0 - reward: -132.52547004641534
# Episode 138: score: -144.0 - reward: -172.52897836574587
# Episode 139: score: -200.0 - reward: -237.76370391064353
# Episode 140: score: -200.0 - reward: -244.82892546209564
# Test Episode 140: test score: -96.0 - test reward: -116.54658198754642
# Episode 141: score: -197.0 - reward: -238.1222215693257
# Episode 142: score: -158.0 - reward: -190.81972594913108
# Episode 143: score: -200.0 - reward: -233.97275433175085
# Episode 144: score: -200.0 - reward: -238.18566239229236
# Episode 145: score: -194.0 - reward: -233.77307185885408
# Episode 146: score: -113.0 - reward: -136.46021394820914
# Episode 147: score: -200.0 - reward: -239.56394701500784
# Episode 148: score: -200.0 - reward: -240.65792172571247
# Episode 149: score: -125.0 - reward: -150.59429174888308
# Episode 150: score: -135.0 - reward: -163.73216552148116
# Test Episode 150: test score: -146.0 - test reward: -175.0258876781672
# Episode 151: score: -140.0 - reward: -167.9938306451304
# Episode 152: score: -109.0 - reward: -132.15315231193844
# Episode 153: score: -149.0 - reward: -179.71550790812043
# Episode 154: score: -200.0 - reward: -244.23567028691505
# Episode 155: score: -107.0 - reward: -129.8717065985712
# Episode 156: score: -127.0 - reward: -153.98979252334397
# Episode 157: score: -109.0 - reward: -132.92716062624467
# Episode 158: score: -200.0 - reward: -245.49409242121462
# Episode 159: score: -108.0 - reward: -132.09054314652474
# Episode 160: score: -108.0 - reward: -131.71417871029635
# Test Episode 160: test score: -131.0 - test reward: -159.43420957592787
# Episode 161: score: -109.0 - reward: -132.45800178576403
# Episode 162: score: -131.0 - reward: -159.27694823633442
# Episode 163: score: -125.0 - reward: -152.12054062759836
# Episode 164: score: -200.0 - reward: -247.4017808979729
# Episode 165: score: -106.0 - reward: -129.76908272324786
# Episode 166: score: -110.0 - reward: -133.73656589461126
# Episode 167: score: -130.0 - reward: -157.87392268605345
# Episode 168: score: -112.0 - reward: -135.9777163568935
# Episode 169: score: -131.0 - reward: -159.39340075674173
# Episode 170: score: -130.0 - reward: -157.12008956450612
# Test Episode 170: test score: -163.0 - test reward: -197.27144628753155
# Episode 171: score: -133.0 - reward: -161.30204988207592
# Episode 172: score: -138.0 - reward: -167.1183568603813
# Episode 173: score: -124.0 - reward: -150.29439160101225
# Episode 174: score: -131.0 - reward: -156.48539203414654
# Episode 175: score: -145.0 - reward: -176.37833342948088
# Episode 176: score: -134.0 - reward: -161.85804960246207
# Episode 177: score: -153.0 - reward: -185.18139662032038
# Episode 178: score: -200.0 - reward: -243.65812720167008
# Episode 179: score: -137.0 - reward: -167.76226780263067
# Episode 180: score: -139.0 - reward: -168.6538128673804
# Test Episode 180: test score: -200.0 - test reward: -233.01816808145117
# Episode 181: score: -142.0 - reward: -174.1505023473419
# Episode 182: score: -132.0 - reward: -159.693394574166
# Episode 183: score: -153.0 - reward: -185.1297099725709
# Episode 184: score: -166.0 - reward: -201.33475644509747
# Episode 185: score: -152.0 - reward: -187.636266956208
# Episode 186: score: -164.0 - reward: -199.77718701436612
# Episode 187: score: -113.0 - reward: -137.60803424423116
# Episode 188: score: -167.0 - reward: -204.78598936646276
# Episode 189: score: -171.0 - reward: -210.57755105711504
# Episode 190: score: -168.0 - reward: -207.24822276479813
# Test Episode 190: test score: -145.0 - test reward: -177.1456750334124
# Episode 191: score: -152.0 - reward: -186.8805076756691
# Episode 192: score: -104.0 - reward: -126.36656952414188
# Episode 193: score: -102.0 - reward: -123.20879090084547
# Episode 194: score: -105.0 - reward: -128.39606017676994
# Episode 195: score: -180.0 - reward: -221.08604232253558
# Episode 196: score: -188.0 - reward: -229.15769002548228
# Episode 197: score: -191.0 - reward: -232.1450007150755
# Episode 198: score: -135.0 - reward: -166.30235606923327
# Episode 199: score: -108.0 - reward: -131.48548909412415
# Episode 200: score: -170.0 - reward: -210.60763445222696
# Test Episode 200: test score: -200.0 - test reward: -244.24914687923146
# Episode 201: score: -107.0 - reward: -131.48943176041618
# Episode 202: score: -159.0 - reward: -194.05461017637128
# Episode 203: score: -151.0 - reward: -184.45082756085853
# Episode 204: score: -200.0 - reward: -245.29464654683892
# Episode 205: score: -132.0 - reward: -162.73158651961012
# Episode 206: score: -126.0 - reward: -155.7152842780098
# Episode 207: score: -92.0 - reward: -112.66853813675621
# Episode 208: score: -114.0 - reward: -140.88563367565015
# Episode 209: score: -113.0 - reward: -140.28306555088122
# Episode 210: score: -110.0 - reward: -136.0914084216877
# Test Episode 210: test score: -114.0 - test reward: -141.27064920236938
# Episode 211: score: -119.0 - reward: -146.48719890715972
# Episode 212: score: -113.0 - reward: -138.29789668320302
# Episode 213: score: -182.0 - reward: -225.9362600908032
# Episode 214: score: -117.0 - reward: -142.72357365952422
# Episode 215: score: -117.0 - reward: -143.3910963642505
# Episode 216: score: -89.0 - reward: -109.13920798801556
# Episode 217: score: -112.0 - reward: -137.08864363930147
# Episode 218: score: -109.0 - reward: -133.19918864161335
# Episode 219: score: -109.0 - reward: -132.83017637226962
# Episode 220: score: -91.0 - reward: -111.55690597778838
# Test Episode 220: test score: -109.0 - test reward: -133.04061206136075
# Episode 221: score: -97.0 - reward: -117.66627571370203
# Episode 222: score: -97.0 - reward: -117.91477638003508
# Episode 223: score: -108.0 - reward: -131.56609746977114
# Episode 224: score: -109.0 - reward: -132.45831924735813
# Episode 225: score: -110.0 - reward: -133.70812244041994
# Episode 226: score: -107.0 - reward: -130.9082114374425
# Episode 227: score: -200.0 - reward: -233.23482282275776
# Episode 228: score: -120.0 - reward: -146.34869111180333
# Episode 229: score: -123.0 - reward: -150.2713677414326
# Episode 230: score: -107.0 - reward: -128.91751034953913
# Test Episode 230: test score: -137.0 - test reward: -164.45604771111545
# Episode 231: score: -135.0 - reward: -163.57473738832635
# Episode 232: score: -136.0 - reward: -164.81354670070516
# Episode 233: score: -137.0 - reward: -163.84252836799703
# Episode 234: score: -186.0 - reward: -224.3463596159215
# Episode 235: score: -176.0 - reward: -213.65148258898637
# Episode 236: score: -145.0 - reward: -173.52296991379157
# Episode 237: score: -200.0 - reward: -238.8299145362065
# Episode 238: score: -179.0 - reward: -217.48559345800632
# Episode 239: score: -200.0 - reward: -230.89569401420198
# Episode 240: score: -134.0 - reward: -162.23895691166044
# Test Episode 240: test score: -170.0 - test reward: -207.61145889946314
# Episode 241: score: -200.0 - reward: -248.85174241823896
# Episode 242: score: -135.0 - reward: -163.82723871162162
# Episode 243: score: -170.0 - reward: -208.1658443403362
# Episode 244: score: -138.0 - reward: -167.99146197455119
# Episode 245: score: -149.0 - reward: -181.0962051596688
# Episode 246: score: -148.0 - reward: -178.91105560526015
# Episode 247: score: -189.0 - reward: -230.71741794352647
# Episode 248: score: -133.0 - reward: -161.26902897071705
# Episode 249: score: -136.0 - reward: -164.97753480251993
# Episode 250: score: -151.0 - reward: -184.3356477999131
# Test Episode 250: test score: -136.0 - test reward: -166.995832053684
# Episode 251: score: -146.0 - reward: -176.1027293811208
# Episode 252: score: -137.0 - reward: -167.9752906322811
# Episode 253: score: -135.0 - reward: -164.9147833821222
# Episode 254: score: -130.0 - reward: -158.79267801500473
# Episode 255: score: -128.0 - reward: -156.00347014080845
# Episode 256: score: -131.0 - reward: -158.74256041431502
# Episode 257: score: -125.0 - reward: -151.04780257087472
# Episode 258: score: -131.0 - reward: -159.9647846089494
# Episode 259: score: -127.0 - reward: -154.76736274966524
# Episode 260: score: -120.0 - reward: -144.5882773934614
# Test Episode 260: test score: -127.0 - test reward: -153.3053531373098
# Episode 261: score: -128.0 - reward: -154.79550729735755
# Episode 262: score: -182.0 - reward: -220.09177556529775
# Episode 263: score: -129.0 - reward: -155.26732244808466
# Episode 264: score: -180.0 - reward: -219.88592846674135
# Episode 265: score: -131.0 - reward: -158.6915498731701
# Episode 266: score: -124.0 - reward: -150.26449791982276
# Episode 267: score: -114.0 - reward: -139.45230514342643
# Episode 268: score: -136.0 - reward: -164.43529123466314
# Episode 269: score: -131.0 - reward: -158.97250184378365
# Episode 270: score: -129.0 - reward: -155.57626739213225
# Test Episode 270: test score: -125.0 - test reward: -151.47151142845658
# Episode 271: score: -131.0 - reward: -158.45152958333477
# Episode 272: score: -134.0 - reward: -161.80395694820524
# Episode 273: score: -174.0 - reward: -208.74030173066546
# Episode 274: score: -200.0 - reward: -230.75356124775132
# Episode 275: score: -134.0 - reward: -161.56435424909466
# Episode 276: score: -199.0 - reward: -236.53092544892408
# Episode 277: score: -195.0 - reward: -231.77405978884866
# Episode 278: score: -134.0 - reward: -161.0254770767655
# Episode 279: score: -130.0 - reward: -155.97596134277208
# Episode 280: score: -200.0 - reward: -237.9621575778073
# Test Episode 280: test score: -115.0 - test reward: -138.95443639436343
# Episode 281: score: -200.0 - reward: -231.27475279208846
# Episode 282: score: -134.0 - reward: -160.43664526025879
# Episode 283: score: -137.0 - reward: -163.59327723574262
# Episode 284: score: -137.0 - reward: -163.65700584664268
# Episode 285: score: -135.0 - reward: -160.8166500591462
# Episode 286: score: -138.0 - reward: -165.3488855297067
# Episode 287: score: -139.0 - reward: -166.16023927920455
# Episode 288: score: -139.0 - reward: -166.5452510098331
# Episode 289: score: -145.0 - reward: -174.02627124740528
# Episode 290: score: -200.0 - reward: -239.95298370048187
# Test Episode 290: test score: -200.0 - test reward: -230.81907701747735
# Episode 291: score: -145.0 - reward: -174.60468174530916
# Episode 292: score: -200.0 - reward: -238.2930690565087
# Episode 293: score: -200.0 - reward: -242.1954780727226
# Episode 294: score: -200.0 - reward: -241.63662867199878
# Episode 295: score: -135.0 - reward: -163.1275345692722
# Episode 296: score: -145.0 - reward: -174.37131217200545
# Episode 297: score: -200.0 - reward: -239.51987256926526
# Episode 298: score: -200.0 - reward: -239.48536725340446
# Episode 299: score: -200.0 - reward: -239.47426117994925
# Episode 300: score: -200.0 - reward: -242.1080783948995
# Test Episode 300: test score: -151.0 - test reward: -182.77995950368376
# Episode 301: score: -148.0 - reward: -178.64240341196574
# Episode 302: score: -148.0 - reward: -180.2658353117634
# Episode 303: score: -142.0 - reward: -171.89949013808294
# Episode 304: score: -200.0 - reward: -237.636068465861
# Episode 305: score: -143.0 - reward: -174.86555430878053
# Episode 306: score: -200.0 - reward: -237.18641960607076
# Episode 307: score: -200.0 - reward: -240.20460471308078
# Episode 308: score: -200.0 - reward: -241.01253139306735
# Episode 309: score: -154.0 - reward: -188.4237034864214
# Episode 310: score: -200.0 - reward: -241.2669415986247
# Test Episode 310: test score: -200.0 - test reward: -239.80752454814885
# Episode 311: score: -200.0 - reward: -245.98586377670176
# Episode 312: score: -200.0 - reward: -243.32999115602036
# Episode 313: score: -200.0 - reward: -242.4889348257971
# Episode 314: score: -200.0 - reward: -245.84870263983797
# Episode 315: score: -200.0 - reward: -247.4034412416922
# Episode 316: score: -200.0 - reward: -247.96360382766628
# Episode 317: score: -200.0 - reward: -242.14713409124084
# Episode 318: score: -200.0 - reward: -244.3030888747299
# Episode 319: score: -200.0 - reward: -244.77820893392428
# Episode 320: score: -200.0 - reward: -244.49653413615388
# Test Episode 320: test score: -200.0 - test reward: -244.45281101628964
# Episode 321: score: -200.0 - reward: -245.95657456919267
# Episode 322: score: -200.0 - reward: -247.1417603094262
# Episode 323: score: -200.0 - reward: -246.01328426419101
# Episode 324: score: -200.0 - reward: -244.52657119249704
# Episode 325: score: -200.0 - reward: -245.01025256174188
# Episode 326: score: -200.0 - reward: -244.55844123605334
# Episode 327: score: -200.0 - reward: -245.51709419600238
# Episode 328: score: -200.0 - reward: -246.266985419255
# Episode 329: score: -200.0 - reward: -244.75621468703665
# Episode 330: score: -200.0 - reward: -246.29064730532966
# Test Episode 330: test score: -200.0 - test reward: -245.5712901507401
# Episode 331: score: -200.0 - reward: -246.90807017998603
# Episode 332: score: -200.0 - reward: -246.52077079753965
# Episode 333: score: -200.0 - reward: -247.23170898569174
# Episode 334: score: -200.0 - reward: -247.6378150278207
# Episode 335: score: -200.0 - reward: -248.08152855176783
# Episode 336: score: -200.0 - reward: -248.9944509613171
# Episode 337: score: -200.0 - reward: -252.23626713514162
# Episode 338: score: -200.0 - reward: -247.11692483648812
# Episode 339: score: -200.0 - reward: -242.9148045415367
# Episode 340: score: -180.0 - reward: -223.2472784667063
# Test Episode 340: test score: -200.0 - test reward: -234.5014104137509
# Episode 341: score: -200.0 - reward: -235.11911371751924
# Episode 342: score: -200.0 - reward: -249.86522942889644
# Episode 343: score: -200.0 - reward: -249.12208495982915
# Episode 344: score: -175.0 - reward: -217.52962141089444
# Episode 345: score: -159.0 - reward: -198.8843604769668
# Episode 346: score: -185.0 - reward: -230.65234136278158
# Episode 347: score: -156.0 - reward: -195.35392269964515
# Episode 348: score: -156.0 - reward: -193.3691997724386
# Episode 349: score: -161.0 - reward: -199.8824508078336
# Episode 350: score: -175.0 - reward: -218.26158713422458
# Test Episode 350: test score: -160.0 - test reward: -200.17033143485492
# Episode 351: score: -184.0 - reward: -228.85032639425586
# Episode 352: score: -163.0 - reward: -204.8964634796763
# Episode 353: score: -159.0 - reward: -199.39954191794874
# Episode 354: score: -160.0 - reward: -201.43237253628368
# Episode 355: score: -158.0 - reward: -198.29591040964962
# Episode 356: score: -155.0 - reward: -193.73277730593358
# Episode 357: score: -155.0 - reward: -194.22252470428649
# Episode 358: score: -157.0 - reward: -196.0795198940635
# Episode 359: score: -169.0 - reward: -207.02713335960496
# Episode 360: score: -174.0 - reward: -212.24968993897224
# Test Episode 360: test score: -168.0 - test reward: -204.94488734440108
# Episode 361: score: -174.0 - reward: -211.57436525667558
# Episode 362: score: -177.0 - reward: -214.83690120740872
# Episode 363: score: -178.0 - reward: -216.54233010331242
# Episode 364: score: -180.0 - reward: -218.3925047895076
# Episode 365: score: -185.0 - reward: -224.60744304890395
# Episode 366: score: -175.0 - reward: -213.9975861857698
# Episode 367: score: -181.0 - reward: -221.73139778033794
# Episode 368: score: -179.0 - reward: -217.79028921336126
# Episode 369: score: -179.0 - reward: -217.3822107613964
# Episode 370: score: -176.0 - reward: -214.3974789773867
# Test Episode 370: test score: -186.0 - test reward: -225.5698216696479
# Episode 371: score: -184.0 - reward: -223.35010261115153
# Episode 372: score: -191.0 - reward: -231.64704709448628
# Episode 373: score: -182.0 - reward: -225.9131323501372
# Episode 374: score: -171.0 - reward: -212.06967275702928
# Episode 375: score: -171.0 - reward: -209.14449045174644
# Episode 376: score: -170.0 - reward: -206.87410256776437
# Episode 377: score: -166.0 - reward: -203.05123989123948
# Episode 378: score: -119.0 - reward: -142.4966449070634
# Episode 379: score: -199.0 - reward: -241.0075057555316
# Episode 380: score: -193.0 - reward: -235.53676268223225
# Test Episode 380: test score: -184.0 - test reward: -223.66187294473073
# Episode 381: score: -183.0 - reward: -224.06989211496813
# Episode 382: score: -181.0 - reward: -223.38701033483244
# Episode 383: score: -176.0 - reward: -215.68344436928817
# Episode 384: score: -186.0 - reward: -227.3323507491876
# Episode 385: score: -200.0 - reward: -244.56359261533808
# Episode 386: score: -200.0 - reward: -244.60245915670532
# Episode 387: score: -200.0 - reward: -245.60929636456112
# Episode 388: score: -199.0 - reward: -244.62539227996916
# Episode 389: score: -137.0 - reward: -165.03462273016459
# Episode 390: score: -145.0 - reward: -174.41890671007738
# Test Episode 390: test score: -192.0 - test reward: -236.26477716806548
# Episode 391: score: -141.0 - reward: -167.98736053493658
# Episode 392: score: -200.0 - reward: -239.48873103231284
# Episode 393: score: -139.0 - reward: -165.48311660964143
# Episode 394: score: -200.0 - reward: -245.13947622494015
# Episode 395: score: -121.0 - reward: -145.39814097248853
# Episode 396: score: -120.0 - reward: -144.03614376564644
# Episode 397: score: -200.0 - reward: -245.61650551857358
# Episode 398: score: -199.0 - reward: -242.43073278540857
# Episode 399: score: -135.0 - reward: -163.1124995968528
# Episode 400: score: -200.0 - reward: -241.75839288565658
# Test Episode 400: test score: -200.0 - test reward: -244.05805919770611
# Episode 401: score: -200.0 - reward: -243.87423361068232
# Episode 402: score: -200.0 - reward: -240.42020161917648
# Episode 403: score: -200.0 - reward: -241.96641485323195
# Episode 404: score: -200.0 - reward: -240.16528331414705
# Episode 405: score: -200.0 - reward: -241.80207085801734
# Episode 406: score: -200.0 - reward: -245.07115483324046
# Episode 407: score: -200.0 - reward: -247.2003065407507
# Episode 408: score: -142.0 - reward: -172.3379353164255
# Episode 409: score: -200.0 - reward: -252.5204207406419
# Episode 410: score: -200.0 - reward: -247.35668045646668
# Test Episode 410: test score: -200.0 - test reward: -250.97320810216155
# Episode 411: score: -170.0 - reward: -204.2293661374185
# Episode 412: score: -200.0 - reward: -247.32972844968572
# Episode 413: score: -200.0 - reward: -247.7333135865201
# Episode 414: score: -200.0 - reward: -247.77753282930846
# Episode 415: score: -200.0 - reward: -248.07237969304418
# Episode 416: score: -200.0 - reward: -249.9124042240102
# Episode 417: score: -200.0 - reward: -245.9175050922861
# Episode 418: score: -200.0 - reward: -242.47297738637388
# Episode 419: score: -200.0 - reward: -241.18872485295904
# Episode 420: score: -200.0 - reward: -240.9230404987262
# Test Episode 420: test score: -200.0 - test reward: -241.0442678248099
# Episode 421: score: -200.0 - reward: -240.87557082906406
# Episode 422: score: -200.0 - reward: -240.5917857727441
# Episode 423: score: -200.0 - reward: -239.82469765403545
# Episode 424: score: -200.0 - reward: -239.70837105135726
# Episode 425: score: -200.0 - reward: -239.75107726590036
# Episode 426: score: -200.0 - reward: -238.64487780981807
# Episode 427: score: -178.0 - reward: -214.7153552557694
# Episode 428: score: -200.0 - reward: -236.6588574181334
# Episode 429: score: -200.0 - reward: -237.66950026418417
# Episode 430: score: -200.0 - reward: -238.39279346592923
# Test Episode 430: test score: -200.0 - test reward: -236.89381112934038
# Episode 431: score: -177.0 - reward: -214.4593916396602
# Episode 432: score: -200.0 - reward: -237.21933113624556
# Episode 433: score: -200.0 - reward: -235.44357402406635
# Episode 434: score: -200.0 - reward: -235.6929293330641
# Episode 435: score: -200.0 - reward: -235.30283337329737
# Episode 436: score: -200.0 - reward: -234.85704690905484
# Episode 437: score: -200.0 - reward: -234.6272968690069
# Episode 438: score: -200.0 - reward: -234.0246121746418
# Episode 439: score: -200.0 - reward: -234.5781857735539
# Episode 440: score: -200.0 - reward: -233.45461632131364
# Test Episode 440: test score: -200.0 - test reward: -234.4680137690077
# Episode 441: score: -200.0 - reward: -235.04292704454042
# Episode 442: score: -200.0 - reward: -233.57996985016442
# Episode 443: score: -200.0 - reward: -234.53052425467135
# Episode 444: score: -200.0 - reward: -233.52540270813313
# Episode 445: score: -200.0 - reward: -234.45960260770656
# Episode 446: score: -200.0 - reward: -234.68404985037668
# Episode 447: score: -200.0 - reward: -232.9710612840256
# Episode 448: score: -200.0 - reward: -234.33607211590774
# Episode 449: score: -200.0 - reward: -234.30750290770249
# Episode 450: score: -200.0 - reward: -234.35610279372887
# Test Episode 450: test score: -200.0 - test reward: -233.00707982751126
# Episode 451: score: -200.0 - reward: -233.9030232271223
# Episode 452: score: -200.0 - reward: -234.2597498028649
# Episode 453: score: -200.0 - reward: -234.03544288670338
# Episode 454: score: -200.0 - reward: -233.89536569868045
# Episode 455: score: -200.0 - reward: -233.8229570501793
# Episode 456: score: -200.0 - reward: -233.85411610587965
# Episode 457: score: -200.0 - reward: -233.8995769769596
# Episode 458: score: -200.0 - reward: -234.23107427937268
# Episode 459: score: -200.0 - reward: -233.48514919360107
# Episode 460: score: -200.0 - reward: -233.88506643780954
# Test Episode 460: test score: -200.0 - test reward: -233.94711997574777
# Episode 461: score: -200.0 - reward: -235.11563284134166
# Episode 462: score: -200.0 - reward: -235.05326135222907
# Episode 463: score: -200.0 - reward: -233.4100236288788
# Episode 464: score: -200.0 - reward: -234.60072868038858
# Episode 465: score: -200.0 - reward: -233.8675427395406
# Episode 466: score: -200.0 - reward: -233.38623290926006
# Episode 467: score: -200.0 - reward: -232.3793743901813
# Episode 468: score: -200.0 - reward: -232.52634893528287
# Episode 469: score: -200.0 - reward: -231.95183328906927
# Episode 470: score: -200.0 - reward: -232.43170499419767
# Test Episode 470: test score: -200.0 - test reward: -231.58878367239518
# Episode 471: score: -200.0 - reward: -231.03564762531917
# Episode 472: score: -200.0 - reward: -232.3973910347413
# Episode 473: score: -200.0 - reward: -245.90278208867718
# Episode 474: score: -200.0 - reward: -244.91662181313166
# Episode 475: score: -200.0 - reward: -246.14003125386193
# Episode 476: score: -200.0 - reward: -246.3641514352229
# Episode 477: score: -200.0 - reward: -247.260515061484
# Episode 478: score: -200.0 - reward: -243.1863363153514
# Episode 479: score: -200.0 - reward: -244.96537923759374
# Episode 480: score: -200.0 - reward: -243.42232008088084
# Test Episode 480: test score: -200.0 - test reward: -230.90160308171707
# Episode 481: score: -200.0 - reward: -246.5687514116647
# Episode 482: score: -200.0 - reward: -245.9785780144815
# Episode 483: score: -200.0 - reward: -246.57290286664698
# Episode 484: score: -200.0 - reward: -246.23791003464132
# Episode 485: score: -200.0 - reward: -248.20867689703542
# Episode 486: score: -200.0 - reward: -248.08410808265464
# Episode 487: score: -200.0 - reward: -245.26557821892396
# Episode 488: score: -200.0 - reward: -246.22721287042967
# Episode 489: score: -200.0 - reward: -245.0538943673397
# Episode 490: score: -200.0 - reward: -251.42621000951422
# Test Episode 490: test score: -200.0 - test reward: -252.4606678957327
# Episode 491: score: -200.0 - reward: -249.57347381857608
# Episode 492: score: -200.0 - reward: -253.6941991286424
# Episode 493: score: -200.0 - reward: -251.0078516160493
# Episode 494: score: -200.0 - reward: -251.04789387232626
# Episode 495: score: -200.0 - reward: -251.02950057140905
# Episode 496: score: -200.0 - reward: -249.26080883610032
# Episode 497: score: -200.0 - reward: -249.86404998945153
# Episode 498: score: -200.0 - reward: -250.91170331153705
# Episode 499: score: -200.0 - reward: -252.35105618796462
# Episode 500: score: -198.0 - reward: -241.39183199303525
# Test Episode 500: test score: -200.0 - test reward: -243.99340476588213
# best test reward: 0
# Run 2/3
# Episode 1: score: -200.0 - reward: -244.7284153606968
# Episode 2: score: -200.0 - reward: -244.14768674611628
# Episode 3: score: -200.0 - reward: -244.552958389749
# Episode 4: score: -200.0 - reward: -243.5450886512732
# Episode 5: score: -200.0 - reward: -244.29711554714106
# Episode 6: score: -200.0 - reward: -242.84065938702386
# Episode 7: score: -200.0 - reward: -243.6795912485605
# Episode 8: score: -200.0 - reward: -247.71060776002358
# Episode 9: score: -200.0 - reward: -245.38384721958914
# Episode 10: score: -200.0 - reward: -245.4118199297177
# Test Episode 10: test score: -200.0 - test reward: -242.28156797523778
# Episode 11: score: -200.0 - reward: -243.20166925027965
# Episode 12: score: -200.0 - reward: -242.3644883479927
# Episode 13: score: -200.0 - reward: -247.47813034239067
# Episode 14: score: -200.0 - reward: -246.66731587955607
# Episode 15: score: -200.0 - reward: -245.59352166940462
# Episode 16: score: -200.0 - reward: -249.98539829827385
# Episode 17: score: -200.0 - reward: -239.5588261809619
# Episode 18: score: -200.0 - reward: -245.79508782684792
# Episode 19: score: -200.0 - reward: -244.34897930833637
# Episode 20: score: -200.0 - reward: -243.42507278737673
# Test Episode 20: test score: -200.0 - test reward: -242.87626738255148
# Episode 21: score: -200.0 - reward: -238.99552930164936
# Episode 22: score: -200.0 - reward: -241.45459746433295
# Episode 23: score: -200.0 - reward: -240.90434928875092
# Episode 24: score: -200.0 - reward: -238.66406817237228
# Episode 25: score: -200.0 - reward: -240.72390279805452
# Episode 26: score: -200.0 - reward: -238.2554186936869
# Episode 27: score: -200.0 - reward: -239.23805441448528
# Episode 28: score: -200.0 - reward: -239.931114498056
# Episode 29: score: -200.0 - reward: -239.99294271937381
# Episode 30: score: -200.0 - reward: -239.34804055387977
# Test Episode 30: test score: -200.0 - test reward: -240.0354494436629
# Episode 31: score: -200.0 - reward: -241.155016287883
# Episode 32: score: -200.0 - reward: -243.7925083994358
# Episode 33: score: -200.0 - reward: -240.86007823129341
# Episode 34: score: -200.0 - reward: -240.53727941824712
# Episode 35: score: -200.0 - reward: -239.10568625429428
# Episode 36: score: -200.0 - reward: -240.85769091104117
# Episode 37: score: -200.0 - reward: -239.87738424258495
# Episode 38: score: -200.0 - reward: -240.44047876822373
# Episode 39: score: -200.0 - reward: -243.29518120249136
# Episode 40: score: -200.0 - reward: -237.34188520838512
# Test Episode 40: test score: -200.0 - test reward: -246.24509540882292
# Episode 41: score: -200.0 - reward: -236.6975141528414
# Episode 42: score: -200.0 - reward: -244.18669655687353
# Episode 43: score: -200.0 - reward: -245.8512190815427
# Episode 44: score: -200.0 - reward: -242.3158544959289
# Episode 45: score: -200.0 - reward: -240.39095866215578
# Episode 46: score: -200.0 - reward: -241.3973201002081
# Episode 47: score: -200.0 - reward: -241.188332482021
# Episode 48: score: -200.0 - reward: -240.4064931792513
# Episode 49: score: -200.0 - reward: -245.61440925836428
# Episode 50: score: -200.0 - reward: -245.50153107367646
# Test Episode 50: test score: -200.0 - test reward: -253.5164807527896
# Episode 51: score: -200.0 - reward: -239.46313095413285
# Episode 52: score: -200.0 - reward: -243.7693420227429
# Episode 53: score: -200.0 - reward: -246.08575969232137
# Episode 54: score: -200.0 - reward: -245.97628964879013
# Episode 55: score: -200.0 - reward: -241.98904198088445
# Episode 56: score: -200.0 - reward: -244.4801304275401
# Episode 57: score: -200.0 - reward: -245.11549295273306
# Episode 58: score: -200.0 - reward: -240.88676652671367
# Episode 59: score: -200.0 - reward: -239.29028498044337
# Episode 60: score: -200.0 - reward: -241.01408257562852
# Test Episode 60: test score: -200.0 - test reward: -242.25990367469598
# Episode 61: score: -200.0 - reward: -246.12717611542146
# Episode 62: score: -200.0 - reward: -242.57562223392736
# Episode 63: score: -200.0 - reward: -237.7263318617779
# Episode 64: score: -200.0 - reward: -246.94079414204276
# Episode 65: score: -200.0 - reward: -251.73725141794662
# Episode 66: score: -200.0 - reward: -243.51056857610848
# Episode 67: score: -200.0 - reward: -251.85280506877322
# Episode 68: score: -200.0 - reward: -251.28181136254892
# Episode 69: score: -200.0 - reward: -251.81759387568695
# Episode 70: score: -200.0 - reward: -251.8877511410518
# Test Episode 70: test score: -200.0 - test reward: -252.80944182467138
# Episode 71: score: -200.0 - reward: -252.83216408836557
# Episode 72: score: -200.0 - reward: -252.17042693045315
# Episode 73: score: -200.0 - reward: -252.7182221167141
# Episode 74: score: -200.0 - reward: -249.3126961402626
# Episode 75: score: -200.0 - reward: -253.15440844296387
# Episode 76: score: -200.0 - reward: -250.5904352751825
# Episode 77: score: -200.0 - reward: -252.19808070933712
# Episode 78: score: -200.0 - reward: -251.91235424470776
# Episode 79: score: -200.0 - reward: -251.41202595473558
# Episode 80: score: -200.0 - reward: -251.23203272373877
# Test Episode 80: test score: -200.0 - test reward: -245.31216851726344
# Episode 81: score: -200.0 - reward: -251.10795993591913
# Episode 82: score: -200.0 - reward: -251.15589767742648
# Episode 83: score: -200.0 - reward: -251.1807916794536
# Episode 84: score: -200.0 - reward: -251.28907095077616
# Episode 85: score: -200.0 - reward: -252.65774302346122
# Episode 86: score: -200.0 - reward: -251.81257782578643
# Episode 87: score: -200.0 - reward: -252.25384495440247
# Episode 88: score: -200.0 - reward: -251.59660326622824
# Episode 89: score: -200.0 - reward: -252.10068935066323
# Episode 90: score: -200.0 - reward: -251.50601341534198
# Test Episode 90: test score: -200.0 - test reward: -253.47222922707664
# Episode 91: score: -200.0 - reward: -253.2403125116718
# Episode 92: score: -200.0 - reward: -251.06631757054464
# Episode 93: score: -200.0 - reward: -253.06668135423436
# Episode 94: score: -200.0 - reward: -251.24392930594445
# Episode 95: score: -200.0 - reward: -252.9683576409838
# Episode 96: score: -200.0 - reward: -250.09268019655872
# Episode 97: score: -200.0 - reward: -252.82288480034623
# Episode 98: score: -200.0 - reward: -251.42966578774056
# Episode 99: score: -200.0 - reward: -246.47766089901887
# Episode 100: score: -200.0 - reward: -249.9033447917343
# Test Episode 100: test score: -200.0 - test reward: -253.2636688816633
# Episode 101: score: -200.0 - reward: -251.64327552124672
# Episode 102: score: -200.0 - reward: -249.56566869246402
# Episode 103: score: -200.0 - reward: -251.99694708620032
# Episode 104: score: -200.0 - reward: -250.03296815291145
# Episode 105: score: -200.0 - reward: -251.8328820045451
# Episode 106: score: -200.0 - reward: -250.45815446036636
# Episode 107: score: -200.0 - reward: -250.80117157550998
# Episode 108: score: -200.0 - reward: -250.18111253941024
# Episode 109: score: -200.0 - reward: -252.24105845076883
# Episode 110: score: -200.0 - reward: -238.13567613740463
# Test Episode 110: test score: -200.0 - test reward: -253.43499899575025
# Episode 111: score: -200.0 - reward: -252.10170752386048
# Episode 112: score: -200.0 - reward: -239.10311794846314
# Episode 113: score: -200.0 - reward: -244.75409771728346
# Episode 114: score: -200.0 - reward: -239.60476096435855
# Episode 115: score: -200.0 - reward: -242.07216538734832
# Episode 116: score: -200.0 - reward: -239.81487600026472
# Episode 117: score: -200.0 - reward: -243.99699035819248
# Episode 118: score: -200.0 - reward: -242.18990532802903
# Episode 119: score: -200.0 - reward: -237.08239646742206
# Episode 120: score: -200.0 - reward: -241.2534808392244
# Test Episode 120: test score: -200.0 - test reward: -231.11928877077938
# Episode 121: score: -200.0 - reward: -238.52390972128464
# Episode 122: score: -200.0 - reward: -239.8336372968254
# Episode 123: score: -200.0 - reward: -237.79532269209926
# Episode 124: score: -200.0 - reward: -241.00082332194737
# Episode 125: score: -200.0 - reward: -237.93501653554324
# Episode 126: score: -200.0 - reward: -241.99777725835452
# Episode 127: score: -200.0 - reward: -242.98314695768076
# Episode 128: score: -200.0 - reward: -241.5165037323382
# Episode 129: score: -200.0 - reward: -243.5667532890681
# Episode 130: score: -200.0 - reward: -243.26887429556572
# Test Episode 130: test score: -200.0 - test reward: -245.26194017379436
# Episode 131: score: -200.0 - reward: -243.84171796076023
# Episode 132: score: -200.0 - reward: -242.9061166335468
# Episode 133: score: -200.0 - reward: -243.46137077893945
# Episode 134: score: -200.0 - reward: -244.90048064490804
# Episode 135: score: -200.0 - reward: -243.88641362498288
# Episode 136: score: -200.0 - reward: -244.8027398533909
# Episode 137: score: -200.0 - reward: -245.2065519909521
# Episode 138: score: -200.0 - reward: -240.8996898025905
# Episode 139: score: -200.0 - reward: -246.36607086579573
# Episode 140: score: -200.0 - reward: -245.5284871380511
# Test Episode 140: test score: -200.0 - test reward: -242.11705480771766
# Episode 141: score: -200.0 - reward: -247.84559349601713
# Episode 142: score: -200.0 - reward: -245.3412023608414
# Episode 143: score: -200.0 - reward: -246.65292172296
# Episode 144: score: -200.0 - reward: -246.91290359664154
# Episode 145: score: -200.0 - reward: -244.897234290912
# Episode 146: score: -200.0 - reward: -245.71123825913702
# Episode 147: score: -200.0 - reward: -246.82017406132076
# Episode 148: score: -200.0 - reward: -246.23141250622155
# Episode 149: score: -200.0 - reward: -245.6975243946798
# Episode 150: score: -200.0 - reward: -244.84501970396866
# Test Episode 150: test score: -200.0 - test reward: -240.78291036800633
# Episode 151: score: -200.0 - reward: -246.66207995812132
# Episode 152: score: -200.0 - reward: -247.5812452737453
# Episode 153: score: -200.0 - reward: -238.43846355315594
# Episode 154: score: -200.0 - reward: -234.43187474074793
# Episode 155: score: -200.0 - reward: -238.79485503305472
# Episode 156: score: -200.0 - reward: -242.46589331304946
# Episode 157: score: -200.0 - reward: -237.42482502751645
# Episode 158: score: -200.0 - reward: -250.29876495899862
# Episode 159: score: -200.0 - reward: -248.53747262213727
# Episode 160: score: -200.0 - reward: -251.89564979586487
# Test Episode 160: test score: -200.0 - test reward: -247.23245157879788
# Episode 161: score: -200.0 - reward: -247.99985403789324
# Episode 162: score: -200.0 - reward: -244.71110517686384
# Episode 163: score: -200.0 - reward: -246.7913972403349
# Episode 164: score: -200.0 - reward: -252.58567805614052
# Episode 165: score: -200.0 - reward: -241.8444146235032
# Episode 166: score: -200.0 - reward: -242.59400709956847
# Episode 167: score: -200.0 - reward: -246.5283386351658
# Episode 168: score: -200.0 - reward: -243.35531125970297
# Episode 169: score: -200.0 - reward: -242.89208490407515
# Episode 170: score: -200.0 - reward: -247.66362520603744
# Test Episode 170: test score: -200.0 - test reward: -248.7544692130379
# Episode 171: score: -200.0 - reward: -252.43461306561466
# Episode 172: score: -200.0 - reward: -244.38882642658018
# Episode 173: score: -200.0 - reward: -250.82217410499666
# Episode 174: score: -200.0 - reward: -243.91128907343827
# Episode 175: score: -200.0 - reward: -243.65552591403062
# Episode 176: score: -200.0 - reward: -243.2300964022441
# Episode 177: score: -200.0 - reward: -242.31092308315817
# Episode 178: score: -200.0 - reward: -243.4522877777524
# Episode 179: score: -200.0 - reward: -243.633690477604
# Episode 180: score: -200.0 - reward: -244.17972534169564
# Test Episode 180: test score: -200.0 - test reward: -240.2757208999506
# Episode 181: score: -119.0 - reward: -145.81329300171808
# Episode 182: score: -200.0 - reward: -243.31400833883467
# Episode 183: score: -199.0 - reward: -241.73514481406477
# Episode 184: score: -191.0 - reward: -231.56054835778906
# Episode 185: score: -184.0 - reward: -223.03318933366114
# Episode 186: score: -183.0 - reward: -222.1775002536289
# Episode 187: score: -183.0 - reward: -228.05153656079955
# Episode 188: score: -132.0 - reward: -160.06118172486612
# Episode 189: score: -177.0 - reward: -214.8721906929952
# Episode 190: score: -172.0 - reward: -208.6489575951587
# Test Episode 190: test score: -182.0 - test reward: -219.74261350876452
# Episode 191: score: -190.0 - reward: -233.20012367758503
# Episode 192: score: -175.0 - reward: -211.59304547629011
# Episode 193: score: -184.0 - reward: -222.16217225805994
# Episode 194: score: -175.0 - reward: -212.31887366427796
# Episode 195: score: -179.0 - reward: -218.602376865124
# Episode 196: score: -200.0 - reward: -248.03622882202052
# Episode 197: score: -165.0 - reward: -201.4219486098016
# Episode 198: score: -150.0 - reward: -184.97779155811764
# Episode 199: score: -171.0 - reward: -209.4991806382288
# Episode 200: score: -91.0 - reward: -112.07698976508763
# Test Episode 200: test score: -162.0 - test reward: -196.94607775933002
# Episode 201: score: -142.0 - reward: -176.25836314719197
# Episode 202: score: -200.0 - reward: -253.09274073380635
# Episode 203: score: -151.0 - reward: -187.58316776706351
# Episode 204: score: -167.0 - reward: -204.93763388176149
# Episode 205: score: -196.0 - reward: -244.00569320446743
# Episode 206: score: -193.0 - reward: -239.6788452390246
# Episode 207: score: -183.0 - reward: -224.0920487508514
# Episode 208: score: -200.0 - reward: -252.388961641377
# Episode 209: score: -190.0 - reward: -235.26916715762243
# Episode 210: score: -188.0 - reward: -235.0646586566486
# Test Episode 210: test score: -185.0 - test reward: -226.94501089268888
# Episode 211: score: -200.0 - reward: -249.1163403754427
# Episode 212: score: -180.0 - reward: -224.6581691856964
# Episode 213: score: -178.0 - reward: -219.31175304373605
# Episode 214: score: -200.0 - reward: -248.9888227977217
# Episode 215: score: -183.0 - reward: -227.08354609198918
# Episode 216: score: -200.0 - reward: -242.4995290499294
# Episode 217: score: -173.0 - reward: -213.81957906963487
# Episode 218: score: -200.0 - reward: -247.68323193322593
# Episode 219: score: -183.0 - reward: -226.32274175577373
# Episode 220: score: -178.0 - reward: -220.97440695014265
# Test Episode 220: test score: -176.0 - test reward: -218.50829503291925
# Episode 221: score: -178.0 - reward: -221.4046382560422
# Episode 222: score: -170.0 - reward: -210.0804971948884
# Episode 223: score: -193.0 - reward: -240.17828528860207
# Episode 224: score: -200.0 - reward: -243.46404625354123
# Episode 225: score: -200.0 - reward: -240.29102206715393
# Episode 226: score: -200.0 - reward: -241.85913751994963
# Episode 227: score: -200.0 - reward: -241.8045245067792
# Episode 228: score: -200.0 - reward: -249.54297516601048
# Episode 229: score: -200.0 - reward: -239.1741526614971
# Episode 230: score: -200.0 - reward: -245.83836849710525
# Test Episode 230: test score: -200.0 - test reward: -244.72477299266592
# Episode 231: score: -200.0 - reward: -244.82666201777863
# Episode 232: score: -200.0 - reward: -243.31518122315907
# Episode 233: score: -200.0 - reward: -243.7213835060014
# Episode 234: score: -200.0 - reward: -243.66689750748137
# Episode 235: score: -200.0 - reward: -247.88194054354938
# Episode 236: score: -200.0 - reward: -244.171414426019
# Episode 237: score: -183.0 - reward: -224.67602067974883
# Episode 238: score: -200.0 - reward: -243.96624503701472
# Episode 239: score: -182.0 - reward: -222.96571889534127
# Episode 240: score: -200.0 - reward: -245.26213007349233
# Test Episode 240: test score: -200.0 - test reward: -242.13335402190194
# Episode 241: score: -200.0 - reward: -246.75556225997468
# Episode 242: score: -200.0 - reward: -245.02751215664017
# Episode 243: score: -194.0 - reward: -237.881801142205
# Episode 244: score: -200.0 - reward: -240.4089152729259
# Episode 245: score: -141.0 - reward: -168.8544270859713
# Episode 246: score: -200.0 - reward: -242.79301311373814
# Episode 247: score: -179.0 - reward: -219.53519487130643
# ...
# Episode 252: score: -200.0 - reward: -242.97233828694795
# Episode 253: score: -200.0 - reward: -243.47173003169783
# Episode 254: score: -190.0 - reward: -228.46337763658647
# Episode 255: score: -200.0 - reward: -231.54663039645806
# Episode 256: score: -200.0 - reward: -230.89779894173995
# Episode 257: score: -200.0 - reward: -231.1268028297464
# Episode 258: score: -200.0 - reward: -244.36920445524314
# Episode 259: score: -200.0 - reward: -243.79341264176452
# Episode 260: score: -200.0 - reward: -232.1763582075339
# Test Episode 260: test score: -200.0 - test reward: -230.98986565479106
# Episode 261: score: -200.0 - reward: -231.29883104401418
# Episode 262: score: -200.0 - reward: -231.4077043021987
# Episode 263: score: -200.0 - reward: -232.58131533401922
# Episode 264: score: -200.0 - reward: -231.82767012682243
# Episode 265: score: -200.0 - reward: -243.32276890900584
# Episode 266: score: -200.0 - reward: -230.77230166297136
# Episode 267: score: -200.0 - reward: -231.92583972439763
# Episode 268: score: -200.0 - reward: -237.78810351640803
# Episode 269: score: -144.0 - reward: -172.8835716163097
# Episode 270: score: -200.0 - reward: -230.80286449058232
# Test Episode 270: test score: -140.0 - test reward: -168.1170773242003
# Episode 271: score: -139.0 - reward: -167.0776086080524
# Episode 272: score: -200.0 - reward: -230.87230385682219
# Episode 273: score: -142.0 - reward: -172.148044229337
# Episode 274: score: -200.0 - reward: -230.98824900070363
# Episode 275: score: -145.0 - reward: -175.93634009362535
# Episode 276: score: -146.0 - reward: -177.45553072998916
# Episode 277: score: -146.0 - reward: -177.34918594548145
# Episode 278: score: -150.0 - reward: -181.85005695018882
# Episode 279: score: -148.0 - reward: -180.04637221582493
# Episode 280: score: -149.0 - reward: -180.61428089337826
# Test Episode 280: test score: -147.0 - test reward: -178.92145569649452
# Episode 281: score: -149.0 - reward: -181.00337434436622
# Episode 282: score: -200.0 - reward: -239.38014835765034
# Episode 283: score: -200.0 - reward: -247.35425500472527
# Episode 284: score: -145.0 - reward: -177.63249905262626
# Episode 285: score: -146.0 - reward: -177.41588938688082
# Episode 286: score: -148.0 - reward: -180.49615969556666
# Episode 287: score: -185.0 - reward: -229.47398307593113
# Episode 288: score: -135.0 - reward: -166.1993154543476
# Episode 289: score: -135.0 - reward: -165.26673745656407
# Episode 290: score: -134.0 - reward: -164.57991613884445
# Test Episode 290: test score: -129.0 - test reward: -158.50430810425237
# Episode 291: score: -124.0 - reward: -153.02394099283558
# Episode 292: score: -148.0 - reward: -182.3583717146308
# Episode 293: score: -128.0 - reward: -157.56749723722442
# Episode 294: score: -108.0 - reward: -131.10780480660597
# Episode 295: score: -173.0 - reward: -212.77439953053064
# Episode 296: score: -145.0 - reward: -178.32225576265964
# Episode 297: score: -92.0 - reward: -113.22885976124545
# Episode 298: score: -188.0 - reward: -235.660241935464
# Episode 299: score: -129.0 - reward: -159.8845857915539
# Episode 300: score: -173.0 - reward: -214.24616156217698
# Test Episode 300: test score: -137.0 - test reward: -170.7917863378622
# Episode 301: score: -179.0 - reward: -223.02615698736844
# Episode 302: score: -178.0 - reward: -221.50516496238555
# Episode 303: score: -134.0 - reward: -168.33335033753548
# Episode 304: score: -164.0 - reward: -205.28001537085285
# Episode 305: score: -134.0 - reward: -166.6901764208722
# Episode 306: score: -178.0 - reward: -220.5496054959093
# Episode 307: score: -168.0 - reward: -207.9636409996001
# Episode 308: score: -173.0 - reward: -215.01500831590948
# Episode 309: score: -114.0 - reward: -141.15255834047315
# Episode 310: score: -114.0 - reward: -141.09994934851295
# Test Episode 310: test score: -128.0 - test reward: -158.12341925117423
# Episode 311: score: -154.0 - reward: -191.47355761415463
# Episode 312: score: -141.0 - reward: -174.649777173013
# Episode 313: score: -111.0 - reward: -134.50784601331966
# Episode 314: score: -135.0 - reward: -167.97327991681337
# Episode 315: score: -165.0 - reward: -204.60846466940927
# Episode 316: score: -112.0 - reward: -136.37071145753356
# Episode 317: score: -190.0 - reward: -235.04980834616316
# Episode 318: score: -86.0 - reward: -105.60751221210418
# Episode 319: score: -155.0 - reward: -190.2587992339554
# Episode 320: score: -199.0 - reward: -242.57752068139973
# Test Episode 320: test score: -164.0 - test reward: -203.19504452530916
# Episode 321: score: -86.0 - reward: -104.97353347096887
# Episode 322: score: -199.0 - reward: -243.32711513818035
# Episode 323: score: -162.0 - reward: -198.99246020840314
# Episode 324: score: -187.0 - reward: -231.05495740773063
# Episode 325: score: -87.0 - reward: -107.01372495328222
# Episode 326: score: -87.0 - reward: -106.5900648855868
# Episode 327: score: -181.0 - reward: -222.62211045274375
# Episode 328: score: -200.0 - reward: -241.33065396005108
# Episode 329: score: -182.0 - reward: -223.5393356170414
# Episode 330: score: -110.0 - reward: -136.0937703156896
# Test Episode 330: test score: -200.0 - test reward: -241.8835883974783
# Episode 331: score: -200.0 - reward: -242.9019274689467
# Episode 332: score: -134.0 - reward: -161.39782954254252
# Episode 333: score: -169.0 - reward: -201.4150489922509
# Episode 334: score: -200.0 - reward: -232.4257018338392
# Episode 335: score: -200.0 - reward: -231.93609798969663
# Episode 336: score: -152.0 - reward: -182.4890786510017
# Episode 337: score: -170.0 - reward: -209.42065748534944
# Episode 338: score: -144.0 - reward: -173.59858441830175
# Episode 339: score: -165.0 - reward: -201.43203841477836
# Episode 340: score: -174.0 - reward: -212.69546874724088
# Test Episode 340: test score: -142.0 - test reward: -170.0556983121749
# Episode 341: score: -136.0 - reward: -164.03931410741848
# Episode 342: score: -181.0 - reward: -220.70480999068272
# Episode 343: score: -197.0 - reward: -242.66736632471063
# Episode 344: score: -166.0 - reward: -204.241409514094
# Episode 345: score: -163.0 - reward: -200.57224712415126
# Episode 346: score: -164.0 - reward: -202.36602482242702
# Episode 347: score: -168.0 - reward: -207.5019840220946
# Episode 348: score: -200.0 - reward: -248.0472138603224
# Episode 349: score: -200.0 - reward: -248.90971450974547
# Episode 350: score: -200.0 - reward: -230.8976407003292
# Test Episode 350: test score: -182.0 - test reward: -227.47943824491853
# Episode 351: score: -200.0 - reward: -251.91666194909146
# Episode 352: score: -200.0 - reward: -230.89449436035002
# Episode 353: score: -200.0 - reward: -230.89606793438642
# Episode 354: score: -184.0 - reward: -227.78934844084728
# Episode 355: score: -183.0 - reward: -226.2325756838343
# Episode 356: score: -139.0 - reward: -167.3985261586998
# Episode 357: score: -200.0 - reward: -252.32034120294674
# Episode 358: score: -137.0 - reward: -165.1536459355501
# Episode 359: score: -200.0 - reward: -252.76206555111088
# Episode 360: score: -200.0 - reward: -251.96525308685614
# Test Episode 360: test score: -134.0 - test reward: -162.47454201137697
# Episode 361: score: -138.0 - reward: -165.66035821417887
# Episode 362: score: -133.0 - reward: -161.80725850320823
# Episode 363: score: -134.0 - reward: -163.09418071201054
# Episode 364: score: -130.0 - reward: -157.62679558277492
# Episode 365: score: -132.0 - reward: -159.3896913385708
# Episode 366: score: -129.0 - reward: -155.7095365638265
# Episode 367: score: -136.0 - reward: -164.54741476884604
# Episode 368: score: -130.0 - reward: -157.5714230488393
# Episode 369: score: -130.0 - reward: -157.25167714707885
# Episode 370: score: -131.0 - reward: -158.661453708631
# Test Episode 370: test score: -130.0 - test reward: -157.40949034895294
# Episode 371: score: -136.0 - reward: -163.5543160713821
# Episode 372: score: -132.0 - reward: -159.94309416358163
# Episode 373: score: -135.0 - reward: -163.0633691626372
# Episode 374: score: -131.0 - reward: -158.5052171128186
# Episode 375: score: -141.0 - reward: -170.52523587847625
# Episode 376: score: -133.0 - reward: -160.4906803779259
# Episode 377: score: -134.0 - reward: -161.7146340720388
# Episode 378: score: -200.0 - reward: -230.88843580842934
# Episode 379: score: -133.0 - reward: -160.86821969545193
# Episode 380: score: -133.0 - reward: -160.59190711896113
# Test Episode 380: test score: -139.0 - test reward: -167.25511486712034
# Episode 381: score: -200.0 - reward: -244.83637574761548
# Episode 382: score: -200.0 - reward: -230.81935122040997
# Episode 383: score: -145.0 - reward: -173.90113683241628
# Episode 384: score: -145.0 - reward: -174.26110306705507
# Episode 385: score: -200.0 - reward: -244.5651628806629
# Episode 386: score: -145.0 - reward: -174.09365124459612
# Episode 387: score: -141.0 - reward: -169.6550936474247
# Episode 388: score: -142.0 - reward: -170.66690270186555
# Episode 389: score: -200.0 - reward: -230.97571076352656
# Episode 390: score: -200.0 - reward: -230.87695795256627
# Test Episode 390: test score: -144.0 - test reward: -173.1098181043587
# Episode 391: score: -200.0 - reward: -230.89961484159542
# Episode 392: score: -143.0 - reward: -171.50165605969957
# Episode 393: score: -129.0 - reward: -155.63242812384203
# Episode 394: score: -131.0 - reward: -157.9041642291907
# Episode 395: score: -129.0 - reward: -156.302217010461
# Episode 396: score: -124.0 - reward: -151.11751180809475
# Episode 397: score: -131.0 - reward: -158.7926875769049
# Episode 398: score: -130.0 - reward: -157.0831915657079
# Episode 399: score: -129.0 - reward: -155.98644972069982
# Episode 400: score: -130.0 - reward: -158.30881791815435
# Test Episode 400: test score: -130.0 - test reward: -158.068431839699
# Episode 401: score: -120.0 - reward: -147.61023712860276
# Episode 402: score: -124.0 - reward: -151.73092269655248
# Episode 403: score: -133.0 - reward: -161.39507849280616
# Episode 404: score: -125.0 - reward: -153.5878856731308
# Episode 405: score: -128.0 - reward: -156.50134360889516
# Episode 406: score: -175.0 - reward: -212.23961645921855
# Episode 407: score: -147.0 - reward: -179.73728135536453
# Episode 408: score: -146.0 - reward: -177.09626916760433
# Episode 409: score: -200.0 - reward: -249.33309554090738
# Episode 410: score: -127.0 - reward: -157.09253502698039
# Test Episode 410: test score: -188.0 - test reward: -230.68408741096619
# Episode 411: score: -200.0 - reward: -251.0777564945263
# Episode 412: score: -200.0 - reward: -247.59552268388427
# Episode 413: score: -200.0 - reward: -249.44912965746727
# Episode 414: score: -200.0 - reward: -250.968952790611
# Episode 415: score: -200.0 - reward: -251.19366838149335
# Episode 416: score: -200.0 - reward: -251.3276451952743
# Episode 417: score: -200.0 - reward: -252.3525371401498
# Episode 418: score: -200.0 - reward: -252.53241587788185
# Episode 419: score: -200.0 - reward: -252.6689481825388
# Episode 420: score: -200.0 - reward: -253.3944713198259
# Test Episode 420: test score: -200.0 - test reward: -252.75130694784016
# Episode 421: score: -200.0 - reward: -253.27943230484018
# Episode 422: score: -200.0 - reward: -253.20491640985543
# Episode 423: score: -200.0 - reward: -252.44183217266433
# Episode 424: score: -200.0 - reward: -252.2756908230155
# Episode 425: score: -200.0 - reward: -253.08199172700486
# Episode 426: score: -200.0 - reward: -253.23654169153818
# Episode 427: score: -200.0 - reward: -253.1045109612961
# Episode 428: score: -200.0 - reward: -252.93388517490322
# Episode 429: score: -200.0 - reward: -253.1149720478509
# Episode 430: score: -200.0 - reward: -253.20513399195286
# Test Episode 430: test score: -200.0 - test reward: -252.2684471436975
# Episode 431: score: -200.0 - reward: -253.15054920588838
# Episode 432: score: -200.0 - reward: -252.86129394829445
# Episode 433: score: -200.0 - reward: -252.6117557605711
# Episode 434: score: -200.0 - reward: -252.81317918299794
# Episode 435: score: -200.0 - reward: -253.1627995731273
# Episode 436: score: -200.0 - reward: -252.54861745709312
# Episode 437: score: -200.0 - reward: -252.94915679380713
# Episode 438: score: -200.0 - reward: -252.8824942402481
# Episode 439: score: -200.0 - reward: -253.44022870030582
# Episode 440: score: -200.0 - reward: -253.5730443929784
# Test Episode 440: test score: -200.0 - test reward: -252.7006776139072
# Episode 441: score: -200.0 - reward: -252.1764661549042
# Episode 442: score: -200.0 - reward: -252.36633136739613
# Episode 443: score: -200.0 - reward: -253.01822496854646
# Episode 444: score: -200.0 - reward: -252.54864204559195
# Episode 445: score: -200.0 - reward: -252.1173876921252
# Episode 446: score: -200.0 - reward: -252.33367837684148
# Episode 447: score: -200.0 - reward: -253.21299037932386
# Episode 448: score: -200.0 - reward: -251.6809186021053
# Episode 449: score: -200.0 - reward: -253.28194087071262
# Episode 450: score: -200.0 - reward: -249.8789082137278
# Test Episode 450: test score: -200.0 - test reward: -252.618934357788
# Episode 451: score: -200.0 - reward: -252.72012268469186
# Episode 452: score: -200.0 - reward: -252.27462673266962
# Episode 453: score: -200.0 - reward: -252.17628727163176
# Episode 454: score: -200.0 - reward: -252.6810438935711
# Episode 455: score: -200.0 - reward: -251.98463901116384
# Episode 456: score: -200.0 - reward: -251.99949027768244
# Episode 457: score: -200.0 - reward: -252.09353842813803
# Episode 458: score: -200.0 - reward: -251.97079265799044
# Episode 459: score: -200.0 - reward: -251.33793400786203
# Episode 460: score: -200.0 - reward: -252.0478269669125
# Test Episode 460: test score: -200.0 - test reward: -252.2663228064478
# Episode 461: score: -200.0 - reward: -252.5362438403783
# Episode 462: score: -200.0 - reward: -250.83600355338035
# Episode 463: score: -200.0 - reward: -251.72151055480114
# Episode 464: score: -200.0 - reward: -251.755077234313
# Episode 465: score: -200.0 - reward: -252.2129179181701
# Episode 466: score: -200.0 - reward: -251.04977795806383
# Episode 467: score: -200.0 - reward: -250.72239936359642
# Episode 468: score: -200.0 - reward: -250.04399093440801
# Episode 469: score: -200.0 - reward: -249.8433724903786
# Episode 470: score: -200.0 - reward: -249.5640995324361
# Test Episode 470: test score: -200.0 - test reward: -249.4282583595856
# Episode 471: score: -200.0 - reward: -248.8931351393943
# Episode 472: score: -200.0 - reward: -243.00763395139802
# Episode 473: score: -200.0 - reward: -248.40123395537108
# Episode 474: score: -200.0 - reward: -247.69065674223197
# Episode 475: score: -200.0 - reward: -247.36670902747392
# Episode 476: score: -200.0 - reward: -247.57771200022734
# Episode 477: score: -200.0 - reward: -248.0704586804935
# Episode 478: score: -200.0 - reward: -245.12049117812055
# Episode 479: score: -200.0 - reward: -243.92021814950672
# Episode 480: score: -200.0 - reward: -242.78768261122323
# Test Episode 480: test score: -200.0 - test reward: -243.23833790452605
# Episode 481: score: -200.0 - reward: -243.4185327769729
# Episode 482: score: -200.0 - reward: -242.85095898037625
# Episode 483: score: -200.0 - reward: -242.24399350275175
# Episode 484: score: -200.0 - reward: -242.4300138300508
# Episode 485: score: -200.0 - reward: -243.56748408594754
# Episode 486: score: -200.0 - reward: -242.80184169050034
# Episode 487: score: -200.0 - reward: -243.5813469096208
# Episode 488: score: -200.0 - reward: -243.45592578732072
# Episode 489: score: -200.0 - reward: -231.24980262858003
# Episode 490: score: -200.0 - reward: -244.17224481402548
# Test Episode 490: test score: -200.0 - test reward: -230.97604586297143
# Episode 491: score: -200.0 - reward: -244.47480545019582
# Episode 492: score: -200.0 - reward: -231.58106727114952
# Episode 493: score: -200.0 - reward: -244.33590755771675
# Episode 494: score: -200.0 - reward: -230.7975211644588
# Episode 495: score: -200.0 - reward: -241.52574458837927
# Episode 496: score: -200.0 - reward: -233.46769553093844
# Episode 497: score: -200.0 - reward: -232.60576099422934
# Episode 498: score: -200.0 - reward: -231.48824632613193
# Episode 499: score: -200.0 - reward: -233.2428538626076
# Episode 500: score: -200.0 - reward: -231.52439662915555
# Test Episode 500: test score: -200.0 - test reward: -231.60877531454614
# best test reward: 0
# Rewards data saved to DDQN_Fourier_MC_2.pkl

# %%
import matplotlib.pyplot as plt

def plot_rewards(rewards_data, algorithm_name="Q learning"):
    """Plot the average performance and IQR of the policy."""
    plt.figure(figsize=(14, 7))

    for epsilon, alphas in rewards_data.items():
        for alpha, data in alphas.items():
            # Calculate average and IQR across runs for each episode
            data = np.array(data)  # Convert to numpy array for easier slicing
            avg_rewards = np.mean(data, axis=0)
            lower_quartile = np.percentile(data, 25, axis=0)
            upper_quartile = np.percentile(data, 75, axis=0)

            episodes = np.arange(len(avg_rewards)) + 1
            plt.plot(episodes, avg_rewards, label=f'ε={epsilon}, α={alpha}')
            plt.fill_between(episodes, lower_quartile, upper_quartile, alpha=0.25)

    plt.title(f'Average Performance and IQR by Epsilon and Alpha ({algorithm_name})')
    plt.xlabel('Episodes')
    plt.ylabel('Average Reward')
    plt.legend()
    plt.show()

# %%
for name,dict_ in rewards_data.items():
    print('the name of the dictionary is ', name)
    print('the dictionary looks like ', dict_)
# Out:
# the name of the dictionary is  0.001
# the dictionary looks like  {0.0001: [[-200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -151.0, -200.0, -139.0, -153.0, -183.0, -129.0, -137.0, -148.0, -135.0, -98.0, -190.0, -198.0, -122.0, -185.0, -97.0, -200.0, -134.0, -200.0, -130.0, -200.0, -161.0, -200.0, -141.0, -146.0, -155.0, -167.0, -141.0, -200.0, -170.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -189.0, -200.0, -200.0, -194.0, -200.0, -190.0, -200.0, -195.0, -200.0, -200.0, -200.0, -175.0, -200.0, -187.0, -176.0, -200.0, -200.0, -200.0, -200.0, -200.0, -178.0, -200.0, -179.0, -200.0, -196.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -111.0, -110.0, -144.0, -200.0, -200.0, -197.0, -158.0, -200.0, -200.0, -194.0, -113.0, -200.0, -200.0, -125.0, -135.0, -140.0, -109.0, -149.0, -200.0, -107.0, -127.0, -109.0, -200.0, -108.0, -108.0, -109.0, -131.0, -125.0, -200.0, -106.0, -110.0, -130.0, -112.0, -131.0, -130.0, -133.0, -138.0, -124.0, -131.0, -145.0, -134.0, -153.0, -200.0, -137.0, -139.0, -142.0, -132.0, -153.0, -166.0, -152.0, -164.0, -113.0, -167.0, -171.0, -168.0, -152.0, -104.0, -102.0, -105.0, -180.0, -188.0, -191.0, -135.0, -108.0, -170.0, -107.0, -159.0, -151.0, -200.0, -132.0, -126.0, -92.0, -114.0, -113.0, -110.0, -119.0, -113.0, -182.0, -117.0, -117.0, -89.0, -112.0, -109.0, -109.0, -91.0, -97.0, -97.0, -108.0, -109.0, -110.0, -107.0, -200.0, -120.0, -123.0, -107.0, -135.0, -136.0, -137.0, -186.0, -176.0, -145.0, -200.0, -179.0, -200.0, -134.0, -200.0, -135.0, -170.0, -138.0, -149.0, -148.0, -189.0, -133.0, -136.0, -151.0, -146.0, -137.0, -135.0, -130.0, -128.0, -131.0, -125.0, -131.0, -127.0, -120.0, -128.0, -182.0, -129.0, -180.0, -131.0, -124.0, -114.0, -136.0, -131.0, -129.0, -131.0, -134.0, -174.0, -200.0, -134.0, -199.0, -195.0, -134.0, -130.0, -200.0, -200.0, -134.0, -137.0, -137.0, -135.0, -138.0, -139.0, -139.0, -145.0, -200.0, -145.0, -200.0, -200.0, -200.0, -135.0, -145.0, -200.0, -200.0, -200.0, -200.0, -148.0, -148.0, -142.0, -200.0, -143.0, -200.0, -200.0, -200.0, -154.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -180.0, -200.0, -200.0, -200.0, -175.0, -159.0, -185.0, -156.0, -156.0, -161.0, -175.0, -184.0, -163.0, -159.0, -160.0, -158.0, -155.0, -155.0, -157.0, -169.0, -174.0, -174.0, -177.0, -178.0, -180.0, -185.0, -175.0, -181.0, -179.0, -179.0, -176.0, -184.0, -191.0, -182.0, -171.0, -171.0, -170.0, -166.0, -119.0, -199.0, -193.0, -183.0, -181.0, -176.0, -186.0, -200.0, -200.0, -200.0, -199.0, -137.0, -145.0, -141.0, -200.0, -139.0, -200.0, -121.0, -120.0, -200.0, -199.0, -135.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -142.0, -200.0, -200.0, -170.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -178.0, -200.0, -200.0, -200.0, -177.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, -200.0, - ...

# %%
plot_rewards(rewards_data, algorithm_name="DDQN (Fourier MountainCar)")
