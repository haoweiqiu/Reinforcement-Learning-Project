# %%
from torch import nn
from torch.nn import functional
import torch
from torch import nn
from torch.utils.data import TensorDataset, DataLoader
import gym
from collections import deque
import random
import numpy as np

# %%
class TileCoder_Carpole:
    def __init__(self, num_tiles_per_dim, num_tilings, state_limits, clip_limits=None):
        self.num_tiles_per_dim = num_tiles_per_dim
        self.num_tilings = num_tilings
        self.state_limits = np.array(state_limits)
        self.clip_limits = np.array(clip_limits) if clip_limits is not None else state_limits
        self.tile_widths = np.zeros(len(state_limits))
        self.offsets = np.zeros(len(state_limits))
        for i, (clip_limit, state_limit) in enumerate(zip(self.clip_limits, self.state_limits)):
            # Use the clipped limit for calculating tile width, but keep the original limit for clipping states
            self.tile_widths[i] = (clip_limit[1] - clip_limit[0]) / (num_tiles_per_dim - 2)
            self.offsets[i] = self.tile_widths[i] / (2 * num_tilings)
        self.total_tiles = num_tilings * num_tiles_per_dim * len(state_limits)

    def get_tile_indices(self, state):
        tile_indices = np.zeros(self.total_tiles)
        for tiling in range(self.num_tilings):
            for dim, (state_dim, limits, clip_limit, offset, tile_width) in enumerate(
                zip(state, self.state_limits, self.clip_limits, self.offsets, self.tile_widths)
            ):
                clipped_state_dim = np.clip(state_dim, clip_limit[0], clip_limit[1])
                norm_state_dim = ((clipped_state_dim - clip_limit[0]) + (tiling * offset)) / tile_width
                # Calculate tile index for the dimension, with special handling for outermost tiles
                tile = int(norm_state_dim) + 1
                tile = max(1, min(self.num_tiles_per_dim - 2, tile))
                index = (tiling * self.num_tiles_per_dim * len(self.state_limits)) + (dim * self.num_tiles_per_dim) + tile
                tile_indices[index] = 1
        return tile_indices

num_tiles_per_dim = 100
num_tilings = 5
state_limits = [[-2.4, 2.4], [-np.inf, np.inf], [-12 * 2 * np.pi / 360, 12 * 2 * np.pi / 360], [-np.inf, np.inf]]
clip_limits = [[-2.4, 2.4], [-10, 10], [-12 * 2 * np.pi / 360, 12 * 2 * np.pi / 360], [-10, 10]]

# Initialize your tile coder here

tile_coder = TileCoder_Carpole(num_tiles_per_dim=num_tiles_per_dim,
                              num_tilings=num_tilings,
                              state_limits=state_limits,
                              clip_limits=clip_limits
                              )
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import pickle

def save_rewards_data(rewards_data, filename='rewards_data.pkl'):
    """Save the rewards data to a pickle file."""
    with open(filename, 'wb') as file:
        pickle.dump(rewards_data, file)
    print(f'Rewards data saved to {filename}')


def load_rewards_data(filename='rewards_data.pkl'):
    """Load the rewards data from a pickle file."""
    try:
        with open(filename, 'rb') as file:
            rewards_data = pickle.load(file)
        print(f'Rewards data loaded from {filename}')
        return rewards_data
    except FileNotFoundError:
        print(f'Error: The file {filename} does not exist. Please check the file path and try again.')
        return None
    except Exception as e:
        print(f'An error occurred while loading the data: {e}')
        return None

# %%
import matplotlib.pyplot as plt

def plot_rewards(rewards_data, algorithm_name="Q learning"):
    """Plot the average performance and IQR of the policy."""
    plt.figure(figsize=(14, 7))

    for epsilon, alphas in rewards_data.items():
        for alpha, data in alphas.items():
            # Calculate average and IQR across runs for each episode
            data = np.array(data)  # Convert to numpy array for easier slicing
            avg_rewards = np.mean(data, axis=0)
            lower_quartile = np.percentile(data, 25, axis=0)
            upper_quartile = np.percentile(data, 75, axis=0)

            episodes = np.arange(len(avg_rewards)) + 1
            plt.plot(episodes, avg_rewards, label=f'ε={epsilon}, α={alpha}')
            plt.fill_between(episodes, lower_quartile, upper_quartile, alpha=0.25)

    plt.title(f'Average Performance and IQR by Epsilon and Alpha ({algorithm_name})')
    plt.xlabel('Episodes')
    plt.ylabel('Average Reward')
    plt.legend()
    plt.show()

# %%
# class RBFDiscritizer:
#     def __init__(self, num_rbf_per_state, state_bounds, num_states):
#         self.num_rbf_per_state = num_rbf_per_state
#         self.state_bounds = state_bounds
#         self.num_states = num_states
#         self.num_rbf = num_rbf_per_state * np.ones(self.num_states).astype(int)
#         self.num_ind = np.prod(self.num_rbf)
#         self.width = 1. / (self.num_rbf - 1.)
#         self.rbf_sigma = self.width[0] / 2.
#         self.rbf_den = 2 * self.rbf_sigma ** 2
#         self.centres = self.build_centers()

#     def build_centers(self):
#         # Generate a meshgrid for the centers based on the number of RBFs per dimension
#         ranges = [np.linspace(0, 1, num) for num in self.num_rbf]
#         mesh = np.meshgrid(*ranges, indexing='ij')
#         # Flatten the meshgrid and stack it to get the center coordinates
#         center_coords = np.stack([axis.flatten() for axis in mesh], axis=-1)
#         return center_coords

#     def normalize_state(self, state):
#         normalized = np.zeros(len(state))
#         for i, (lower, upper) in enumerate(self.state_bounds):
#             normalized[i] = (state[i] - lower) / (upper - lower)
#         return normalized

#     def encode(self, state):
#         normalized_state = self.normalize_state(state)
#         _phi = np.zeros(self.num_ind)
#         for _k in range(self.num_ind):
#             _phi[_k] = np.exp(-np.linalg.norm(normalized_state - self.centres[_k, :]) ** 2 / self.rbf_den)
#         return _phi

# %%
class Model(nn.Module):
    def __init__(self, input_features, output_values):
        super(Model, self).__init__()
        self.fc1 = nn.Linear(in_features=input_features, out_features=32)
        self.fc2 = nn.Linear(in_features=32, out_features=32)
        self.fc3 = nn.Linear(in_features=32, out_features=output_values)

    def forward(self, x):
        x = functional.selu(self.fc1(x))
        x = functional.selu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
# class DDQN:
#     def __init__(self, env, discretizer, use_cuda=True, learning_rate=1e-5, gamma=0.7, memory_len=10000, start_epsilon=1):
#         self.device = torch.device("cuda" if use_cuda and torch.cuda.is_available() else "cpu")
#         self.env = env
#         self.discretizer = discretizer
#         self.learning_rate = learning_rate
#         self.gamma = gamma

#         self.epsilon = start_epsilon
#         self.min_epsilon = 0.1
#         self.epsilon_decay = 0.9 / 2.5e3
#         self.memory_len = memory_len
#         self.memory = deque(maxlen=self.memory_len)
#         self.criterion = nn.MSELoss()

#         input_features = discretizer.num_ind
#         output_values = env.action_space.n
#         self.policy_net = Model(input_features, output_values).to(self.device)
#         self.target_net = Model(input_features, output_values).to(self.device)

#         self.target_net.load_state_dict(self.policy_net.state_dict())
#         self.target_net.eval()

#     def get_states_tensor(self, sample, states_idx):
#         sample_len = len(sample)
#         states_tensor = torch.empty((sample_len, self.discretizer.num_ind), dtype=torch.float32, requires_grad=False)

#         for i, state in enumerate(sample):
#             num_array = state[states_idx]
#             states_tensor[i, :] = torch.from_numpy(num_array)

#         return states_tensor

#     def normalize_state(self, state):
#         state[0] /= 2.5
#         state[1] /= 2.5
#         state[2] /= 0.3
#         state[3] /= 0.3

#     def state_reward(self, state, env_reward):
#         return env_reward - (abs(state[0]) + abs(state[2])) / 2.5

#     def get_action(self, state, e=None):
#         if e is None:
#             e = self.epsilon
#         if random.random() < e:
#             return random.randrange(0, self.env.action_space.n)
#         else:
#             encoded_state = self.discretizer.encode(state)
#             encoded_state = torch.tensor(encoded_state, dtype=torch.float32, device=self.device)
#             return self.policy_net(encoded_state).argmax().item()

#     def fit(self, model, inputs, labels):
#         inputs = inputs.to(self.device)
#         labels = labels.to(self.device)
#         train_ds = TensorDataset(inputs, labels)
#         train_dl = DataLoader(train_ds, batch_size=5)

#         optimizer = torch.optim.Adam(params=model.parameters(), lr=self.learning_rate)
#         model.train()
#         total_loss = 0.0

#         for x, y in train_dl:
#             out = model(x)
#             loss = self.criterion(out, y)
#             total_loss += loss.item()
#             optimizer.zero_grad()
#             loss.backward()
#             optimizer.step()

#         model.eval()
#         return total_loss / len(train_dl)

#     def optimize_model(self, train_batch_size=100):
#         if len(self.memory) < train_batch_size:
#             return
#         train_sample = random.sample(self.memory, train_batch_size)

#         state = self.get_states_tensor(train_sample, 0).to(self.device)
#         next_state = self.get_states_tensor(train_sample, 3).to(self.device)

#         q_estimates = self.policy_net(state).detach()
#         next_state_q_estimates = self.target_net(next_state).detach()
#         next_actions = self.policy_net(next_state).argmax(dim=1)

#         for i in range(len(train_sample)):
#             next_action = next_actions[i].item()
#             q_estimates[i][train_sample[i][1]] = (self.state_reward(next_state[i], train_sample[i][2]) +
#                                                   self.gamma * next_state_q_estimates[i][next_action].item())

#         self.fit(self.policy_net, state, q_estimates)

#     def train_one_episode(self):
#         current_state = self.env.reset()
#         self.normalize_state(current_state)
#         done = False
#         score = 0
#         reward = 0
#         while not done:
#             action = self.get_action(current_state, self.epsilon)
#             next_state, env_reward, done, _ = self.env.step(action)
#             self.normalize_state(next_state)
#             encoded_current_state = self.discretizer.encode(current_state)
#             encoded_next_state = self.discretizer.encode(next_state)
#             self.memory.append((encoded_current_state, action, env_reward, encoded_next_state))
#             current_state = next_state
#             score += env_reward
#             reward += self.state_reward(next_state, env_reward)

#             self.optimize_model(100)

#             self.epsilon = max(self.min_epsilon, self.epsilon - self.epsilon_decay)

#         return score, reward

#     def test(self):
#         state = self.env.reset()
#         self.normalize_state(state)
#         done = False
#         score = 0
#         reward = 0
#         while not done:
#             action = self.get_action(state, 0)  # Using 0 to bypass random action selection
#             state, env_reward, done, _ = self.env.step(action)
#             self.normalize_state(state)
#             score += env_reward
#             reward += self.state_reward(state, env_reward)

#         return score, reward

# %%
class DDQN:
    def __init__(self, env, tile_coder, use_cuda=True, learning_rate=1e-5, gamma=0.7, memory_len=10000, start_epsilon=1):
        self.device = torch.device("cuda" if use_cuda and torch.cuda.is_available() else "cpu")
        self.env = env
        self.tile_coder = tile_coder
        self.learning_rate = learning_rate
        self.gamma = gamma

        self.epsilon = start_epsilon
        self.min_epsilon = 0.1
        self.epsilon_decay = 0.9 / 2.5e3
        self.memory_len = memory_len
        self.memory = deque(maxlen=self.memory_len)
        self.criterion = nn.MSELoss()

        input_features = tile_coder.total_tiles
        output_values = env.action_space.n
        self.policy_net = Model(input_features, output_values).to(self.device)
        self.target_net = Model(input_features, output_values).to(self.device)

        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()

    def get_states_tensor(self, sample, states_idx):
        sample_len = len(sample)
        states_tensor = torch.empty((sample_len, self.tile_coder.total_tiles), dtype=torch.float32, requires_grad=False)

        for i, state in enumerate(sample):
            num_array = state[states_idx]
            states_tensor[i, :] = torch.from_numpy(num_array)

        return states_tensor

    def state_reward(self, state, env_reward):
        return env_reward - (abs(state[0]) + abs(state[2])) / 2.5

    def get_action(self, state, e=None):
        if e is None:
            e = self.epsilon
        if random.random() < e:
            return random.randrange(0, self.env.action_space.n)
        else:
            encoded_state = self.tile_coder.get_tile_indices(state)
            encoded_state = torch.tensor(encoded_state, dtype=torch.float32, device=self.device)
            return self.policy_net(encoded_state).argmax().item()

    def fit(self, model, inputs, labels):
        inputs = inputs.to(self.device)
        labels = labels.to(self.device)
        train_ds = TensorDataset(inputs, labels)
        train_dl = DataLoader(train_ds, batch_size=5)

        optimizer = torch.optim.Adam(params=model.parameters(), lr=self.learning_rate)
        model.train()
        total_loss = 0.0

        for x, y in train_dl:
            out = model(x)
            loss = self.criterion(out, y)
            total_loss += loss.item()
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        model.eval()
        return total_loss / len(train_dl)

    def optimize_model(self, train_batch_size=100):
        if len(self.memory) < train_batch_size:
            return
        train_sample = random.sample(self.memory, train_batch_size)

        state = self.get_states_tensor(train_sample, 0).to(self.device)
        next_state = self.get_states_tensor(train_sample, 3).to(self.device)

        q_estimates = self.policy_net(state).detach()
        next_state_q_estimates = self.target_net(next_state).detach()
        next_actions = self.policy_net(next_state).argmax(dim=1)

        for i in range(len(train_sample)):
            next_action = next_actions[i].item()
            q_estimates[i][train_sample[i][1]] = (self.state_reward(next_state[i], train_sample[i][2]) +
                                                  self.gamma * next_state_q_estimates[i][next_action].item())

        self.fit(self.policy_net, state, q_estimates)

    def train_one_episode(self):
        current_state = self.env.reset()
        done = False
        score = 0
        reward = 0
        while not done:
            action = self.get_action(current_state, self.epsilon)
            next_state, env_reward, done, _ = self.env.step(action)
            encoded_current_state = self.tile_coder.get_tile_indices(current_state)
            encoded_next_state = self.tile_coder.get_tile_indices(next_state)
            self.memory.append((encoded_current_state, action, env_reward, encoded_next_state))
            current_state = next_state
            score += env_reward
            reward += self.state_reward(next_state, env_reward)

            self.optimize_model(100)

            self.epsilon = max(self.min_epsilon, self.epsilon - self.epsilon_decay)

        return score, reward

    def test(self):
        state = self.env.reset()
        done = False
        score = 0
        reward = 0
        while not done:
            action = self.get_action(state, 0)  # Using 0 to bypass random action selection
            state, env_reward, done, _ = self.env.step(action)
            score += env_reward
            reward += self.state_reward(state, env_reward)

        return score, reward

# %%
num_states = 4
num_rbf_per_state=4
state_bounds = [(-2.4, 2.4), (-10.0, 10.0), (-0.42, 0.42), (-10.0, 10.0)]

# discretizer = RBFDiscritizer(num_rbf_per_state=num_rbf_per_state, state_bounds=state_bounds, num_states=num_states)

env = gym.make('CartPole-v1')
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(

# %%
def main(used_alpha, used_epsilon, env, tile_coder, target_update_delay, test_delay, memory_len=10000, num_runs=1, num_episode=1000, save_file=""):


    # Initialize storage for reward data
    rewards_data = {epsilon: {alpha: [] for alpha in used_alpha} for epsilon in used_epsilon}

    for epsilon in used_epsilon:
        for alpha in used_alpha:
            print(f"Training with epsilon: {epsilon}, alpha: {alpha}")
            run_rewards = []  # Collect rewards for each run for the current config

            for run in range(num_runs):

                # avoid decay
                current_epsilon = epsilon

                print(f"Run {run + 1}/{num_runs}")

                # renew the wrapper class
                ddqn = DDQN(
                    env=env,
                    tile_coder=tile_coder,
                    use_cuda=True,
                    learning_rate=alpha,
                    gamma=0.99,
                    memory_len=memory_len,
                    start_epsilon=current_epsilon
                )

                best_test_reward = 0

                episode_rewards = []  # Collect rewards for each episode in the current run
                for i in range(num_episode):
                    score, reward = ddqn.train_one_episode()

                    print(f'Episode {i + 1}: score: {score} - reward: {reward}')

                    if i % target_update_delay == 0:
                        ddqn.target_net.load_state_dict(ddqn.policy_net.state_dict())
                        ddqn.target_net.eval()

                    if (i + 1) % test_delay == 0:
                        test_score, test_reward = ddqn.test()
                        print(f'Test Episode {i + 1}: test score: {test_score} - test reward: {test_reward}')
                        if test_reward > best_test_reward:
                            print('New best test reward. Saving model')
                            best_test_reward = test_reward
                            # torch.save(ddqn.policy_net.state_dict(), f'policy_net_{run}.pth')

                    # Add the rewards
                    episode_rewards.append(score)

                if num_episode % test_delay != 0:
                    test_score, test_reward = ddqn.test()
                    print(f'Test Episode {num_episode}: test score: {test_score} - test reward: {test_reward}')
                    if test_reward > best_test_reward:
                        print('New best test reward. Saving model')
                        best_test_reward = test_reward
                        # torch.save(ddqn.policy_net.state_dict(), f'policy_net_{run}.pth')

                # save the run rewards
                run_rewards.append(episode_rewards)

                print(f'best test reward: {best_test_reward}')

            # Store the rewards for the current epsilon and alpha configuration
            rewards_data[epsilon][alpha] = run_rewards

    if not(save_file == ""):
        save_rewards_data(rewards_data, save_file)

    return rewards_data

# %%
rewards_data = main(
    used_alpha=[1e-2,1e-3,1e-4],
    used_epsilon=[0.1,0.5,0.9],  # start epsilon
    env=env,
    tile_coder=tile_coder,
    target_update_delay=5,
    test_delay=10,
    memory_len=10000,
    num_runs=1,
    num_episode=500,
    save_file="example_data.pkl"
)
# Out:
# Training with epsilon: 0.1, alpha: 0.01
# Run 1/1
# /usr/local/lib/python3.10/dist-packages/gym/utils/passive_env_checker.py:241: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# Streaming output truncated to the last 5000 lines.
# Episode 27: score: 9.0 - reward: 8.3818636149168
# Episode 28: score: 10.0 - reward: 9.461746913194656
# Episode 29: score: 10.0 - reward: 9.318017593026159
# Episode 30: score: 10.0 - reward: 9.224015228450298
# Test Episode 30: test score: 9.0 - test reward: 8.356846764683725
# Episode 31: score: 10.0 - reward: 9.480265969038012
# Episode 32: score: 10.0 - reward: 9.361182302236559
# Episode 33: score: 10.0 - reward: 9.527260144799948
# Episode 34: score: 10.0 - reward: 9.4876094520092
# Episode 35: score: 9.0 - reward: 8.398934461176395
# Episode 36: score: 12.0 - reward: 11.439576788246631
# Episode 37: score: 37.0 - reward: 35.47758551985025
# Episode 38: score: 10.0 - reward: 9.384692607820034
# Episode 39: score: 28.0 - reward: 26.637432661652568
# Episode 40: score: 10.0 - reward: 9.425081642344596
# Test Episode 40: test score: 9.0 - test reward: 8.315495392680168
# Episode 41: score: 41.0 - reward: 39.947439882159216
# Episode 42: score: 13.0 - reward: 12.404550598189235
# Episode 43: score: 23.0 - reward: 22.231110682338475
# Episode 44: score: 11.0 - reward: 10.394759285449982
# Episode 45: score: 31.0 - reward: 29.41010170280934
# Episode 46: score: 14.0 - reward: 13.07760768532753
# Episode 47: score: 11.0 - reward: 10.542280112951993
# Episode 48: score: 19.0 - reward: 18.076493132114415
# Episode 49: score: 11.0 - reward: 10.273815368115903
# Episode 50: score: 13.0 - reward: 12.20885527729988
# Test Episode 50: test score: 9.0 - test reward: 8.317635571956634
# Episode 51: score: 12.0 - reward: 11.289843431115152
# Episode 52: score: 14.0 - reward: 13.219409625604747
# Episode 53: score: 13.0 - reward: 12.081826788187028
# Episode 54: score: 17.0 - reward: 16.15053591430187
# Episode 55: score: 11.0 - reward: 10.343927769362924
# Episode 56: score: 18.0 - reward: 17.10348944813013
# Episode 57: score: 10.0 - reward: 9.446202858537434
# Episode 58: score: 9.0 - reward: 8.571413725614548
# Episode 59: score: 16.0 - reward: 15.22707977741957
# Episode 60: score: 23.0 - reward: 22.145663732290263
# Test Episode 60: test score: 11.0 - test reward: 10.406004827842116
# New best test reward. Saving model
# Episode 61: score: 9.0 - reward: 8.437941563129426
# Episode 62: score: 12.0 - reward: 11.188983763754369
# Episode 63: score: 11.0 - reward: 10.40182970482856
# Episode 64: score: 22.0 - reward: 20.010456258058547
# Episode 65: score: 15.0 - reward: 14.210272447764874
# Episode 66: score: 16.0 - reward: 15.095243638753892
# Episode 67: score: 47.0 - reward: 45.26582595929503
# Episode 68: score: 45.0 - reward: 42.58113268092274
# Episode 69: score: 14.0 - reward: 13.2146873280406
# Episode 70: score: 14.0 - reward: 13.22322598621249
# Test Episode 70: test score: 10.0 - test reward: 9.244214823842048
# Episode 71: score: 21.0 - reward: 19.893841249495747
# Episode 72: score: 12.0 - reward: 11.383167846500873
# Episode 73: score: 17.0 - reward: 16.266212299466133
# Episode 74: score: 52.0 - reward: 49.59014051742851
# Episode 75: score: 48.0 - reward: 45.34444042816758
# Episode 76: score: 23.0 - reward: 21.433968516439197
# Episode 77: score: 14.0 - reward: 13.186363635957237
# Episode 78: score: 17.0 - reward: 15.68863596022129
# Episode 79: score: 32.0 - reward: 29.694436322152608
# Episode 80: score: 18.0 - reward: 16.850230653584003
# Test Episode 80: test score: 9.0 - test reward: 8.506361977756024
# Episode 81: score: 22.0 - reward: 20.94576720073819
# Episode 82: score: 9.0 - reward: 8.459675773978233
# Episode 83: score: 23.0 - reward: 21.9908010289073
# Episode 84: score: 29.0 - reward: 27.096738042682407
# Episode 85: score: 19.0 - reward: 17.991225366294383
# Episode 86: score: 12.0 - reward: 11.360320100188256
# Episode 87: score: 27.0 - reward: 25.582518009841444
# Episode 88: score: 25.0 - reward: 22.63025994896889
# Episode 89: score: 21.0 - reward: 19.7292466044426
# Episode 90: score: 17.0 - reward: 15.722208094596864
# Test Episode 90: test score: 69.0 - test reward: 66.62372006997465
# New best test reward. Saving model
# Episode 91: score: 26.0 - reward: 24.582312001660465
# Episode 92: score: 14.0 - reward: 13.303514990210532
# Episode 93: score: 47.0 - reward: 45.11471397019925
# Episode 94: score: 23.0 - reward: 21.384241291880606
# Episode 95: score: 62.0 - reward: 58.68321377485993
# Episode 96: score: 14.0 - reward: 12.93205504119396
# Episode 97: score: 23.0 - reward: 22.08567593246698
# Episode 98: score: 27.0 - reward: 25.687691688723863
# Episode 99: score: 12.0 - reward: 11.327651715278625
# Episode 100: score: 40.0 - reward: 38.33554288446904
# Test Episode 100: test score: 39.0 - test reward: 35.4556141242385
# Episode 101: score: 19.0 - reward: 17.891542695462704
# Episode 102: score: 38.0 - reward: 35.542476412653926
# Episode 103: score: 18.0 - reward: 17.21744417026639
# Episode 104: score: 11.0 - reward: 10.312701296061277
# Episode 105: score: 15.0 - reward: 14.277420879155395
# Episode 106: score: 14.0 - reward: 13.149840562045574
# Episode 107: score: 21.0 - reward: 20.039021836966285
# Episode 108: score: 17.0 - reward: 16.11124987304211
# Episode 109: score: 15.0 - reward: 13.927520695328715
# Episode 110: score: 13.0 - reward: 12.010341873764991
# Test Episode 110: test score: 10.0 - test reward: 9.365870455652477
# Episode 111: score: 14.0 - reward: 13.173182226717474
# Episode 112: score: 28.0 - reward: 26.548960579931734
# Episode 113: score: 10.0 - reward: 9.33802060931921
# Episode 114: score: 30.0 - reward: 28.419242577999835
# Episode 115: score: 17.0 - reward: 16.033278806507585
# Episode 116: score: 10.0 - reward: 9.440372329950334
# Episode 117: score: 28.0 - reward: 26.69626399949193
# Episode 118: score: 34.0 - reward: 32.19805678874255
# Episode 119: score: 14.0 - reward: 13.257265402562917
# Episode 120: score: 11.0 - reward: 10.345671334862708
# Test Episode 120: test score: 11.0 - test reward: 10.336892342567445
# Episode 121: score: 24.0 - reward: 23.17267886660993
# Episode 122: score: 35.0 - reward: 33.274538588523875
# Episode 123: score: 16.0 - reward: 15.378712363541123
# Episode 124: score: 17.0 - reward: 15.97818134278059
# Episode 125: score: 27.0 - reward: 24.83969042897224
# Episode 126: score: 15.0 - reward: 13.963087077438834
# Episode 127: score: 27.0 - reward: 26.00902688354254
# Episode 128: score: 13.0 - reward: 12.318405009806154
# Episode 129: score: 26.0 - reward: 24.57380031198263
# Episode 130: score: 14.0 - reward: 13.3266361951828
# Test Episode 130: test score: 10.0 - test reward: 9.391694217920302
# Episode 131: score: 20.0 - reward: 18.43778911978006
# Episode 132: score: 10.0 - reward: 9.385664011724291
# Episode 133: score: 16.0 - reward: 14.73805150091648
# Episode 134: score: 19.0 - reward: 18.08711065500975
# Episode 135: score: 28.0 - reward: 26.396843613684176
# Episode 136: score: 9.0 - reward: 8.511490359902382
# Episode 137: score: 19.0 - reward: 17.87388010323048
# Episode 138: score: 33.0 - reward: 31.3615380436182
# Episode 139: score: 13.0 - reward: 12.1776764921844
# Episode 140: score: 19.0 - reward: 17.997403018176556
# Test Episode 140: test score: 25.0 - test reward: 24.13698665648699
# Episode 141: score: 13.0 - reward: 12.391030037403107
# Episode 142: score: 14.0 - reward: 13.280614058673383
# Episode 143: score: 23.0 - reward: 21.569646205008027
# Episode 144: score: 15.0 - reward: 14.037136373296379
# Episode 145: score: 11.0 - reward: 10.150281405448913
# Episode 146: score: 20.0 - reward: 18.628919538855552
# Episode 147: score: 19.0 - reward: 18.132190702855585
# Episode 148: score: 21.0 - reward: 19.900795996561644
# Episode 149: score: 47.0 - reward: 44.10612611025571
# Episode 150: score: 30.0 - reward: 28.580753965675825
# Test Episode 150: test score: 10.0 - test reward: 9.375377248227595
# Episode 151: score: 16.0 - reward: 14.888996079564095
# Episode 152: score: 33.0 - reward: 30.49394613802433
# Episode 153: score: 14.0 - reward: 13.256020417809486
# Episode 154: score: 10.0 - reward: 9.153805917501451
# Episode 155: score: 22.0 - reward: 20.79158999957144
# Episode 156: score: 12.0 - reward: 11.311784055829047
# Episode 157: score: 12.0 - reward: 11.234962110966443
# Episode 158: score: 9.0 - reward: 8.428014734387396
# Episode 159: score: 20.0 - reward: 18.966723103821273
# Episode 160: score: 44.0 - reward: 41.73622713908555
# Test Episode 160: test score: 9.0 - test reward: 8.317637005448342
# Episode 161: score: 29.0 - reward: 28.013965641334657
# Episode 162: score: 27.0 - reward: 25.739010448753834
# Episode 163: score: 34.0 - reward: 32.731149472668776
# Episode 164: score: 18.0 - reward: 17.281158551573757
# Episode 165: score: 17.0 - reward: 16.098768895864485
# Episode 166: score: 16.0 - reward: 14.95241264477372
# Episode 167: score: 30.0 - reward: 28.346714143455024
# Episode 168: score: 13.0 - reward: 12.176738345250488
# Episode 169: score: 30.0 - reward: 28.68579551707953
# Episode 170: score: 23.0 - reward: 21.59506743252277
# Test Episode 170: test score: 10.0 - test reward: 9.50992709696293
# Episode 171: score: 18.0 - reward: 16.810525730252266
# Episode 172: score: 27.0 - reward: 26.03336780518293
# Episode 173: score: 40.0 - reward: 38.156576137617236
# Episode 174: score: 13.0 - reward: 12.514264433830979
# Episode 175: score: 21.0 - reward: 20.128615571558477
# Episode 176: score: 32.0 - reward: 30.192531216144562
# Episode 177: score: 43.0 - reward: 40.33878877460956
# Episode 178: score: 23.0 - reward: 21.7664749763906
# Episode 179: score: 16.0 - reward: 15.10865096896887
# Episode 180: score: 21.0 - reward: 20.112203574180604
# Test Episode 180: test score: 43.0 - test reward: 41.580012519285084
# Episode 181: score: 36.0 - reward: 34.29234993606806
# Episode 182: score: 9.0 - reward: 8.55790140479803
# Episode 183: score: 30.0 - reward: 28.713945491611963
# Episode 184: score: 11.0 - reward: 10.087694700062276
# Episode 185: score: 24.0 - reward: 23.138318841159343
# Episode 186: score: 42.0 - reward: 39.93572233840823
# Episode 187: score: 32.0 - reward: 29.912735047936437
# Episode 188: score: 22.0 - reward: 20.6041951879859
# Episode 189: score: 19.0 - reward: 18.107600326836106
# Episode 190: score: 29.0 - reward: 27.21319307684898
# Test Episode 190: test score: 18.0 - test reward: 17.25449187606573
# Episode 191: score: 21.0 - reward: 19.652992923557758
# Episode 192: score: 12.0 - reward: 11.025960928201677
# Episode 193: score: 21.0 - reward: 19.95880072042346
# Episode 194: score: 12.0 - reward: 11.150489136576653
# Episode 195: score: 20.0 - reward: 18.98900963962078
# Episode 196: score: 14.0 - reward: 13.208135744929315
# Episode 197: score: 11.0 - reward: 10.039254772663115
# Episode 198: score: 14.0 - reward: 13.284907581657171
# Episode 199: score: 15.0 - reward: 13.894623494148254
# Episode 200: score: 30.0 - reward: 28.889460004866123
# Test Episode 200: test score: 9.0 - test reward: 8.274091446399689
# Episode 201: score: 19.0 - reward: 17.65871397852898
# Episode 202: score: 10.0 - reward: 9.411780663765967
# Episode 203: score: 12.0 - reward: 11.139262606203557
# Episode 204: score: 20.0 - reward: 18.424950206279753
# Episode 205: score: 26.0 - reward: 24.671365898847576
# Episode 206: score: 21.0 - reward: 20.04456757828593
# Episode 207: score: 10.0 - reward: 9.393670144677161
# Episode 208: score: 13.0 - reward: 12.28482818081975
# Episode 209: score: 17.0 - reward: 15.952435400336979
# Episode 210: score: 21.0 - reward: 19.614421629905696
# Test Episode 210: test score: 9.0 - test reward: 8.457105375826359
# Episode 211: score: 38.0 - reward: 36.13943356722593
# Episode 212: score: 9.0 - reward: 8.353125399351121
# Episode 213: score: 33.0 - reward: 31.502022710442546
# Episode 214: score: 16.0 - reward: 15.104201687872413
# Episode 215: score: 11.0 - reward: 10.18088300228119
# Episode 216: score: 38.0 - reward: 35.91360931713134
# Episode 217: score: 10.0 - reward: 9.406551514565946
# Episode 218: score: 20.0 - reward: 18.528373035788533
# Episode 219: score: 14.0 - reward: 13.080213874578476
# Episode 220: score: 15.0 - reward: 14.188293878361584
# Test Episode 220: test score: 12.0 - test reward: 11.314810645580291
# Episode 221: score: 11.0 - reward: 10.237223693728447
# Episode 222: score: 33.0 - reward: 31.94569595176726
# Episode 223: score: 16.0 - reward: 15.149490779638292
# Episode 224: score: 24.0 - reward: 23.177919007837776
# Episode 225: score: 16.0 - reward: 15.289127054065466
# Episode 226: score: 24.0 - reward: 22.796020955592397
# Episode 227: score: 10.0 - reward: 9.351580029726028
# Episode 228: score: 12.0 - reward: 11.438277132809162
# Episode 229: score: 12.0 - reward: 11.160292652994393
# Episode 230: score: 26.0 - reward: 24.777698486298327
# Test Episode 230: test score: 24.0 - test reward: 22.69544322341681
# Episode 231: score: 19.0 - reward: 17.986130988597875
# Episode 232: score: 61.0 - reward: 58.09163198173045
# Episode 233: score: 12.0 - reward: 11.288610807806252
# Episode 234: score: 18.0 - reward: 16.56914005577564
# Episode 235: score: 18.0 - reward: 16.79731857776642
# Episode 236: score: 23.0 - reward: 21.85714670419693
# Episode 237: score: 25.0 - reward: 24.217006435245278
# Episode 238: score: 17.0 - reward: 15.88741578012705
# Episode 239: score: 25.0 - reward: 22.87678177952766
# Episode 240: score: 20.0 - reward: 19.14981848523021
# Test Episode 240: test score: 10.0 - test reward: 9.380052040889858
# Episode 241: score: 21.0 - reward: 19.61534559875727
# Episode 242: score: 45.0 - reward: 42.715380035340786
# Episode 243: score: 22.0 - reward: 20.81064974665642
# Episode 244: score: 16.0 - reward: 15.269979517161847
# Episode 245: score: 22.0 - reward: 20.796842496842142
# Episode 246: score: 11.0 - reward: 10.215402129292487
# Episode 247: score: 16.0 - reward: 15.306192758679389
# Episode 248: score: 14.0 - reward: 13.147802805900575
# Episode 249: score: 51.0 - reward: 48.27144524827599
# Episode 250: score: 20.0 - reward: 18.724269987642764
# Test Episode 250: test score: 101.0 - test reward: 96.252386200428
# New best test reward. Saving model
# Episode 251: score: 15.0 - reward: 14.20918472930789
# Episode 252: score: 19.0 - reward: 17.48058374971151
# Episode 253: score: 13.0 - reward: 12.15003207027912
# Episode 254: score: 14.0 - reward: 12.895597276091577
# Episode 255: score: 16.0 - reward: 14.746576176583767
# Episode 256: score: 16.0 - reward: 15.116036576032638
# Episode 257: score: 9.0 - reward: 8.305267208814621
# Episode 258: score: 15.0 - reward: 14.29972806610167
# Episode 259: score: 10.0 - reward: 9.481759452819823
# Episode 260: score: 14.0 - reward: 12.969524270296096
# Test Episode 260: test score: 9.0 - test reward: 8.521203741431236
# Episode 261: score: 47.0 - reward: 44.851350505650046
# Episode 262: score: 10.0 - reward: 9.486138152331113
# Episode 263: score: 20.0 - reward: 19.112446796894073
# Episode 264: score: 11.0 - reward: 10.455134736746551
# Episode 265: score: 47.0 - reward: 44.05007451251149
# Episode 266: score: 54.0 - reward: 50.219009223580365
# Episode 267: score: 22.0 - reward: 21.080231605470182
# Episode 268: score: 34.0 - reward: 32.71787798851729
# Episode 269: score: 59.0 - reward: 54.60277837291361
# Episode 270: score: 10.0 - reward: 9.262332953512669
# Test Episode 270: test score: 8.0 - test reward: 7.433684808015824
# Episode 271: score: 29.0 - reward: 27.844449032843116
# Episode 272: score: 20.0 - reward: 19.123896878212694
# Episode 273: score: 25.0 - reward: 23.99023779667914
# Episode 274: score: 19.0 - reward: 17.76705086380243
# Episode 275: score: 13.0 - reward: 11.932094058394433
# Episode 276: score: 14.0 - reward: 13.320230522006751
# Episode 277: score: 15.0 - reward: 13.942280653119088
# Episode 278: score: 18.0 - reward: 16.62584243416786
# Episode 279: score: 22.0 - reward: 20.936801753938198
# Episode 280: score: 22.0 - reward: 20.826041444391013
# Test Episode 280: test score: 9.0 - test reward: 8.547766472399235
# Episode 281: score: 23.0 - reward: 21.486626575887204
# Episode 282: score: 12.0 - reward: 10.998721620440483
# Episode 283: score: 10.0 - reward: 9.315788663923739
# Episode 284: score: 29.0 - reward: 26.918717187643047
# Episode 285: score: 10.0 - reward: 9.357494470477105
# Episode 286: score: 23.0 - reward: 22.061465819180018
# Episode 287: score: 14.0 - reward: 12.824462366104127
# Episode 288: score: 30.0 - reward: 28.86644794642925
# Episode 289: score: 12.0 - reward: 11.387549029290676
# Episode 290: score: 24.0 - reward: 22.38260904550552
# Test Episode 290: test score: 9.0 - test reward: 8.525789795815944
# Episode 291: score: 18.0 - reward: 17.082592262327672
# Episode 292: score: 13.0 - reward: 12.16489922553301
# Episode 293: score: 11.0 - reward: 10.373992341011762
# Episode 294: score: 19.0 - reward: 18.149463636800647
# Episode 295: score: 18.0 - reward: 16.839605773985387
# Episode 296: score: 22.0 - reward: 20.8654876857996
# Episode 297: score: 11.0 - reward: 10.183564457297324
# Episode 298: score: 11.0 - reward: 10.40782555192709
# Episode 299: score: 16.0 - reward: 15.27259844094515
# Episode 300: score: 20.0 - reward: 18.860237044095992
# Test Episode 300: test score: 10.0 - test reward: 9.255575928092004
# Episode 301: score: 17.0 - reward: 16.0418244369328
# Episode 302: score: 15.0 - reward: 14.038864387571813
# Episode 303: score: 10.0 - reward: 9.399796360731123
# Episode 304: score: 20.0 - reward: 18.99533220306039
# Episode 305: score: 27.0 - reward: 25.795880712568763
# Episode 306: score: 28.0 - reward: 26.078461834788317
# Episode 307: score: 11.0 - reward: 10.37649672292173
# Episode 308: score: 9.0 - reward: 8.498663084208966
# Episode 309: score: 14.0 - reward: 13.203734540939331
# Episode 310: score: 15.0 - reward: 14.312517122179269
# Test Episode 310: test score: 12.0 - test reward: 11.257329200208186
# Episode 311: score: 36.0 - reward: 34.14455729871988
# Episode 312: score: 14.0 - reward: 12.99478137791157
# Episode 313: score: 17.0 - reward: 16.26186428964138
# Episode 314: score: 61.0 - reward: 58.82218839600683
# Episode 315: score: 25.0 - reward: 22.80448716282845
# Episode 316: score: 13.0 - reward: 12.043392369151118
# Episode 317: score: 19.0 - reward: 17.98015001267195
# Episode 318: score: 20.0 - reward: 19.191225597262385
# Episode 319: score: 28.0 - reward: 26.755597127601504
# Episode 320: score: 12.0 - reward: 11.130357509851455
# Test Episode 320: test score: 9.0 - test reward: 8.411413387954235
# Episode 321: score: 13.0 - reward: 12.127361485362053
# Episode 322: score: 12.0 - reward: 11.06571054458618
# Episode 323: score: 19.0 - reward: 17.536105039715768
# Episode 324: score: 43.0 - reward: 39.60574879795313
# Episode 325: score: 21.0 - reward: 19.527761909365655
# Episode 326: score: 51.0 - reward: 46.32145781517029
# Episode 327: score: 16.0 - reward: 15.104448417574167
# Episode 328: score: 15.0 - reward: 14.209357544779776
# Episode 329: score: 10.0 - reward: 9.515399089455604
# Episode 330: score: 10.0 - reward: 9.217928677797316
# Test Episode 330: test score: 8.0 - test reward: 7.416800069808961
# Episode 331: score: 11.0 - reward: 10.181914028525354
# Episode 332: score: 20.0 - reward: 18.8328321814537
# Episode 333: score: 22.0 - reward: 20.407034894824026
# Episode 334: score: 24.0 - reward: 22.69652150943875
# Episode 335: score: 13.0 - reward: 12.354329620301725
# Episode 336: score: 12.0 - reward: 11.40274811089039
# Episode 337: score: 9.0 - reward: 8.376728048920631
# Episode 338: score: 11.0 - reward: 10.420931769162415
# Episode 339: score: 10.0 - reward: 9.332323591411114
# Episode 340: score: 12.0 - reward: 11.220270203053953
# Test Episode 340: test score: 10.0 - test reward: 9.286945344507695
# Episode 341: score: 22.0 - reward: 20.796306580305103
# Episode 342: score: 13.0 - reward: 12.191778773069382
# Episode 343: score: 12.0 - reward: 11.287767618149521
# Episode 344: score: 32.0 - reward: 30.514275568723672
# Episode 345: score: 27.0 - reward: 26.059156665392216
# Episode 346: score: 18.0 - reward: 17.087926596403122
# Episode 347: score: 27.0 - reward: 25.878516946733
# Episode 348: score: 35.0 - reward: 33.25207366272807
# Episode 349: score: 17.0 - reward: 15.888786281645299
# Episode 350: score: 21.0 - reward: 20.272242082655424
# Test Episode 350: test score: 8.0 - test reward: 7.407196429371835
# Episode 351: score: 24.0 - reward: 21.84409033060074
# Episode 352: score: 12.0 - reward: 11.230843837559224
# Episode 353: score: 12.0 - reward: 11.182877619564534
# Episode 354: score: 31.0 - reward: 29.23143801391124
# Episode 355: score: 15.0 - reward: 13.89900573194027
# Episode 356: score: 23.0 - reward: 21.97590392548591
# Episode 357: score: 32.0 - reward: 30.00170596353709
# Episode 358: score: 13.0 - reward: 12.173086977005006
# Episode 359: score: 22.0 - reward: 20.901412090659143
# Episode 360: score: 24.0 - reward: 22.564304854348304
# Test Episode 360: test score: 10.0 - test reward: 9.47124760299921
# Episode 361: score: 25.0 - reward: 24.025595645606522
# Episode 362: score: 23.0 - reward: 21.89205233305693
# Episode 363: score: 65.0 - reward: 53.82520713955166
# Episode 364: score: 12.0 - reward: 11.13654328584671
# Episode 365: score: 25.0 - reward: 24.093205858767035
# Episode 366: score: 13.0 - reward: 12.227820707857608
# Episode 367: score: 14.0 - reward: 13.355826131999496
# Episode 368: score: 19.0 - reward: 18.06613284349441
# Episode 369: score: 19.0 - reward: 18.006430403888228
# Episode 370: score: 17.0 - reward: 16.26620512455702
# Test Episode 370: test score: 9.0 - test reward: 8.4476895570755
# Episode 371: score: 20.0 - reward: 18.708240458369254
# Episode 372: score: 19.0 - reward: 17.987986344099046
# Episode 373: score: 56.0 - reward: 53.30093233976512
# Episode 374: score: 16.0 - reward: 15.268932059407234
# Episode 375: score: 10.0 - reward: 9.200945241749285
# Episode 376: score: 16.0 - reward: 15.110338334739211
# Episode 377: score: 15.0 - reward: 13.963307365775107
# Episode 378: score: 19.0 - reward: 18.146092831343413
# Episode 379: score: 26.0 - reward: 24.73672958016396
# Episode 380: score: 22.0 - reward: 20.92056378796697
# Test Episode 380: test score: 9.0 - test reward: 8.54620432406664
# Episode 381: score: 26.0 - reward: 24.74771668463946
# Episode 382: score: 19.0 - reward: 18.16773444861174
# Episode 383: score: 43.0 - reward: 40.594681565836076
# Episode 384: score: 26.0 - reward: 24.662870981544255
# Episode 385: score: 48.0 - reward: 44.33833459019662
# Episode 386: score: 20.0 - reward: 19.09352265894413
# Episode 387: score: 17.0 - reward: 15.961924101412295
# Episode 388: score: 19.0 - reward: 18.03416493535042
# Episode 389: score: 22.0 - reward: 20.671138888597486
# Episode 390: score: 13.0 - reward: 12.15994330793619
# Test Episode 390: test score: 11.0 - test reward: 10.32977661192417
# Episode 391: score: 16.0 - reward: 15.104331541806461
# Episode 392: score: 37.0 - reward: 35.00477779954671
# Episode 393: score: 15.0 - reward: 14.319047713279724
# Episode 394: score: 14.0 - reward: 13.180983037129042
# Episode 395: score: 23.0 - reward: 21.82962856292724
# Episode 396: score: 34.0 - reward: 32.27520888000726
# Episode 397: score: 19.0 - reward: 18.091984074562788
# Episode 398: score: 26.0 - reward: 24.69795665889979
# Episode 399: score: 18.0 - reward: 16.948484814167024
# Episode 400: score: 34.0 - reward: 32.35882818251849
# Test Episode 400: test score: 11.0 - test reward: 10.332346490770579
# Episode 401: score: 16.0 - reward: 15.190192587673666
# Episode 402: score: 16.0 - reward: 14.98675851747394
# Episode 403: score: 56.0 - reward: 50.30636846721172
# Episode 404: score: 17.0 - reward: 16.107382284104823
# Episode 405: score: 21.0 - reward: 20.144690480828285
# Episode 406: score: 43.0 - reward: 40.53003947436809
# Episode 407: score: 18.0 - reward: 16.835278068482875
# Episode 408: score: 33.0 - reward: 31.31735479384661
# Episode 409: score: 36.0 - reward: 34.0021786365658
# Episode 410: score: 13.0 - reward: 12.124796376377345
# Test Episode 410: test score: 10.0 - test reward: 9.317603339254855
# Episode 411: score: 22.0 - reward: 21.333210526406763
# Episode 412: score: 11.0 - reward: 10.103821609914302
# Episode 413: score: 23.0 - reward: 21.892010228335856
# Episode 414: score: 38.0 - reward: 36.938087252900004
# Episode 415: score: 29.0 - reward: 27.709179425239565
# Episode 416: score: 14.0 - reward: 13.381507164984942
# Episode 417: score: 36.0 - reward: 34.65509800463915
# Episode 418: score: 49.0 - reward: 46.04756960272788
# Episode 419: score: 30.0 - reward: 28.44564577266574
# Episode 420: score: 11.0 - reward: 10.316061235964298
# Test Episode 420: test score: 8.0 - test reward: 7.551156127452851
# Episode 421: score: 24.0 - reward: 22.27994774580002
# Episode 422: score: 20.0 - reward: 18.287296256422998
# Episode 423: score: 17.0 - reward: 15.995347444713115
# Episode 424: score: 16.0 - reward: 14.626018822193146
# Episode 425: score: 24.0 - reward: 22.791464436054227
# Episode 426: score: 31.0 - reward: 29.668925642967224
# Episode 427: score: 18.0 - reward: 16.98365065082908
# Episode 428: score: 18.0 - reward: 17.07909122705459
# Episode 429: score: 20.0 - reward: 19.04366336911917
# Episode 430: score: 38.0 - reward: 35.57845954149961
# Test Episode 430: test score: 10.0 - test reward: 9.423485549166799
# Episode 431: score: 28.0 - reward: 26.68201510384679
# Episode 432: score: 21.0 - reward: 19.915363419801
# Episode 433: score: 20.0 - reward: 18.74443922787904
# Episode 434: score: 39.0 - reward: 37.486610431596645
# Episode 435: score: 12.0 - reward: 11.376463202387097
# Episode 436: score: 28.0 - reward: 26.298970809578897
# Episode 437: score: 25.0 - reward: 23.78401139974594
# Episode 438: score: 27.0 - reward: 25.783296611905094
# Episode 439: score: 34.0 - reward: 32.491251909732824
# Episode 440: score: 20.0 - reward: 18.70661979615688
# Test Episode 440: test score: 10.0 - test reward: 9.310674412548542
# Episode 441: score: 18.0 - reward: 16.939436200261117
# Episode 442: score: 19.0 - reward: 18.075701805204154
# Episode 443: score: 48.0 - reward: 45.27423004470766
# Episode 444: score: 14.0 - reward: 13.272035959362986
# Episode 445: score: 26.0 - reward: 24.679972565174108
# Episode 446: score: 13.0 - reward: 11.914401039481163
# Episode 447: score: 42.0 - reward: 40.235495242476446
# Episode 448: score: 45.0 - reward: 42.221743302792305
# Episode 449: score: 52.0 - reward: 48.26097811553626
# Episode 450: score: 29.0 - reward: 28.12547270879149
# Test Episode 450: test score: 8.0 - test reward: 7.551876312494278
# Episode 451: score: 14.0 - reward: 13.216310064494612
# Episode 452: score: 11.0 - reward: 10.428355902433395
# Episode 453: score: 16.0 - reward: 15.225357810407877
# Episode 454: score: 15.0 - reward: 14.031472024321557
# Episode 455: score: 13.0 - reward: 12.14110347479582
# Episode 456: score: 32.0 - reward: 30.534941449761387
# Episode 457: score: 16.0 - reward: 14.770790623128413
# Episode 458: score: 24.0 - reward: 22.698483750969167
# Episode 459: score: 16.0 - reward: 15.16542144343257
# Episode 460: score: 38.0 - reward: 35.15201004147529
# Test Episode 460: test score: 10.0 - test reward: 9.40510822609067
# Episode 461: score: 12.0 - reward: 11.230893528461456
# Episode 462: score: 41.0 - reward: 37.966360626369706
# Episode 463: score: 13.0 - reward: 12.104343469440936
# Episode 464: score: 24.0 - reward: 22.478197091817854
# Episode 465: score: 42.0 - reward: 39.84172215163707
# Episode 466: score: 48.0 - reward: 45.77435537502169
# Episode 467: score: 12.0 - reward: 11.034763434529303
# Episode 468: score: 17.0 - reward: 16.11300738397986
# Episode 469: score: 11.0 - reward: 10.249624247848987
# Episode 470: score: 21.0 - reward: 20.23200064450502
# Test Episode 470: test score: 10.0 - test reward: 9.427073194086553
# Episode 471: score: 34.0 - reward: 32.22374753952027
# Episode 472: score: 12.0 - reward: 11.13675099313259
# Episode 473: score: 14.0 - reward: 13.285397561639547
# Episode 474: score: 26.0 - reward: 24.935802817344666
# Episode 475: score: 15.0 - reward: 14.315434902906414
# Episode 476: score: 20.0 - reward: 19.04368674457073
# Episode 477: score: 30.0 - reward: 28.63177868723869
# Episode 478: score: 30.0 - reward: 28.662836542725564
# Episode 479: score: 38.0 - reward: 36.66997842937709
# Episode 480: score: 40.0 - reward: 37.385609215497965
# Test Episode 480: test score: 8.0 - test reward: 7.513369734585286
# Episode 481: score: 29.0 - reward: 27.17519547045231
# Episode 482: score: 29.0 - reward: 27.48410831987858
# Episode 483: score: 18.0 - reward: 16.86137041449547
# Episode 484: score: 31.0 - reward: 29.664182305336002
# Episode 485: score: 19.0 - reward: 17.72262820824981
# Episode 486: score: 13.0 - reward: 12.10049179494381
# Episode 487: score: 18.0 - reward: 17.0926493473351
# Episode 488: score: 16.0 - reward: 14.980048510432244
# Episode 489: score: 13.0 - reward: 12.375584366917609
# Episode 490: score: 13.0 - reward: 11.899093790352344
# Test Episode 490: test score: 10.0 - test reward: 9.304216034710407
# Episode 491: score: 12.0 - reward: 11.129731112718583
# Episode 492: score: 16.0 - reward: 14.892251336574553
# Episode 493: score: 14.0 - reward: 13.233474206924438
# Episode 494: score: 15.0 - reward: 13.825939774513245
# Episode 495: score: 23.0 - reward: 21.89912903308868
# Episode 496: score: 23.0 - reward: 21.600271642953153
# Episode 497: score: 61.0 - reward: 58.6218302834779
# Episode 498: score: 36.0 - reward: 34.32024153843522
# Episode 499: score: 16.0 - reward: 15.227654464542864
# Episode 500: score: 16.0 - reward: 15.314911775290966
# Test Episode 500: test score: 9.0 - test reward: 8.519653171300888
# best test reward: 96.252386200428
# Training with epsilon: 0.1, alpha: 0.001
# Run 1/1
# Episode 1: score: 17.0 - reward: 15.977753743529322
# Episode 2: score: 13.0 - reward: 11.930844721198081
# Episode 3: score: 9.0 - reward: 8.435020667314529
# Episode 4: score: 9.0 - reward: 8.46789637207985
# Episode 5: score: 11.0 - reward: 10.206017190217972
# Episode 6: score: 10.0 - reward: 9.180888685584067
# Episode 7: score: 11.0 - reward: 10.144770471751691
# Episode 8: score: 8.0 - reward: 7.569075673818588
# Episode 9: score: 10.0 - reward: 9.34572842568159
# Episode 10: score: 9.0 - reward: 8.445390485227108
# Test Episode 10: test score: 10.0 - test reward: 9.51094351131469
# New best test reward. Saving model
# Episode 11: score: 10.0 - reward: 9.328014755249024
# Episode 12: score: 9.0 - reward: 8.268328827619554
# Episode 13: score: 10.0 - reward: 9.263492438197135
# Episode 14: score: 9.0 - reward: 8.525828205049038
# Episode 15: score: 9.0 - reward: 8.36559832394123
# Episode 16: score: 11.0 - reward: 10.323106522858142
# Episode 17: score: 10.0 - reward: 9.44209285378456
# Episode 18: score: 9.0 - reward: 8.408902871608735
# Episode 19: score: 9.0 - reward: 8.573860330879688
# Episode 20: score: 10.0 - reward: 9.45337321460247
# Test Episode 20: test score: 9.0 - test reward: 8.546834327280521
# Episode 21: score: 9.0 - reward: 8.432265216112137
# Episode 22: score: 11.0 - reward: 10.467078588157893
# Episode 23: score: 9.0 - reward: 8.333652587234974
# Episode 24: score: 13.0 - reward: 12.223313020169734
# Episode 25: score: 10.0 - reward: 9.4692209944129
# Episode 26: score: 9.0 - reward: 8.499859601259232
# Episode 27: score: 8.0 - reward: 7.540276269614696
# Episode 28: score: 9.0 - reward: 8.290652099251746
# Episode 29: score: 13.0 - reward: 12.30007093846798
# Episode 30: score: 10.0 - reward: 9.37155061364174
# Test Episode 30: test score: 9.0 - test reward: 8.462819048762322
# Episode 31: score: 9.0 - reward: 8.32667783498764
# Episode 32: score: 10.0 - reward: 9.348794371634723
# Episode 33: score: 9.0 - reward: 8.478712118044495
# Episode 34: score: 12.0 - reward: 11.316462504118682
# Episode 35: score: 13.0 - reward: 12.252078896760938
# Episode 36: score: 10.0 - reward: 9.449246856570245
# Episode 37: score: 17.0 - reward: 15.925393384695052
# Episode 38: score: 10.0 - reward: 9.329658402502536
# Episode 39: score: 11.0 - reward: 10.251645153760911
# Episode 40: score: 10.0 - reward: 9.499312482774258
# Test Episode 40: test score: 11.0 - test reward: 10.431989746913315
# New best test reward. Saving model
# Episode 41: score: 8.0 - reward: 7.550964920222759
# Episode 42: score: 9.0 - reward: 8.356263515353202
# Episode 43: score: 13.0 - reward: 12.318962889909745
# Episode 44: score: 9.0 - reward: 8.380874697864055
# Episode 45: score: 12.0 - reward: 11.255781470984221
# Episode 46: score: 16.0 - reward: 15.296693044900897
# Episode 47: score: 19.0 - reward: 18.019455367326735
# Episode 48: score: 9.0 - reward: 8.369790820777416
# Episode 49: score: 13.0 - reward: 11.885031342506407
# Episode 50: score: 16.0 - reward: 15.021670363098382
# Test Episode 50: test score: 16.0 - test reward: 15.35855682455003
# New best test reward. Saving model
# Episode 51: score: 29.0 - reward: 27.05669914484024
# Episode 52: score: 10.0 - reward: 9.427189180999994
# Episode 53: score: 13.0 - reward: 12.382975743710995
# Episode 54: score: 13.0 - reward: 12.368235045671465
# Episode 55: score: 11.0 - reward: 10.35471844673157
# Episode 56: score: 19.0 - reward: 17.696347944438457
# Episode 57: score: 21.0 - reward: 19.86321041733027
# Episode 58: score: 16.0 - reward: 14.973197171837091
# Episode 59: score: 13.0 - reward: 12.266432183980942
# Episode 60: score: 11.0 - reward: 10.402623136341571
# Test Episode 60: test score: 13.0 - test reward: 12.146172781288623
# Episode 61: score: 11.0 - reward: 10.417348434776068
# Episode 62: score: 10.0 - reward: 9.486289450526238
# Episode 63: score: 30.0 - reward: 28.82891527116299
# Episode 64: score: 12.0 - reward: 11.326165974140167
# Episode 65: score: 11.0 - reward: 10.246163767576219
# Episode 66: score: 11.0 - reward: 10.46994830928743
# Episode 67: score: 16.0 - reward: 14.804945446550844
# Episode 68: score: 19.0 - reward: 17.580448760092256
# Episode 69: score: 12.0 - reward: 11.37015523314476
# Episode 70: score: 19.0 - reward: 18.226278389990334
# Test Episode 70: test score: 20.0 - test reward: 18.595410632062706
# New best test reward. Saving model
# Episode 71: score: 10.0 - reward: 9.504292084276678
# Episode 72: score: 13.0 - reward: 12.301832067966462
# Episode 73: score: 17.0 - reward: 15.934893143177032
# Episode 74: score: 10.0 - reward: 9.378738418221474
# Episode 75: score: 10.0 - reward: 9.488724222034215
# Episode 76: score: 12.0 - reward: 11.351978866755962
# Episode 77: score: 11.0 - reward: 10.541887706145644
# Episode 78: score: 11.0 - reward: 10.416563439369202
# Episode 79: score: 17.0 - reward: 16.089633855223656
# Episode 80: score: 21.0 - reward: 19.978847408294676
# Test Episode 80: test score: 11.0 - test reward: 10.313595277070998
# Episode 81: score: 18.0 - reward: 17.088802289962768
# Episode 82: score: 19.0 - reward: 17.495934805274008
# Episode 83: score: 29.0 - reward: 27.137486828863615
# Episode 84: score: 32.0 - reward: 30.487646941840655
# Episode 85: score: 48.0 - reward: 45.165130308270456
# Episode 86: score: 10.0 - reward: 9.429573956131936
# Episode 87: score: 10.0 - reward: 9.501189045608044
# Episode 88: score: 46.0 - reward: 44.475886600697415
# Episode 89: score: 9.0 - reward: 8.579010443389416
# Episode 90: score: 30.0 - reward: 28.491267313063148
# Test Episode 90: test score: 31.0 - test reward: 28.959242126345636
# New best test reward. Saving model
# Episode 91: score: 39.0 - reward: 37.392262770235526
# Episode 92: score: 20.0 - reward: 18.948320788145065
# Episode 93: score: 22.0 - reward: 20.94475688189268
# Episode 94: score: 21.0 - reward: 19.576683446764946
# Episode 95: score: 19.0 - reward: 18.078131258487705
# Episode 96: score: 17.0 - reward: 16.216443445533514
# Episode 97: score: 22.0 - reward: 20.951285076141357
# Episode 98: score: 28.0 - reward: 26.127343827486037
# Episode 99: score: 19.0 - reward: 17.84498823583126
# Episode 100: score: 26.0 - reward: 24.67255330681801
# Test Episode 100: test score: 11.0 - test reward: 10.381433495879174
# Episode 101: score: 19.0 - reward: 18.11454105973243
# Episode 102: score: 25.0 - reward: 23.828554615378383
# Episode 103: score: 35.0 - reward: 33.83650155961513
# Episode 104: score: 20.0 - reward: 19.019165873527523
# Episode 105: score: 27.0 - reward: 25.287934795022014
# Episode 106: score: 22.0 - reward: 20.228010095655915
# Episode 107: score: 29.0 - reward: 26.965295737981794
# Episode 108: score: 19.0 - reward: 17.994353373348716
# Episode 109: score: 30.0 - reward: 28.545794114470482
# Episode 110: score: 39.0 - reward: 37.58912343084812
# Test Episode 110: test score: 39.0 - test reward: 37.304105564206836
# New best test reward. Saving model
# Episode 111: score: 38.0 - reward: 36.6020613450557
# Episode 112: score: 14.0 - reward: 13.430613053776325
# Episode 113: score: 94.0 - reward: 86.457174167037
# Episode 114: score: 26.0 - reward: 24.417023862898347
# Episode 115: score: 40.0 - reward: 38.3930841460824
# Episode 116: score: 21.0 - reward: 19.55529628545046
# Episode 117: score: 15.0 - reward: 14.067107984423634
# Episode 118: score: 15.0 - reward: 14.190853516757487
# Episode 119: score: 17.0 - reward: 16.03094725906849
# Episode 120: score: 30.0 - reward: 28.206634787470104
# Test Episode 120: test score: 16.0 - test reward: 15.007003933191296
# Episode 121: score: 18.0 - reward: 16.51641765534878
# Episode 122: score: 15.0 - reward: 14.249226273596287
# Episode 123: score: 14.0 - reward: 13.327921702712775
# Episode 124: score: 16.0 - reward: 15.092962031811478
# Episode 125: score: 11.0 - reward: 10.29900509417057
# Episode 126: score: 20.0 - reward: 18.844103223085405
# Episode 127: score: 22.0 - reward: 20.52901118118316
# Episode 128: score: 12.0 - reward: 11.311825338751081
# Episode 129: score: 32.0 - reward: 30.490124216675756
# Episode 130: score: 12.0 - reward: 11.358222483098507
# Test Episode 130: test score: 14.0 - test reward: 12.832266822457314
# Episode 131: score: 10.0 - reward: 9.260984057188034
# Episode 132: score: 23.0 - reward: 21.887938216328617
# Episode 133: score: 18.0 - reward: 16.671740597486494
# Episode 134: score: 34.0 - reward: 32.41479118466377
# Episode 135: score: 26.0 - reward: 24.652076104283335
# Episode 136: score: 32.0 - reward: 30.60847410410643
# Episode 137: score: 15.0 - reward: 14.164969541132452
# Episode 138: score: 15.0 - reward: 14.071637816727163
# Episode 139: score: 12.0 - reward: 11.037162777781486
# Episode 140: score: 16.0 - reward: 15.328362867236137
# Test Episode 140: test score: 12.0 - test reward: 11.215975031256677
# Episode 141: score: 10.0 - reward: 9.176382583379745
# Episode 142: score: 14.0 - reward: 12.951122598350048
# Episode 143: score: 10.0 - reward: 9.341852757334708
# Episode 144: score: 14.0 - reward: 13.227788917720318
# Episode 145: score: 21.0 - reward: 20.01985329166055
# Episode 146: score: 13.0 - reward: 12.164357809722427
# Episode 147: score: 18.0 - reward: 16.869702358543872
# Episode 148: score: 9.0 - reward: 8.353797359764576
# Episode 149: score: 23.0 - reward: 21.096440652012827
# Episode 150: score: 14.0 - reward: 13.069546009600163
# Test Episode 150: test score: 29.0 - test reward: 27.527717195451263
# Episode 151: score: 26.0 - reward: 24.19548631906509
# Episode 152: score: 13.0 - reward: 12.21649569272995
# Episode 153: score: 16.0 - reward: 15.287622678279876
# Episode 154: score: 19.0 - reward: 18.23090733885765
# Episode 155: score: 25.0 - reward: 23.46761467754841
# Episode 156: score: 16.0 - reward: 15.215150929987434
# Episode 157: score: 13.0 - reward: 12.265012677013875
# Episode 158: score: 10.0 - reward: 9.323615032434462
# Episode 159: score: 12.0 - reward: 11.112366735935213
# Episode 160: score: 27.0 - reward: 25.516247233748437
# Test Episode 160: test score: 35.0 - test reward: 32.714283869415524
# Episode 161: score: 18.0 - reward: 16.96395268291235
# Episode 162: score: 19.0 - reward: 17.752407567203047
# Episode 163: score: 11.0 - reward: 10.145700442790984
# Episode 164: score: 10.0 - reward: 9.273152682185172
# Episode 165: score: 22.0 - reward: 20.877750179916617
# Episode 166: score: 13.0 - reward: 12.16864882297814
# Episode 167: score: 19.0 - reward: 17.727753703296187
# Episode 168: score: 12.0 - reward: 11.15607750415802
# Episode 169: score: 11.0 - reward: 10.207578307390213
# Episode 170: score: 12.0 - reward: 11.10683877468109
# Test Episode 170: test score: 17.0 - test reward: 16.053438547253613
# Episode 171: score: 13.0 - reward: 12.113320309668778
# Episode 172: score: 14.0 - reward: 13.007344099879266
# Episode 173: score: 11.0 - reward: 10.31145276725292
# Episode 174: score: 19.0 - reward: 18.057050478458404
# Episode 175: score: 43.0 - reward: 39.92912262082099
# Episode 176: score: 11.0 - reward: 10.148606503009796
# Episode 177: score: 14.0 - reward: 13.057260808348655
# Episode 178: score: 22.0 - reward: 20.171009784936903
# Episode 179: score: 16.0 - reward: 15.282484827935697
# Episode 180: score: 9.0 - reward: 8.30961860716343
# Test Episode 180: test score: 15.0 - test reward: 14.308835972100496
# Episode 181: score: 18.0 - reward: 17.05924869552255
# Episode 182: score: 10.0 - reward: 9.49082733094692
# Episode 183: score: 19.0 - reward: 17.685140681266788
# Episode 184: score: 40.0 - reward: 38.06260898560286
# Episode 185: score: 20.0 - reward: 18.200854063034058
# Episode 186: score: 10.0 - reward: 9.35455907434225
# Episode 187: score: 14.0 - reward: 12.952142015099524
# Episode 188: score: 11.0 - reward: 10.383819507062436
# Episode 189: score: 30.0 - reward: 28.575620350241657
# Episode 190: score: 27.0 - reward: 25.46687072515488
# Test Episode 190: test score: 11.0 - test reward: 10.386534890532493
# Episode 191: score: 23.0 - reward: 20.75840367078781
# Episode 192: score: 31.0 - reward: 29.507788867689673
# Episode 193: score: 11.0 - reward: 10.425974018871784
# Episode 194: score: 80.0 - reward: 75.30726723223923
# Episode 195: score: 27.0 - reward: 24.87013139724731
# Episode 196: score: 14.0 - reward: 13.1375024497509
# Episode 197: score: 12.0 - reward: 11.258407263457773
# Episode 198: score: 12.0 - reward: 11.338222394883635
# Episode 199: score: 16.0 - reward: 15.279793794453145
# Episode 200: score: 40.0 - reward: 38.59891368746757
# Test Episode 200: test score: 14.0 - test reward: 13.065217249095442
# Episode 201: score: 12.0 - reward: 11.247617491334678
# Episode 202: score: 47.0 - reward: 45.06383498981595
# Episode 203: score: 30.0 - reward: 27.84217579364777
# Episode 204: score: 56.0 - reward: 51.14308117330076
# Episode 205: score: 16.0 - reward: 14.93689877167344
# Episode 206: score: 17.0 - reward: 16.29297089204192
# Episode 207: score: 18.0 - reward: 16.917540650069714
# Episode 208: score: 30.0 - reward: 28.599570819735526
# Episode 209: score: 26.0 - reward: 24.692083664238453
# Episode 210: score: 19.0 - reward: 17.640522798895837
# Test Episode 210: test score: 38.0 - test reward: 36.32748989760876
# Episode 211: score: 41.0 - reward: 38.81102115809917
# Episode 212: score: 31.0 - reward: 29.817172037065024
# Episode 213: score: 27.0 - reward: 26.036267003417024
# Episode 214: score: 15.0 - reward: 13.990746033936741
# Episode 215: score: 74.0 - reward: 69.80355213731525
# Episode 216: score: 17.0 - reward: 15.91360638141632
# Episode 217: score: 72.0 - reward: 66.74774411842225
# Episode 218: score: 36.0 - reward: 34.35510570146144
# Episode 219: score: 16.0 - reward: 14.734108516573906
# Episode 220: score: 45.0 - reward: 43.04158111661672
# Test Episode 220: test score: 13.0 - test reward: 12.235961005091667
# Episode 221: score: 15.0 - reward: 13.957283943891527
# Episode 222: score: 25.0 - reward: 23.274780576303602
# Episode 223: score: 72.0 - reward: 65.83594944179058
# Episode 224: score: 25.0 - reward: 23.485949823260306
# Episode 225: score: 29.0 - reward: 27.529074146971105
# Episode 226: score: 33.0 - reward: 31.21238126307727
# Episode 227: score: 13.0 - reward: 12.240861782431603
# Episode 228: score: 88.0 - reward: 81.89604047238825
# Episode 229: score: 11.0 - reward: 10.202250503003597
# Episode 230: score: 73.0 - reward: 67.22834165245294
# Test Episode 230: test score: 73.0 - test reward: 67.10099750161173
# New best test reward. Saving model
# Episode 231: score: 24.0 - reward: 22.860916243493556
# Episode 232: score: 31.0 - reward: 29.399893730878826
# Episode 233: score: 167.0 - reward: 155.57110207080834
# Episode 234: score: 72.0 - reward: 66.28217638880015
# Episode 235: score: 62.0 - reward: 56.55988138467071
# Episode 236: score: 69.0 - reward: 64.24397894144056
# Episode 237: score: 98.0 - reward: 91.28768714815376
# Episode 238: score: 21.0 - reward: 20.01089022457599
# Episode 239: score: 25.0 - reward: 23.126818659901623
# Episode 240: score: 85.0 - reward: 77.85861638784407
# Test Episode 240: test score: 66.0 - test reward: 59.4698721498251
# Episode 241: score: 37.0 - reward: 35.508421069383616
# Episode 242: score: 79.0 - reward: 69.1885394975543
# Episode 243: score: 73.0 - reward: 66.70065017193556
# Episode 244: score: 73.0 - reward: 67.64146038740874
# Episode 245: score: 74.0 - reward: 68.2110566854477
# Episode 246: score: 90.0 - reward: 86.45024502016604
# Episode 247: score: 128.0 - reward: 120.55684305094172
# Episode 248: score: 148.0 - reward: 142.6010322116316
# Episode 249: score: 47.0 - reward: 44.90900530219079
# Episode 250: score: 46.0 - reward: 44.48399183154107
# Test Episode 250: test score: 12.0 - test reward: 11.298828402534125
# Episode 251: score: 50.0 - reward: 47.60575680583717
# Episode 252: score: 55.0 - reward: 52.83732938878239
# Episode 253: score: 46.0 - reward: 44.16335486322641
# Episode 254: score: 31.0 - reward: 29.744325771927834
# Episode 255: score: 59.0 - reward: 54.32393225058912
# Episode 256: score: 47.0 - reward: 44.94919624179602
# Episode 257: score: 59.0 - reward: 57.36376660093666
# Episode 258: score: 90.0 - reward: 79.07647431157531
# Episode 259: score: 54.0 - reward: 51.28017565310003
# Episode 260: score: 47.0 - reward: 42.93087313324214
# Test Episode 260: test score: 31.0 - test reward: 28.633228130638596
# Episode 261: score: 40.0 - reward: 38.34691821932792
# Episode 262: score: 82.0 - reward: 76.40214439630509
# Episode 263: score: 79.0 - reward: 75.53105274587872
# Episode 264: score: 63.0 - reward: 59.25051220953465
# Episode 265: score: 20.0 - reward: 18.525169850885867
# Episode 266: score: 35.0 - reward: 32.797511127591136
# Episode 267: score: 13.0 - reward: 12.288125607371331
# Episode 268: score: 36.0 - reward: 33.83323411941528
# Episode 269: score: 40.0 - reward: 37.57514595282264
# Episode 270: score: 47.0 - reward: 44.892950287461275
# Test Episode 270: test score: 60.0 - test reward: 57.653644160926355
# Episode 271: score: 36.0 - reward: 33.888636136055
# Episode 272: score: 24.0 - reward: 22.341322382539516
# Episode 273: score: 77.0 - reward: 66.87041228264572
# Episode 274: score: 30.0 - reward: 28.395376091450448
# Episode 275: score: 58.0 - reward: 51.14996245503424
# Episode 276: score: 86.0 - reward: 79.87632365077732
# Episode 277: score: 18.0 - reward: 16.543019893765447
# Episode 278: score: 25.0 - reward: 23.999028551578522
# Episode 279: score: 97.0 - reward: 89.1696690812707
# Episode 280: score: 36.0 - reward: 34.13506576269865
# Test Episode 280: test score: 109.0 - test reward: 96.25221404135229
# New best test reward. Saving model
# Episode 281: score: 34.0 - reward: 32.44910566993058
# Episode 282: score: 28.0 - reward: 25.931197964772583
# Episode 283: score: 87.0 - reward: 79.5282790929079
# Episode 284: score: 26.0 - reward: 24.5357791274786
# Episode 285: score: 88.0 - reward: 80.14417740181088
# Episode 286: score: 23.0 - reward: 21.556002558767798
# Episode 287: score: 47.0 - reward: 44.87753263115883
# Episode 288: score: 71.0 - reward: 66.41600473672153
# Episode 289: score: 49.0 - reward: 45.57821679860354
# Episode 290: score: 50.0 - reward: 48.18794613126667
# Test Episode 290: test score: 92.0 - test reward: 79.97227200791242
# Episode 291: score: 30.0 - reward: 28.8523052945733
# Episode 292: score: 43.0 - reward: 40.183978952467456
# Episode 293: score: 14.0 - reward: 13.000537967681886
# Episode 294: score: 19.0 - reward: 17.73262421041727
# Episode 295: score: 42.0 - reward: 40.06373293697834
# Episode 296: score: 47.0 - reward: 44.094930260255936
# Episode 297: score: 37.0 - reward: 35.822525023669
# Episode 298: score: 97.0 - reward: 89.21423512846235
# Episode 299: score: 46.0 - reward: 42.85639131069183
# Episode 300: score: 10.0 - reward: 9.39904166162014
# Test Episode 300: test score: 34.0 - test reward: 31.811240489780907
# Episode 301: score: 22.0 - reward: 20.495585507899523
# Episode 302: score: 17.0 - reward: 16.01307431012392
# Episode 303: score: 51.0 - reward: 48.283555378764866
# Episode 304: score: 38.0 - reward: 35.746747355908155
# Episode 305: score: 24.0 - reward: 22.779745949804784
# Episode 306: score: 21.0 - reward: 20.19543696790934
# Episode 307: score: 67.0 - reward: 63.07708146795631
# Episode 308: score: 26.0 - reward: 24.860261103510854
# Episode 309: score: 29.0 - reward: 27.258470538258557
# Episode 310: score: 31.0 - reward: 29.753447500616314
# Test Episode 310: test score: 84.0 - test reward: 75.57732415013017
# Episode 311: score: 73.0 - reward: 66.19898641854525
# Episode 312: score: 10.0 - reward: 9.368313804268837
# ...
# Episode 238: score: 49.0 - reward: 46.799642354249954
# Episode 239: score: 15.0 - reward: 14.16787949204445
# Episode 240: score: 17.0 - reward: 16.21242671385407
# Test Episode 240: test score: 14.0 - test reward: 13.368366275727752
# Episode 241: score: 18.0 - reward: 16.760088880360126
# Episode 242: score: 35.0 - reward: 32.12077704966068
# Episode 243: score: 47.0 - reward: 42.20988090485334
# Episode 244: score: 36.0 - reward: 34.51851535085588
# Episode 245: score: 78.0 - reward: 74.16905533373357
# Episode 246: score: 62.0 - reward: 56.298995590209955
# Episode 247: score: 27.0 - reward: 25.83250543922186
# Episode 248: score: 56.0 - reward: 51.16660250574349
# Episode 249: score: 12.0 - reward: 11.30890083163977
# Episode 250: score: 32.0 - reward: 29.665222224593162
# Test Episode 250: test score: 33.0 - test reward: 31.613720287382606
# Episode 251: score: 49.0 - reward: 44.91222547292709
# Episode 252: score: 25.0 - reward: 23.63135747592897
# Episode 253: score: 51.0 - reward: 47.19385406672955
# Episode 254: score: 19.0 - reward: 17.46514033973217
# Episode 255: score: 53.0 - reward: 49.58670428432523
# Episode 256: score: 65.0 - reward: 62.18162600547075
# Episode 257: score: 24.0 - reward: 22.89507510215044
# Episode 258: score: 34.0 - reward: 31.560744861140844
# Episode 259: score: 23.0 - reward: 21.65008716210723
# Episode 260: score: 14.0 - reward: 13.230002941191197
# Test Episode 260: test score: 14.0 - test reward: 12.838087344169617
# Episode 261: score: 50.0 - reward: 48.07086165659129
# Episode 262: score: 32.0 - reward: 30.62162959277631
# Episode 263: score: 40.0 - reward: 37.21666847467423
# Episode 264: score: 12.0 - reward: 11.313529121875762
# Episode 265: score: 26.0 - reward: 24.052680981159202
# Episode 266: score: 38.0 - reward: 36.6936989620328
# Episode 267: score: 22.0 - reward: 20.99399369806051
# Episode 268: score: 13.0 - reward: 11.988577222824095
# Episode 269: score: 10.0 - reward: 9.385468447208403
# Episode 270: score: 20.0 - reward: 18.42029907554388
# Test Episode 270: test score: 18.0 - test reward: 17.02222377359867
# Episode 271: score: 23.0 - reward: 21.725925046205514
# Episode 272: score: 24.0 - reward: 21.958871123194694
# Episode 273: score: 16.0 - reward: 14.99345232695341
# Episode 274: score: 37.0 - reward: 35.2552321203053
# Episode 275: score: 43.0 - reward: 41.467019556090236
# Episode 276: score: 14.0 - reward: 13.037864419817923
# Episode 277: score: 18.0 - reward: 17.16293530985713
# Episode 278: score: 40.0 - reward: 36.8274421006441
# Episode 279: score: 12.0 - reward: 11.04024241566658
# Episode 280: score: 17.0 - reward: 16.005767220258715
# Test Episode 280: test score: 21.0 - test reward: 19.612080851197245
# Episode 281: score: 20.0 - reward: 18.571822375059124
# Episode 282: score: 9.0 - reward: 8.504709365963937
# Episode 283: score: 31.0 - reward: 29.318971383571625
# Episode 284: score: 22.0 - reward: 20.42680894136429
# Episode 285: score: 20.0 - reward: 18.719059264659883
# Episode 286: score: 59.0 - reward: 56.376354371756314
# Episode 287: score: 37.0 - reward: 34.8634557902813
# Episode 288: score: 27.0 - reward: 25.68444425091147
# Episode 289: score: 16.0 - reward: 15.141281630843878
# Episode 290: score: 10.0 - reward: 9.291106629371642
# Test Episode 290: test score: 10.0 - test reward: 9.350189781188964
# Episode 291: score: 50.0 - reward: 45.46962170004846
# Episode 292: score: 34.0 - reward: 32.70629231762141
# Episode 293: score: 42.0 - reward: 38.601090978085985
# Episode 294: score: 23.0 - reward: 21.863398315012457
# Episode 295: score: 21.0 - reward: 20.21512673944235
# Episode 296: score: 23.0 - reward: 22.13165449388325
# Episode 297: score: 13.0 - reward: 12.17372965682298
# Episode 298: score: 11.0 - reward: 10.383866974711419
# Episode 299: score: 18.0 - reward: 16.754084272682665
# Episode 300: score: 90.0 - reward: 83.21399824917316
# Test Episode 300: test score: 23.0 - test reward: 21.438871078938245
# Episode 301: score: 11.0 - reward: 10.26495635062456
# Episode 302: score: 30.0 - reward: 28.377966810762878
# Episode 303: score: 23.0 - reward: 21.668320903182032
# Episode 304: score: 71.0 - reward: 65.41572826607151
# Episode 305: score: 22.0 - reward: 21.14071042686701
# Episode 306: score: 61.0 - reward: 58.164566198736445
# Episode 307: score: 18.0 - reward: 16.761313892900947
# Episode 308: score: 22.0 - reward: 20.69850143902004
# Episode 309: score: 40.0 - reward: 37.61364226005971
# Episode 310: score: 40.0 - reward: 38.154320263862616
# Test Episode 310: test score: 12.0 - test reward: 11.224222770333292
# Episode 311: score: 38.0 - reward: 36.437178055197
# Episode 312: score: 16.0 - reward: 15.111522075533868
# Episode 313: score: 52.0 - reward: 49.982072529196756
# Episode 314: score: 22.0 - reward: 20.70652406215668
# Episode 315: score: 88.0 - reward: 82.76699610352517
# Episode 316: score: 31.0 - reward: 29.273880863189696
# Episode 317: score: 36.0 - reward: 34.67210905831306
# Episode 318: score: 44.0 - reward: 42.5345541415736
# Episode 319: score: 28.0 - reward: 26.89619362652302
# Episode 320: score: 50.0 - reward: 46.81105200275778
# Test Episode 320: test score: 76.0 - test reward: 71.5922806956805
# Episode 321: score: 22.0 - reward: 20.851402465999126
# Episode 322: score: 22.0 - reward: 20.96371149867773
# Episode 323: score: 24.0 - reward: 22.326695415377618
# Episode 324: score: 28.0 - reward: 26.284635040163984
# Episode 325: score: 20.0 - reward: 18.63717662841082
# Episode 326: score: 52.0 - reward: 48.03800165206193
# Episode 327: score: 49.0 - reward: 47.1608484795317
# Episode 328: score: 17.0 - reward: 15.964308565855026
# Episode 329: score: 19.0 - reward: 17.984249214828015
# Episode 330: score: 44.0 - reward: 42.86711919978263
# Test Episode 330: test score: 16.0 - test reward: 14.753546185046435
# Episode 331: score: 12.0 - reward: 11.255061082541943
# Episode 332: score: 12.0 - reward: 11.196687926352023
# Episode 333: score: 65.0 - reward: 61.00195516441019
# Episode 334: score: 46.0 - reward: 42.97552009820937
# Episode 335: score: 17.0 - reward: 16.268280123174193
# Episode 336: score: 11.0 - reward: 10.362997923791408
# Episode 337: score: 11.0 - reward: 10.25946457386017
# Episode 338: score: 25.0 - reward: 24.129066191613674
# Episode 339: score: 49.0 - reward: 45.52226178944109
# Episode 340: score: 52.0 - reward: 49.76063822479917
# Test Episode 340: test score: 73.0 - test reward: 68.63349460996685
# Episode 341: score: 16.0 - reward: 15.128915470093489
# Episode 342: score: 17.0 - reward: 15.963557296991345
# Episode 343: score: 29.0 - reward: 26.79210272729397
# Episode 344: score: 42.0 - reward: 38.043704929947864
# Episode 345: score: 24.0 - reward: 22.625187519937757
# Episode 346: score: 56.0 - reward: 49.393551904708154
# Episode 347: score: 10.0 - reward: 9.3452532351017
# Episode 348: score: 15.0 - reward: 14.188899739086626
# Episode 349: score: 24.0 - reward: 22.373821996152394
# Episode 350: score: 20.0 - reward: 18.51323408037424
# Test Episode 350: test score: 26.0 - test reward: 24.28398864865303
# Episode 351: score: 15.0 - reward: 13.854832962155342
# Episode 352: score: 35.0 - reward: 33.39013305306435
# Episode 353: score: 35.0 - reward: 34.046521327644584
# Episode 354: score: 47.0 - reward: 43.64291210472584
# Episode 355: score: 18.0 - reward: 16.2333350777626
# Episode 356: score: 23.0 - reward: 21.345574550330642
# Episode 357: score: 11.0 - reward: 10.054472205042838
# Episode 358: score: 65.0 - reward: 61.066552487015734
# Episode 359: score: 97.0 - reward: 92.15775739774112
# Episode 360: score: 67.0 - reward: 62.54773292839525
# Test Episode 360: test score: 88.0 - test reward: 83.84089316856115
# Episode 361: score: 25.0 - reward: 23.69524983782322
# Episode 362: score: 61.0 - reward: 58.489208347164066
# Episode 363: score: 26.0 - reward: 24.80910815298557
# Episode 364: score: 73.0 - reward: 67.39215047359464
# Episode 365: score: 11.0 - reward: 10.361945617198945
# Episode 366: score: 39.0 - reward: 37.74046220630408
# Episode 367: score: 11.0 - reward: 10.28184056431055
# Episode 368: score: 25.0 - reward: 23.241885745525355
# Episode 369: score: 10.0 - reward: 9.35409662798047
# Episode 370: score: 57.0 - reward: 52.33783261775971
# Test Episode 370: test score: 20.0 - test reward: 19.296461881697176
# Episode 371: score: 64.0 - reward: 58.86483179330826
# Episode 372: score: 56.0 - reward: 52.50392916798591
# Episode 373: score: 55.0 - reward: 52.73043778538703
# Episode 374: score: 35.0 - reward: 33.11623797416687
# Episode 375: score: 39.0 - reward: 36.23953669071198
# Episode 376: score: 51.0 - reward: 48.46461513452232
# Episode 377: score: 16.0 - reward: 15.027103125303984
# Episode 378: score: 12.0 - reward: 11.288031274080277
# Episode 379: score: 79.0 - reward: 74.07276830077171
# Episode 380: score: 24.0 - reward: 22.061265262216324
# Test Episode 380: test score: 56.0 - test reward: 53.702785368263704
# Episode 381: score: 46.0 - reward: 42.64937864616514
# Episode 382: score: 15.0 - reward: 14.338473714888098
# Episode 383: score: 27.0 - reward: 25.27048785556108
# Episode 384: score: 13.0 - reward: 12.324576228484512
# Episode 385: score: 20.0 - reward: 18.104682902991776
# Episode 386: score: 35.0 - reward: 33.9407578971237
# Episode 387: score: 13.0 - reward: 12.202319355309008
# Episode 388: score: 10.0 - reward: 9.254097957909106
# Episode 389: score: 19.0 - reward: 17.973962539434435
# Episode 390: score: 12.0 - reward: 11.16333175599575
# Test Episode 390: test score: 11.0 - test reward: 10.406406401097774
# Episode 391: score: 10.0 - reward: 9.388518866524102
# Episode 392: score: 13.0 - reward: 12.320279507339
# Episode 393: score: 13.0 - reward: 12.362577980756758
# Episode 394: score: 12.0 - reward: 11.325933428108693
# Episode 395: score: 14.0 - reward: 13.33139207623899
# Episode 396: score: 13.0 - reward: 12.18825705945492
# Episode 397: score: 11.0 - reward: 10.218971610069275
# Episode 398: score: 13.0 - reward: 12.004911594092846
# Episode 399: score: 47.0 - reward: 44.01171362102033
# Episode 400: score: 28.0 - reward: 26.60803665816784
# Test Episode 400: test score: 12.0 - test reward: 11.249267241731287
# Episode 401: score: 11.0 - reward: 10.232273390889167
# Episode 402: score: 11.0 - reward: 10.423387312889101
# Episode 403: score: 17.0 - reward: 15.649084371328355
# Episode 404: score: 11.0 - reward: 10.313131570816042
# Episode 405: score: 26.0 - reward: 24.491501483321187
# Episode 406: score: 36.0 - reward: 33.66984142288566
# Episode 407: score: 15.0 - reward: 13.87819608747959
# Episode 408: score: 23.0 - reward: 21.558156741410492
# Episode 409: score: 37.0 - reward: 35.95567458001897
# Episode 410: score: 18.0 - reward: 16.293958753347397
# Test Episode 410: test score: 21.0 - test reward: 19.39596229046583
# Episode 411: score: 26.0 - reward: 23.930335053801535
# Episode 412: score: 34.0 - reward: 32.65807170718907
# Episode 413: score: 24.0 - reward: 22.698748622089624
# Episode 414: score: 13.0 - reward: 11.99451458454132
# Episode 415: score: 10.0 - reward: 9.420531868934631
# Episode 416: score: 11.0 - reward: 10.126086670160294
# Episode 417: score: 22.0 - reward: 20.532807540893558
# Episode 418: score: 27.0 - reward: 25.474939075671134
# Episode 419: score: 10.0 - reward: 9.406108161807062
# Episode 420: score: 32.0 - reward: 29.716838601231572
# Test Episode 420: test score: 37.0 - test reward: 33.663867400586604
# Episode 421: score: 10.0 - reward: 9.26836834102869
# Episode 422: score: 22.0 - reward: 20.493863034248353
# Episode 423: score: 28.0 - reward: 26.919693484157328
# Episode 424: score: 15.0 - reward: 13.71071781516075
# Episode 425: score: 31.0 - reward: 28.970925222337247
# Episode 426: score: 13.0 - reward: 11.840454724431037
# Episode 427: score: 48.0 - reward: 45.31028479039671
# Episode 428: score: 23.0 - reward: 21.978028756380084
# Episode 429: score: 19.0 - reward: 18.24727981686592
# Episode 430: score: 45.0 - reward: 43.065072560310355
# Test Episode 430: test score: 31.0 - test reward: 28.311293651163577
# Episode 431: score: 21.0 - reward: 19.23959940969944
# Episode 432: score: 10.0 - reward: 9.272166821360587
# Episode 433: score: 73.0 - reward: 70.12204234823582
# Episode 434: score: 62.0 - reward: 58.59739193283022
# Episode 435: score: 28.0 - reward: 26.019622197747232
# Episode 436: score: 95.0 - reward: 75.28319281339645
# Episode 437: score: 45.0 - reward: 42.363919088244444
# Episode 438: score: 42.0 - reward: 39.33051675260068
# Episode 439: score: 15.0 - reward: 14.285813754796983
# Episode 440: score: 35.0 - reward: 33.70522718653082
# Test Episode 440: test score: 111.0 - test reward: 98.30325342565769
# Episode 441: score: 116.0 - reward: 109.56945536881682
# Episode 442: score: 15.0 - reward: 14.161742058396339
# Episode 443: score: 118.0 - reward: 108.78595046494152
# Episode 444: score: 19.0 - reward: 17.375128829479216
# Episode 445: score: 50.0 - reward: 45.98133565485478
# Episode 446: score: 81.0 - reward: 77.94193267822266
# Episode 447: score: 32.0 - reward: 30.681022733449943
# Episode 448: score: 31.0 - reward: 29.063134171068672
# Episode 449: score: 23.0 - reward: 21.17501029781997
# Episode 450: score: 32.0 - reward: 29.98000878691673
# Test Episode 450: test score: 66.0 - test reward: 64.23396453633904
# Episode 451: score: 29.0 - reward: 27.397714880108833
# Episode 452: score: 74.0 - reward: 69.98190106451511
# Episode 453: score: 33.0 - reward: 30.767959724366666
# Episode 454: score: 23.0 - reward: 22.054102633148432
# Episode 455: score: 39.0 - reward: 36.44904855191707
# Episode 456: score: 37.0 - reward: 34.31061709821224
# Episode 457: score: 31.0 - reward: 28.859793203324077
# Episode 458: score: 24.0 - reward: 22.78069915473461
# Episode 459: score: 31.0 - reward: 29.16441607475281
# Episode 460: score: 9.0 - reward: 8.29250095486641
# Test Episode 460: test score: 52.0 - test reward: 49.837209969013934
# Episode 461: score: 12.0 - reward: 11.263938692212104
# Episode 462: score: 17.0 - reward: 15.733282306790352
# Episode 463: score: 40.0 - reward: 36.99412967711688
# Episode 464: score: 34.0 - reward: 32.18005675375461
# Episode 465: score: 73.0 - reward: 67.11282597631215
# Episode 466: score: 33.0 - reward: 31.839971028268344
# Episode 467: score: 15.0 - reward: 14.188397909328343
# Episode 468: score: 12.0 - reward: 11.124485865235327
# Episode 469: score: 16.0 - reward: 14.4432119846344
# Episode 470: score: 24.0 - reward: 22.669485953077672
# Test Episode 470: test score: 15.0 - test reward: 14.165643767267467
# Episode 471: score: 13.0 - reward: 12.25110225379467
# Episode 472: score: 18.0 - reward: 17.252513113617894
# Episode 473: score: 11.0 - reward: 10.181965428590773
# Episode 474: score: 20.0 - reward: 18.30471078306437
# Episode 475: score: 70.0 - reward: 65.48562012761833
# Episode 476: score: 13.0 - reward: 12.26320180594921
# Episode 477: score: 22.0 - reward: 20.866780953109263
# Episode 478: score: 18.0 - reward: 16.66350931227207
# Episode 479: score: 21.0 - reward: 19.48464563637972
# Episode 480: score: 31.0 - reward: 28.574844902753824
# Test Episode 480: test score: 54.0 - test reward: 51.21647938638927
# Episode 481: score: 23.0 - reward: 21.54087510034442
# Episode 482: score: 36.0 - reward: 34.3972016632557
# Episode 483: score: 31.0 - reward: 28.921009795367723
# Episode 484: score: 39.0 - reward: 36.19075210392476
# Episode 485: score: 10.0 - reward: 9.290756486356258
# Episode 486: score: 10.0 - reward: 9.423232421278952
# Episode 487: score: 17.0 - reward: 16.34955359995365
# Episode 488: score: 27.0 - reward: 25.790346658229833
# Episode 489: score: 47.0 - reward: 43.99459457993507
# Episode 490: score: 26.0 - reward: 24.995087902992967
# Test Episode 490: test score: 27.0 - test reward: 25.30117269009352
# Episode 491: score: 13.0 - reward: 12.238941046595574
# Episode 492: score: 24.0 - reward: 22.071369224041703
# Episode 493: score: 39.0 - reward: 35.20628336668015
# Episode 494: score: 22.0 - reward: 20.508601669967177
# Episode 495: score: 15.0 - reward: 13.984167376253756
# Episode 496: score: 26.0 - reward: 24.39286859035492
# Episode 497: score: 11.0 - reward: 10.290471829473972
# Episode 498: score: 27.0 - reward: 25.010895027965304
# Episode 499: score: 11.0 - reward: 10.315591613948344
# Episode 500: score: 12.0 - reward: 11.216705695260316
# Test Episode 500: test score: 16.0 - test reward: 14.597414422035218
# best test reward: 252.35105057386662
# Rewards data saved to example_data.pkl

# %%
plot_rewards(rewards_data, algorithm_name="DDQN (TC CartPole)")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
