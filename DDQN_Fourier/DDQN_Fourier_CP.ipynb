# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import gym
from collections import deque
import random
import itertools
from torch import nn
from torch.nn import functional
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

import pickle

def save_rewards_data(rewards_data, filename='rewards_data.pkl'):
    """Save the rewards data to a pickle file."""
    with open(filename, 'wb') as file:
        pickle.dump(rewards_data, file)
    print(f'Rewards data saved to {filename}')


def load_rewards_data(filename='rewards_data.pkl'):
    """Load the rewards data from a pickle file."""
    try:
        with open(filename, 'rb') as file:
            rewards_data = pickle.load(file)
        print(f'Rewards data loaded from {filename}')
        return rewards_data
    except FileNotFoundError:
        print(f'Error: The file {filename} does not exist. Please check the file path and try again.')
        return None
    except Exception as e:
        print(f'An error occurred while loading the data: {e}')
        return None

class Fourier_Basis:
  def __init__(self, order, k):
    #self.env = env
    self.order = [order]*k
    self.coefficients = np.array([])

  def get_coefficients(self):
    prods = [range(0, i+1) for i in self.order]
    #print(prods)
    coeffs = [v for v in itertools.product(*prods)]
    self.coefficients = np.array(coeffs)
    return self.coefficients
  
  def value(self, state):
    self.get_coefficients()
    return np.cos(np.pi*np.dot(self.coefficients, state))
# Out:
# cpu

# %%
class Model(nn.Module):
    def __init__(self, input_features, output_values):
        super(Model, self).__init__()
        self.fc1 = nn.Linear(in_features=input_features, out_features=32)
        self.fc2 = nn.Linear(in_features=32, out_features=32)
        self.fc3 = nn.Linear(in_features=32, out_features=output_values)

    def forward(self, x):
        x = functional.selu(self.fc1(x))
        x = functional.selu(self.fc2(x))
        x = self.fc3(x)
        return x

class DDQN:
    def __init__(self, env, order, discretizer, use_cuda=True, learning_rate=1e-5, gamma=0.7, memory_len=10000, start_epsilon=1):
        self.device = torch.device("cuda" if use_cuda and torch.cuda.is_available() else "cpu")
        self.env = env
        self.discretizer = discretizer
        self.learning_rate = learning_rate
        self.gamma = gamma
        self.u_state = np.array([env.observation_space.high[0], 10, env.observation_space.high[2], 5])
        self.l_state = np.array([env.observation_space.low[0], -10, env.observation_space.low[2], -5])
        self.d_state = self.u_state - self.l_state
        self.n_features = len(env.observation_space.high)

        self.epsilon = start_epsilon
        self.min_epsilon = 0.001
        self.epsilon_decay = 0.9 / 2.5e3
        self.memory_len = memory_len
        self.memory = deque(maxlen=self.memory_len)
        self.criterion = nn.MSELoss()

        input_features = (order + 1)**env.observation_space.shape[0]
        output_values = env.action_space.n
        self.policy_net = Model(input_features, output_values).to(self.device)
        self.target_net = Model(input_features, output_values).to(self.device)

        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()

    def get_states_tensor(self, sample, states_idx):
        sample_len = len(sample)
        states_tensor = torch.empty((sample_len, self.n_features), dtype=torch.float32, requires_grad=False)

        features_range = range(self.n_features)
        for i in range(sample_len):
            for j in features_range:
                states_tensor[i, j] = sample[i][states_idx][j].item()

        return states_tensor

    def normalize_state(self, state):
        if len(state) != 4:
            state = state[0]
        state[0] /= 2.5
        state[1] /= 2.5
        state[2] /= 0.3
        state[3] /= 0.3

    def state_reward(self, state, env_reward):
        return env_reward - (abs(state[0]) + abs(state[2])) / 2.5

    def get_action(self, state, e=0.001):
        if random.random() < e:
            return random.randrange(0, self.env.action_space.n)
        else:
            encoded_state = (state - self.l_state) / self.d_state
            state_cos = self.discretizer.value(encoded_state)
            encoded_state = torch.tensor(state_cos, dtype=torch.float32, device=self.device)
            return self.policy_net(encoded_state).argmax().item()

    def fit(self, model, inputs, labels):
        inputs = inputs.to(self.device)
        labels = labels.to(self.device)
        train_ds = TensorDataset(inputs, labels)
        train_dl = DataLoader(train_ds, batch_size=5)

        optimizer = torch.optim.Adam(params=model.parameters(), lr=self.learning_rate)
        model.train()
        total_loss = 0.0

        for x, y in train_dl:
            out = model(x)
            loss = self.criterion(out, y)
            total_loss += loss.item()
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        model.eval()
        return total_loss / len(train_dl)

    def optimize_model(self, train_batch_size=100):
        if len(self.memory) < train_batch_size:
            return
        train_sample = random.sample(self.memory, train_batch_size)

        state = torch.tensor([s[0] for s in train_sample], dtype=torch.float32, device=device)
        next_state = torch.tensor([s[3] for s in train_sample], dtype=torch.float32, device=device)

        q_estimates = self.policy_net(state).detach()
        next_state_q_estimates = self.target_net(next_state).detach()
        next_actions = self.policy_net(next_state).argmax(dim=1)

        for i in range(len(train_sample)):
            next_action = next_actions[i].item()
            q_estimates[i][train_sample[i][1]] = (self.state_reward(next_state[i], train_sample[i][2]) +
                                                  self.gamma * next_state_q_estimates[i][next_action].item())

        self.fit(self.policy_net, state, q_estimates)

    def train_one_episode(self):
        current_state = self.env.reset()
        #self.normalize_state(current_state)
        done = False
        score = 0
        reward = 0
        step = 0
        while not done and step < 501:
            if len(current_state) != 4:
                current_state = current_state[0]
            action = self.get_action(current_state, self.epsilon)
            next_state, env_reward, done,info,  _ = self.env.step(action)
            #self.normalize_state(next_state)
            encoded_current_state = self.discretizer.value((current_state - self.l_state) / self.d_state)
            encoded_next_state = self.discretizer.value((next_state - self.l_state) / self.d_state)
            self.memory.append((encoded_current_state, action, env_reward, encoded_next_state))
            current_state = next_state
            score += env_reward
            reward += self.state_reward(next_state, env_reward)

            self.optimize_model(100)
            step += 1

            self.epsilon = max(self.min_epsilon, self.epsilon - self.epsilon_decay)

        return score, reward

    def test(self):
        state = self.env.reset()
        #self.normalize_state(state)
        done = False
        score = 0
        reward = 0
        step = 0
        while not done and step < 501:
            if len(state) != 4:
                state = state[0]
            action = self.get_action(state, 0)  # Using 0 to bypass random action selection
            state, env_reward, done, info,  _ = self.env.step(action)
            #self.normalize_state(state)
            score += env_reward
            reward += self.state_reward(state, env_reward)
            step += 1

        return score, reward

# %%
env = gym.make('CartPole-v1')

order = 5
k = env.observation_space.shape[0]
FB = Fourier_Basis(order, k)

# %%
def main(used_alpha, used_epsilon, env, order, discretizer, target_update_delay, test_delay, memory_len=10000, num_runs=1, num_episode=1000, save_file=""):


    # Initialize storage for reward data
    rewards_data = {epsilon: {alpha: [] for alpha in used_alpha} for epsilon in used_epsilon}

    for epsilon in used_epsilon:
        for alpha in used_alpha:
            print(f"Training with epsilon: {epsilon}, alpha: {alpha}")
            run_rewards = []  # Collect rewards for each run for the current config

            for run in range(num_runs):
                
                # avoid decay
                current_epsilon = epsilon

                print(f"Run {run + 1}/{num_runs}")
                
                # renew the wrapper class
                ddqn = DDQN(
                    env=env, 
                    order = order,
                    discretizer=discretizer, 
                    use_cuda=True, 
                    learning_rate=alpha, 
                    gamma=0.99,
                    memory_len=memory_len, 
                    start_epsilon=current_epsilon
                )

                best_test_reward = 0

                episode_rewards = []  # Collect rewards for each episode in the current run
                for i in range(num_episode):
                    score, reward = ddqn.train_one_episode()

                    print(f'Episode {i + 1}: score: {score} - reward: {reward}')

                    if i % target_update_delay == 0:
                        ddqn.target_net.load_state_dict(ddqn.policy_net.state_dict())
                        ddqn.target_net.eval()

                    if (i + 1) % test_delay == 0:
                        test_score, test_reward = ddqn.test()
                        print(f'Test Episode {i + 1}: test score: {test_score} - test reward: {test_reward}')
                        if test_reward > best_test_reward:
                            print('New best test reward. Saving model')
                            best_test_reward = test_reward
                            # torch.save(ddqn.policy_net.state_dict(), f'policy_net_{run}.pth')

                    # Add the rewards
                    episode_rewards.append(score)

                if num_episode % test_delay != 0:
                    test_score, test_reward = ddqn.test()
                    print(f'Test Episode {num_episode}: test score: {test_score} - test reward: {test_reward}')
                    if test_reward > best_test_reward:
                        print('New best test reward. Saving model')
                        best_test_reward = test_reward
                        # torch.save(ddqn.policy_net.state_dict(), f'policy_net_{run}.pth')

                # save the run rewards
                run_rewards.append(episode_rewards)

                print(f'best test reward: {best_test_reward}')

            # Store the rewards for the current epsilon and alpha configuration
            rewards_data[epsilon][alpha] = run_rewards

    if not(save_file == ""):
        save_rewards_data(rewards_data, save_file)

    return rewards_data

# %%
rewards_data = main(
    used_alpha= [1e-3, 5e-4, 1e-4], 
    used_epsilon=[0.1, 0.01],  # start epsilon
    env=env, 
    order = order,
    discretizer=FB,
    target_update_delay=2, 
    test_delay=10,
    memory_len=10000, 
    num_runs=3, 
    num_episode=500, 
    save_file="DDQN_Fourier_CP.pkl"
)
# Out:
# Training with epsilon: 0.1, alpha: 0.001
# Run 1/3
# Episode 1: score: 11.0 - reward: 10.176358456909655
# Episode 2: score: 9.0 - reward: 8.240145656466485
# Episode 3: score: 9.0 - reward: 8.448603214323521
# Episode 4: score: 9.0 - reward: 8.37840636521578
# Episode 5: score: 11.0 - reward: 10.415231926739214
# Episode 6: score: 10.0 - reward: 9.473732434213161
# Episode 7: score: 11.0 - reward: 10.358460474014281
# Episode 8: score: 9.0 - reward: 8.326074782013894
# Episode 9: score: 9.0 - reward: 8.513540126755833
# Episode 10: score: 10.0 - reward: 9.403187546133994
# Test Episode 10: test score: 8.0 - test reward: 7.545022907853127
# New best test reward. Saving model
# Episode 11: score: 8.0 - reward: 7.40681768655777
# Episode 12: score: 9.0 - reward: 8.444902956485748
# Episode 13: score: 10.0 - reward: 9.345956575125456
# Episode 14: score: 10.0 - reward: 9.482909953594207
# Episode 15: score: 11.0 - reward: 10.089577442407608
# Episode 16: score: 10.0 - reward: 9.2709160476923
# Episode 17: score: 44.0 - reward: 41.043255967646836
# Episode 18: score: 9.0 - reward: 8.594206523895263
# Episode 19: score: 8.0 - reward: 7.510261440277099
# Episode 20: score: 11.0 - reward: 10.206597372889519
# Test Episode 20: test score: 9.0 - test reward: 8.42175720334053
# New best test reward. Saving model
# Episode 21: score: 10.0 - reward: 9.511922247707844
# Episode 22: score: 9.0 - reward: 8.400208270549772
# Episode 23: score: 9.0 - reward: 8.409219709038734
# Episode 24: score: 9.0 - reward: 8.448070627450944
# Episode 25: score: 9.0 - reward: 8.304328441619873
# Episode 26: score: 9.0 - reward: 8.428460778295994
# Episode 27: score: 9.0 - reward: 8.378740181028844
# Episode 28: score: 11.0 - reward: 10.376520340144634
# Episode 29: score: 10.0 - reward: 9.247489078342914
# Episode 30: score: 9.0 - reward: 8.23740821480751
# Test Episode 30: test score: 10.0 - test reward: 9.28842137902975
# New best test reward. Saving model
# Episode 31: score: 9.0 - reward: 8.430352640151977
# Episode 32: score: 12.0 - reward: 11.233811783045528
# Episode 33: score: 10.0 - reward: 9.422416435182097
# Episode 34: score: 9.0 - reward: 8.44252826720476
# Episode 35: score: 11.0 - reward: 10.397399060428144
# Episode 36: score: 9.0 - reward: 8.450403314828872
# Episode 37: score: 10.0 - reward: 9.196537953615188
# Episode 38: score: 10.0 - reward: 9.448476480692626
# Episode 39: score: 8.0 - reward: 7.465759199857711
# Episode 40: score: 10.0 - reward: 9.248711651563644
# Test Episode 40: test score: 11.0 - test reward: 10.286926977336407
# New best test reward. Saving model
# Episode 41: score: 10.0 - reward: 9.421150073036552
# Episode 42: score: 10.0 - reward: 9.451641153544188
# Episode 43: score: 11.0 - reward: 10.34385463669896
# Episode 44: score: 10.0 - reward: 9.252987088263035
# Episode 45: score: 11.0 - reward: 10.177584539353846
# Episode 46: score: 11.0 - reward: 10.17848598510027
# Episode 47: score: 10.0 - reward: 9.502375961840153
# Episode 48: score: 11.0 - reward: 10.283749113231895
# Episode 49: score: 9.0 - reward: 8.477265028655529
# Episode 50: score: 9.0 - reward: 8.43104829788208
# Test Episode 50: test score: 10.0 - test reward: 9.409841179847719
# Episode 51: score: 12.0 - reward: 11.149424484372142
# Episode 52: score: 9.0 - reward: 8.49409701526165
# Episode 53: score: 9.0 - reward: 8.3952481046319
# Episode 54: score: 9.0 - reward: 8.525738181173802
# Episode 55: score: 9.0 - reward: 8.391733975708485
# Episode 56: score: 9.0 - reward: 8.288923254609108
# Episode 57: score: 9.0 - reward: 8.238158750534057
# Episode 58: score: 9.0 - reward: 8.377171435952187
# Episode 59: score: 11.0 - reward: 10.251320399343967
# Episode 60: score: 10.0 - reward: 9.311081905663013
# Test Episode 60: test score: 79.0 - test reward: 64.62253299653527
# New best test reward. Saving model
# Episode 61: score: 10.0 - reward: 9.465771412849424
# Episode 62: score: 11.0 - reward: 10.105686840415002
# Episode 63: score: 9.0 - reward: 8.443191692233086
# Episode 64: score: 9.0 - reward: 8.526246176660061
# Episode 65: score: 9.0 - reward: 8.41780282482505
# Episode 66: score: 9.0 - reward: 8.472858041524887
# Episode 67: score: 9.0 - reward: 8.441572442650795
# Episode 68: score: 11.0 - reward: 10.178304517269135
# Episode 69: score: 11.0 - reward: 10.412582896277309
# Episode 70: score: 11.0 - reward: 10.221732836961747
# Test Episode 70: test score: 11.0 - test reward: 10.299561491608618
# Episode 71: score: 11.0 - reward: 10.329827078431846
# Episode 72: score: 9.0 - reward: 8.312928009033202
# Episode 73: score: 12.0 - reward: 11.285524462163448
# Episode 74: score: 9.0 - reward: 8.478737401217222
# Episode 75: score: 10.0 - reward: 9.381413120031358
# Episode 76: score: 10.0 - reward: 9.44328905940056
# Episode 77: score: 12.0 - reward: 11.023047092556954
# Episode 78: score: 10.0 - reward: 9.356543624401091
# Episode 79: score: 10.0 - reward: 9.42917249109596
# Episode 80: score: 9.0 - reward: 8.400564748048783
# Test Episode 80: test score: 11.0 - test reward: 10.198118004202843
# Episode 81: score: 10.0 - reward: 9.480708536505698
# Episode 82: score: 9.0 - reward: 8.331990417838098
# Episode 83: score: 9.0 - reward: 8.481402629613877
# Episode 84: score: 11.0 - reward: 10.269956265389919
# Episode 85: score: 9.0 - reward: 8.465467739105224
# Episode 86: score: 10.0 - reward: 9.406658510863782
# Episode 87: score: 10.0 - reward: 9.329522386193275
# Episode 88: score: 10.0 - reward: 9.26272169202566
# Episode 89: score: 12.0 - reward: 11.276615385711192
# Episode 90: score: 10.0 - reward: 9.435722938459367
# Test Episode 90: test score: 10.0 - test reward: 9.209126743674279
# Episode 91: score: 10.0 - reward: 9.46432720720768
# Episode 92: score: 9.0 - reward: 8.247579115629197
# Episode 93: score: 10.0 - reward: 9.39115340784192
# Episode 94: score: 9.0 - reward: 8.450840456783771
# Episode 95: score: 9.0 - reward: 8.296954703330993
# Episode 96: score: 13.0 - reward: 11.92813200056553
# Episode 97: score: 13.0 - reward: 12.282933133840562
# Episode 98: score: 10.0 - reward: 9.241002352535725
# Episode 99: score: 14.0 - reward: 13.14445611871779
# Episode 100: score: 14.0 - reward: 12.947586640715599
# Test Episode 100: test score: 11.0 - test reward: 10.294178580120205
# Episode 101: score: 189.0 - reward: 139.74154669791463
# Episode 102: score: 12.0 - reward: 10.956882095336915
# Episode 103: score: 27.0 - reward: 25.859507775306696
# Episode 104: score: 15.0 - reward: 14.041058994829653
# Episode 105: score: 21.0 - reward: 19.41437030211091
# Episode 106: score: 24.0 - reward: 21.535341019928456
# Episode 107: score: 25.0 - reward: 22.999251431226728
# Episode 108: score: 23.0 - reward: 21.37054762542247
# Episode 109: score: 46.0 - reward: 42.2722147718072
# Episode 110: score: 88.0 - reward: 73.48360924571749
# Test Episode 110: test score: 11.0 - test reward: 10.281570130586625
# Episode 111: score: 12.0 - reward: 11.137695366144182
# Episode 112: score: 24.0 - reward: 22.299084082990884
# Episode 113: score: 21.0 - reward: 19.686166954040527
# Episode 114: score: 16.0 - reward: 15.016706576943399
# Episode 115: score: 20.0 - reward: 18.265150201879443
# Episode 116: score: 73.0 - reward: 61.43705498576164
# Episode 117: score: 73.0 - reward: 60.52556340694428
# Episode 118: score: 24.0 - reward: 22.410157653689385
# Episode 119: score: 59.0 - reward: 55.0681434161961
# Episode 120: score: 33.0 - reward: 31.89324246644973
# Test Episode 120: test score: 501.0 - test reward: 404.3805067420009
# New best test reward. Saving model
# Episode 121: score: 16.0 - reward: 15.315919527411461
# Episode 122: score: 40.0 - reward: 38.14963081628085
# Episode 123: score: 189.0 - reward: 166.11774874478576
# Episode 124: score: 11.0 - reward: 10.277760681509973
# Episode 125: score: 203.0 - reward: 181.32641146853572
# Episode 126: score: 51.0 - reward: 49.092286731302735
# Episode 127: score: 63.0 - reward: 61.64539305865765
# Episode 128: score: 19.0 - reward: 18.0267291739583
# Episode 129: score: 39.0 - reward: 36.45325540006161
# Episode 130: score: 17.0 - reward: 15.678241324424743
# Test Episode 130: test score: 11.0 - test reward: 10.09359078258276
# Episode 131: score: 20.0 - reward: 18.75250535979867
# Episode 132: score: 13.0 - reward: 12.038605855405331
# Episode 133: score: 13.0 - reward: 11.974917531013489
# Episode 134: score: 12.0 - reward: 11.039051607251167
# Episode 135: score: 25.0 - reward: 23.642279873788354
# Episode 136: score: 10.0 - reward: 9.44359468370676
# Episode 137: score: 293.0 - reward: 251.61808314397942
# Episode 138: score: 173.0 - reward: 150.25060121342543
# Episode 139: score: 190.0 - reward: 161.99611054081473
# Episode 140: score: 154.0 - reward: 136.77581210732455
# Test Episode 140: test score: 193.0 - test reward: 124.687423017621
# Episode 141: score: 501.0 - reward: 435.0137705620379
# Episode 142: score: 141.0 - reward: 95.45823515355585
# Episode 143: score: 185.0 - reward: 158.7910137936473
# Episode 144: score: 126.0 - reward: 80.71563397645957
# Episode 145: score: 192.0 - reward: 166.1997030682862
# Episode 146: score: 69.0 - reward: 59.979051796346916
# Episode 147: score: 109.0 - reward: 93.99453767761585
# Episode 148: score: 185.0 - reward: 157.64048894420264
# Episode 149: score: 215.0 - reward: 187.6544245250523
# Episode 150: score: 83.0 - reward: 76.27767568826674
# Test Episode 150: test score: 501.0 - test reward: 471.97359830755715
# New best test reward. Saving model
# Episode 151: score: 143.0 - reward: 78.40618056058884
# Episode 152: score: 84.0 - reward: 72.36036428064108
# Episode 153: score: 49.0 - reward: 42.09828737676144
# Episode 154: score: 94.0 - reward: 83.71971559226512
# Episode 155: score: 130.0 - reward: 123.5025872305035
# Episode 156: score: 25.0 - reward: 23.060783150792123
# Episode 157: score: 53.0 - reward: 45.39738007187842
# Episode 158: score: 30.0 - reward: 28.023717524856323
# Episode 159: score: 30.0 - reward: 28.551305466517814
# Episode 160: score: 23.0 - reward: 21.024572226405144
# Test Episode 160: test score: 501.0 - test reward: 376.79804136827585
# Episode 161: score: 36.0 - reward: 34.41976047828793
# Episode 162: score: 33.0 - reward: 31.057746535539632
# Episode 163: score: 37.0 - reward: 34.2060751914978
# Episode 164: score: 10.0 - reward: 9.449818212538958
# Episode 165: score: 12.0 - reward: 10.887334048748015
# Episode 166: score: 33.0 - reward: 31.09952741116285
# Episode 167: score: 26.0 - reward: 25.347041426459324
# Episode 168: score: 11.0 - reward: 10.187357079982757
# Episode 169: score: 52.0 - reward: 49.76958264112474
# Episode 170: score: 13.0 - reward: 12.33445316925645
# Test Episode 170: test score: 9.0 - test reward: 8.522296252846717
# Episode 171: score: 10.0 - reward: 9.494882317539306
# Episode 172: score: 15.0 - reward: 14.096139395982027
# Episode 173: score: 12.0 - reward: 11.07590155899525
# Episode 174: score: 15.0 - reward: 14.197859585285187
# Episode 175: score: 11.0 - reward: 10.02801151573658
# Episode 176: score: 37.0 - reward: 35.5726047091186
# Episode 177: score: 16.0 - reward: 15.282437504827977
# Episode 178: score: 49.0 - reward: 47.658047792315486
# Episode 179: score: 40.0 - reward: 37.91768200695514
# Episode 180: score: 32.0 - reward: 30.22346035093069
# Test Episode 180: test score: 501.0 - test reward: 493.51037862063373
# New best test reward. Saving model
# Episode 181: score: 123.0 - reward: 111.1507785990834
# Episode 182: score: 501.0 - reward: 348.8037656586617
# Episode 183: score: 194.0 - reward: 120.89767679423092
# Episode 184: score: 161.0 - reward: 102.11059473156922
# Episode 185: score: 184.0 - reward: 117.7177759513258
# Episode 186: score: 193.0 - reward: 120.49940579831595
# Episode 187: score: 187.0 - reward: 116.97896575480704
# Episode 188: score: 102.0 - reward: 91.99126658290629
# Episode 189: score: 406.0 - reward: 331.7229888655247
# Episode 190: score: 124.0 - reward: 113.2834763787687
# Test Episode 190: test score: 106.0 - test reward: 95.99363885149363
# Episode 191: score: 109.0 - reward: 99.5851958587766
# Episode 192: score: 161.0 - reward: 109.08573426157231
# Episode 193: score: 114.0 - reward: 90.104878243804
# Episode 194: score: 21.0 - reward: 19.79608646184206
# Episode 195: score: 84.0 - reward: 71.34241486489775
# Episode 196: score: 242.0 - reward: 102.5792788505554
# Episode 197: score: 11.0 - reward: 10.262143130600451
# Episode 198: score: 13.0 - reward: 12.017126354575158
# Episode 199: score: 9.0 - reward: 8.501251050829888
# Episode 200: score: 13.0 - reward: 12.130534154549242
# Test Episode 200: test score: 12.0 - test reward: 10.991200047731398
# Episode 201: score: 13.0 - reward: 12.178796002268792
# Episode 202: score: 20.0 - reward: 18.422150102257735
# Episode 203: score: 107.0 - reward: 66.22104930281641
# Episode 204: score: 137.0 - reward: 76.14628337323667
# Episode 205: score: 177.0 - reward: 90.45478368103502
# Episode 206: score: 127.0 - reward: 81.81227673590185
# Episode 207: score: 138.0 - reward: 86.29955040514471
# Episode 208: score: 141.0 - reward: 92.17911387979987
# Episode 209: score: 130.0 - reward: 86.54415340367706
# Episode 210: score: 84.0 - reward: 70.9836135834456
# Test Episode 210: test score: 137.0 - test reward: 94.9471855729818
# Episode 211: score: 137.0 - reward: 92.42438113465907
# Episode 212: score: 142.0 - reward: 94.81043355166916
# Episode 213: score: 163.0 - reward: 110.97506884448224
# Episode 214: score: 170.0 - reward: 117.28793952912096
# Episode 215: score: 155.0 - reward: 103.70691742300993
# Episode 216: score: 146.0 - reward: 102.79602788835767
# Episode 217: score: 164.0 - reward: 119.06296822875741
# Episode 218: score: 155.0 - reward: 111.54688293486826
# Episode 219: score: 131.0 - reward: 117.9855235010385
# Episode 220: score: 239.0 - reward: 167.66278239935636
# Test Episode 220: test score: 125.0 - test reward: 112.15760742798452
# Episode 221: score: 192.0 - reward: 153.55190081596373
# Episode 222: score: 501.0 - reward: 395.1751703120769
# Episode 223: score: 501.0 - reward: 343.43815215490764
# Episode 224: score: 501.0 - reward: 375.8720240738244
# Episode 225: score: 501.0 - reward: 352.6985581800344
# Episode 226: score: 501.0 - reward: 354.99806481897866
# Episode 227: score: 501.0 - reward: 344.46065289378174
# Episode 228: score: 501.0 - reward: 331.04835361540324
# Episode 229: score: 501.0 - reward: 342.0087204769255
# Episode 230: score: 351.0 - reward: 262.98433747980766
# Test Episode 230: test score: 501.0 - test reward: 260.3806997708975
# Episode 231: score: 383.0 - reward: 309.4958650955931
# Episode 232: score: 501.0 - reward: 269.2537644777446
# Episode 233: score: 178.0 - reward: 119.157998368144
# Episode 234: score: 501.0 - reward: 340.71863612979575
# Episode 235: score: 501.0 - reward: 353.0323701620098
# Episode 236: score: 501.0 - reward: 294.80021274276106
# Episode 237: score: 501.0 - reward: 288.3821672581133
# Episode 238: score: 501.0 - reward: 270.95338417962193
# Episode 239: score: 501.0 - reward: 261.05475774109374
# Episode 240: score: 501.0 - reward: 418.3241591349247
# Test Episode 240: test score: 501.0 - test reward: 288.46908804029266
# Episode 241: score: 501.0 - reward: 413.101043644268
# Episode 242: score: 200.0 - reward: 178.79272236227982
# Episode 243: score: 152.0 - reward: 137.21360573992132
# Episode 244: score: 501.0 - reward: 387.6255202427505
# Episode 245: score: 501.0 - reward: 378.9620190791789
# Episode 246: score: 501.0 - reward: 391.744456665777
# Episode 247: score: 501.0 - reward: 392.98582011237755
# Episode 248: score: 501.0 - reward: 370.4736573025586
# Episode 249: score: 492.0 - reward: 380.9767684411261
# Episode 250: score: 501.0 - reward: 399.5615374304355
# Test Episode 250: test score: 501.0 - test reward: 460.7730378694831
# Episode 251: score: 501.0 - reward: 407.97245609089737
# Episode 252: score: 501.0 - reward: 410.47806010376667
# Episode 253: score: 501.0 - reward: 410.3368743624539
# Episode 254: score: 24.0 - reward: 22.97456583306193
# Episode 255: score: 501.0 - reward: 329.5484470278029
# Episode 256: score: 501.0 - reward: 351.756853450835
# Episode 257: score: 501.0 - reward: 360.1240072593094
# Episode 258: score: 501.0 - reward: 392.8298635736111
# Episode 259: score: 501.0 - reward: 381.20828090086553
# Episode 260: score: 501.0 - reward: 433.8871534556149
# Test Episode 260: test score: 501.0 - test reward: 414.87681181430867
# Episode 261: score: 501.0 - reward: 425.6893727675082
# Episode 262: score: 501.0 - reward: 387.7076401010156
# Episode 263: score: 501.0 - reward: 388.7123242333531
# Episode 264: score: 501.0 - reward: 334.21834184657797
# Episode 265: score: 501.0 - reward: 321.09251052737204
# Episode 266: score: 501.0 - reward: 438.0829464957122
# Episode 267: score: 501.0 - reward: 431.7673847224563
# Episode 268: score: 501.0 - reward: 429.0784089297055
# Episode 269: score: 501.0 - reward: 422.365957756341
# Episode 270: score: 501.0 - reward: 451.0674504518507
# Test Episode 270: test score: 110.0 - test reward: 64.96908499002457
# Episode 271: score: 142.0 - reward: 127.4237839654088
# Episode 272: score: 501.0 - reward: 466.65239653773637
# Episode 273: score: 501.0 - reward: 470.83651574179504
# Episode 274: score: 501.0 - reward: 449.7549462869763
# Episode 275: score: 501.0 - reward: 443.8165542930362
# Episode 276: score: 501.0 - reward: 430.93759645149095
# Episode 277: score: 501.0 - reward: 442.8727715846153
# Episode 278: score: 501.0 - reward: 412.5742183804516
# Episode 279: score: 501.0 - reward: 417.8225983656011
# Episode 280: score: 501.0 - reward: 392.91346678212267
# Test Episode 280: test score: 501.0 - test reward: 407.6338367294521
# Episode 281: score: 501.0 - reward: 390.32240583747677
# Episode 282: score: 501.0 - reward: 409.3943828105925
# Episode 283: score: 501.0 - reward: 403.2254920065402
# Episode 284: score: 501.0 - reward: 397.3097614109517
# Episode 285: score: 501.0 - reward: 391.15430932044956
# Episode 286: score: 501.0 - reward: 404.24301877766914
# Episode 287: score: 501.0 - reward: 405.7206165652719
# Episode 288: score: 501.0 - reward: 399.1253344699742
# Episode 289: score: 501.0 - reward: 396.9041711561383
# Episode 290: score: 501.0 - reward: 410.73795570358635
# Test Episode 290: test score: 501.0 - test reward: 391.60025188773903
# Episode 291: score: 501.0 - reward: 405.5540542066098
# Episode 292: score: 501.0 - reward: 395.62278362065547
# Episode 293: score: 501.0 - reward: 391.25018334090737
# Episode 294: score: 405.0 - reward: 335.0665528774264
# Episode 295: score: 501.0 - reward: 390.951920050382
# Episode 296: score: 95.0 - reward: 80.83033658526836
# Episode 297: score: 501.0 - reward: 425.71868840605
# Episode 298: score: 501.0 - reward: 419.79550840854625
# Episode 299: score: 501.0 - reward: 424.2930245447903
# Episode 300: score: 142.0 - reward: 97.09347380548722
# Test Episode 300: test score: 501.0 - test reward: 354.9743812210858
# Episode 301: score: 79.0 - reward: 68.71581625044344
# Episode 302: score: 501.0 - reward: 432.57771783918156
# Episode 303: score: 501.0 - reward: 401.9707317955789
# Episode 304: score: 501.0 - reward: 377.4344896219673
# Episode 305: score: 100.0 - reward: 84.90505122169853
# Episode 306: score: 111.0 - reward: 94.04636676833036
# Episode 307: score: 501.0 - reward: 392.0479573190213
# Episode 308: score: 263.0 - reward: 202.2812732100489
# Episode 309: score: 102.0 - reward: 81.54328534007075
# Episode 310: score: 501.0 - reward: 332.80194654911736
# Test Episode 310: test score: 501.0 - test reward: 329.33065387457583
# Episode 311: score: 15.0 - reward: 14.154777854681017
# Episode 312: score: 11.0 - reward: 10.40433623790741
# Episode 313: score: 13.0 - reward: 12.04124965965748
# Episode 314: score: 10.0 - reward: 9.331325407326222
# Episode 315: score: 11.0 - reward: 10.351714757084848
# Episode 316: score: 212.0 - reward: 161.5220110431313
# Episode 317: score: 462.0 - reward: 314.5603699818254
# Episode 318: score: 281.0 - reward: 231.71061187610044
# Episode 319: score: 176.0 - reward: 149.33235946521165
# Episode 320: score: 104.0 - reward: 80.46444900780914
# Test Episode 320: test score: 133.0 - test reward: 90.43309617042543
# Episode 321: score: 160.0 - reward: 125.8535535633564
# Episode 322: score: 501.0 - reward: 404.30292726606166
# Episode 323: score: 501.0 - reward: 406.27937939167043
# Episode 324: score: 466.0 - reward: 389.69061759561305
# Episode 325: score: 501.0 - reward: 418.0333925813432
# Episode 326: score: 501.0 - reward: 387.50191352032095
# Episode 327: score: 501.0 - reward: 342.7751819342374
# Episode 328: score: 501.0 - reward: 446.2204020682721
# Episode 329: score: 264.0 - reward: 157.6709264010191
# Episode 330: score: 501.0 - reward: 460.5800316365437
# Test Episode 330: test score: 67.0 - test reward: 53.44481116011739
# Episode 331: score: 501.0 - reward: 411.38259753361336
# Episode 332: score: 318.0 - reward: 282.02427685782317
# Episode 333: score: 467.0 - reward: 374.01527748778466
# Episode 334: score: 501.0 - reward: 452.3711746025831
# Episode 335: score: 501.0 - reward: 442.391346927173
# Episode 336: score: 501.0 - reward: 453.39357358440736
# Episode 337: score: 501.0 - reward: 469.76928090266875
# Episode 338: score: 501.0 - reward: 475.49759122375355
# Episode 339: score: 501.0 - reward: 471.84231201559317
# Episode 340: score: 501.0 - reward: 470.95398332867774
# Test Episode 340: test score: 501.0 - test reward: 458.80051299035597
# Episode 341: score: 501.0 - reward: 466.899164542928
# Episode 342: score: 324.0 - reward: 290.9335454329845
# Episode 343: score: 501.0 - reward: 445.15475771957995
# Episode 344: score: 501.0 - reward: 447.6433910794558
# Episode 345: score: 501.0 - reward: 426.29178408235293
# Episode 346: score: 501.0 - reward: 427.4338037397713
# Episode 347: score: 501.0 - reward: 416.1490962877873
# Episode 348: score: 501.0 - reward: 421.1830234520136
# Episode 349: score: 501.0 - reward: 416.9468380123377
# Episode 350: score: 501.0 - reward: 457.2502270213327
# Test Episode 350: test score: 501.0 - test reward: 433.13520582169247
# Episode 351: score: 501.0 - reward: 439.6975581601256
# Episode 352: score: 501.0 - reward: 455.2133378319443
# Episode 353: score: 434.0 - reward: 323.91483982652437
# Episode 354: score: 501.0 - reward: 324.1935842595996
# Episode 355: score: 501.0 - reward: 375.8460044384003
# Episode 356: score: 501.0 - reward: 382.7047775596381
# Episode 357: score: 501.0 - reward: 422.3417934082449
# Episode 358: score: 501.0 - reward: 460.02909332923593
# Episode 359: score: 501.0 - reward: 465.7309971883892
# Episode 360: score: 501.0 - reward: 455.5651565402744
# Test Episode 360: test score: 501.0 - test reward: 409.76846739798793
# Episode 361: score: 501.0 - reward: 452.57136492729217
# Episode 362: score: 370.0 - reward: 333.765205347538
# Episode 363: score: 41.0 - reward: 38.59468548893929
# Episode 364: score: 308.0 - reward: 265.91710469126696
# Episode 365: score: 103.0 - reward: 91.19446986988184
# Episode 366: score: 55.0 - reward: 49.01442064791917
# Episode 367: score: 108.0 - reward: 94.6035587590654
# Episode 368: score: 230.0 - reward: 192.9569791480898
# Episode 369: score: 62.0 - reward: 56.23400256931782
# Episode 370: score: 71.0 - reward: 65.82204043120143
# Test Episode 370: test score: 501.0 - test reward: 389.86840071082116
# Episode 371: score: 122.0 - reward: 108.16079836785794
# Episode 372: score: 96.0 - reward: 87.39389158114791
# Episode 373: score: 37.0 - reward: 34.30794151425361
# Episode 374: score: 238.0 - reward: 220.3288874827326
# Episode 375: score: 501.0 - reward: 437.89346846789124
# Episode 376: score: 378.0 - reward: 337.5838571144267
# Episode 377: score: 184.0 - reward: 168.14747138358658
# Episode 378: score: 501.0 - reward: 447.98910597935304
# Episode 379: score: 149.0 - reward: 136.23613326549534
# Episode 380: score: 70.0 - reward: 63.82190559804438
# Test Episode 380: test score: 501.0 - test reward: 462.15587925910984
# Episode 381: score: 216.0 - reward: 188.78357253521682
# Episode 382: score: 13.0 - reward: 12.175399484485387
# Episode 383: score: 171.0 - reward: 142.1279889404774
# Episode 384: score: 93.0 - reward: 82.93422836400566
# Episode 385: score: 36.0 - reward: 33.03593870997429
# Episode 386: score: 242.0 - reward: 201.34374685809019
# Episode 387: score: 137.0 - reward: 116.90185003764927
# Episode 388: score: 46.0 - reward: 43.56062065958977
# Episode 389: score: 20.0 - reward: 18.53396231494844
# Episode 390: score: 60.0 - reward: 53.28476974815131
# Test Episode 390: test score: 58.0 - test reward: 49.89881163537503
# Episode 391: score: 33.0 - reward: 30.15317893475294
# Episode 392: score: 54.0 - reward: 48.54774564541878
# Episode 393: score: 56.0 - reward: 48.7039613068104
# Episode 394: score: 39.0 - reward: 35.51484411656856
# Episode 395: score: 25.0 - reward: 22.92264097630978
# Episode 396: score: 13.0 - reward: 12.156112203001975
# Episode 397: score: 52.0 - reward: 46.80523969084025
# Episode 398: score: 81.0 - reward: 68.57708966434
# Episode 399: score: 15.0 - reward: 13.608677941560744
# Episode 400: score: 55.0 - reward: 47.46710074692966
# Test Episode 400: test score: 501.0 - test reward: 263.4987535864115
# Episode 401: score: 13.0 - reward: 12.090177259221672
# Episode 402: score: 43.0 - reward: 37.778823435306556
# Episode 403: score: 64.0 - reward: 55.71299493014813
# Episode 404: score: 54.0 - reward: 47.413914170861254
# Episode 405: score: 135.0 - reward: 111.74730096310375
# Episode 406: score: 149.0 - reward: 126.88359681107099
# Episode 407: score: 100.0 - reward: 81.85476475283504
# Episode 408: score: 501.0 - reward: 401.671986875497
# Episode 409: score: 108.0 - reward: 89.49852500855926
# Episode 410: score: 133.0 - reward: 117.52910976856951
# Test Episode 410: test score: 52.0 - test reward: 44.26837414950132
# Episode 411: score: 163.0 - reward: 133.87868337575352
# Episode 412: score: 133.0 - reward: 116.62361679673195
# Episode 413: score: 43.0 - reward: 39.63258157595992
# Episode 414: score: 55.0 - reward: 47.762065222859384
# Episode 415: score: 31.0 - reward: 28.818122449517247
# Episode 416: score: 76.0 - reward: 70.07132792770862
# Episode 417: score: 58.0 - reward: 49.108190624415876
# Episode 418: score: 55.0 - reward: 46.93800456821919
# Episode 419: score: 99.0 - reward: 82.65211131870748
# Episode 420: score: 57.0 - reward: 49.050464333593865
# Test Episode 420: test score: 501.0 - test reward: 243.48688245564702
# Episode 421: score: 47.0 - reward: 41.634886866807946
# Episode 422: score: 44.0 - reward: 38.96095985323192
# Episode 423: score: 36.0 - reward: 33.186696016043435
# Episode 424: score: 40.0 - reward: 36.22902717590331
# Episode 425: score: 38.0 - reward: 34.47763544321061
# Episode 426: score: 27.0 - reward: 25.482805161178113
# Episode 427: score: 76.0 - reward: 63.20286546200512
# Episode 428: score: 12.0 - reward: 11.2283183157444
# Episode 429: score: 18.0 - reward: 16.85971052646637
# Episode 430: score: 96.0 - reward: 85.85677330140025
# Test Episode 430: test score: 15.0 - test reward: 13.745206588506699
# Episode 431: score: 26.0 - reward: 24.549713967740534
# Episode 432: score: 14.0 - reward: 13.057850852608683
# Episode 433: score: 24.0 - reward: 22.793534190952776
# Episode 434: score: 16.0 - reward: 14.971686322800815
# Episode 435: score: 75.0 - reward: 58.33655426055192
# Episode 436: score: 20.0 - reward: 18.841219893470402
# Episode 437: score: 17.0 - reward: 15.916765481233597
# Episode 438: score: 13.0 - reward: 11.85149481445551
# Episode 439: score: 48.0 - reward: 42.7387237034738
# Episode 440: score: 28.0 - reward: 26.439205108210444
# Test Episode 440: test score: 14.0 - test reward: 13.085276708006859
# Episode 441: score: 15.0 - reward: 13.936196046229451
# Episode 442: score: 27.0 - reward: 25.779797294735904
# Episode 443: score: 60.0 - reward: 55.391003898531196
# Episode 444: score: 14.0 - reward: 13.115528846904635
# Episode 445: score: 16.0 - reward: 14.862915157526732
# Episode 446: score: 35.0 - reward: 32.05433413982391
# Episode 447: score: 22.0 - reward: 20.73151365816593
# Episode 448: score: 23.0 - reward: 21.525582459568973
# Episode 449: score: 31.0 - reward: 29.344760935008527
# Episode 450: score: 41.0 - reward: 38.72442164123058
# Test Episode 450: test score: 501.0 - test reward: 478.81878352314226
# Episode 451: score: 42.0 - reward: 38.16070659607649
# Episode 452: score: 14.0 - reward: 12.7141548961401
# Episode 453: score: 15.0 - reward: 13.713477246463299
# Episode 454: score: 38.0 - reward: 36.45716645643115
# Episode 455: score: 39.0 - reward: 36.945814067963525
# Episode 456: score: 82.0 - reward: 70.36755150035025
# Episode 457: score: 12.0 - reward: 11.293561039865018
# Episode 458: score: 17.0 - reward: 15.589206722378732
# Episode 459: score: 16.0 - reward: 15.201111304573715
# Episode 460: score: 46.0 - reward: 41.08428715020419
# Test Episode 460: test score: 13.0 - test reward: 12.192833953350782
# Episode 461: score: 43.0 - reward: 39.945386537909506
# Episode 462: score: 38.0 - reward: 35.2918043717742
# Episode 463: score: 60.0 - reward: 55.885095780342816
# Episode 464: score: 22.0 - reward: 21.07574114948511
# Episode 465: score: 33.0 - reward: 30.929332260787486
# Episode 466: score: 13.0 - reward: 11.989400130510331
# Episode 467: score: 31.0 - reward: 29.84822579920292
# Episode 468: score: 10.0 - reward: 9.29300266355276
# Episode 469: score: 11.0 - reward: 10.119354239106178
# Episode 470: score: 13.0 - reward: 12.08667887672782
# Test Episode 470: test score: 14.0 - test reward: 13.143593961000443
# Episode 471: score: 29.0 - reward: 27.599753978848454
# Episode 472: score: 28.0 - reward: 26.095370365679265
# Episode 473: score: 12.0 - reward: 11.221132238209247
# Episode 474: score: 23.0 - reward: 22.005398574098944
# Episode 475: score: 27.0 - reward: 25.833863138407473
# Episode 476: score: 35.0 - reward: 32.821943604946135
# Episode 477: score: 12.0 - reward: 11.303517413139343
# Episode 478: score: 22.0 - reward: 20.879313910007475
# Episode 479: score: 35.0 - reward: 32.997890626639126
# Episode 480: score: 25.0 - reward: 23.594603365659715
# Test Episode 480: test score: 11.0 - test reward: 10.105476088821888
# Episode 481: score: 25.0 - reward: 23.455635331571106
# Episode 482: score: 12.0 - reward: 10.965277276933193
# Episode 483: score: 17.0 - reward: 15.49477300941944
# Episode 484: score: 23.0 - reward: 21.88882714174688
# Episode 485: score: 45.0 - reward: 42.81911770030857
# Episode 486: score: 29.0 - reward: 27.892392173409466
# Episode 487: score: 11.0 - reward: 10.330207757651806
# Episode 488: score: 13.0 - reward: 12.183536653593181
# Episode 489: score: 15.0 - reward: 13.96447140723467
# Episode 490: score: 14.0 - reward: 13.076744427531956
# Test Episode 490: test score: 10.0 - test reward: 9.32419948875904
# Episode 491: score: 17.0 - reward: 15.846399453282356
# Episode 492: score: 13.0 - reward: 12.186996716260909
# Episode 493: score: 12.0 - reward: 10.948378702998163
# Episode 494: score: 11.0 - reward: 10.052868986129761
# Episode 495: score: 14.0 - reward: 13.023346315324307
# Episode 496: score: 13.0 - reward: 12.189086478948592
# Episode 497: score: 18.0 - reward: 16.918945595622063
# Episode 498: score: 13.0 - reward: 12.214986002445224
# Episode 499: score: 13.0 - reward: 12.200274574011564
# Episode 500: score: 11.0 - reward: 10.151014986634255
# Test Episode 500: test score: 11.0 - test reward: 10.267908380925654
# best test reward: 493.51037862063373
# Run 2/3
# Episode 1: score: 9.0 - reward: 8.496139235794544
# Episode 2: score: 13.0 - reward: 12.355277183651925
# Episode 3: score: 9.0 - reward: 8.362652459740639
# Episode 4: score: 8.0 - reward: 7.547711353003978
# Episode 5: score: 9.0 - reward: 8.448666974902153
# Episode 6: score: 12.0 - reward: 11.348281639814378
# Episode 7: score: 8.0 - reward: 7.57499251961708
# Episode 8: score: 10.0 - reward: 9.318738999962806
# Episode 9: score: 10.0 - reward: 9.503501819819212
# Episode 10: score: 8.0 - reward: 7.518827241659165
# Test Episode 10: test score: 8.0 - test reward: 7.352194440364839
# New best test reward. Saving model
# Episode 11: score: 11.0 - reward: 10.06927978992462
# Episode 12: score: 8.0 - reward: 7.535795924067497
# Episode 13: score: 12.0 - reward: 11.386838026344774
# Episode 14: score: 9.0 - reward: 8.383780206739903
# Episode 15: score: 10.0 - reward: 9.336370404064656
# Episode 16: score: 10.0 - reward: 9.341006480157375
# Episode 17: score: 13.0 - reward: 12.399855780601502
# Episode 18: score: 11.0 - reward: 10.296786402910946
# Episode 19: score: 9.0 - reward: 8.444226866960525
# Episode 20: score: 10.0 - reward: 9.36399492174387
# Test Episode 20: test score: 10.0 - test reward: 9.401805119588973
# New best test reward. Saving model
# Episode 21: score: 10.0 - reward: 9.38570969942957
# Episode 22: score: 11.0 - reward: 10.358924522995949
# Episode 23: score: 10.0 - reward: 9.463693195581437
# Episode 24: score: 9.0 - reward: 8.541604323685169
# Episode 25: score: 10.0 - reward: 9.468882212787866
# Episode 26: score: 9.0 - reward: 8.472267971932888
# Episode 27: score: 8.0 - reward: 7.5362815201282505
# Episode 28: score: 10.0 - reward: 9.506288477033378
# Episode 29: score: 9.0 - reward: 8.3734804302454
# Episode 30: score: 8.0 - reward: 7.549973890185356
# Test Episode 30: test score: 10.0 - test reward: 9.439073146879672
# New best test reward. Saving model
# Episode 31: score: 8.0 - reward: 7.437560439109802
# Episode 32: score: 8.0 - reward: 7.56899800002575
# Episode 33: score: 10.0 - reward: 9.481898861378431
# Episode 34: score: 10.0 - reward: 9.459799363464116
# Episode 35: score: 9.0 - reward: 8.463735312223434
# Episode 36: score: 9.0 - reward: 8.302410571277141
# Episode 37: score: 10.0 - reward: 9.447182795405388
# Episode 38: score: 9.0 - reward: 8.452981209754943
# Episode 39: score: 10.0 - reward: 9.444861809257418
# Episode 40: score: 9.0 - reward: 8.344620981812477
# Test Episode 40: test score: 9.0 - test reward: 8.318175345659256
# Episode 41: score: 10.0 - reward: 9.514222344756126
# Episode 42: score: 10.0 - reward: 9.459034155309201
# Episode 43: score: 10.0 - reward: 9.471072939783333
# Episode 44: score: 11.0 - reward: 10.34131326675415
# Episode 45: score: 9.0 - reward: 8.41079011708498
# Episode 46: score: 11.0 - reward: 10.364183617383244
# Episode 47: score: 10.0 - reward: 9.234499455988407
# Episode 48: score: 11.0 - reward: 10.116663189232348
# Episode 49: score: 13.0 - reward: 12.06890035867691
# Episode 50: score: 10.0 - reward: 9.293823163211346
# Test Episode 50: test score: 10.0 - test reward: 9.418672021850943
# Episode 51: score: 12.0 - reward: 11.203149339556694
# Episode 52: score: 10.0 - reward: 9.30429050475359
# Episode 53: score: 10.0 - reward: 9.420556823909283
# Episode 54: score: 11.0 - reward: 10.397362364828588
# Episode 55: score: 10.0 - reward: 9.334940689802172
# Episode 56: score: 11.0 - reward: 10.056318679451941
# Episode 57: score: 11.0 - reward: 10.350191217660903
# Episode 58: score: 10.0 - reward: 9.431279803812505
# Episode 59: score: 10.0 - reward: 9.427249875082634
# Episode 60: score: 22.0 - reward: 21.233909123390912
# Test Episode 60: test score: 501.0 - test reward: 435.21536611020565
# New best test reward. Saving model
# Episode 61: score: 501.0 - reward: 429.9112617097797
# Episode 62: score: 33.0 - reward: 30.92415557801724
# Episode 63: score: 142.0 - reward: 124.88606734722853
# Episode 64: score: 501.0 - reward: 395.1256079733371
# Episode 65: score: 207.0 - reward: 152.8294135436416
# Episode 66: score: 501.0 - reward: 402.95614009276034
# Episode 67: score: 501.0 - reward: 398.29079276807573
# Episode 68: score: 26.0 - reward: 24.85261337161064
# Episode 69: score: 501.0 - reward: 370.00404446199553
# Episode 70: score: 501.0 - reward: 481.57899211891913
# Test Episode 70: test score: 501.0 - test reward: 450.8461179155855
# New best test reward. Saving model
# Episode 71: score: 370.0 - reward: 355.30290058432166
# Episode 72: score: 88.0 - reward: 81.34837480485439
# Episode 73: score: 128.0 - reward: 101.499282450974
# Episode 74: score: 84.0 - reward: 66.98285661935805
# Episode 75: score: 413.0 - reward: 205.5369666203855
# Episode 76: score: 359.0 - reward: 182.77390961647035
# Episode 77: score: 501.0 - reward: 242.57595497965815
# Episode 78: score: 501.0 - reward: 277.5057958140971
# Episode 79: score: 501.0 - reward: 333.13256485760195
# Episode 80: score: 194.0 - reward: 137.13068075701605
# Test Episode 80: test score: 245.0 - test reward: 134.6863523513079
# Episode 81: score: 501.0 - reward: 284.40406962633136
# Episode 82: score: 501.0 - reward: 316.5175228953362
# Episode 83: score: 501.0 - reward: 306.6994258075952
# Episode 84: score: 501.0 - reward: 340.8963751107459
# Episode 85: score: 501.0 - reward: 354.4022128723563
# Episode 86: score: 152.0 - reward: 85.71577039360999
# Episode 87: score: 70.0 - reward: 60.243708220869316
# Episode 88: score: 133.0 - reward: 94.19874513447279
# Episode 89: score: 379.0 - reward: 255.84445659518238
# Episode 90: score: 20.0 - reward: 18.105054661631584
# Test Episode 90: test score: 501.0 - test reward: 400.33825770467524
# Episode 91: score: 501.0 - reward: 288.80627700984513
# Episode 92: score: 501.0 - reward: 300.6508926155045
# Episode 93: score: 17.0 - reward: 15.492330402135847
# Episode 94: score: 14.0 - reward: 12.887667477130892
# Episode 95: score: 26.0 - reward: 24.32364899665118
# Episode 96: score: 501.0 - reward: 302.60504866912976
# Episode 97: score: 16.0 - reward: 15.0337620023638
# Episode 98: score: 14.0 - reward: 13.04301412552595
# Episode 99: score: 17.0 - reward: 15.604193598031998
# Episode 100: score: 268.0 - reward: 185.57347841560826
# Test Episode 100: test score: 501.0 - test reward: 333.7454894058404
# Episode 101: score: 501.0 - reward: 356.3750694438817
# Episode 102: score: 90.0 - reward: 75.22258937060832
# Episode 103: score: 501.0 - reward: 348.8230489224195
# Episode 104: score: 501.0 - reward: 418.04928792417064
# Episode 105: score: 501.0 - reward: 375.2940564244989
# Episode 106: score: 170.0 - reward: 113.0515637636185
# Episode 107: score: 501.0 - reward: 377.7692258894448
# Episode 108: score: 282.0 - reward: 233.82097334340202
# Episode 109: score: 20.0 - reward: 19.047045535594222
# Episode 110: score: 22.0 - reward: 21.066954633593557
# Test Episode 110: test score: 501.0 - test reward: 348.1743898753078
# Episode 111: score: 501.0 - reward: 357.98087924905144
# Episode 112: score: 159.0 - reward: 116.7434203699232
# Episode 113: score: 30.0 - reward: 28.67341691404581
# Episode 114: score: 57.0 - reward: 52.232448399066925
# Episode 115: score: 92.0 - reward: 75.09180014878511
# Episode 116: score: 11.0 - reward: 10.1678827509284
# Episode 117: score: 14.0 - reward: 12.74765403866768
# Episode 118: score: 15.0 - reward: 13.997643798589705
# Episode 119: score: 32.0 - reward: 29.973860172927377
# Episode 120: score: 403.0 - reward: 302.5481903359292
# Test Episode 120: test score: 501.0 - test reward: 467.82180917561067
# New best test reward. Saving model
# Episode 121: score: 227.0 - reward: 176.51821929998695
# Episode 122: score: 501.0 - reward: 408.10870659649396
# Episode 123: score: 501.0 - reward: 407.5055465981367
# Episode 124: score: 18.0 - reward: 17.093055685423312
# Episode 125: score: 458.0 - reward: 384.5744378507139
# Episode 126: score: 10.0 - reward: 9.491081951558591
# Episode 127: score: 162.0 - reward: 124.68868130072948
# Episode 128: score: 130.0 - reward: 108.3810288608074
# Episode 129: score: 48.0 - reward: 44.35555650889872
# Episode 130: score: 34.0 - reward: 32.46807675492019
# Test Episode 130: test score: 501.0 - test reward: 476.96336972415486
# New best test reward. Saving model
# Episode 131: score: 14.0 - reward: 13.064120925962927
# Episode 132: score: 11.0 - reward: 10.276051266491413
# Episode 133: score: 43.0 - reward: 40.71447908934207
# Episode 134: score: 61.0 - reward: 58.10395980346947
# Episode 135: score: 13.0 - reward: 12.466943825036289
# Episode 136: score: 9.0 - reward: 8.419472044706344
# Episode 137: score: 17.0 - reward: 16.145880755782127
# Episode 138: score: 36.0 - reward: 35.0328402414918
# Episode 139: score: 8.0 - reward: 7.430526697635651
# Episode 140: score: 11.0 - reward: 10.347015861421825
# Test Episode 140: test score: 94.0 - test reward: 88.53846994787452
# Episode 141: score: 12.0 - reward: 11.29463267326355
# Episode 142: score: 10.0 - reward: 9.480381533503534
# Episode 143: score: 10.0 - reward: 9.41680375635624
# Episode 144: score: 94.0 - reward: 81.66759322732686
# Episode 145: score: 31.0 - reward: 28.723875651136044
# Episode 146: score: 32.0 - reward: 29.473147937655455
# Episode 147: score: 37.0 - reward: 34.90596684366464
# Episode 148: score: 13.0 - reward: 12.372662124782801
# Episode 149: score: 24.0 - reward: 22.47559779845178
# Episode 150: score: 10.0 - reward: 9.333066534996032
# Test Episode 150: test score: 8.0 - test reward: 7.581177717447281
# Episode 151: score: 11.0 - reward: 10.20873695909977
# Episode 152: score: 10.0 - reward: 9.198632134497165
# Episode 153: score: 9.0 - reward: 8.457758459448815
# Episode 154: score: 10.0 - reward: 9.467384853959084
# Episode 155: score: 24.0 - reward: 22.791747307404876
# Episode 156: score: 10.0 - reward: 9.365510860085488
# Episode 157: score: 9.0 - reward: 8.473182073235511
# Episode 158: score: 10.0 - reward: 9.446132944524289
# Episode 159: score: 9.0 - reward: 8.386128668487073
# Episode 160: score: 11.0 - reward: 10.358619736135006
# Test Episode 160: test score: 26.0 - test reward: 23.72689273655415
# Episode 161: score: 9.0 - reward: 8.42462829425931
# Episode 162: score: 9.0 - reward: 8.499209458753466
# Episode 163: score: 11.0 - reward: 10.268624398857355
# Episode 164: score: 10.0 - reward: 9.476838586479424
# Episode 165: score: 10.0 - reward: 9.326677410304546
# Episode 166: score: 11.0 - reward: 10.181971229612829
# Episode 167: score: 11.0 - reward: 10.347391529381275
# Episode 168: score: 34.0 - reward: 31.922926536202436
# Episode 169: score: 13.0 - reward: 12.347678771615026
# Episode 170: score: 9.0 - reward: 8.369796052575111
# Test Episode 170: test score: 10.0 - test reward: 9.469201320409775
# Episode 171: score: 11.0 - reward: 10.14544602036476
# Episode 172: score: 332.0 - reward: 313.30667557455615
# Episode 173: score: 132.0 - reward: 122.4139754734933
# Episode 174: score: 44.0 - reward: 41.961326423287375
# Episode 175: score: 131.0 - reward: 123.6035639100708
# Episode 176: score: 52.0 - reward: 49.67345622479915
# Episode 177: score: 38.0 - reward: 36.270281542465085
# Episode 178: score: 51.0 - reward: 48.37672028392553
# Episode 179: score: 39.0 - reward: 36.73865722939374
# Episode 180: score: 20.0 - reward: 19.03944993466139
# Test Episode 180: test score: 28.0 - test reward: 26.629196071624758
# Episode 181: score: 9.0 - reward: 8.429692867398261
# Episode 182: score: 8.0 - reward: 7.3847020149230955
# Episode 183: score: 10.0 - reward: 9.360418845713138
# Episode 184: score: 14.0 - reward: 13.166436521708965
# Episode 185: score: 8.0 - reward: 7.55534353852272
# Episode 186: score: 11.0 - reward: 10.17916106581688
# Episode 187: score: 12.0 - reward: 11.353810997493566
# Episode 188: score: 11.0 - reward: 10.100451979041098
# Episode 189: score: 11.0 - reward: 10.474152624607084
# Episode 190: score: 9.0 - reward: 8.348764052987098
# Test Episode 190: test score: 12.0 - test reward: 11.333062510937454
# Episode 191: score: 10.0 - reward: 9.472819328308104
# Episode 192: score: 10.0 - reward: 9.19212934076786
# Episode 193: score: 75.0 - reward: 61.49772437363863
# Episode 194: score: 85.0 - reward: 69.73876824975015
# Episode 195: score: 99.0 - reward: 78.98307691812516
# Episode 196: score: 501.0 - reward: 319.6092997401953
# Episode 197: score: 501.0 - reward: 353.89041119664864
# Episode 198: score: 501.0 - reward: 427.093667545915
# Episode 199: score: 501.0 - reward: 443.50484149083536
# Episode 200: score: 501.0 - reward: 491.5450487089573
# Test Episode 200: test score: 501.0 - test reward: 482.4552888613195
# New best test reward. Saving model
# Episode 201: score: 501.0 - reward: 487.17502751927816
# Episode 202: score: 501.0 - reward: 478.14091262556605
# Episode 203: score: 501.0 - reward: 482.7358952982355
# Episode 204: score: 501.0 - reward: 386.358558244747
# Episode 205: score: 299.0 - reward: 260.00079114809614
# Episode 206: score: 501.0 - reward: 458.3154019236563
# Episode 207: score: 501.0 - reward: 436.350625761226
# Episode 208: score: 397.0 - reward: 234.44018680006246
# Episode 209: score: 138.0 - reward: 104.07018559128045
# Episode 210: score: 43.0 - reward: 40.11083350032568
# Test Episode 210: test score: 116.0 - test reward: 83.56838525235652
# Episode 211: score: 139.0 - reward: 104.28467541933061
# Episode 212: score: 134.0 - reward: 96.9073458701372
# Episode 213: score: 147.0 - reward: 106.3437357909978
# Episode 214: score: 124.0 - reward: 90.45703313648704
# Episode 215: score: 141.0 - reward: 97.1981566287577
# Episode 216: score: 144.0 - reward: 108.89681798666712
# Episode 217: score: 135.0 - reward: 101.10285011082887
# Episode 218: score: 140.0 - reward: 101.11463705003261
# Episode 219: score: 143.0 - reward: 107.68527973294258
# Episode 220: score: 134.0 - reward: 98.77453809008001
# Test Episode 220: test score: 501.0 - test reward: 318.12230813875766
# Episode 221: score: 145.0 - reward: 113.0251907460391
# Episode 222: score: 30.0 - reward: 28.03204348683357
# Episode 223: score: 113.0 - reward: 86.95304056443267
# Episode 224: score: 50.0 - reward: 46.62883926481008
# Episode 225: score: 39.0 - reward: 36.390631093084814
# Episode 226: score: 17.0 - reward: 15.688424348831179
# Episode 227: score: 54.0 - reward: 48.01918702721595
# Episode 228: score: 20.0 - reward: 18.62234525531531
# Episode 229: score: 25.0 - reward: 23.322031289339062
# Episode 230: score: 145.0 - reward: 91.11777122616769
# Test Episode 230: test score: 142.0 - test reward: 83.3139304846525
# Episode 231: score: 159.0 - reward: 99.34122820086779
# Episode 232: score: 21.0 - reward: 19.8866706430912
# Episode 233: score: 19.0 - reward: 17.68232815414667
# Episode 234: score: 12.0 - reward: 11.225515490025282
# Episode 235: score: 12.0 - reward: 11.067548424005508
# Episode 236: score: 18.0 - reward: 16.902988379448647
# Episode 237: score: 14.0 - reward: 13.08841669112444
# Episode 238: score: 11.0 - reward: 10.402727541327476
# Episode 239: score: 11.0 - reward: 10.412834043800832
# Episode 240: score: 10.0 - reward: 9.304842375218868
# Test Episode 240: test score: 9.0 - test reward: 8.480862212181092
# Episode 241: score: 12.0 - reward: 11.46833163499832
# Episode 242: score: 10.0 - reward: 9.27050658762455
# Episode 243: score: 13.0 - reward: 12.050667399168011
# Episode 244: score: 9.0 - reward: 8.2480264544487
# Episode 245: score: 10.0 - reward: 9.336710466444494
# Episode 246: score: 10.0 - reward: 9.233539688587188
# Episode 247: score: 9.0 - reward: 8.51313406676054
# Episode 248: score: 10.0 - reward: 9.404874133318662
# Episode 249: score: 10.0 - reward: 9.423654341697691
# Episode 250: score: 138.0 - reward: 75.17684092819695
# Test Episode 250: test score: 208.0 - test reward: 98.06099155992266
# Episode 251: score: 13.0 - reward: 12.106932470202446
# Episode 252: score: 334.0 - reward: 183.8096415981652
# Episode 253: score: 501.0 - reward: 293.13101148605364
# Episode 254: score: 501.0 - reward: 380.1163708060979
# Episode 255: score: 21.0 - reward: 19.65699389278889
# Episode 256: score: 501.0 - reward: 377.59881284832954
# Episode 257: score: 501.0 - reward: 392.57456981986724
# Episode 258: score: 501.0 - reward: 438.0679639402776
# Episode 259: score: 501.0 - reward: 448.3859852582215
# Episode 260: score: 501.0 - reward: 441.2765626575798
# Test Episode 260: test score: 501.0 - test reward: 407.9778160020709
# Episode 261: score: 501.0 - reward: 451.6534503258763
# Episode 262: score: 501.0 - reward: 443.96359673514934
# Episode 263: score: 501.0 - reward: 460.12269159108416
# Episode 264: score: 501.0 - reward: 471.4230585059151
# Episode 265: score: 501.0 - reward: 469.94037290960506
# Episode 266: score: 501.0 - reward: 477.2807365443554
# Episode 267: score: 501.0 - reward: 458.817797485739
# Episode 268: score: 501.0 - reward: 414.26258349046094
# Episode 269: score: 501.0 - reward: 466.4703246474261
# Episode 270: score: 501.0 - reward: 391.4953167235479
# Test Episode 270: test score: 501.0 - test reward: 436.959592443402
# Episode 271: score: 501.0 - reward: 404.1005625836553
# Episode 272: score: 385.0 - reward: 322.0506237030033
# Episode 273: score: 501.0 - reward: 262.1401061624288
# Episode 274: score: 501.0 - reward: 384.844259186834
# Episode 275: score: 501.0 - reward: 383.7895809695125
# Episode 276: score: 501.0 - reward: 365.485506878793
# Episode 277: score: 501.0 - reward: 383.4462110191586
# Episode 278: score: 501.0 - reward: 360.05878273099665
# Episode 279: score: 501.0 - reward: 336.30154123529786
# Episode 280: score: 501.0 - reward: 380.732784990966
# Test Episode 280: test score: 501.0 - test reward: 374.3415105775001
# Episode 281: score: 501.0 - reward: 388.9885378740728
# Episode 282: score: 501.0 - reward: 369.8813520327207
# Episode 283: score: 501.0 - reward: 371.75253440141694
# Episode 284: score: 501.0 - reward: 365.310783246905
# Episode 285: score: 501.0 - reward: 369.50455681681615
# Episode 286: score: 501.0 - reward: 370.57924623191354
# Episode 287: score: 501.0 - reward: 371.46003855988357
# ...
# New best test reward. Saving model
# Episode 241: score: 13.0 - reward: 11.983296245336533
# Episode 242: score: 12.0 - reward: 11.216077698767185
# Episode 243: score: 12.0 - reward: 11.079937513172627
# Episode 244: score: 11.0 - reward: 10.391702750325203
# Episode 245: score: 12.0 - reward: 11.0102305367589
# Episode 246: score: 10.0 - reward: 9.36975622177124
# Episode 247: score: 12.0 - reward: 10.961283473670484
# Episode 248: score: 14.0 - reward: 13.036574623174968
# Episode 249: score: 10.0 - reward: 9.290838791429996
# Episode 250: score: 13.0 - reward: 11.810790580511094
# Test Episode 250: test score: 11.0 - test reward: 10.113696727156638
# Episode 251: score: 15.0 - reward: 13.730153203755618
# Episode 252: score: 11.0 - reward: 10.22386522591114
# Episode 253: score: 14.0 - reward: 13.087385715544222
# Episode 254: score: 13.0 - reward: 12.080337679386139
# Episode 255: score: 13.0 - reward: 12.184138514101505
# Episode 256: score: 13.0 - reward: 12.098296867311001
# Episode 257: score: 13.0 - reward: 12.10561759993434
# Episode 258: score: 12.0 - reward: 10.96625235080719
# Episode 259: score: 14.0 - reward: 12.84628457725048
# Episode 260: score: 12.0 - reward: 11.20921920835972
# Test Episode 260: test score: 12.0 - test reward: 11.041848857700826
# Episode 261: score: 13.0 - reward: 12.017983961850407
# Episode 262: score: 11.0 - reward: 10.280966284871102
# Episode 263: score: 12.0 - reward: 11.198132583498953
# Episode 264: score: 13.0 - reward: 12.076835903525351
# Episode 265: score: 12.0 - reward: 10.945203888416293
# Episode 266: score: 12.0 - reward: 10.977723121643065
# Episode 267: score: 10.0 - reward: 9.18327343761921
# Episode 268: score: 13.0 - reward: 11.887555553019048
# Episode 269: score: 13.0 - reward: 12.000292216241357
# Episode 270: score: 10.0 - reward: 9.285122701525689
# Test Episode 270: test score: 12.0 - test reward: 11.036162954568862
# Episode 271: score: 12.0 - reward: 10.886455887556075
# Episode 272: score: 12.0 - reward: 10.943620517849922
# Episode 273: score: 15.0 - reward: 13.884431793913246
# Episode 274: score: 14.0 - reward: 12.862070213258267
# Episode 275: score: 12.0 - reward: 11.086715547740459
# Episode 276: score: 10.0 - reward: 9.381804159283638
# Episode 277: score: 11.0 - reward: 10.091324852406979
# Episode 278: score: 12.0 - reward: 11.252935367822648
# Episode 279: score: 12.0 - reward: 10.945545682311057
# Episode 280: score: 16.0 - reward: 14.85721713900566
# Test Episode 280: test score: 15.0 - test reward: 13.996072250604632
# Episode 281: score: 12.0 - reward: 11.281774072349071
# Episode 282: score: 15.0 - reward: 13.710503532737494
# Episode 283: score: 12.0 - reward: 11.262209050357342
# Episode 284: score: 11.0 - reward: 10.153364491462709
# Episode 285: score: 11.0 - reward: 10.38452136963606
# Episode 286: score: 10.0 - reward: 9.343090510368349
# Episode 287: score: 14.0 - reward: 12.938061337918043
# Episode 288: score: 10.0 - reward: 9.1330881267786
# Episode 289: score: 16.0 - reward: 14.780604475736618
# Episode 290: score: 16.0 - reward: 14.727133161574601
# Test Episode 290: test score: 11.0 - test reward: 10.362337026745081
# Episode 291: score: 12.0 - reward: 11.244959942996502
# Episode 292: score: 14.0 - reward: 12.977007104456424
# Episode 293: score: 12.0 - reward: 10.919500628113745
# Episode 294: score: 13.0 - reward: 12.179805208742618
# Episode 295: score: 12.0 - reward: 11.226156885176897
# Episode 296: score: 11.0 - reward: 10.091203033924103
# Episode 297: score: 14.0 - reward: 12.940495866537097
# Episode 298: score: 15.0 - reward: 13.813077060878276
# Episode 299: score: 13.0 - reward: 12.056496116518975
# Episode 300: score: 15.0 - reward: 13.944614415615796
# Test Episode 300: test score: 12.0 - test reward: 11.216218271851538
# Episode 301: score: 12.0 - reward: 11.061384737491608
# Episode 302: score: 11.0 - reward: 10.376334840059279
# Episode 303: score: 12.0 - reward: 11.284052617847918
# Episode 304: score: 13.0 - reward: 12.032860910892488
# Episode 305: score: 12.0 - reward: 11.02606534063816
# Episode 306: score: 12.0 - reward: 11.040266102552414
# Episode 307: score: 13.0 - reward: 11.832707917690277
# Episode 308: score: 13.0 - reward: 12.207180155813694
# Episode 309: score: 14.0 - reward: 12.724204567074775
# Episode 310: score: 12.0 - reward: 11.12189940661192
# Test Episode 310: test score: 13.0 - test reward: 12.080278211832047
# Episode 311: score: 14.0 - reward: 13.036776094138625
# Episode 312: score: 13.0 - reward: 12.159242443740368
# Episode 313: score: 13.0 - reward: 12.1161714784801
# Episode 314: score: 13.0 - reward: 12.16462311297655
# Episode 315: score: 11.0 - reward: 10.12922100275755
# Episode 316: score: 11.0 - reward: 10.083021360635756
# Episode 317: score: 14.0 - reward: 12.836734460294247
# Episode 318: score: 14.0 - reward: 13.087382942810654
# Episode 319: score: 15.0 - reward: 13.92500051856041
# Episode 320: score: 14.0 - reward: 12.878430277109146
# Test Episode 320: test score: 15.0 - test reward: 13.928463929891585
# Episode 321: score: 14.0 - reward: 12.975663046538829
# Episode 322: score: 12.0 - reward: 11.01653236746788
# Episode 323: score: 14.0 - reward: 12.76085794866085
# Episode 324: score: 10.0 - reward: 9.257108502089975
# Episode 325: score: 12.0 - reward: 10.967668104171754
# Episode 326: score: 14.0 - reward: 12.809056124091148
# Episode 327: score: 11.0 - reward: 10.282861690968275
# Episode 328: score: 11.0 - reward: 10.103400608897209
# Episode 329: score: 10.0 - reward: 9.356348621845246
# Episode 330: score: 15.0 - reward: 13.835101280361412
# Test Episode 330: test score: 11.0 - test reward: 10.06775151193142
# Episode 331: score: 15.0 - reward: 13.797355895116924
# Episode 332: score: 14.0 - reward: 12.950874572992324
# Episode 333: score: 14.0 - reward: 13.033740894496441
# Episode 334: score: 12.0 - reward: 11.24104676246643
# Episode 335: score: 14.0 - reward: 12.861427118629216
# Episode 336: score: 13.0 - reward: 11.92547192722559
# Episode 337: score: 17.0 - reward: 15.730859452486039
# Episode 338: score: 15.0 - reward: 13.600395466387273
# Episode 339: score: 14.0 - reward: 13.054216922074557
# Episode 340: score: 11.0 - reward: 10.36181839555502
# Test Episode 340: test score: 13.0 - test reward: 11.964406031370162
# Episode 341: score: 12.0 - reward: 11.306132757663727
# Episode 342: score: 13.0 - reward: 11.93531633913517
# Episode 343: score: 15.0 - reward: 13.858995476365088
# Episode 344: score: 12.0 - reward: 10.963863119482994
# Episode 345: score: 11.0 - reward: 10.185435040295124
# Episode 346: score: 15.0 - reward: 13.651399397850035
# Episode 347: score: 10.0 - reward: 9.235119035840034
# Episode 348: score: 11.0 - reward: 10.30099233314395
# Episode 349: score: 11.0 - reward: 10.371017039567231
# Episode 350: score: 11.0 - reward: 10.34863528497517
# Test Episode 350: test score: 12.0 - test reward: 10.959219957888127
# Episode 351: score: 13.0 - reward: 12.111313444375993
# Episode 352: score: 11.0 - reward: 10.233265624940396
# Episode 353: score: 11.0 - reward: 10.384404726326466
# Episode 354: score: 11.0 - reward: 10.297939971089363
# Episode 355: score: 13.0 - reward: 11.891487601399422
# Episode 356: score: 10.0 - reward: 9.261420120298862
# Episode 357: score: 12.0 - reward: 11.068619519472122
# Episode 358: score: 15.0 - reward: 13.530671906471254
# Episode 359: score: 89.0 - reward: 57.126229991763836
# Episode 360: score: 11.0 - reward: 10.218089780211447
# Test Episode 360: test score: 11.0 - test reward: 10.066785272955894
# Episode 361: score: 16.0 - reward: 14.825250051915647
# Episode 362: score: 14.0 - reward: 12.693394161760807
# Episode 363: score: 13.0 - reward: 12.08267946317792
# Episode 364: score: 11.0 - reward: 10.348458831012248
# Episode 365: score: 13.0 - reward: 11.76515444815159
# Episode 366: score: 11.0 - reward: 10.127630779147148
# Episode 367: score: 18.0 - reward: 16.597343213856224
# Episode 368: score: 12.0 - reward: 11.165108247101307
# Episode 369: score: 11.0 - reward: 10.380831094086169
# Episode 370: score: 16.0 - reward: 14.782151175849137
# Test Episode 370: test score: 11.0 - test reward: 10.26660465300083
# Episode 371: score: 10.0 - reward: 9.274582366645337
# Episode 372: score: 12.0 - reward: 11.112555903196334
# Episode 373: score: 13.0 - reward: 12.01647769212723
# Episode 374: score: 11.0 - reward: 10.235446657985449
# Episode 375: score: 13.0 - reward: 12.10974097549915
# Episode 376: score: 13.0 - reward: 12.044132566452028
# Episode 377: score: 15.0 - reward: 13.72943277657032
# Episode 378: score: 16.0 - reward: 14.901480455696584
# Episode 379: score: 12.0 - reward: 11.050447364151479
# Episode 380: score: 16.0 - reward: 14.919257169961929
# Test Episode 380: test score: 13.0 - test reward: 11.94228570535779
# Episode 381: score: 16.0 - reward: 14.862185479700564
# Episode 382: score: 11.0 - reward: 10.341611405462025
# Episode 383: score: 12.0 - reward: 11.154603318497538
# Episode 384: score: 12.0 - reward: 11.025080686807632
# Episode 385: score: 13.0 - reward: 11.909902170300484
# Episode 386: score: 11.0 - reward: 10.04966379404068
# Episode 387: score: 12.0 - reward: 11.077926417440175
# Episode 388: score: 12.0 - reward: 11.16909463107586
# Episode 389: score: 14.0 - reward: 12.66916518807411
# Episode 390: score: 15.0 - reward: 13.77913700193167
# Test Episode 390: test score: 14.0 - test reward: 13.019337895512582
# Episode 391: score: 12.0 - reward: 11.309085176885128
# Episode 392: score: 14.0 - reward: 12.889751330763103
# Episode 393: score: 12.0 - reward: 11.254352539777754
# Episode 394: score: 12.0 - reward: 11.28345606327057
# Episode 395: score: 16.0 - reward: 14.355482885241505
# Episode 396: score: 14.0 - reward: 12.87791161686182
# Episode 397: score: 14.0 - reward: 12.98640419691801
# Episode 398: score: 13.0 - reward: 12.05911352559924
# Episode 399: score: 90.0 - reward: 57.529155635833725
# Episode 400: score: 13.0 - reward: 11.960696467757225
# Test Episode 400: test score: 13.0 - test reward: 12.02985243499279
# Episode 401: score: 13.0 - reward: 11.876848301291467
# Episode 402: score: 13.0 - reward: 12.027231585234405
# Episode 403: score: 12.0 - reward: 10.98640014231205
# Episode 404: score: 15.0 - reward: 13.630279801785948
# Episode 405: score: 16.0 - reward: 14.518011137843132
# Episode 406: score: 13.0 - reward: 11.880972246825696
# Episode 407: score: 10.0 - reward: 9.124516993761063
# Episode 408: score: 20.0 - reward: 18.344561821967364
# Episode 409: score: 16.0 - reward: 14.48456439524889
# Episode 410: score: 14.0 - reward: 12.803903920948507
# Test Episode 410: test score: 11.0 - test reward: 10.207280302047732
# Episode 411: score: 16.0 - reward: 14.821738888323308
# Episode 412: score: 16.0 - reward: 14.665280777961014
# Episode 413: score: 10.0 - reward: 9.137770348787308
# Episode 414: score: 10.0 - reward: 9.366800040006636
# Episode 415: score: 11.0 - reward: 10.214048174768687
# Episode 416: score: 13.0 - reward: 12.210284674167633
# Episode 417: score: 12.0 - reward: 11.167883390933275
# Episode 418: score: 19.0 - reward: 17.513219842314722
# Episode 419: score: 95.0 - reward: 61.82899533212187
# Episode 420: score: 15.0 - reward: 13.727894766628742
# Test Episode 420: test score: 11.0 - test reward: 10.25889305472374
# Episode 421: score: 95.0 - reward: 60.98849308937789
# Episode 422: score: 11.0 - reward: 10.38627948462963
# Episode 423: score: 10.0 - reward: 9.206182366609573
# Episode 424: score: 94.0 - reward: 59.76281183809042
# Episode 425: score: 11.0 - reward: 10.058420318365096
# Episode 426: score: 91.0 - reward: 56.63805967271327
# Episode 427: score: 13.0 - reward: 11.994039732217788
# Episode 428: score: 13.0 - reward: 11.971646997332572
# Episode 429: score: 14.0 - reward: 12.958830623328687
# Episode 430: score: 93.0 - reward: 58.51724108755586
# Test Episode 430: test score: 11.0 - test reward: 10.275059622526168
# Episode 431: score: 14.0 - reward: 12.926616427302362
# Episode 432: score: 14.0 - reward: 13.028369163163008
# Episode 433: score: 18.0 - reward: 16.53560202186927
# Episode 434: score: 19.0 - reward: 17.49440625756979
# Episode 435: score: 18.0 - reward: 16.48248851615936
# Episode 436: score: 13.0 - reward: 12.014133980870247
# Episode 437: score: 11.0 - reward: 10.32928046192974
# Episode 438: score: 11.0 - reward: 10.152057340741159
# Episode 439: score: 11.0 - reward: 10.374203346669674
# Episode 440: score: 14.0 - reward: 13.112380331754684
# Test Episode 440: test score: 12.0 - test reward: 11.248107860982417
# Episode 441: score: 11.0 - reward: 10.351694903522732
# Episode 442: score: 14.0 - reward: 12.770922304689885
# Episode 443: score: 9.0 - reward: 8.276165416836738
# Episode 444: score: 14.0 - reward: 12.877137421071529
# Episode 445: score: 12.0 - reward: 10.966304066777228
# Episode 446: score: 14.0 - reward: 13.116806533932685
# Episode 447: score: 19.0 - reward: 17.180070096254347
# Episode 448: score: 19.0 - reward: 17.54593230932951
# Episode 449: score: 11.0 - reward: 10.35928971618414
# Episode 450: score: 15.0 - reward: 13.531860914826394
# Test Episode 450: test score: 12.0 - test reward: 11.237693926692009
# Episode 451: score: 10.0 - reward: 9.111195251345634
# Episode 452: score: 12.0 - reward: 11.190440179035068
# Episode 453: score: 14.0 - reward: 12.877342754602433
# Episode 454: score: 16.0 - reward: 14.821887178719047
# Episode 455: score: 13.0 - reward: 11.938259182870388
# Episode 456: score: 18.0 - reward: 16.507895629666745
# Episode 457: score: 95.0 - reward: 60.44214655980468
# Episode 458: score: 12.0 - reward: 11.243398924544454
# Episode 459: score: 92.0 - reward: 57.96637169569731
# Episode 460: score: 16.0 - reward: 14.537197768688202
# Test Episode 460: test score: 11.0 - test reward: 10.00759201645851
# Episode 461: score: 96.0 - reward: 61.380965185165444
# Episode 462: score: 94.0 - reward: 59.068441337347025
# Episode 463: score: 98.0 - reward: 62.56215762570502
# Episode 464: score: 95.0 - reward: 60.132249876856804
# Episode 465: score: 96.0 - reward: 61.66855540573598
# Episode 466: score: 18.0 - reward: 16.211554224789143
# Episode 467: score: 14.0 - reward: 12.98236052915454
# Episode 468: score: 94.0 - reward: 59.26523201614619
# Episode 469: score: 13.0 - reward: 12.11789170317352
# Episode 470: score: 12.0 - reward: 11.202626299858093
# Test Episode 470: test score: 11.0 - test reward: 10.186303976923227
# Episode 471: score: 95.0 - reward: 60.23718464225532
# Episode 472: score: 97.0 - reward: 61.712948775663996
# Episode 473: score: 13.0 - reward: 12.075922678038477
# Episode 474: score: 13.0 - reward: 12.179118452966215
# Episode 475: score: 13.0 - reward: 12.170985970646141
# Episode 476: score: 12.0 - reward: 11.059898880869149
# Episode 477: score: 94.0 - reward: 59.73571822345257
# Episode 478: score: 15.0 - reward: 13.504503348469735
# Episode 479: score: 14.0 - reward: 12.83801963031292
# Episode 480: score: 16.0 - reward: 14.379430195689201
# Test Episode 480: test score: 93.0 - test reward: 58.32166474461557
# New best test reward. Saving model
# Episode 481: score: 96.0 - reward: 61.9391658961773
# Episode 482: score: 15.0 - reward: 13.780635464191434
# Episode 483: score: 15.0 - reward: 13.788240537419913
# Episode 484: score: 17.0 - reward: 15.725093410909176
# Episode 485: score: 14.0 - reward: 12.705143703520298
# Episode 486: score: 11.0 - reward: 10.062283539772034
# Episode 487: score: 12.0 - reward: 11.184230591263622
# Episode 488: score: 13.0 - reward: 11.890634648501871
# Episode 489: score: 14.0 - reward: 12.907602967321871
# Episode 490: score: 94.0 - reward: 59.41977711319924
# Test Episode 490: test score: 95.0 - test reward: 59.35995137393476
# New best test reward. Saving model
# Episode 491: score: 16.0 - reward: 14.404138493537902
# Episode 492: score: 19.0 - reward: 17.05745768547058
# Episode 493: score: 18.0 - reward: 16.3691008746624
# Episode 494: score: 11.0 - reward: 10.02787650823593
# Episode 495: score: 96.0 - reward: 60.9510674316436
# Episode 496: score: 16.0 - reward: 14.453282676637173
# Episode 497: score: 13.0 - reward: 11.845455685257912
# Episode 498: score: 12.0 - reward: 11.172285637259483
# Episode 499: score: 93.0 - reward: 59.078157150745405
# Episode 500: score: 95.0 - reward: 60.323410966992384
# Test Episode 500: test score: 94.0 - test reward: 60.049364211037755
# New best test reward. Saving model
# best test reward: 60.049364211037755
# Rewards data saved to DDQN_Fourier_CP.pkl

# %%
import matplotlib.pyplot as plt

def plot_rewards(rewards_data, algorithm_name="Q learning"):
    """Plot the average performance and IQR of the policy."""
    plt.figure(figsize=(14, 7))

    for epsilon, alphas in rewards_data.items():
        for alpha, data in alphas.items():
            # Calculate average and IQR across runs for each episode
            data = np.array(data)  # Convert to numpy array for easier slicing
            avg_rewards = np.mean(data, axis=0)
            lower_quartile = np.percentile(data, 25, axis=0)
            upper_quartile = np.percentile(data, 75, axis=0)

            episodes = np.arange(len(avg_rewards)) + 1
            plt.plot(episodes, avg_rewards, label=f'ε={epsilon}, α={alpha}')
            plt.fill_between(episodes, lower_quartile, upper_quartile, alpha=0.25)

    plt.title(f'Average Performance and IQR by Epsilon and Alpha ({algorithm_name})')
    plt.xlabel('Episodes')
    plt.ylabel('Average Reward')
    plt.legend()
    plt.show()

# %%
plot_rewards(rewards_data, algorithm_name="DDQN (Fourier CartPole)")
